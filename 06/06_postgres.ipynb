# %% [markdown]
# # Работа в SQL Alchemy с PostgreSQL
#
# <a target="_blank" href="https://colab.research.google.com/github/sozykin/middle_python/blob/main/06/06_postgres.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
from sqlalchemy.orm import DeclarativeBase
from sqlalchemy.orm import mapped_column
from sqlalchemy.orm import Mapped
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import URL
from sqlalchemy import select
from typing import Optional
from typing import List

# %% [markdown]
# ## Установка соединения с PostgreSQL
#
# Для работы с PostgreSQL необходимо предварительно установить библиотеку psycopg2

# %%
url = "postgresql+psycopg2://postgres:1234qwer@localhost:5432/postgres"

# %% [markdown]
# Создание ссылки для подключения к базе данных

# %%
url_object = URL.create(
    "postgresql+psycopg2",
    username="postgres",
    password="1234qwer",  
    host="localhost",
    database="postgres",
)

# %%
url_object
# Out:
# postgresql+psycopg2://postgres:***@localhost/postgres

# %%
engine = create_engine(url_object, echo=True)

# %% [markdown]
# ## Создание класса с ORM

# %%
# Базовый класс для создание классов, которые будут сохраняться в базе данных
class Base(DeclarativeBase):
    pass

# %%
# Создаем класс и описываем отображение атрибутов в столбцы таблицы базы данных
class Name(Base):
    # Название таблицы в базе данных
    __tablename__ = 'names'

    # Атрибуты  
    id: Mapped[int] 
    name: Mapped[str]
    number_of_persons: Mapped[str] 
    global_id: Mapped[int] = mapped_column(primary_key=True)
    year: Mapped[int]
    month: Mapped[str]

    # Текстовое представление объекта
    def __repr__(self):
        return(f"{self.id}, {self.name}, {self.number_of_persons}, {self.global_id}, {self.year}, {self.month}")

# %%
# Создаем таблицу
Base.metadata.create_all(engine)
# Out:
# 2023-06-19 07:45:53,214 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2023-06-19 07:45:53,215 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-06-19 07:45:53,216 INFO sqlalchemy.engine.Engine select current_schema()
# 2023-06-19 07:45:53,216 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-06-19 07:45:53,217 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2023-06-19 07:45:53,217 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-06-19 07:45:53,218 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-19 07:45:53,221 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-19 07:45:53,221 INFO sqlalchemy.engine.Engine [generated in 0.00067s] {'table_name': 'names', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-19 07:45:53,223 INFO sqlalchemy.engine.Engine
# CREATE TABLE names (
# 	id INTEGER NOT NULL,
# 	name VARCHAR NOT NULL,
# 	number_of_persons VARCHAR NOT NULL,
# 	global_id SERIAL NOT NULL,
# 	year INTEGER NOT NULL,
# 	month VARCHAR NOT NULL,
# 	PRIMARY KEY (global_id)
# )
#
#
# 2023-06-19 07:45:53,224 INFO sqlalchemy.engine.Engine [no key 0.00068s] {}
# 2023-06-19 07:45:53,231 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ## Добавляем объект в таблицу

# %%
new_name = Name(id=3,
                 name='Анна', 
                 number_of_persons=190, 
                 global_id=37750256,
                 year=2015, 
                 month='январь')

# %%
with Session(engine) as session:
    session.add(new_name)
    session.commit()
# Out:
# 2023-06-19 07:46:02,948 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-19 07:46:02,950 INFO sqlalchemy.engine.Engine INSERT INTO names (id, name, number_of_persons, global_id, year, month) VALUES (%(id)s, %(name)s, %(number_of_persons)s, %(global_id)s, %(year)s, %(month)s)
# 2023-06-19 07:46:02,951 INFO sqlalchemy.engine.Engine [generated in 0.00090s] {'id': 3, 'name': 'Анна', 'number_of_persons': 190, 'global_id': 37750256, 'year': 2015, 'month': 'январь'}
# 2023-06-19 07:46:02,953 INFO sqlalchemy.engine.Engine COMMIT

# %%
new_name.metadata.tables
# Out:
# FacadeDict({'names': Table('names', MetaData(), Column('id', Integer(), table=<names>, nullable=False), Column('name', String(), table=<names>, nullable=False), Column('number_of_persons', String(), table=<names>, nullable=False), Column('global_id', Integer(), table=<names>, primary_key=True, nullable=False), Column('year', Integer(), table=<names>, nullable=False), Column('month', String(), table=<names>, nullable=False), schema=None)})

# %% [markdown]
# ## Получение информации о таблице из базы данных

# %%
class Base(DeclarativeBase):
    pass

# %%
# Загружаем информацию обо всех таблицах
Base.metadata.reflect(bind=engine)
# Out:
# 2023-06-19 07:47:47,260 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-19 07:47:47,260 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s]) AND pg_catalog.pg_class.relpersistence != %(relpersistence_1)s AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-19 07:47:47,261 INFO sqlalchemy.engine.Engine [cached since 72.07s ago] {'param_1': 'r', 'param_2': 'p', 'relpersistence_1': 't', 'nspname_1': 'pg_catalog'}
# 2023-06-19 07:47:47,262 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_attribute.attname AS name, pg_catalog.format_type(pg_catalog.pg_attribute.atttypid, pg_catalog.pg_attribute.atttypmod) AS format_type, (SELECT pg_catalog.pg_get_expr(pg_catalog.pg_attrdef.adbin, pg_catalog.pg_attrdef.adrelid) AS pg_get_expr_1
# FROM pg_catalog.pg_attrdef
# WHERE pg_catalog.pg_attrdef.adrelid = pg_catalog.pg_attribute.attrelid AND pg_catalog.pg_attrdef.adnum = pg_catalog.pg_attribute.attnum AND pg_catalog.pg_attribute.atthasdef) AS "default", pg_catalog.pg_attribute.attnotnull AS not_null, pg_catalog.pg_class.relname AS table_name, pg_catalog.pg_description.description AS comment, pg_catalog.pg_attribute.attgenerated AS generated, (SELECT json_build_object(%(json_build_object_2)s, pg_catalog.pg_attribute.attidentity = %(attidentity_1)s, %(json_build_object_3)s, pg_catalog.pg_sequence.seqstart, %(json_build_object_4)s, pg_catalog.pg_sequence.seqincrement, %(json_build_object_5)s, pg_catalog.pg_sequence.seqmin, %(json_build_object_6)s, pg_catalog.pg_sequence.seqmax, %(json_build_object_7)s, pg_catalog.pg_sequence.seqcache, %(json_build_object_8)s, pg_catalog.pg_sequence.seqcycle) AS json_build_object_1
# FROM pg_catalog.pg_sequence
# WHERE pg_catalog.pg_attribute.attidentity != %(attidentity_2)s AND pg_catalog.pg_sequence.seqrelid = CAST(CAST(pg_catalog.pg_get_serial_sequence(CAST(CAST(pg_catalog.pg_attribute.attrelid AS REGCLASS) AS TEXT), pg_catalog.pg_attribute.attname) AS REGCLASS) AS OID)) AS identity_options
# FROM pg_catalog.pg_class LEFT OUTER JOIN pg_catalog.pg_attribute ON pg_catalog.pg_class.oid = pg_catalog.pg_attribute.attrelid AND pg_catalog.pg_attribute.attnum > %(attnum_1)s AND NOT pg_catalog.pg_attribute.attisdropped LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_description.objoid = pg_catalog.pg_attribute.attrelid AND pg_catalog.pg_description.objsubid = pg_catalog.pg_attribute.attnum JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s AND pg_catalog.pg_class.relname IN (%(filter_names_1)s, %(filter_names_2)s, %(filter_names_3)s, %(filter_names_4)s, %(filter_names_5)s, %(filter_names_6)s, %(filter_names_7)s, %(filter_names_8)s, %(filter_names_9)s, %(filter_names_10)s, %(filter_names_11)s, %(filter_names_12)s, %(filter_names_13)s, %(filter_names_14)s) ORDER BY pg_catalog.pg_class.relname, pg_catalog.pg_attribute.attnum
# 2023-06-19 07:47:47,263 INFO sqlalchemy.engine.Engine [cached since 72.07s ago] {'json_build_object_2': 'always', 'attidentity_1': 'a', 'json_build_object_3': 'start', 'json_build_object_4': 'increment', 'json_build_object_5': 'minvalue', 'json_build_object_6': 'maxvalue', 'json_build_object_7': 'cache', 'json_build_object_8': 'cycle', 'attidentity_2': '', 'attnum_1': 0, 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'nspname_1': 'pg_catalog', 'filter_names_1': 'salesperson', 'filter_names_2': 'company', 'filter_names_3': 'person', 'filter_names_4': 'employee', 'filter_names_5': 'blocks', 'filter_names_6': 'decrypted_ballots', 'filter_names_7': 'transactions', 'filter_names_8': 'superheroes', 'filter_names_9': 'customers', 'filter_names_10': 'names', 'filter_names_11': 'sales', 'filter_names_12': 'product_types', 'filter_names_13': 'products', 'filter_names_14': 'orders'}
# 2023-06-19 07:47:47,266 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_type.typname AS name, pg_catalog.format_type(pg_catalog.pg_type.typbasetype, pg_catalog.pg_type.typtypmod) AS attype, NOT pg_catalog.pg_type.typnotnull AS nullable, pg_catalog.pg_type.typdefault AS "default", pg_catalog.pg_type_is_visible(pg_catalog.pg_type.oid) AS visible, pg_catalog.pg_namespace.nspname AS schema, domain_constraints.condefs, domain_constraints.connames
# FROM pg_catalog.pg_type JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_type.typnamespace LEFT OUTER JOIN (SELECT pg_catalog.pg_constraint.contypid AS contypid, array_agg(pg_catalog.pg_get_constraintdef(pg_catalog.pg_constraint.oid, %(pg_get_constraintdef_1)s)) AS condefs, array_agg(pg_catalog.pg_constraint.conname) AS connames
# FROM pg_catalog.pg_constraint
# WHERE pg_catalog.pg_constraint.contypid != %(contypid_1)s GROUP BY pg_catalog.pg_constraint.contypid) AS domain_constraints ON pg_catalog.pg_type.oid = domain_constraints.contypid
# WHERE pg_catalog.pg_type.typtype = %(typtype_1)s ORDER BY pg_catalog.pg_namespace.nspname, pg_catalog.pg_type.typname
# 2023-06-19 07:47:47,266 INFO sqlalchemy.engine.Engine [cached since 72.06s ago] {'pg_get_constraintdef_1': True, 'contypid_1': 0, 'typtype_1': 'd'}
# 2023-06-19 07:47:47,268 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_type.typname AS name, pg_catalog.pg_type_is_visible(pg_catalog.pg_type.oid) AS visible, pg_catalog.pg_namespace.nspname AS schema, lbl_agg.labels AS labels
# FROM pg_catalog.pg_type JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_type.typnamespace LEFT OUTER JOIN (SELECT pg_catalog.pg_enum.enumtypid AS enumtypid, array_agg(pg_catalog.pg_enum.enumlabel ORDER BY pg_catalog.pg_enum.enumsortorder) AS labels
# FROM pg_catalog.pg_enum GROUP BY pg_catalog.pg_enum.enumtypid) AS lbl_agg ON pg_catalog.pg_type.oid = lbl_agg.enumtypid
# WHERE pg_catalog.pg_type.typtype = %(typtype_1)s ORDER BY pg_catalog.pg_namespace.nspname, pg_catalog.pg_type.typname
# 2023-06-19 07:47:47,268 INFO sqlalchemy.engine.Engine [cached since 72.06s ago] {'typtype_1': 'e'}
# 2023-06-19 07:47:47,269 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.oid, pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s AND pg_catalog.pg_class.relname IN (%(filter_names_1)s, %(filter_names_2)s, %(filter_names_3)s, %(filter_names_4)s, %(filter_names_5)s, %(filter_names_6)s, %(filter_names_7)s, %(filter_names_8)s, %(filter_names_9)s, %(filter_names_10)s, %(filter_names_11)s, %(filter_names_12)s, %(filter_names_13)s, %(filter_names_14)s)
# 2023-06-19 07:47:47,270 INFO sqlalchemy.engine.Engine [cached since 72.05s ago] {'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'nspname_1': 'pg_catalog', 'filter_names_1': 'salesperson', 'filter_names_2': 'company', 'filter_names_3': 'person', 'filter_names_4': 'employee', 'filter_names_5': 'blocks', 'filter_names_6': 'decrypted_ballots', 'filter_names_7': 'transactions', 'filter_names_8': 'superheroes', 'filter_names_9': 'customers', 'filter_names_10': 'names', 'filter_names_11': 'sales', 'filter_names_12': 'product_types', 'filter_names_13': 'products', 'filter_names_14': 'orders'}
# 2023-06-19 07:47:47,270 INFO sqlalchemy.engine.Engine SELECT attr.conrelid, array_agg(attr.attname ORDER BY attr.ord) AS cols, attr.conname, min(attr.description) AS description
# FROM (SELECT con.conrelid AS conrelid, con.conname AS conname, con.description AS description, con.ord AS ord, pg_catalog.pg_attribute.attname AS attname
# FROM pg_catalog.pg_attribute JOIN (SELECT pg_catalog.pg_constraint.conrelid AS conrelid, pg_catalog.pg_constraint.conname AS conname, unnest(pg_catalog.pg_constraint.conkey) AS attnum, generate_subscripts(pg_catalog.pg_constraint.conkey, %(generate_subscripts_1)s) AS ord, pg_catalog.pg_description.description AS description
# FROM pg_catalog.pg_constraint LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_description.objoid = pg_catalog.pg_constraint.oid
# WHERE pg_catalog.pg_constraint.contype = %(contype)s AND pg_catalog.pg_constraint.conrelid IN (%(oids_1)s, %(oids_2)s, %(oids_3)s, %(oids_4)s, %(oids_5)s, %(oids_6)s, %(oids_7)s, %(oids_8)s, %(oids_9)s, %(oids_10)s, %(oids_11)s, %(oids_12)s, %(oids_13)s, %(oids_14)s)) AS con ON pg_catalog.pg_attribute.attnum = con.attnum AND pg_catalog.pg_attribute.attrelid = con.conrelid) AS attr GROUP BY attr.conrelid, attr.conname ORDER BY attr.conrelid, attr.conname
# 2023-06-19 07:47:47,271 INFO sqlalchemy.engine.Engine [cached since 72.05s ago] {'generate_subscripts_1': 1, 'contype': 'p', 'oids_1': 20266, 'oids_2': 20269, 'oids_3': 16823, 'oids_4': 16828, 'oids_5': 16836, 'oids_6': 16842, 'oids_7': 16847, 'oids_8': 20415, 'oids_9': 20427, 'oids_10': 20698, 'oids_11': 20433, 'oids_12': 20421, 'oids_13': 20444, 'oids_14': 20454}
# 2023-06-19 07:47:47,272 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname, pg_catalog.pg_constraint.conname, CASE WHEN (pg_catalog.pg_constraint.oid IS NOT NULL) THEN pg_catalog.pg_get_constraintdef(pg_catalog.pg_constraint.oid, %(pg_get_constraintdef_1)s) END AS anon_1, nsp_ref.nspname, pg_catalog.pg_description.description
# FROM pg_catalog.pg_class LEFT OUTER JOIN pg_catalog.pg_constraint ON pg_catalog.pg_class.oid = pg_catalog.pg_constraint.conrelid AND pg_catalog.pg_constraint.contype = %(contype_1)s LEFT OUTER JOIN pg_catalog.pg_class AS cls_ref ON cls_ref.oid = pg_catalog.pg_constraint.confrelid LEFT OUTER JOIN pg_catalog.pg_namespace AS nsp_ref ON cls_ref.relnamespace = nsp_ref.oid LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_description.objoid = pg_catalog.pg_constraint.oid JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s AND pg_catalog.pg_class.relname IN (%(filter_names_1)s, %(filter_names_2)s, %(filter_names_3)s, %(filter_names_4)s, %(filter_names_5)s, %(filter_names_6)s, %(filter_names_7)s, %(filter_names_8)s, %(filter_names_9)s, %(filter_names_10)s, %(filter_names_11)s, %(filter_names_12)s, %(filter_names_13)s, %(filter_names_14)s) ORDER BY pg_catalog.pg_class.relname, pg_catalog.pg_constraint.conname
# 2023-06-19 07:47:47,273 INFO sqlalchemy.engine.Engine [cached since 72.05s ago] {'pg_get_constraintdef_1': True, 'contype_1': 'f', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'nspname_1': 'pg_catalog', 'filter_names_1': 'salesperson', 'filter_names_2': 'company', 'filter_names_3': 'person', 'filter_names_4': 'employee', 'filter_names_5': 'blocks', 'filter_names_6': 'decrypted_ballots', 'filter_names_7': 'transactions', 'filter_names_8': 'superheroes', 'filter_names_9': 'customers', 'filter_names_10': 'names', 'filter_names_11': 'sales', 'filter_names_12': 'product_types', 'filter_names_13': 'products', 'filter_names_14': 'orders'}
# 2023-06-19 07:47:47,274 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_index.indrelid, cls_idx.relname AS relname_index, pg_catalog.pg_index.indisunique, pg_catalog.pg_constraint.conrelid IS NOT NULL AS has_constraint, pg_catalog.pg_index.indoption, cls_idx.reloptions, pg_catalog.pg_am.amname, CASE WHEN (pg_catalog.pg_index.indpred IS NOT NULL) THEN pg_catalog.pg_get_expr(pg_catalog.pg_index.indpred, pg_catalog.pg_index.indrelid) END AS filter_definition, pg_catalog.pg_index.indnkeyatts, idx_cols.elements, idx_cols.elements_is_expr
# FROM pg_catalog.pg_index JOIN pg_catalog.pg_class AS cls_idx ON pg_catalog.pg_index.indexrelid = cls_idx.oid JOIN pg_catalog.pg_am ON cls_idx.relam = pg_catalog.pg_am.oid LEFT OUTER JOIN (SELECT idx_attr.indexrelid AS indexrelid, min(idx_attr.indrelid) AS min_1, array_agg(idx_attr.element ORDER BY idx_attr.ord) AS elements, array_agg(idx_attr.is_expr ORDER BY idx_attr.ord) AS elements_is_expr
# FROM (SELECT idx.indexrelid AS indexrelid, idx.indrelid AS indrelid, idx.ord AS ord, CASE WHEN (idx.attnum = %(attnum_1)s) THEN pg_catalog.pg_get_indexdef(idx.indexrelid, idx.ord + %(ord_1)s, %(pg_get_indexdef_1)s) ELSE CAST(pg_catalog.pg_attribute.attname AS TEXT) END AS element, idx.attnum = %(attnum_2)s AS is_expr
# FROM (SELECT pg_catalog.pg_index.indexrelid AS indexrelid, pg_catalog.pg_index.indrelid AS indrelid, unnest(pg_catalog.pg_index.indkey) AS attnum, generate_subscripts(pg_catalog.pg_index.indkey, %(generate_subscripts_1)s) AS ord
# FROM pg_catalog.pg_index
# WHERE NOT pg_catalog.pg_index.indisprimary AND pg_catalog.pg_index.indrelid IN (%(oids_1)s, %(oids_2)s, %(oids_3)s, %(oids_4)s, %(oids_5)s, %(oids_6)s, %(oids_7)s, %(oids_8)s, %(oids_9)s, %(oids_10)s, %(oids_11)s, %(oids_12)s, %(oids_13)s, %(oids_14)s)) AS idx LEFT OUTER JOIN pg_catalog.pg_attribute ON pg_catalog.pg_attribute.attnum = idx.attnum AND pg_catalog.pg_attribute.attrelid = idx.indrelid
# WHERE idx.indrelid IN (%(oids_1)s, %(oids_2)s, %(oids_3)s, %(oids_4)s, %(oids_5)s, %(oids_6)s, %(oids_7)s, %(oids_8)s, %(oids_9)s, %(oids_10)s, %(oids_11)s, %(oids_12)s, %(oids_13)s, %(oids_14)s)) AS idx_attr GROUP BY idx_attr.indexrelid) AS idx_cols ON pg_catalog.pg_index.indexrelid = idx_cols.indexrelid LEFT OUTER JOIN pg_catalog.pg_constraint ON pg_catalog.pg_index.indrelid = pg_catalog.pg_constraint.conrelid AND pg_catalog.pg_index.indexrelid = pg_catalog.pg_constraint.conindid AND pg_catalog.pg_constraint.contype = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s])
# WHERE pg_catalog.pg_index.indrelid IN (%(oids_1)s, %(oids_2)s, %(oids_3)s, %(oids_4)s, %(oids_5)s, %(oids_6)s, %(oids_7)s, %(oids_8)s, %(oids_9)s, %(oids_10)s, %(oids_11)s, %(oids_12)s, %(oids_13)s, %(oids_14)s) AND NOT pg_catalog.pg_index.indisprimary ORDER BY pg_catalog.pg_index.indrelid, cls_idx.relname
# 2023-06-19 07:47:47,275 INFO sqlalchemy.engine.Engine [cached since 72.04s ago] {'attnum_1': 0, 'ord_1': 1, 'pg_get_indexdef_1': True, 'attnum_2': 0, 'generate_subscripts_1': 1, 'param_1': 'p', 'param_2': 'u', 'param_3': 'x', 'oids_1': 20266, 'oids_2': 20269, 'oids_3': 16823, 'oids_4': 16828, 'oids_5': 16836, 'oids_6': 16842, 'oids_7': 16847, 'oids_8': 20415, 'oids_9': 20427, 'oids_10': 20698, 'oids_11': 20433, 'oids_12': 20421, 'oids_13': 20444, 'oids_14': 20454}
# 2023-06-19 07:47:47,277 INFO sqlalchemy.engine.Engine SELECT attr.conrelid, array_agg(attr.attname ORDER BY attr.ord) AS cols, attr.conname, min(attr.description) AS description
# FROM (SELECT con.conrelid AS conrelid, con.conname AS conname, con.description AS description, con.ord AS ord, pg_catalog.pg_attribute.attname AS attname
# FROM pg_catalog.pg_attribute JOIN (SELECT pg_catalog.pg_constraint.conrelid AS conrelid, pg_catalog.pg_constraint.conname AS conname, unnest(pg_catalog.pg_constraint.conkey) AS attnum, generate_subscripts(pg_catalog.pg_constraint.conkey, %(generate_subscripts_1)s) AS ord, pg_catalog.pg_description.description AS description
# FROM pg_catalog.pg_constraint LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_description.objoid = pg_catalog.pg_constraint.oid
# WHERE pg_catalog.pg_constraint.contype = %(contype)s AND pg_catalog.pg_constraint.conrelid IN (%(oids_1)s, %(oids_2)s, %(oids_3)s, %(oids_4)s, %(oids_5)s, %(oids_6)s, %(oids_7)s, %(oids_8)s, %(oids_9)s, %(oids_10)s, %(oids_11)s, %(oids_12)s, %(oids_13)s, %(oids_14)s)) AS con ON pg_catalog.pg_attribute.attnum = con.attnum AND pg_catalog.pg_attribute.attrelid = con.conrelid) AS attr GROUP BY attr.conrelid, attr.conname ORDER BY attr.conrelid, attr.conname
# 2023-06-19 07:47:47,278 INFO sqlalchemy.engine.Engine [cached since 72.06s ago] {'generate_subscripts_1': 1, 'contype': 'u', 'oids_1': 20266, 'oids_2': 20269, 'oids_3': 16823, 'oids_4': 16828, 'oids_5': 16836, 'oids_6': 16842, 'oids_7': 16847, 'oids_8': 20415, 'oids_9': 20427, 'oids_10': 20698, 'oids_11': 20433, 'oids_12': 20421, 'oids_13': 20444, 'oids_14': 20454}
# 2023-06-19 07:47:47,279 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname, pg_catalog.pg_description.description
# FROM pg_catalog.pg_class LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_class.oid = pg_catalog.pg_description.objoid AND pg_catalog.pg_description.objsubid = %(objsubid_1)s JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s AND pg_catalog.pg_class.relname IN (%(filter_names_1)s, %(filter_names_2)s, %(filter_names_3)s, %(filter_names_4)s, %(filter_names_5)s, %(filter_names_6)s, %(filter_names_7)s, %(filter_names_8)s, %(filter_names_9)s, %(filter_names_10)s, %(filter_names_11)s, %(filter_names_12)s, %(filter_names_13)s, %(filter_names_14)s)
# 2023-06-19 07:47:47,280 INFO sqlalchemy.engine.Engine [cached since 72.04s ago] {'objsubid_1': 0, 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'nspname_1': 'pg_catalog', 'filter_names_1': 'salesperson', 'filter_names_2': 'company', 'filter_names_3': 'person', 'filter_names_4': 'employee', 'filter_names_5': 'blocks', 'filter_names_6': 'decrypted_ballots', 'filter_names_7': 'transactions', 'filter_names_8': 'superheroes', 'filter_names_9': 'customers', 'filter_names_10': 'names', 'filter_names_11': 'sales', 'filter_names_12': 'product_types', 'filter_names_13': 'products', 'filter_names_14': 'orders'}
# 2023-06-19 07:47:47,281 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname, pg_catalog.pg_constraint.conname, CASE WHEN (pg_catalog.pg_constraint.oid IS NOT NULL) THEN pg_catalog.pg_get_constraintdef(pg_catalog.pg_constraint.oid, %(pg_get_constraintdef_1)s) END AS anon_1, pg_catalog.pg_description.description
# FROM pg_catalog.pg_class LEFT OUTER JOIN pg_catalog.pg_constraint ON pg_catalog.pg_class.oid = pg_catalog.pg_constraint.conrelid AND pg_catalog.pg_constraint.contype = %(contype_1)s LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_description.objoid = pg_catalog.pg_constraint.oid JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s AND pg_catalog.pg_class.relname IN (%(filter_names_1)s, %(filter_names_2)s, %(filter_names_3)s, %(filter_names_4)s, %(filter_names_5)s, %(filter_names_6)s, %(filter_names_7)s, %(filter_names_8)s, %(filter_names_9)s, %(filter_names_10)s, %(filter_names_11)s, %(filter_names_12)s, %(filter_names_13)s, %(filter_names_14)s) ORDER BY pg_catalog.pg_class.relname, pg_catalog.pg_constraint.conname
# 2023-06-19 07:47:47,281 INFO sqlalchemy.engine.Engine [cached since 72.04s ago] {'pg_get_constraintdef_1': True, 'contype_1': 'c', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'nspname_1': 'pg_catalog', 'filter_names_1': 'salesperson', 'filter_names_2': 'company', 'filter_names_3': 'person', 'filter_names_4': 'employee', 'filter_names_5': 'blocks', 'filter_names_6': 'decrypted_ballots', 'filter_names_7': 'transactions', 'filter_names_8': 'superheroes', 'filter_names_9': 'customers', 'filter_names_10': 'names', 'filter_names_11': 'sales', 'filter_names_12': 'product_types', 'filter_names_13': 'products', 'filter_names_14': 'orders'}
# 2023-06-19 07:47:47,282 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s]) AND pg_catalog.pg_class.relpersistence = %(relpersistence_1)s AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-19 07:47:47,282 INFO sqlalchemy.engine.Engine [cached since 72.04s ago] {'param_1': 'r', 'param_2': 'p', 'relpersistence_1': 't', 'nspname_1': 'pg_catalog'}
# 2023-06-19 07:47:47,287 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
# Просматриваем имена таблиц
for table in Base.metadata.tables:
    print(table)
# Out:
# salesperson
# company
# person
# employee
# blocks
# decrypted_ballots
# transactions
# superheroes
# customers
# names
# sales
# orders
# products
# product_types

# %%
Base.metadata.tables['products']
# Out:
# Table('products', MetaData(), Column('id', INTEGER(), table=<products>, primary_key=True, nullable=False, server_default=Identity(start=1, increment=1, minvalue=1, maxvalue=2147483647, cycle=False, cache=1)), Column('name', VARCHAR(length=100), table=<products>), Column('type_id', INTEGER(), ForeignKey('product_types.id'), table=<products>), Column('price', INTEGER(), table=<products>), schema=None)

# %% [markdown]
# ## Создаем класс на основе загруженной таблицы

# %%
class Product(Base):
    __table__ = Base.metadata.tables['products']

    def __repr__(self):
        return(f"{self.name}, {self.price}")

# %%
# Читаем данные из таблицы и загружаем в класс
with Session(engine) as session:
    results = session.execute(select(Product))
    for row in results:
        print(row)
# Out:
# 2023-06-19 07:47:59,349 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-19 07:47:59,351 INFO sqlalchemy.engine.Engine SELECT products.id, products.name, products.type_id, products.price
# FROM products
# 2023-06-19 07:47:59,352 INFO sqlalchemy.engine.Engine [generated in 0.00079s] {}
# (Основы искусственного интеллекта, 15000,)
# (Технологии обработки больших данных, 50000,)
# (Программирование глубоких нейронных сетей, 30000,)
# (Нейронные сети для анализа текстов, 50000,)
# (Нейронные сети для анализа изображений, 50000,)
# (Инженерия искусственного интеллекта, 60000,)
# (Как стать DataScientist'ом, 0,)
# (Планирование карьеры в DataScience, 2000,)
# (Области применения нейросетей: в какой развивать экспертность, 4000,)
# (Программирование глубоких нейронных сетей на Python, 1000,)
# (Математика для DataScience, 2000,)
# (Основы визуализации данных, 500,)
# (Анализ временных рядов, 30000,)
# 2023-06-19 07:47:59,354 INFO sqlalchemy.engine.Engine ROLLBACK

# %% [markdown]
# ## Описываем два связанных класса

# %%
from sqlalchemy.orm import relationship
from sqlalchemy import ForeignKey

# %%
class Base(DeclarativeBase):
    pass

# %%
# Пользователи
class User(Base):
    __tablename__ = "users"

    id: Mapped[int] = mapped_column(primary_key=True)
    name: Mapped[Optional[str]]
    login: Mapped[Optional[str]]
    # Связи с объектом/таблицей email
    emails: Mapped[List["Email"]] = relationship(back_populates="user")


    def __repr__(self) -> str:
        return f"Пользователь (id={self.id}, name={self.name!r}, login={self.login})"

# %%
# email адреса
class Email(Base):
     __tablename__ = "emails"

     id: Mapped[int] = mapped_column(primary_key=True)
     email_address: Mapped[str]
     user_id = mapped_column(ForeignKey("users.id"))
     # Связи с объектом/таблицей users
     user: Mapped[User] = relationship(back_populates="emails")

     def __repr__(self) -> str:
         return f"email (id={self.id}, email_address={self.email_address})"

# %%
Base.metadata.create_all(engine)
# Out:
# 2023-06-19 07:49:01,661 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-19 07:49:01,662 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-19 07:49:01,662 INFO sqlalchemy.engine.Engine [cached since 188.4s ago] {'table_name': 'users', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-19 07:49:01,663 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-19 07:49:01,664 INFO sqlalchemy.engine.Engine [cached since 188.4s ago] {'table_name': 'emails', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-19 07:49:01,665 INFO sqlalchemy.engine.Engine
# CREATE TABLE users (
# 	id SERIAL NOT NULL,
# 	name VARCHAR,
# 	login VARCHAR,
# 	PRIMARY KEY (id)
# )
#
#
# 2023-06-19 07:49:01,665 INFO sqlalchemy.engine.Engine [no key 0.00037s] {}
# 2023-06-19 07:49:01,672 INFO sqlalchemy.engine.Engine
# CREATE TABLE emails (
# 	id SERIAL NOT NULL,
# 	email_address VARCHAR NOT NULL,
# 	user_id INTEGER,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(user_id) REFERENCES users (id)
# )
#
#
# 2023-06-19 07:49:01,672 INFO sqlalchemy.engine.Engine [no key 0.00084s] {}
# 2023-06-19 07:49:01,679 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ## Создаем связанные объекты

# %%
user1 = User(id=1, name="Andrey Sozykin", login="sozykin")

# %%
user1
# Out:
# Пользователь (id=1, name='Andrey Sozykin', login=sozykin)

# %%
user1.emails
# Out:
# []

# %%
email1 = Email(id=1, email_address='sozykin@gmail.com')

# %%
user1.emails.append(email1)

# %%
user1.emails
# Out:
# [email (id=1, email_address=sozykin@gmail.com)]

# %%
email2 = Email(id=2, email_address='sozykin@mail.ru')

# %%
user1.emails.append(email2)

# %%
user1.emails
# Out:
# [email (id=1, email_address=sozykin@gmail.com),
#  email (id=2, email_address=sozykin@mail.ru)]

# %% [markdown]
# ## Записываем связанные объекты в базу данных

# %%
with Session(engine) as session:
    session.add(user1)
    session.commit()
# Out:
# 2023-06-19 07:49:33,788 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-19 07:49:33,789 INFO sqlalchemy.engine.Engine INSERT INTO users (id, name, login) VALUES (%(id)s, %(name)s, %(login)s)
# 2023-06-19 07:49:33,789 INFO sqlalchemy.engine.Engine [generated in 0.00063s] {'id': 1, 'name': 'Andrey Sozykin', 'login': 'sozykin'}
# 2023-06-19 07:49:33,792 INFO sqlalchemy.engine.Engine INSERT INTO emails (id, email_address, user_id) VALUES (%(id__0)s, %(email_address__0)s, %(user_id__0)s), (%(id__1)s, %(email_address__1)s, %(user_id__1)s)
# 2023-06-19 07:49:33,792 INFO sqlalchemy.engine.Engine [generated in 0.00005s (insertmanyvalues) 1/1 (unordered)] {'id__0': 1, 'user_id__0': 1, 'email_address__0': 'sozykin@gmail.com', 'id__1': 2, 'user_id__1': 1, 'email_address__1': 'sozykin@mail.ru'}
# 2023-06-19 07:49:33,794 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ## Пакетная вставка

# %%
import json
from sqlalchemy import insert
from sqlalchemy.types import BigInteger

# %%
with open("names_f.json", "r") as read_file:
    data = json.load(read_file)

# %%
data
# Out:
# [{'ID': 1,
#   'Name': 'Мария',
#   'NumberOfPersons': 252,
#   'global_id': 37750254,
#   'Year': 2015,
#   'Month': 'январь'},
#  {'ID': 2,
#   'Name': 'Анастасия',
#   'NumberOfPersons': 224,
#   'global_id': 37750255,
#   'Year': 2015,
#   'Month': 'январь'},
#  {'ID': 3,
#   'Name': 'Анна',
#   'NumberOfPersons': 190,
#   'global_id': 37750256,
#   'Year': 2015,
#   'Month': 'январь'},
#  {'ID': 4,
#   'Name': 'Варвара',
#   'NumberOfPersons': 190,
#   'global_id': 37750257,
#   'Year': 2015,
#   'Month': 'январь'},
#  {'ID': 5,
#   'Name': 'Виктория',
#   'NumberOfPersons': 186,
#   'global_id': 37750258,
#   'Year': 2015,
#   'Month': 'январь'},
#  {'ID': 483,
#   'Name': 'Амелия',
#   'NumberOfPersons': 8,
#   'global_id': 62367755,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 484,
#   'Name': 'Камила',
#   'NumberOfPersons': 8,
#   'global_id': 62367756,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 485,
#   'Name': 'Евангелина',
#   'NumberOfPersons': 8,
#   'global_id': 62367757,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 486,
#   'Name': 'Альбина',
#   'NumberOfPersons': 8,
#   'global_id': 62367758,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 487,
#   'Name': 'Владислава',
#   'NumberOfPersons': 8,
#   'global_id': 62367759,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 488,
#   'Name': 'Айлин',
#   'NumberOfPersons': 8,
#   'global_id': 62367760,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 489,
#   'Name': 'Евдокия',
#   'NumberOfPersons': 7,
#   'global_id': 62367761,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 490,
#   'Name': 'Марьям',
#   'NumberOfPersons': 7,
#   'global_id': 62367762,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 491,
#   'Name': 'Лейла',
#   'NumberOfPersons': 7,
#   'global_id': 62367763,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 492,
#   'Name': 'Мелисса',
#   'NumberOfPersons': 7,
#   'global_id': 62367764,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 493,
#   'Name': 'Амира',
#   'NumberOfPersons': 7,
#   'global_id': 62367765,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 494,
#   'Name': 'Оливия',
#   'NumberOfPersons': 7,
#   'global_id': 62367766,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 495,
#   'Name': 'Виталина',
#   'NumberOfPersons': 7,
#   'global_id': 62367767,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 496,
#   'Name': 'Станислава',
#   'NumberOfPersons': 6,
#   'global_id': 62367768,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 497,
#   'Name': 'Марьяна',
#   'NumberOfPersons': 6,
#   'global_id': 62367769,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 498,
#   'Name': 'Фатима',
#   'NumberOfPersons': 6,
#   'global_id': 62367770,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 499,
#   'Name': 'Влада',
#   'NumberOfPersons': 6,
#   'global_id': 62367771,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 500,
#   'Name': 'Дана',
#   'NumberOfPersons': 6,
#   'global_id': 62367772,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 501,
#   'Name': 'Мария',
#   'NumberOfPersons': 271,
#   'global_id': 62367773,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 502,
#   'Name': 'Анастасия',
#   'NumberOfPersons': 242,
#   'global_id': 62367774,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 503,
#   'Name': 'Виктория',
#   'NumberOfPersons': 226,
#   'global_id': 62367775,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 504,
#   'Name': 'София',
#   'NumberOfPersons': 217,
#   'global_id': 62367776,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 505,
#   'Name': 'Анна',
#   'NumberOfPersons': 216,
#   'global_id': 62367777,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 506,
#   'Name': 'Елизавета',
#   'NumberOfPersons': 214,
#   'global_id': 62367778,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 507,
#   'Name': 'Алиса',
#   'NumberOfPersons': 191,
#   'global_id': 62367779,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 508,
#   'Name': 'Дарья',
#   'NumberOfPersons': 189,
#   'global_id': 62367780,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 509,
#   'Name': 'Александра',
#   'NumberOfPersons': 182,
#   'global_id': 62367781,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 510,
#   'Name': 'Полина',
#   'NumberOfPersons': 161,
#   'global_id': 62367782,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 511,
#   'Name': 'Ксения',
#   'NumberOfPersons': 157,
#   'global_id': 62367783,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 512,
#   'Name': 'Варвара',
#   'NumberOfPersons': 155,
#   'global_id': 62367784,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 513,
#   'Name': 'Валерия',
#   'NumberOfPersons': 149,
#   'global_id': 62367785,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 514,
#   'Name': 'Екатерина',
#   'NumberOfPersons': 141,
#   'global_id': 62367786,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 515,
#   'Name': 'Арина',
#   'NumberOfPersons': 134,
#   'global_id': 62367787,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 516,
#   'Name': 'Вероника',
#   'NumberOfPersons': 118,
#   'global_id': 62367789,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 517,
#   'Name': 'Софья',
#   'NumberOfPersons': 110,
#   'global_id': 62367790,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 518,
#   'Name': 'Василиса',
#   'NumberOfPersons': 108,
#   'global_id': 62367791,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 519,
#   'Name': 'Милана',
#   'NumberOfPersons': 103,
#   'global_id': 62367792,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 520,
#   'Name': 'Ульяна',
#   'NumberOfPersons': 101,
#   'global_id': 62367794,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 521,
#   'Name': 'Ева',
#   'NumberOfPersons': 99,
#   'global_id': 62367795,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 522,
#   'Name': 'Кира',
#   'NumberOfPersons': 86,
#   'global_id': 62367796,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 523,
#   'Name': 'Вера',
#   'NumberOfPersons': 67,
#   'global_id': 62367797,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 524,
#   'Name': 'Маргарита',
#   'NumberOfPersons': 66,
#   'global_id': 62367798,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 525,
#   'Name': 'Таисия',
#   'NumberOfPersons': 65,
#   'global_id': 62367800,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 526,
#   'Name': 'Алёна',
#   'NumberOfPersons': 62,
#   'global_id': 62367801,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 527,
#   'Name': 'Кристина',
#   'NumberOfPersons': 62,
#   'global_id': 62367802,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 528,
#   'Name': 'Алина',
#   'NumberOfPersons': 59,
#   'global_id': 62367803,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 529,
#   'Name': 'Юлия',
#   'NumberOfPersons': 53,
#   'global_id': 62367804,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 530,
#   'Name': 'Елена',
#   'NumberOfPersons': 46,
#   'global_id': 62367805,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 531,
#   'Name': 'Диана',
#   'NumberOfPersons': 45,
#   'global_id': 62367806,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 532,
#   'Name': 'Амина',
#   'NumberOfPersons': 44,
#   'global_id': 62367807,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 533,
#   'Name': 'Ольга',
#   'NumberOfPersons': 43,
#   'global_id': 62367808,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 534,
#   'Name': 'Стефания',
#   'NumberOfPersons': 42,
#   'global_id': 62367809,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 535,
#   'Name': 'Евгения',
#   'NumberOfPersons': 36,
#   'global_id': 62367810,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 536,
#   'Name': 'Майя',
#   'NumberOfPersons': 34,
#   'global_id': 62367811,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 537,
#   'Name': 'Ангелина',
#   'NumberOfPersons': 32,
#   'global_id': 62367812,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 538,
#   'Name': 'Надежда',
#   'NumberOfPersons': 30,
#   'global_id': 62367813,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 539,
#   'Name': 'Яна',
#   'NumberOfPersons': 29,
#   'global_id': 62367814,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 540,
#   'Name': 'Марина',
#   'NumberOfPersons': 29,
#   'global_id': 62367815,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 541,
#   'Name': 'Есения',
#   'NumberOfPersons': 28,
#   'global_id': 62367816,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 542,
#   'Name': 'Татьяна',
#   'NumberOfPersons': 27,
#   'global_id': 62367817,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 543,
#   'Name': 'Эмилия',
#   'NumberOfPersons': 27,
#   'global_id': 62367818,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 544,
#   'Name': 'Мирослава',
#   'NumberOfPersons': 26,
#   'global_id': 62367819,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 545,
#   'Name': 'Элина',
#   'NumberOfPersons': 26,
#   'global_id': 62367820,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 546,
#   'Name': 'Злата',
#   'NumberOfPersons': 26,
#   'global_id': 62367821,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 547,
#   'Name': 'Агата',
#   'NumberOfPersons': 25,
#   'global_id': 62367822,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 548,
#   'Name': 'Ирина',
#   'NumberOfPersons': 23,
#   'global_id': 62367823,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 549,
#   'Name': 'Ярослава',
#   'NumberOfPersons': 23,
#   'global_id': 62367824,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 550,
#   'Name': 'Сафия',
#   'NumberOfPersons': 23,
#   'global_id': 62367825,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 551,
#   'Name': 'Аделина',
#   'NumberOfPersons': 22,
#   'global_id': 62367826,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 552,
#   'Name': 'Марьям',
#   'NumberOfPersons': 20,
#   'global_id': 62367827,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 553,
#   'Name': 'Евдокия',
#   'NumberOfPersons': 18,
#   'global_id': 62367828,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 554,
#   'Name': 'Антонина',
#   'NumberOfPersons': 18,
#   'global_id': 62367829,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 555,
#   'Name': 'Ясмина',
#   'NumberOfPersons': 17,
#   'global_id': 62367830,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 556,
#   'Name': 'Любовь',
#   'NumberOfPersons': 17,
#   'global_id': 62367831,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 557,
#   'Name': 'Нина',
#   'NumberOfPersons': 17,
#   'global_id': 62367832,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 558,
#   'Name': 'Олеся',
#   'NumberOfPersons': 16,
#   'global_id': 62367834,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 559,
#   'Name': 'Светлана',
#   'NumberOfPersons': 16,
#   'global_id': 62367835,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 560,
#   'Name': 'Ника',
#   'NumberOfPersons': 16,
#   'global_id': 62367836,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 561,
#   'Name': 'Николь',
#   'NumberOfPersons': 16,
#   'global_id': 62367837,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 562,
#   'Name': 'Карина',
#   'NumberOfPersons': 15,
#   'global_id': 62367838,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 563,
#   'Name': 'Алия',
#   'NumberOfPersons': 15,
#   'global_id': 62367839,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 564,
#   'Name': 'Лидия',
#   'NumberOfPersons': 14,
#   'global_id': 62367840,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 565,
#   'Name': 'Дарина',
#   'NumberOfPersons': 13,
#   'global_id': 62367841,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 566,
#   'Name': 'Милена',
#   'NumberOfPersons': 13,
#   'global_id': 62367842,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 567,
#   'Name': 'Лилия',
#   'NumberOfPersons': 13,
#   'global_id': 62367843,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 568,
#   'Name': 'Марьяна',
#   'NumberOfPersons': 12,
#   'global_id': 62367844,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 569,
#   'Name': 'Лейла',
#   'NumberOfPersons': 12,
#   'global_id': 62367845,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 570,
#   'Name': 'Мила',
#   'NumberOfPersons': 12,
#   'global_id': 62367846,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 571,
#   'Name': 'Камилла',
#   'NumberOfPersons': 11,
#   'global_id': 62367847,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 572,
#   'Name': 'Камила',
#   'NumberOfPersons': 11,
#   'global_id': 62367848,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 573,
#   'Name': 'Зоя',
#   'NumberOfPersons': 11,
#   'global_id': 62367849,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 574,
#   'Name': 'Амелия',
#   'NumberOfPersons': 11,
#   'global_id': 62367850,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 575,
#   'Name': 'Фатима',
#   'NumberOfPersons': 11,
#   'global_id': 62367851,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 576,
#   'Name': 'Амалия',
#   'NumberOfPersons': 11,
#   'global_id': 62367852,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 577,
#   'Name': 'Ариана',
#   'NumberOfPersons': 10,
#   'global_id': 62367853,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 578,
#   'Name': 'Марианна',
#   'NumberOfPersons': 10,
#   'global_id': 62367854,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 579,
#   'Name': 'Виолетта',
#   'NumberOfPersons': 10,
#   'global_id': 62367855,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 580,
#   'Name': 'Каролина',
#   'NumberOfPersons': 10,
#   'global_id': 62367857,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 581,
#   'Name': 'Альбина',
#   'NumberOfPersons': 9,
#   'global_id': 62367858,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 582,
#   'Name': 'Аиша',
#   'NumberOfPersons': 9,
#   'global_id': 62367859,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 583,
#   'Name': 'Марта',
#   'NumberOfPersons': 9,
#   'global_id': 62367860,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 584,
#   'Name': 'Амира',
#   'NumberOfPersons': 9,
#   'global_id': 62367861,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 585,
#   'Name': 'Аглая',
#   'NumberOfPersons': 9,
#   'global_id': 62367862,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 586,
#   'Name': 'Самира',
#   'NumberOfPersons': 9,
#   'global_id': 62367863,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 587,
#   'Name': 'Эмма',
#   'NumberOfPersons': 9,
#   'global_id': 62367864,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 588,
#   'Name': 'Малика',
#   'NumberOfPersons': 8,
#   'global_id': 62367865,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 589,
#   'Name': 'Раяна',
#   'NumberOfPersons': 8,
#   'global_id': 62367866,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 590,
#   'Name': 'Эвелина',
#   'NumberOfPersons': 8,
#   'global_id': 62367867,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 591,
#   'Name': 'Наталья',
#   'NumberOfPersons': 8,
#   'global_id': 62367868,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 592,
#   'Name': 'Анжелика',
#   'NumberOfPersons': 8,
#   'global_id': 62367869,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 593,
#   'Name': 'Айлин',
#   'NumberOfPersons': 8,
#   'global_id': 62367870,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 594,
#   'Name': 'Асия',
#   'NumberOfPersons': 8,
#   'global_id': 62367871,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 595,
#   'Name': 'Аяна',
#   'NumberOfPersons': 8,
#   'global_id': 62367872,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 596,
#   'Name': 'Агния',
#   'NumberOfPersons': 8,
#   'global_id': 62367873,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 597,
#   'Name': 'Милослава',
#   'NumberOfPersons': 8,
#   'global_id': 62367874,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 598,
#   'Name': 'Евангелина',
#   'NumberOfPersons': 8,
#   'global_id': 62367875,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 599,
#   'Name': 'Алисия',
#   'NumberOfPersons': 7,
#   'global_id': 62367876,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 600,
#   'Name': 'Сабина',
#   'NumberOfPersons': 7,
#   'global_id': 62367877,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 601,
#   'Name': 'Мария',
#   'NumberOfPersons': 331,
#   'global_id': 62367878,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 602,
#   'Name': 'Анна',
#   'NumberOfPersons': 287,
#   'global_id': 62367879,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 603,
#   'Name': 'Анастасия',
#   'NumberOfPersons': 270,
#   'global_id': 62367880,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 604,
#   'Name': 'София',
#   'NumberOfPersons': 230,
#   'global_id': 62367881,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 605,
#   'Name': 'Виктория',
#   'NumberOfPersons': 226,
#   'global_id': 62367882,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 606,
#   'Name': 'Елизавета',
#   'NumberOfPersons': 218,
#   'global_id': 62367883,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 607,
#   'Name': 'Александра',
#   'NumberOfPersons': 214,
#   'global_id': 62367884,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 608,
#   'Name': 'Полина',
#   'NumberOfPersons': 203,
#   'global_id': 62367885,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 609,
#   'Name': 'Алиса',
#   'NumberOfPersons': 200,
#   'global_id': 62367886,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 610,
#   'Name': 'Варвара',
#   'NumberOfPersons': 191,
#   'global_id': 62367887,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 611,
#   'Name': 'Дарья',
#   'NumberOfPersons': 179,
#   'global_id': 62367888,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 612,
#   'Name': 'Екатерина',
#   'NumberOfPersons': 172,
#   'global_id': 62367889,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 613,
#   'Name': 'Арина',
#   'NumberOfPersons': 149,
#   'global_id': 62367890,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 614,
#   'Name': 'Софья',
#   'NumberOfPersons': 138,
#   'global_id': 62367891,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 615,
#   'Name': 'Ксения',
#   'NumberOfPersons': 133,
#   'global_id': 62367892,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 616,
#   'Name': 'Вероника',
#   'NumberOfPersons': 128,
#   'global_id': 62367893,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 617,
#   'Name': 'Василиса',
#   'NumberOfPersons': 124,
#   'global_id': 62367894,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 618,
#   'Name': 'Валерия',
#   'NumberOfPersons': 122,
#   'global_id': 62367895,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 619,
#   'Name': 'Милана',
#   'NumberOfPersons': 121,
#   'global_id': 62367896,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 620,
#   'Name': 'Ульяна',
#   'NumberOfPersons': 121,
#   'global_id': 62367897,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 621,
#   'Name': 'Ева',
#   'NumberOfPersons': 107,
#   'global_id': 62367898,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 622,
#   'Name': 'Маргарита',
#   'NumberOfPersons': 82,
#   'global_id': 62367899,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 623,
#   'Name': 'Вера',
#   'NumberOfPersons': 81,
#   'global_id': 62367900,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 624,
#   'Name': 'Алёна',
#   'NumberOfPersons': 79,
#   'global_id': 62367901,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 625,
#   'Name': 'Ольга',
#   'NumberOfPersons': 75,
#   'global_id': 62367902,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 626,
#   'Name': 'Кира',
#   'NumberOfPersons': 74,
#   'global_id': 62367903,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 627,
#   'Name': 'Кристина',
#   'NumberOfPersons': 65,
#   'global_id': 62367904,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 628,
#   'Name': 'Юлия',
#   'NumberOfPersons': 61,
#   'global_id': 62367905,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 629,
#   'Name': 'Ангелина',
#   'NumberOfPersons': 58,
#   'global_id': 62367906,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 630,
#   'Name': 'Алина',
#   'NumberOfPersons': 58,
#   'global_id': 62367907,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 631,
#   'Name': 'Таисия',
#   'NumberOfPersons': 55,
#   'global_id': 62367908,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 632,
#   'Name': 'Диана',
#   'NumberOfPersons': 49,
#   'global_id': 62367909,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 633,
#   'Name': 'Амина',
#   'NumberOfPersons': 46,
#   'global_id': 62367911,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 634,
#   'Name': 'Яна',
#   'NumberOfPersons': 44,
#   'global_id': 62367912,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 635,
#   'Name': 'Евгения',
#   'NumberOfPersons': 42,
#   'global_id': 62367913,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 636,
#   'Name': 'Мирослава',
#   'NumberOfPersons': 40,
#   'global_id': 62367914,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 637,
#   'Name': 'Сафия',
#   'NumberOfPersons': 34,
#   'global_id': 62367915,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 638,
#   'Name': 'Ирина',
#   'NumberOfPersons': 29,
#   'global_id': 62367916,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 639,
#   'Name': 'Надежда',
#   'NumberOfPersons': 29,
#   'global_id': 62367917,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 640,
#   'Name': 'Елена',
#   'NumberOfPersons': 28,
#   'global_id': 62367918,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 641,
#   'Name': 'Стефания',
#   'NumberOfPersons': 28,
#   'global_id': 62367919,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 642,
#   'Name': 'Татьяна',
#   'NumberOfPersons': 26,
#   'global_id': 62367920,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 643,
#   'Name': 'Марина',
#   'NumberOfPersons': 26,
#   'global_id': 62367921,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 644,
#   'Name': 'Ника',
#   'NumberOfPersons': 26,
#   'global_id': 62367922,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 645,
#   'Name': 'Аделина',
#   'NumberOfPersons': 25,
#   'global_id': 62367924,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 646,
#   'Name': 'Майя',
#   'NumberOfPersons': 25,
#   'global_id': 62367925,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 647,
#   'Name': 'Элина',
#   'NumberOfPersons': 24,
#   'global_id': 62367926,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 648,
#   'Name': 'Эмилия',
#   'NumberOfPersons': 24,
#   'global_id': 62367927,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 649,
#   'Name': 'Олеся',
#   'NumberOfPersons': 22,
#   'global_id': 62367928,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 650,
#   'Name': 'Ясмина',
#   'NumberOfPersons': 22,
#   'global_id': 62367929,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 651,
#   'Name': 'Агата',
#   'NumberOfPersons': 22,
#   'global_id': 62367930,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 652,
#   'Name': 'Марьям',
#   'NumberOfPersons': 22,
#   'global_id': 62367931,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 653,
#   'Name': 'Аиша',
#   'NumberOfPersons': 21,
#   'global_id': 62367932,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 654,
#   'Name': 'Ярослава',
#   'NumberOfPersons': 20,
#   'global_id': 62367933,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 655,
#   'Name': 'Милена',
#   'NumberOfPersons': 20,
#   'global_id': 62367934,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 656,
#   'Name': 'Злата',
#   'NumberOfPersons': 19,
#   'global_id': 62367936,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 657,
#   'Name': 'Дарина',
#   'NumberOfPersons': 18,
#   'global_id': 62367937,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 658,
#   'Name': 'Любовь',
#   'NumberOfPersons': 18,
#   'global_id': 62367938,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 659,
#   'Name': 'Есения',
#   'NumberOfPersons': 18,
#   'global_id': 62367939,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 660,
#   'Name': 'Антонина',
#   'NumberOfPersons': 15,
#   'global_id': 62367940,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 661,
#   'Name': 'Камилла',
#   'NumberOfPersons': 15,
#   'global_id': 62367941,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 662,
#   'Name': 'Алия',
#   'NumberOfPersons': 14,
#   'global_id': 62367942,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 663,
#   'Name': 'Мила',
#   'NumberOfPersons': 14,
#   'global_id': 62367943,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 664,
#   'Name': 'Каролина',
#   'NumberOfPersons': 14,
#   'global_id': 62367944,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 665,
#   'Name': 'Агния',
#   'NumberOfPersons': 14,
#   'global_id': 62367945,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 666,
#   'Name': 'Эвелина',
#   'NumberOfPersons': 14,
#   'global_id': 62367946,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 667,
#   'Name': 'Светлана',
#   'NumberOfPersons': 14,
#   'global_id': 62367947,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 668,
#   'Name': 'Зоя',
#   'NumberOfPersons': 14,
#   'global_id': 62367948,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 669,
#   'Name': 'Камила',
#   'NumberOfPersons': 13,
#   'global_id': 62367949,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 670,
#   'Name': 'Евангелина',
#   'NumberOfPersons': 12,
#   'global_id': 62367950,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 671,
#   'Name': 'Владислава',
#   'NumberOfPersons': 12,
#   'global_id': 62367951,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 672,
#   'Name': 'Амелия',
#   'NumberOfPersons': 12,
#   'global_id': 62367952,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 673,
#   'Name': 'Лилия',
#   'NumberOfPersons': 12,
#   'global_id': 62367953,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 674,
#   'Name': 'Нина',
#   'NumberOfPersons': 12,
#   'global_id': 62367954,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 675,
#   'Name': 'Раяна',
#   'NumberOfPersons': 12,
#   'global_id': 62367955,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 676,
#   'Name': 'Марианна',
#   'NumberOfPersons': 11,
#   'global_id': 62367956,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 677,
#   'Name': 'Валентина',
#   'NumberOfPersons': 11,
#   'global_id': 62367957,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 678,
#   'Name': 'Карина',
#   'NumberOfPersons': 11,
#   'global_id': 62367958,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 679,
#   'Name': 'Лейла',
#   'NumberOfPersons': 11,
#   'global_id': 62367959,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 680,
#   'Name': 'Николь',
#   'NumberOfPersons': 11,
#   'global_id': 62367960,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 681,
#   'Name': 'Айлин',
#   'NumberOfPersons': 10,
#   'global_id': 62367961,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 682,
#   'Name': 'Юлиана',
#   'NumberOfPersons': 10,
#   'global_id': 62367962,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 683,
#   'Name': 'Малика',
#   'NumberOfPersons': 10,
#   'global_id': 62367964,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 684,
#   'Name': 'Ариана',
#   'NumberOfPersons': 9,
#   'global_id': 62367965,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 685,
#   'Name': 'Наталья',
#   'NumberOfPersons': 9,
#   'global_id': 62367966,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 686,
#   'Name': 'Анжелика',
#   'NumberOfPersons': 9,
#   'global_id': 62367967,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 687,
#   'Name': 'Мира',
#   'NumberOfPersons': 9,
#   'global_id': 62367968,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 688,
#   'Name': 'Марьяна',
#   'NumberOfPersons': 9,
#   'global_id': 62367969,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 689,
#   'Name': 'Самира',
#   'NumberOfPersons': 9,
#   'global_id': 62367970,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 690,
#   'Name': 'Виолетта',
#   'NumberOfPersons': 9,
#   'global_id': 62367971,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 691,
#   'Name': 'Мадина',
#   'NumberOfPersons': 9,
#   'global_id': 62367972,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 692,
#   'Name': 'Аглая',
#   'NumberOfPersons': 9,
#   'global_id': 62367973,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 693,
#   'Name': 'Лада',
#   'NumberOfPersons': 9,
#   'global_id': 62367974,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 694,
#   'Name': 'Лидия',
#   'NumberOfPersons': 9,
#   'global_id': 62367975,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 695,
#   'Name': 'Наталия',
#   'NumberOfPersons': 9,
#   'global_id': 62367976,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 696,
#   'Name': 'Евдокия',
#   'NumberOfPersons': 8,
#   'global_id': 62367977,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 697,
#   'Name': 'Марта',
#   'NumberOfPersons': 8,
#   'global_id': 62367978,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 698,
#   'Name': 'Алсу',
#   'NumberOfPersons': 8,
#   'global_id': 62367979,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 699,
#   'Name': 'Зарина',
#   'NumberOfPersons': 8,
#   'global_id': 62367980,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 700,
#   'Name': 'Амира',
#   'NumberOfPersons': 8,
#   'global_id': 62367981,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 701,
#   'Name': 'Мария',
#   'NumberOfPersons': 312,
#   'global_id': 62367982,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 702,
#   'Name': 'Анна',
#   'NumberOfPersons': 257,
#   'global_id': 62367983,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 703,
#   'Name': 'София',
#   'NumberOfPersons': 225,
#   'global_id': 62367984,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 704,
#   'Name': 'Анастасия',
#   'NumberOfPersons': 216,
#   'global_id': 62367985,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 705,
#   'Name': 'Елизавета',
#   'NumberOfPersons': 202,
#   'global_id': 62367986,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 706,
#   'Name': 'Виктория',
#   'NumberOfPersons': 201,
#   'global_id': 62367987,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 707,
#   'Name': 'Полина',
#   'NumberOfPersons': 192,
#   'global_id': 62367988,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 708,
#   'Name': 'Дарья',
#   'NumberOfPersons': 187,
#   'global_id': 62367989,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 709,
#   'Name': 'Алиса',
#   'NumberOfPersons': 180,
#   'global_id': 62367990,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 710,
#   'Name': 'Александра',
#   'NumberOfPersons': 159,
#   'global_id': 62367991,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 711,
#   'Name': 'Арина',
#   'NumberOfPersons': 149,
#   'global_id': 62367993,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 712,
#   'Name': 'Екатерина',
#   'NumberOfPersons': 148,
#   'global_id': 62367994,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 713,
#   'Name': 'Ксения',
#   'NumberOfPersons': 140,
#   'global_id': 62367995,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 714,
#   'Name': 'Вероника',
#   'NumberOfPersons': 133,
#   'global_id': 62367996,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 715,
#   'Name': 'Варвара',
#   'NumberOfPersons': 132,
#   'global_id': 62367997,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 716,
#   'Name': 'Милана',
#   'NumberOfPersons': 109,
#   'global_id': 62367998,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 717,
#   'Name': 'Василиса',
#   'NumberOfPersons': 100,
#   'global_id': 62367999,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 718,
#   'Name': 'Валерия',
#   'NumberOfPersons': 97,
#   'global_id': 62368000,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 719,
#   'Name': 'Ева',
#   'NumberOfPersons': 97,
#   'global_id': 62368001,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 720,
#   'Name': 'Софья',
#   'NumberOfPersons': 94,
#   'global_id': 62368002,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 721,
#   'Name': 'Ульяна',
#   'NumberOfPersons': 90,
#   'global_id': 62368003,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 722,
#   'Name': 'Маргарита',
#   'NumberOfPersons': 81,
#   'global_id': 62368004,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 723,
#   'Name': 'Кира',
#   'NumberOfPersons': 76,
#   'global_id': 62368005,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 724,
#   'Name': 'Кристина',
#   'NumberOfPersons': 68,
#   'global_id': 62368006,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 725,
#   'Name': 'Ольга',
#   'NumberOfPersons': 68,
#   'global_id': 62368007,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 726,
#   'Name': 'Таисия',
#   'NumberOfPersons': 64,
#   'global_id': 62368008,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 727,
#   'Name': 'Алёна',
#   'NumberOfPersons': 61,
#   'global_id': 62368009,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 728,
#   'Name': 'Диана',
#   'NumberOfPersons': 61,
#   'global_id': 62368010,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 729,
#   'Name': 'Юлия',
#   'NumberOfPersons': 60,
#   'global_id': 62368011,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 730,
#   'Name': 'Алина',
#   'NumberOfPersons': 56,
#   'global_id': 62368012,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 731,
#   'Name': 'Вера',
#   'NumberOfPersons': 55,
#   'global_id': 62368013,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 732,
#   'Name': 'Мирослава',
#   'NumberOfPersons': 51,
#   'global_id': 62368014,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 733,
#   'Name': 'Ангелина',
#   'NumberOfPersons': 50,
#   'global_id': 62368015,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 734,
#   'Name': 'Амина',
#   'NumberOfPersons': 49,
#   'global_id': 62368016,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 735,
#   'Name': 'Злата',
#   'NumberOfPersons': 32,
#   'global_id': 62368017,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 736,
#   'Name': 'Елена',
#   'NumberOfPersons': 31,
#   'global_id': 62368018,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 737,
#   'Name': 'Яна',
#   'NumberOfPersons': 31,
#   'global_id': 62368019,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 738,
#   'Name': 'Евгения',
#   'NumberOfPersons': 30,
#   'global_id': 62368020,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 739,
#   'Name': 'Татьяна',
#   'NumberOfPersons': 30,
#   'global_id': 62368021,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 740,
#   'Name': 'Ирина',
#   'NumberOfPersons': 27,
#   'global_id': 62368022,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 741,
#   'Name': 'Сафия',
#   'NumberOfPersons': 27,
#   'global_id': 62368023,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 742,
#   'Name': 'Аделина',
#   'NumberOfPersons': 25,
#   'global_id': 62368024,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 743,
#   'Name': 'Есения',
#   'NumberOfPersons': 25,
#   'global_id': 62368025,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 744,
#   'Name': 'Элина',
#   'NumberOfPersons': 23,
#   'global_id': 62368026,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 745,
#   'Name': 'Майя',
#   'NumberOfPersons': 22,
#   'global_id': 62368027,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 746,
#   'Name': 'Стефания',
#   'NumberOfPersons': 22,
#   'global_id': 62368028,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 747,
#   'Name': 'Марина',
#   'NumberOfPersons': 21,
#   'global_id': 62368029,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 748,
#   'Name': 'Камилла',
#   'NumberOfPersons': 19,
#   'global_id': 62368030,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 749,
#   'Name': 'Милена',
#   'NumberOfPersons': 19,
#   'global_id': 62368031,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 750,
#   'Name': 'Надежда',
#   'NumberOfPersons': 19,
#   'global_id': 62368032,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 751,
#   'Name': 'Нина',
#   'NumberOfPersons': 19,
#   'global_id': 62368033,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 752,
#   'Name': 'Эмилия',
#   'NumberOfPersons': 19,
#   'global_id': 62368034,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 753,
#   'Name': 'Агата',
#   'NumberOfPersons': 18,
#   'global_id': 62368036,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 754,
#   'Name': 'Светлана',
#   'NumberOfPersons': 18,
#   'global_id': 62368037,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 755,
#   'Name': 'Любовь',
#   'NumberOfPersons': 17,
#   'global_id': 62368038,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 756,
#   'Name': 'Ярослава',
#   'NumberOfPersons': 17,
#   'global_id': 62368039,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 757,
#   'Name': 'Агния',
#   'NumberOfPersons': 16,
#   'global_id': 62368040,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 758,
#   'Name': 'Ника',
#   'NumberOfPersons': 16,
#   'global_id': 62368041,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 759,
#   'Name': 'Лилия',
#   'NumberOfPersons': 15,
#   'global_id': 62368042,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 760,
#   'Name': 'Малика',
#   'NumberOfPersons': 15,
#   'global_id': 62368043,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 761,
#   'Name': 'Марьям',
#   'NumberOfPersons': 15,
#   'global_id': 62368044,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 762,
#   'Name': 'Николь',
#   'NumberOfPersons': 15,
#   'global_id': 62368045,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 763,
#   'Name': 'Амелия',
#   'NumberOfPersons': 14,
#   'global_id': 62368046,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 764,
#   'Name': 'Антонина',
#   'NumberOfPersons': 14,
#   'global_id': 62368047,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 765,
#   'Name': 'Алия',
#   'NumberOfPersons': 13,
#   'global_id': 62368048,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 766,
#   'Name': 'Евангелина',
#   'NumberOfPersons': 13,
#   'global_id': 62368049,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 767,
#   'Name': 'Олеся',
#   'NumberOfPersons': 13,
#   'global_id': 62368050,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 768,
#   'Name': 'Ясмина',
#   'NumberOfPersons': 13,
#   'global_id': 62368051,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 769,
#   'Name': 'Валентина',
#   'NumberOfPersons': 12,
#   'global_id': 62368052,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 770,
#   'Name': 'Виолетта',
#   'NumberOfPersons': 12,
#   'global_id': 62368053,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 771,
#   'Name': 'Мадина',
#   'NumberOfPersons': 12,
#   'global_id': 62368054,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 772,
#   'Name': 'Самира',
#   'NumberOfPersons': 12,
#   'global_id': 62368055,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 773,
#   'Name': 'Дарина',
#   'NumberOfPersons': 11,
#   'global_id': 62368056,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 774,
#   'Name': 'Зоя',
#   'NumberOfPersons': 11,
#   'global_id': 62368057,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 775,
#   'Name': 'Камила',
#   'NumberOfPersons': 11,
#   'global_id': 62368058,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 776,
#   'Name': 'Марианна',
#   'NumberOfPersons': 11,
#   'global_id': 62368060,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 777,
#   'Name': 'Мила',
#   'NumberOfPersons': 11,
#   'global_id': 62368061,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 778,
#   'Name': 'Ариана',
#   'NumberOfPersons': 10,
#   'global_id': 62368062,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 779,
#   'Name': 'Карина',
#   'NumberOfPersons': 10,
#   'global_id': 62368063,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 780,
#   'Name': 'Оливия',
#   'NumberOfPersons': 10,
#   'global_id': 62368064,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 781,
#   'Name': 'Дана',
#   'NumberOfPersons': 9,
#   'global_id': 62368065,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 782,
#   'Name': 'Марьяна',
#   'NumberOfPersons': 9,
#   'global_id': 62368066,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 783,
#   'Name': 'Наталия',
#   'NumberOfPersons': 9,
#   'global_id': 62368067,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 784,
#   'Name': 'Серафима',
#   'NumberOfPersons': 9,
#   'global_id': 62368068,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 785,
#   'Name': 'Альбина',
#   'NumberOfPersons': 8,
#   'global_id': 62368069,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 786,
#   'Name': 'Аиша',
#   'NumberOfPersons': 8,
#   'global_id': 62368070,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 787,
#   'Name': 'Евдокия',
#   'NumberOfPersons': 8,
#   'global_id': 62368071,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 788,
#   'Name': 'Лада',
#   'NumberOfPersons': 8,
#   'global_id': 62368072,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 789,
#   'Name': 'Мариам',
#   'NumberOfPersons': 8,
#   'global_id': 62368073,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 790,
#   'Name': 'Марта',
#   'NumberOfPersons': 8,
#   'global_id': 62368074,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 791,
#   'Name': 'Мира',
#   'NumberOfPersons': 8,
#   'global_id': 62368075,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 792,
#   'Name': 'Наталья',
#   'NumberOfPersons': 8,
#   'global_id': 62368076,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 793,
#   'Name': 'Пелагея',
#   'NumberOfPersons': 8,
#   'global_id': 62368077,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 794,
#   'Name': 'Раяна',
#   'NumberOfPersons': 8,
#   'global_id': 62368078,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 795,
#   'Name': 'Тамара',
#   'NumberOfPersons': 8,
#   'global_id': 62368079,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 796,
#   'Name': 'Аглая',
#   'NumberOfPersons': 7,
#   'global_id': 62368080,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 797,
#   'Name': 'Лидия',
#   'NumberOfPersons': 7,
#   'global_id': 62368081,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 798,
#   'Name': 'Лина',
#   'NumberOfPersons': 7,
#   'global_id': 62368082,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 799,
#   'Name': 'Медина',
#   'NumberOfPersons': 7,
#   'global_id': 62368083,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 800,
#   'Name': 'Мелания',
#   'NumberOfPersons': 7,
#   'global_id': 62368084,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 801,
#   'Name': 'Мария',
#   'NumberOfPersons': 305,
#   'global_id': 62368085,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 802,
#   'Name': 'София',
#   'NumberOfPersons': 252,
#   'global_id': 62368086,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 803,
#   'Name': 'Анна',
#   'NumberOfPersons': 244,
#   'global_id': 62368087,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 804,
#   'Name': 'Виктория',
#   'NumberOfPersons': 223,
#   'global_id': 62368088,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 805,
#   'Name': 'Алиса',
#   'NumberOfPersons': 189,
#   'global_id': 62368089,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 806,
#   'Name': 'Анастасия',
#   'NumberOfPersons': 188,
#   'global_id': 62368090,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 807,
#   'Name': 'Полина',
#   'NumberOfPersons': 184,
#   'global_id': 62368091,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 808,
#   'Name': 'Елизавета',
#   'NumberOfPersons': 180,
#   'global_id': 62368092,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 809,
#   'Name': 'Дарья',
#   'NumberOfPersons': 167,
#   'global_id': 62368093,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 810,
#   'Name': 'Ксения',
#   'NumberOfPersons': 153,
#   'global_id': 62368094,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 811,
#   'Name': 'Арина',
#   'NumberOfPersons': 146,
#   'global_id': 62368095,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 812,
#   'Name': 'Варвара',
#   'NumberOfPersons': 140,
#   'global_id': 62368096,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 813,
#   'Name': 'Александра',
#   'NumberOfPersons': 134,
#   'global_id': 62368097,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 814,
#   'Name': 'Екатерина',
#   'NumberOfPersons': 130,
#   'global_id': 62368098,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 815,
#   'Name': 'Василиса',
#   'NumberOfPersons': 126,
#   'global_id': 62368099,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 816,
#   'Name': 'Валерия',
#   'NumberOfPersons': 114,
#   'global_id': 62368100,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 817,
#   'Name': 'Софья',
#   'NumberOfPersons': 109,
#   'global_id': 62368101,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 818,
#   'Name': 'Вероника',
#   'NumberOfPersons': 107,
#   'global_id': 62368102,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 819,
#   'Name': 'Милана',
#   'NumberOfPersons': 103,
#   'global_id': 62368103,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 820,
#   'Name': 'Ева',
#   'NumberOfPersons': 101,
#   'global_id': 62368104,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 821,
#   'Name': 'Вера',
#   'NumberOfPersons': 85,
#   'global_id': 62368105,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 822,
#   'Name': 'Кристина',
#   'NumberOfPersons': 73,
#   'global_id': 62368106,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 823,
#   'Name': 'Ульяна',
#   'NumberOfPersons': 72,
#   'global_id': 62368108,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 824,
#   'Name': 'Кира',
#   'NumberOfPersons': 70,
#   'global_id': 62368109,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 825,
#   'Name': 'Диана',
#   'NumberOfPersons': 68,
#   'global_id': 62368110,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 826,
#   'Name': 'Алёна',
#   'NumberOfPersons': 62,
#   'global_id': 62368111,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 827,
#   'Name': 'Маргарита',
#   'NumberOfPersons': 62,
#   'global_id': 62368112,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 828,
#   'Name': 'Алина',
#   'NumberOfPersons': 59,
#   'global_id': 62368113,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 829,
#   'Name': 'Мирослава',
#   'NumberOfPersons': 46,
#   'global_id': 62368114,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 830,
#   'Name': 'Амина',
#   'NumberOfPersons': 42,
#   'global_id': 62368115,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 831,
#   'Name': 'Таисия',
#   'NumberOfPersons': 41,
#   'global_id': 62368117,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 832,
#   'Name': 'Юлия',
#   'NumberOfPersons': 40,
#   'global_id': 62368118,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 833,
#   'Name': 'Ангелина',
#   'NumberOfPersons': 39,
#   'global_id': 62368119,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 834,
#   'Name': 'Ольга',
#   'NumberOfPersons': 39,
#   'global_id': 62368120,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 835,
#   'Name': 'Ирина',
#   'NumberOfPersons': 34,
#   'global_id': 62368121,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 836,
#   'Name': 'Татьяна',
#   'NumberOfPersons': 33,
#   'global_id': 62368122,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 837,
#   'Name': 'Яна',
#   'NumberOfPersons': 33,
#   'global_id': 62368123,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 838,
#   'Name': 'Евгения',
#   'NumberOfPersons': 32,
#   'global_id': 62368125,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 839,
#   'Name': 'Стефания',
#   'NumberOfPersons': 29,
#   'global_id': 62368126,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 840,
#   'Name': 'Злата',
#   'NumberOfPersons': 27,
#   'global_id': 62368127,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 841,
#   'Name': 'Сафия',
#   'NumberOfPersons': 27,
#   'global_id': 62368128,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 842,
#   'Name': 'Марьям',
#   'NumberOfPersons': 25,
#   'global_id': 62368129,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 843,
#   'Name': 'Любовь',
#   'NumberOfPersons': 24,
#   'global_id': 62368130,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 844,
#   'Name': 'Милена',
#   'NumberOfPersons': 24,
#   'global_id': 62368131,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 845,
#   'Name': 'Елена',
#   'NumberOfPersons': 23,
#   'global_id': 62368133,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 846,
#   'Name': 'Эмилия',
#   'NumberOfPersons': 23,
#   'global_id': 62368134,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 847,
#   'Name': 'Лидия',
#   'NumberOfPersons': 22,
#   'global_id': 62368135,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 848,
#   'Name': 'Ярослава',
#   'NumberOfPersons': 22,
#   'global_id': 62368136,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 849,
#   'Name': 'Марина',
#   'NumberOfPersons': 20,
#   'global_id': 62368137,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 850,
#   'Name': 'Элина',
#   'NumberOfPersons': 18,
#   'global_id': 62368138,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 851,
#   'Name': 'Надежда',
#   'NumberOfPersons': 17,
#   'global_id': 62368139,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 852,
#   'Name': 'Амелия',
#   'NumberOfPersons': 15,
#   'global_id': 62368141,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 853,
#   'Name': 'Агата',
#   'NumberOfPersons': 15,
#   'global_id': 62368142,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 854,
#   'Name': 'Есения',
#   'NumberOfPersons': 15,
#   'global_id': 62368143,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 855,
#   'Name': 'Майя',
#   'NumberOfPersons': 15,
#   'global_id': 62368144,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 856,
#   'Name': 'Анфиса',
#   'NumberOfPersons': 14,
#   'global_id': 62368145,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 857,
#   'Name': 'Дарина',
#   'NumberOfPersons': 14,
#   'global_id': 62368146,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 858,
#   'Name': 'Олеся',
#   'NumberOfPersons': 14,
#   'global_id': 62368147,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 859,
#   'Name': 'Светлана',
#   'NumberOfPersons': 14,
#   'global_id': 62368148,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 860,
#   'Name': 'Фатима',
#   'NumberOfPersons': 14,
#   'global_id': 62368149,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 861,
#   'Name': 'Ясмина',
#   'NumberOfPersons': 14,
#   'global_id': 62368150,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 862,
#   'Name': 'Агния',
#   'NumberOfPersons': 13,
#   'global_id': 62368151,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 863,
#   'Name': 'Каролина',
#   'NumberOfPersons': 13,
#   'global_id': 62368152,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 864,
#   'Name': 'Наталья',
#   'NumberOfPersons': 13,
#   'global_id': 62368153,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 865,
#   'Name': 'Аделина',
#   'NumberOfPersons': 12,
#   'global_id': 62368154,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 866,
#   'Name': 'Лилия',
#   'NumberOfPersons': 12,
#   'global_id': 62368155,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 867,
#   'Name': 'Мила',
#   'NumberOfPersons': 12,
#   'global_id': 62368156,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 868,
#   'Name': 'Ника',
#   'NumberOfPersons': 12,
#   'global_id': 62368157,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 869,
#   'Name': 'Нина',
#   'NumberOfPersons': 12,
#   'global_id': 62368158,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 870,
#   'Name': 'Аиша',
#   'NumberOfPersons': 11,
#   'global_id': 62368159,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 871,
#   'Name': 'Амира',
#   'NumberOfPersons': 11,
#   'global_id': 62368160,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 872,
#   'Name': 'Ариана',
#   'NumberOfPersons': 11,
#   'global_id': 62368161,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 873,
#   'Name': 'Виолетта',
#   'NumberOfPersons': 11,
#   'global_id': 62368162,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 874,
#   'Name': 'Евдокия',
#   'NumberOfPersons': 11,
#   'global_id': 62368163,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 875,
#   'Name': 'Камила',
#   'NumberOfPersons': 11,
#   'global_id': 62368164,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 876,
#   'Name': 'Карина',
#   'NumberOfPersons': 11,
#   'global_id': 62368165,
#   'Year': 2015,
# ...
#   'Name': 'Милена',
#   'NumberOfPersons': 16,
#   'global_id': 62368660,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 251,
#   'Name': 'Евдокия',
#   'NumberOfPersons': 16,
#   'global_id': 62368661,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 252,
#   'Name': 'Дарина',
#   'NumberOfPersons': 16,
#   'global_id': 62368662,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 253,
#   'Name': 'Ясмина',
#   'NumberOfPersons': 16,
#   'global_id': 62368663,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 254,
#   'Name': 'Стефания',
#   'NumberOfPersons': 15,
#   'global_id': 62368664,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 255,
#   'Name': 'Марианна',
#   'NumberOfPersons': 15,
#   'global_id': 62368665,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 256,
#   'Name': 'Есения',
#   'NumberOfPersons': 15,
#   'global_id': 62368666,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 257,
#   'Name': 'Зоя',
#   'NumberOfPersons': 15,
#   'global_id': 62368667,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 258,
#   'Name': 'Валентина',
#   'NumberOfPersons': 15,
#   'global_id': 62368668,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 259,
#   'Name': 'Владислава',
#   'NumberOfPersons': 15,
#   'global_id': 62368669,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 260,
#   'Name': 'Агния',
#   'NumberOfPersons': 15,
#   'global_id': 62368670,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 261,
#   'Name': 'Майя',
#   'NumberOfPersons': 15,
#   'global_id': 62368671,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 262,
#   'Name': 'Ярослава',
#   'NumberOfPersons': 15,
#   'global_id': 62368672,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 263,
#   'Name': 'Агата',
#   'NumberOfPersons': 14,
#   'global_id': 62368673,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 264,
#   'Name': 'Раяна',
#   'NumberOfPersons': 14,
#   'global_id': 62368674,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 265,
#   'Name': 'Нина',
#   'NumberOfPersons': 13,
#   'global_id': 62368675,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 266,
#   'Name': 'Эмилия',
#   'NumberOfPersons': 13,
#   'global_id': 62368676,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 267,
#   'Name': 'Алия',
#   'NumberOfPersons': 13,
#   'global_id': 62368677,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 268,
#   'Name': 'Самира',
#   'NumberOfPersons': 12,
#   'global_id': 62368678,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 269,
#   'Name': 'Сафия',
#   'NumberOfPersons': 12,
#   'global_id': 62368679,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 270,
#   'Name': 'Лилия',
#   'NumberOfPersons': 12,
#   'global_id': 62368680,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 271,
#   'Name': 'Антонина',
#   'NumberOfPersons': 12,
#   'global_id': 62368681,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 272,
#   'Name': 'Малика',
#   'NumberOfPersons': 11,
#   'global_id': 62368682,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 273,
#   'Name': 'Наталья',
#   'NumberOfPersons': 11,
#   'global_id': 62368683,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 274,
#   'Name': 'Амелия',
#   'NumberOfPersons': 11,
#   'global_id': 62368685,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 275,
#   'Name': 'Мадина',
#   'NumberOfPersons': 10,
#   'global_id': 62368686,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 276,
#   'Name': 'Лада',
#   'NumberOfPersons': 10,
#   'global_id': 62368687,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 277,
#   'Name': 'Сабина',
#   'NumberOfPersons': 10,
#   'global_id': 62368688,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 278,
#   'Name': 'Лидия',
#   'NumberOfPersons': 10,
#   'global_id': 62368690,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 279,
#   'Name': 'Камилла',
#   'NumberOfPersons': 10,
#   'global_id': 62368691,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 280,
#   'Name': 'Аниса',
#   'NumberOfPersons': 10,
#   'global_id': 62368692,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 281,
#   'Name': 'Карина',
#   'NumberOfPersons': 9,
#   'global_id': 62368693,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 282,
#   'Name': 'Ариана',
#   'NumberOfPersons': 9,
#   'global_id': 62368695,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 283,
#   'Name': 'Виолетта',
#   'NumberOfPersons': 9,
#   'global_id': 62368696,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 284,
#   'Name': 'Марьяна',
#   'NumberOfPersons': 9,
#   'global_id': 62368697,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 285,
#   'Name': 'Юлиана',
#   'NumberOfPersons': 8,
#   'global_id': 62368698,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 286,
#   'Name': 'Алеся',
#   'NumberOfPersons': 8,
#   'global_id': 62368700,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 287,
#   'Name': 'Любовь',
#   'NumberOfPersons': 8,
#   'global_id': 62368701,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 288,
#   'Name': 'Мила',
#   'NumberOfPersons': 8,
#   'global_id': 62368702,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 289,
#   'Name': 'Серафима',
#   'NumberOfPersons': 8,
#   'global_id': 62368703,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 290,
#   'Name': 'Камила',
#   'NumberOfPersons': 7,
#   'global_id': 62368705,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 291,
#   'Name': 'Альбина',
#   'NumberOfPersons': 7,
#   'global_id': 62368706,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 292,
#   'Name': 'Марьям',
#   'NumberOfPersons': 7,
#   'global_id': 62368707,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 293,
#   'Name': 'Станислава',
#   'NumberOfPersons': 7,
#   'global_id': 62368708,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 294,
#   'Name': 'Амира',
#   'NumberOfPersons': 7,
#   'global_id': 62368709,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 295,
#   'Name': 'Пелагея',
#   'NumberOfPersons': 7,
#   'global_id': 62368710,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 296,
#   'Name': 'Жасмина',
#   'NumberOfPersons': 6,
#   'global_id': 62368711,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 297,
#   'Name': 'Арууке',
#   'NumberOfPersons': 6,
#   'global_id': 62368712,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 298,
#   'Name': 'Эмма',
#   'NumberOfPersons': 6,
#   'global_id': 62368713,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 299,
#   'Name': 'Аделя',
#   'NumberOfPersons': 6,
#   'global_id': 62368714,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 300,
#   'Name': 'Дана',
#   'NumberOfPersons': 6,
#   'global_id': 62368715,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 301,
#   'Name': 'Мария',
#   'NumberOfPersons': 314,
#   'global_id': 62368716,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 302,
#   'Name': 'Анастасия',
#   'NumberOfPersons': 214,
#   'global_id': 62368717,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 303,
#   'Name': 'София',
#   'NumberOfPersons': 206,
#   'global_id': 62368718,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 304,
#   'Name': 'Виктория',
#   'NumberOfPersons': 205,
#   'global_id': 62368719,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 305,
#   'Name': 'Анна',
#   'NumberOfPersons': 202,
#   'global_id': 62368720,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 306,
#   'Name': 'Дарья',
#   'NumberOfPersons': 191,
#   'global_id': 62368721,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 307,
#   'Name': 'Полина',
#   'NumberOfPersons': 188,
#   'global_id': 62368723,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 308,
#   'Name': 'Алиса',
#   'NumberOfPersons': 178,
#   'global_id': 62368724,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 309,
#   'Name': 'Елизавета',
#   'NumberOfPersons': 171,
#   'global_id': 62368725,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 310,
#   'Name': 'Варвара',
#   'NumberOfPersons': 167,
#   'global_id': 62368726,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 311,
#   'Name': 'Александра',
#   'NumberOfPersons': 161,
#   'global_id': 62368727,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 312,
#   'Name': 'Екатерина',
#   'NumberOfPersons': 157,
#   'global_id': 62368728,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 313,
#   'Name': 'Арина',
#   'NumberOfPersons': 120,
#   'global_id': 62368729,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 314,
#   'Name': 'Ксения',
#   'NumberOfPersons': 119,
#   'global_id': 62368730,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 315,
#   'Name': 'Василиса',
#   'NumberOfPersons': 116,
#   'global_id': 62368731,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 316,
#   'Name': 'Валерия',
#   'NumberOfPersons': 105,
#   'global_id': 62368732,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 317,
#   'Name': 'Софья',
#   'NumberOfPersons': 99,
#   'global_id': 62368733,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 318,
#   'Name': 'Вероника',
#   'NumberOfPersons': 86,
#   'global_id': 62368734,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 319,
#   'Name': 'Ева',
#   'NumberOfPersons': 84,
#   'global_id': 62368735,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 320,
#   'Name': 'Милана',
#   'NumberOfPersons': 84,
#   'global_id': 62368736,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 321,
#   'Name': 'Ульяна',
#   'NumberOfPersons': 81,
#   'global_id': 62368737,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 322,
#   'Name': 'Маргарита',
#   'NumberOfPersons': 77,
#   'global_id': 62368738,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 323,
#   'Name': 'Вера',
#   'NumberOfPersons': 73,
#   'global_id': 62368739,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 324,
#   'Name': 'Кира',
#   'NumberOfPersons': 70,
#   'global_id': 62368740,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 325,
#   'Name': 'Кристина',
#   'NumberOfPersons': 55,
#   'global_id': 62368741,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 326,
#   'Name': 'Таисия',
#   'NumberOfPersons': 53,
#   'global_id': 62368742,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 327,
#   'Name': 'Юлия',
#   'NumberOfPersons': 51,
#   'global_id': 62368744,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 328,
#   'Name': 'Алёна',
#   'NumberOfPersons': 46,
#   'global_id': 62368745,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 329,
#   'Name': 'Ольга',
#   'NumberOfPersons': 43,
#   'global_id': 62368746,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 330,
#   'Name': 'Алина',
#   'NumberOfPersons': 43,
#   'global_id': 62368747,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 331,
#   'Name': 'Мирослава',
#   'NumberOfPersons': 37,
#   'global_id': 62368748,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 332,
#   'Name': 'Ника',
#   'NumberOfPersons': 36,
#   'global_id': 62368749,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 333,
#   'Name': 'Диана',
#   'NumberOfPersons': 36,
#   'global_id': 62368750,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 334,
#   'Name': 'Амина',
#   'NumberOfPersons': 36,
#   'global_id': 62368751,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 335,
#   'Name': 'Ирина',
#   'NumberOfPersons': 35,
#   'global_id': 62368752,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 336,
#   'Name': 'Злата',
#   'NumberOfPersons': 34,
#   'global_id': 62368753,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 337,
#   'Name': 'Татьяна',
#   'NumberOfPersons': 32,
#   'global_id': 62368754,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 338,
#   'Name': 'Елена',
#   'NumberOfPersons': 31,
#   'global_id': 62368755,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 339,
#   'Name': 'Надежда',
#   'NumberOfPersons': 30,
#   'global_id': 62368756,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 340,
#   'Name': 'Яна',
#   'NumberOfPersons': 30,
#   'global_id': 62368757,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 341,
#   'Name': 'Евгения',
#   'NumberOfPersons': 27,
#   'global_id': 62368758,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 342,
#   'Name': 'Ярослава',
#   'NumberOfPersons': 26,
#   'global_id': 62368759,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 343,
#   'Name': 'Марина',
#   'NumberOfPersons': 25,
#   'global_id': 62368760,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 344,
#   'Name': 'Ангелина',
#   'NumberOfPersons': 24,
#   'global_id': 62368761,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 345,
#   'Name': 'Светлана',
#   'NumberOfPersons': 22,
#   'global_id': 62368762,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 346,
#   'Name': 'Майя',
#   'NumberOfPersons': 20,
#   'global_id': 62368763,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 347,
#   'Name': 'Элина',
#   'NumberOfPersons': 20,
#   'global_id': 62368764,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 348,
#   'Name': 'Стефания',
#   'NumberOfPersons': 19,
#   'global_id': 62368765,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 349,
#   'Name': 'Есения',
#   'NumberOfPersons': 18,
#   'global_id': 62368766,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 350,
#   'Name': 'Сафия',
#   'NumberOfPersons': 18,
#   'global_id': 62368767,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 351,
#   'Name': 'Карина',
#   'NumberOfPersons': 18,
#   'global_id': 62368768,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 352,
#   'Name': 'Милена',
#   'NumberOfPersons': 17,
#   'global_id': 62368769,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 353,
#   'Name': 'Эмилия',
#   'NumberOfPersons': 17,
#   'global_id': 62368770,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 354,
#   'Name': 'Наталья',
#   'NumberOfPersons': 16,
#   'global_id': 62368771,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 355,
#   'Name': 'Аделина',
#   'NumberOfPersons': 16,
#   'global_id': 62368773,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 356,
#   'Name': 'Лидия',
#   'NumberOfPersons': 16,
#   'global_id': 62368774,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 357,
#   'Name': 'Дарина',
#   'NumberOfPersons': 15,
#   'global_id': 62368775,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 358,
#   'Name': 'Олеся',
#   'NumberOfPersons': 15,
#   'global_id': 62368776,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 359,
#   'Name': 'Лилия',
#   'NumberOfPersons': 15,
#   'global_id': 62368777,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 360,
#   'Name': 'Зоя',
#   'NumberOfPersons': 14,
#   'global_id': 62368778,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 361,
#   'Name': 'Марта',
#   'NumberOfPersons': 14,
#   'global_id': 62368779,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 362,
#   'Name': 'Марьям',
#   'NumberOfPersons': 14,
#   'global_id': 62368780,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 363,
#   'Name': 'Агата',
#   'NumberOfPersons': 14,
#   'global_id': 62368781,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 364,
#   'Name': 'Николь',
#   'NumberOfPersons': 13,
#   'global_id': 62368782,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 365,
#   'Name': 'Антонина',
#   'NumberOfPersons': 13,
#   'global_id': 62368783,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 366,
#   'Name': 'Ариана',
#   'NumberOfPersons': 12,
#   'global_id': 62368784,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 367,
#   'Name': 'Любовь',
#   'NumberOfPersons': 12,
#   'global_id': 62368785,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 368,
#   'Name': 'Фатима',
#   'NumberOfPersons': 12,
#   'global_id': 62368786,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 369,
#   'Name': 'Алия',
#   'NumberOfPersons': 12,
#   'global_id': 62368787,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 370,
#   'Name': 'Владислава',
#   'NumberOfPersons': 12,
#   'global_id': 62368788,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 371,
#   'Name': 'Евангелина',
#   'NumberOfPersons': 11,
#   'global_id': 62368789,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 372,
#   'Name': 'Амелия',
#   'NumberOfPersons': 11,
#   'global_id': 62368790,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 373,
#   'Name': 'Валентина',
#   'NumberOfPersons': 11,
#   'global_id': 62368791,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 374,
#   'Name': 'Нина',
#   'NumberOfPersons': 10,
#   'global_id': 62368792,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 375,
#   'Name': 'Марианна',
#   'NumberOfPersons': 10,
#   'global_id': 62368793,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 376,
#   'Name': 'Малика',
#   'NumberOfPersons': 10,
#   'global_id': 62368794,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 377,
#   'Name': 'Агния',
#   'NumberOfPersons': 10,
#   'global_id': 62368795,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 378,
#   'Name': 'Евдокия',
#   'NumberOfPersons': 9,
#   'global_id': 62368796,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 379,
#   'Name': 'Камилла',
#   'NumberOfPersons': 9,
#   'global_id': 62368797,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 380,
#   'Name': 'Мила',
#   'NumberOfPersons': 8,
#   'global_id': 62368798,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 381,
#   'Name': 'Лейла',
#   'NumberOfPersons': 8,
#   'global_id': 62368799,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 382,
#   'Name': 'Каролина',
#   'NumberOfPersons': 8,
#   'global_id': 62368800,
#   'Year': 2015,
#   'Month': 'апрель'},
#  ...]

# %%
class Base(DeclarativeBase):
    pass

# %%
# Создаем класс и описываем отображение атрибутов в столбцы таблицы базы данных
class Name(Base):
    # Название таблицы в базе данных
    __tablename__ = 'bulk_names'

    # Атрибуты  
    ID: Mapped[int] = mapped_column('id')
    Name: Mapped[str] = mapped_column('name')
    NumberOfPersons: Mapped[str] = mapped_column('number_of_persons')
    global_id: Mapped[int] = mapped_column(BigInteger, primary_key=True)
    Year: Mapped[int] = mapped_column('year')
    Month: Mapped[str] = mapped_column('month')

# %%
Base.metadata.create_all(engine)
# Out:
# 2023-06-19 07:50:20,852 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-19 07:50:20,853 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-19 07:50:20,853 INFO sqlalchemy.engine.Engine [cached since 267.6s ago] {'table_name': 'bulk_names', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-19 07:50:20,855 INFO sqlalchemy.engine.Engine
# CREATE TABLE bulk_names (
# 	id INTEGER NOT NULL,
# 	name VARCHAR NOT NULL,
# 	number_of_persons VARCHAR NOT NULL,
# 	global_id BIGSERIAL NOT NULL,
# 	year INTEGER NOT NULL,
# 	month VARCHAR NOT NULL,
# 	PRIMARY KEY (global_id)
# )
#
#
# 2023-06-19 07:50:20,855 INFO sqlalchemy.engine.Engine [no key 0.00032s] {}
# 2023-06-19 07:50:20,861 INFO sqlalchemy.engine.Engine COMMIT

# %%
with Session(engine) as session:
    session.execute(insert(Name), data)
    session.commit()
# Out:
# 2023-06-19 07:51:03,579 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-19 07:51:03,653 INFO sqlalchemy.engine.Engine INSERT INTO bulk_names (id, name, number_of_persons, global_id, year, month) VALUES (%(id__0)s, %(name__0)s, %(number_of_persons__0)s, %(global_id__0)s, %(year__0)s, %(month__0)s), (%(id__1)s, %(name__1)s, %(number_of_persons__1)s, %(global_id__1)s,  ... 108072 characters truncated ... 999)s, %(name__999)s, %(number_of_persons__999)s, %(global_id__999)s, %(year__999)s, %(month__999)s)
# 2023-06-19 07:51:03,653 INFO sqlalchemy.engine.Engine [generated in 0.04665s (insertmanyvalues) 1/10 (unordered)] {'name__0': 'Мария', 'global_id__0': 37750254, 'month__0': 'январь', 'id__0': 1, 'number_of_persons__0': 252, 'year__0': 2015, 'name__1': 'Анастасия', 'global_id__1': 37750255, 'month__1': 'январь', 'id__1': 2, 'number_of_persons__1': 224, 'year__1': 2015, 'name__2': 'Анна', 'global_id__2': 37750256, 'month__2': 'январь', 'id__2': 3, 'number_of_persons__2': 190, 'year__2': 2015, 'name__3': 'Варвара', 'global_id__3': 37750257, 'month__3': 'январь', 'id__3': 4, 'number_of_persons__3': 190, 'year__3': 2015, 'name__4': 'Виктория', 'global_id__4': 37750258, 'month__4': 'январь', 'id__4': 5, 'number_of_persons__4': 186, 'year__4': 2015, 'name__5': 'Амелия', 'global_id__5': 62367755, 'month__5': 'май', 'id__5': 483, 'number_of_persons__5': 8, 'year__5': 2015, 'name__6': 'Камила', 'global_id__6': 62367756, 'month__6': 'май', 'id__6': 484, 'number_of_persons__6': 8, 'year__6': 2015, 'name__7': 'Евангелина', 'global_id__7': 62367757, 'month__7': 'май', 'id__7': 485, 'number_of_persons__7': 8, 'year__7': 2015, 'name__8': 'Альбина', 'global_id__8': 62367758 ... 5900 parameters truncated ... 'number_of_persons__991': 10, 'year__991': 2015, 'name__992': 'Марианна', 'global_id__992': 62368793, 'month__992': 'апрель', 'id__992': 375, 'number_of_persons__992': 10, 'year__992': 2015, 'name__993': 'Малика', 'global_id__993': 62368794, 'month__993': 'апрель', 'id__993': 376, 'number_of_persons__993': 10, 'year__993': 2015, 'name__994': 'Агния', 'global_id__994': 62368795, 'month__994': 'апрель', 'id__994': 377, 'number_of_persons__994': 10, 'year__994': 2015, 'name__995': 'Евдокия', 'global_id__995': 62368796, 'month__995': 'апрель', 'id__995': 378, 'number_of_persons__995': 9, 'year__995': 2015, 'name__996': 'Камилла', 'global_id__996': 62368797, 'month__996': 'апрель', 'id__996': 379, 'number_of_persons__996': 9, 'year__996': 2015, 'name__997': 'Мила', 'global_id__997': 62368798, 'month__997': 'апрель', 'id__997': 380, 'number_of_persons__997': 8, 'year__997': 2015, 'name__998': 'Лейла', 'global_id__998': 62368799, 'month__998': 'апрель', 'id__998': 381, 'number_of_persons__998': 8, 'year__998': 2015, 'name__999': 'Каролина', 'global_id__999': 62368800, 'month__999': 'апрель', 'id__999': 382, 'number_of_persons__999': 8, 'year__999': 2015}
# 2023-06-19 07:51:03,671 INFO sqlalchemy.engine.Engine INSERT INTO bulk_names (id, name, number_of_persons, global_id, year, month) VALUES (%(id__0)s, %(name__0)s, %(number_of_persons__0)s, %(global_id__0)s, %(year__0)s, %(month__0)s), (%(id__1)s, %(name__1)s, %(number_of_persons__1)s, %(global_id__1)s,  ... 108072 characters truncated ... 999)s, %(name__999)s, %(number_of_persons__999)s, %(global_id__999)s, %(year__999)s, %(month__999)s)
# 2023-06-19 07:51:03,671 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/10 (unordered)] {'name__0': 'Людмила', 'global_id__0': 62368801, 'month__0': 'апрель', 'id__0': 383, 'number_of_persons__0': 8, 'year__0': 2015, 'name__1': 'Лада', 'global_id__1': 62368802, 'month__1': 'апрель', 'id__1': 384, 'number_of_persons__1': 8, 'year__1': 2015, 'name__2': 'Аглая', 'global_id__2': 62368804, 'month__2': 'апрель', 'id__2': 385, 'number_of_persons__2': 8, 'year__2': 2015, 'name__3': 'Мадина', 'global_id__3': 62368805, 'month__3': 'апрель', 'id__3': 386, 'number_of_persons__3': 8, 'year__3': 2015, 'name__4': 'Марьяна', 'global_id__4': 62368806, 'month__4': 'апрель', 'id__4': 387, 'number_of_persons__4': 8, 'year__4': 2015, 'name__5': 'Алеся', 'global_id__5': 62368807, 'month__5': 'апрель', 'id__5': 388, 'number_of_persons__5': 8, 'year__5': 2015, 'name__6': 'Самира', 'global_id__6': 62368808, 'month__6': 'апрель', 'id__6': 389, 'number_of_persons__6': 8, 'year__6': 2015, 'name__7': 'Влада', 'global_id__7': 62368809, 'month__7': 'апрель', 'id__7': 390, 'number_of_persons__7': 7, 'year__7': 2015, 'name__8': 'Амира', 'global_id__8': 62368810 ... 5900 parameters truncated ... 'number_of_persons__991': 21, 'year__991': 2016, 'name__992': 'Марьям', 'global_id__992': 284583250, 'month__992': 'июль', 'id__992': 1853, 'number_of_persons__992': 20, 'year__992': 2016, 'name__993': 'Николь', 'global_id__993': 284583266, 'month__993': 'июль', 'id__993': 1854, 'number_of_persons__993': 18, 'year__993': 2016, 'name__994': 'Аиша', 'global_id__994': 284583283, 'month__994': 'июль', 'id__994': 1855, 'number_of_persons__994': 17, 'year__994': 2016, 'name__995': 'Аделина', 'global_id__995': 284583301, 'month__995': 'июль', 'id__995': 1856, 'number_of_persons__995': 17, 'year__995': 2016, 'name__996': 'Лилия', 'global_id__996': 284583351, 'month__996': 'июль', 'id__996': 1857, 'number_of_persons__996': 17, 'year__996': 2016, 'name__997': 'Нина', 'global_id__997': 284583373, 'month__997': 'июль', 'id__997': 1858, 'number_of_persons__997': 17, 'year__997': 2016, 'name__998': 'Элина', 'global_id__998': 284583391, 'month__998': 'июль', 'id__998': 1859, 'number_of_persons__998': 17, 'year__998': 2016, 'name__999': 'Амелия', 'global_id__999': 284583706, 'month__999': 'июль', 'id__999': 1860, 'number_of_persons__999': 16, 'year__999': 2016}
# 2023-06-19 07:51:03,687 INFO sqlalchemy.engine.Engine INSERT INTO bulk_names (id, name, number_of_persons, global_id, year, month) VALUES (%(id__0)s, %(name__0)s, %(number_of_persons__0)s, %(global_id__0)s, %(year__0)s, %(month__0)s), (%(id__1)s, %(name__1)s, %(number_of_persons__1)s, %(global_id__1)s,  ... 108072 characters truncated ... 999)s, %(name__999)s, %(number_of_persons__999)s, %(global_id__999)s, %(year__999)s, %(month__999)s)
# 2023-06-19 07:51:03,687 INFO sqlalchemy.engine.Engine [insertmanyvalues 3/10 (unordered)] {'name__0': 'Амира', 'global_id__0': 284583732, 'month__0': 'июль', 'id__0': 1861, 'number_of_persons__0': 16, 'year__0': 2016, 'name__1': 'Антонина', 'global_id__1': 284584824, 'month__1': 'июль', 'id__1': 1862, 'number_of_persons__1': 14, 'year__1': 2016, 'name__2': 'Марта', 'global_id__2': 284584826, 'month__2': 'июль', 'id__2': 1863, 'number_of_persons__2': 14, 'year__2': 2016, 'name__3': 'Агния', 'global_id__3': 284584828, 'month__3': 'июль', 'id__3': 1864, 'number_of_persons__3': 13, 'year__3': 2016, 'name__4': 'Ариана', 'global_id__4': 284584830, 'month__4': 'июль', 'id__4': 1865, 'number_of_persons__4': 13, 'year__4': 2016, 'name__5': 'Асия', 'global_id__5': 284584832, 'month__5': 'июль', 'id__5': 1866, 'number_of_persons__5': 13, 'year__5': 2016, 'name__6': 'Лидия', 'global_id__6': 284584833, 'month__6': 'июль', 'id__6': 1867, 'number_of_persons__6': 13, 'year__6': 2016, 'name__7': 'Наталья', 'global_id__7': 284584834, 'month__7': 'июль', 'id__7': 1868, 'number_of_persons__7': 13, 'year__7': 2016, 'name__8': 'Сабина', 'global_id__8': 284584835 ... 5900 parameters truncated ... 'number_of_persons__991': 8, 'year__991': 2017, 'name__992': 'Антонина', 'global_id__992': 628446811, 'month__992': 'июнь', 'id__992': 2993, 'number_of_persons__992': 8, 'year__992': 2017, 'name__993': 'Мила', 'global_id__993': 628446829, 'month__993': 'июнь', 'id__993': 2994, 'number_of_persons__993': 8, 'year__993': 2017, 'name__994': 'Раяна', 'global_id__994': 628446844, 'month__994': 'июнь', 'id__994': 2995, 'number_of_persons__994': 8, 'year__994': 2017, 'name__995': 'Сабина', 'global_id__995': 628446863, 'month__995': 'июнь', 'id__995': 2996, 'number_of_persons__995': 8, 'year__995': 2017, 'name__996': 'Эмма', 'global_id__996': 628446881, 'month__996': 'июнь', 'id__996': 2997, 'number_of_persons__996': 8, 'year__996': 2017, 'name__997': 'Юлиана', 'global_id__997': 628446898, 'month__997': 'июнь', 'id__997': 2998, 'number_of_persons__997': 7, 'year__997': 2017, 'name__998': 'Сара', 'global_id__998': 628446930, 'month__998': 'июнь', 'id__998': 2999, 'number_of_persons__998': 7, 'year__998': 2017, 'name__999': 'Лидия', 'global_id__999': 628446948, 'month__999': 'июнь', 'id__999': 3000, 'number_of_persons__999': 7, 'year__999': 2017}
# 2023-06-19 07:51:03,703 INFO sqlalchemy.engine.Engine INSERT INTO bulk_names (id, name, number_of_persons, global_id, year, month) VALUES (%(id__0)s, %(name__0)s, %(number_of_persons__0)s, %(global_id__0)s, %(year__0)s, %(month__0)s), (%(id__1)s, %(name__1)s, %(number_of_persons__1)s, %(global_id__1)s,  ... 108072 characters truncated ... 999)s, %(name__999)s, %(number_of_persons__999)s, %(global_id__999)s, %(year__999)s, %(month__999)s)
# 2023-06-19 07:51:03,704 INFO sqlalchemy.engine.Engine [insertmanyvalues 4/10 (unordered)] {'name__0': 'София, Софья', 'global_id__0': 639909512, 'month__0': 'июль', 'id__0': 3901, 'number_of_persons__0': 311, 'year__0': 2017, 'name__1': 'Мария', 'global_id__1': 639909618, 'month__1': 'июль', 'id__1': 3902, 'number_of_persons__1': 249, 'year__1': 2017, 'name__2': 'Анна', 'global_id__2': 639910018, 'month__2': 'июль', 'id__2': 3903, 'number_of_persons__2': 245, 'year__2': 2017, 'name__3': 'Виктория', 'global_id__3': 639910144, 'month__3': 'июль', 'id__3': 3904, 'number_of_persons__3': 187, 'year__3': 2017, 'name__4': 'Анастасия', 'global_id__4': 639910523, 'month__4': 'июль', 'id__4': 3905, 'number_of_persons__4': 187, 'year__4': 2017, 'name__5': 'Алиса', 'global_id__5': 639910624, 'month__5': 'июль', 'id__5': 3906, 'number_of_persons__5': 185, 'year__5': 2017, 'name__6': 'Полина', 'global_id__6': 639911007, 'month__6': 'июль', 'id__6': 3907, 'number_of_persons__6': 181, 'year__6': 2017, 'name__7': 'Елизавета', 'global_id__7': 639911231, 'month__7': 'июль', 'id__7': 3908, 'number_of_persons__7': 180, 'year__7': 2017, 'name__8': 'Александра', 'global_id__8': 639911431 ... 5900 parameters truncated ... 'number_of_persons__991': 7, 'year__991': 2018, 'name__992': 'Владислава', 'global_id__992': 862563997, 'month__992': 'апрель', 'id__992': 4893, 'number_of_persons__992': 7, 'year__992': 2018, 'name__993': 'Медина', 'global_id__993': 862563998, 'month__993': 'апрель', 'id__993': 4894, 'number_of_persons__993': 7, 'year__993': 2018, 'name__994': 'Мила', 'global_id__994': 862563999, 'month__994': 'апрель', 'id__994': 4895, 'number_of_persons__994': 6, 'year__994': 2018, 'name__995': 'Милена', 'global_id__995': 862564000, 'month__995': 'апрель', 'id__995': 4896, 'number_of_persons__995': 6, 'year__995': 2018, 'name__996': 'Эвелина', 'global_id__996': 862564001, 'month__996': 'апрель', 'id__996': 4897, 'number_of_persons__996': 6, 'year__996': 2018, 'name__997': 'Евангелина', 'global_id__997': 862564002, 'month__997': 'апрель', 'id__997': 4898, 'number_of_persons__997': 6, 'year__997': 2018, 'name__998': 'Лилия', 'global_id__998': 862564003, 'month__998': 'апрель', 'id__998': 4899, 'number_of_persons__998': 6, 'year__998': 2018, 'name__999': 'Лада', 'global_id__999': 862564004, 'month__999': 'апрель', 'id__999': 4900, 'number_of_persons__999': 6, 'year__999': 2018}
# 2023-06-19 07:51:03,721 INFO sqlalchemy.engine.Engine INSERT INTO bulk_names (id, name, number_of_persons, global_id, year, month) VALUES (%(id__0)s, %(name__0)s, %(number_of_persons__0)s, %(global_id__0)s, %(year__0)s, %(month__0)s), (%(id__1)s, %(name__1)s, %(number_of_persons__1)s, %(global_id__1)s,  ... 108072 characters truncated ... 999)s, %(name__999)s, %(number_of_persons__999)s, %(global_id__999)s, %(year__999)s, %(month__999)s)
# 2023-06-19 07:51:03,721 INFO sqlalchemy.engine.Engine [insertmanyvalues 5/10 (unordered)] {'name__0': 'София, Софья', 'global_id__0': 880864952, 'month__0': 'май', 'id__0': 4901, 'number_of_persons__0': 281, 'year__0': 2018, 'name__1': 'Виктория', 'global_id__1': 880865008, 'month__1': 'май', 'id__1': 4902, 'number_of_persons__1': 206, 'year__1': 2018, 'name__2': 'Мария', 'global_id__2': 880865017, 'month__2': 'май', 'id__2': 4903, 'number_of_persons__2': 204, 'year__2': 2018, 'name__3': 'Анастасия', 'global_id__3': 880865037, 'month__3': 'май', 'id__3': 4904, 'number_of_persons__3': 186, 'year__3': 2018, 'name__4': 'Алиса', 'global_id__4': 880865044, 'month__4': 'май', 'id__4': 4905, 'number_of_persons__4': 184, 'year__4': 2018, 'name__5': 'Анна', 'global_id__5': 880865055, 'month__5': 'май', 'id__5': 4906, 'number_of_persons__5': 176, 'year__5': 2018, 'name__6': 'Александра', 'global_id__6': 880865069, 'month__6': 'май', 'id__6': 4907, 'number_of_persons__6': 150, 'year__6': 2018, 'name__7': 'Полина', 'global_id__7': 880865072, 'month__7': 'май', 'id__7': 4908, 'number_of_persons__7': 150, 'year__7': 2018, 'name__8': 'Ева', 'global_id__8': 880865077 ... 5900 parameters truncated ... 'number_of_persons__991': 8, 'year__991': 2019, 'name__992': 'Марианна', 'global_id__992': 1023016545, 'month__992': 'Февраль', 'id__992': 5893, 'number_of_persons__992': 8, 'year__992': 2019, 'name__993': 'Регина', 'global_id__993': 1023016546, 'month__993': 'Февраль', 'id__993': 5894, 'number_of_persons__993': 8, 'year__993': 2019, 'name__994': 'Айша', 'global_id__994': 1023016547, 'month__994': 'Февраль', 'id__994': 5895, 'number_of_persons__994': 7, 'year__994': 2019, 'name__995': 'Лейла', 'global_id__995': 1023016548, 'month__995': 'Февраль', 'id__995': 5896, 'number_of_persons__995': 7, 'year__995': 2019, 'name__996': 'Марина', 'global_id__996': 1023016549, 'month__996': 'Февраль', 'id__996': 5897, 'number_of_persons__996': 7, 'year__996': 2019, 'name__997': 'Асия', 'global_id__997': 1023016550, 'month__997': 'Февраль', 'id__997': 5898, 'number_of_persons__997': 7, 'year__997': 2019, 'name__998': 'Наталья', 'global_id__998': 1023016551, 'month__998': 'Февраль', 'id__998': 5899, 'number_of_persons__998': 7, 'year__998': 2019, 'name__999': 'Станислава', 'global_id__999': 1023016552, 'month__999': 'Февраль', 'id__999': 5900, 'number_of_persons__999': 7, 'year__999': 2019}
# 2023-06-19 07:51:03,738 INFO sqlalchemy.engine.Engine INSERT INTO bulk_names (id, name, number_of_persons, global_id, year, month) VALUES (%(id__0)s, %(name__0)s, %(number_of_persons__0)s, %(global_id__0)s, %(year__0)s, %(month__0)s), (%(id__1)s, %(name__1)s, %(number_of_persons__1)s, %(global_id__1)s,  ... 108072 characters truncated ... 999)s, %(name__999)s, %(number_of_persons__999)s, %(global_id__999)s, %(year__999)s, %(month__999)s)
# 2023-06-19 07:51:03,739 INFO sqlalchemy.engine.Engine [insertmanyvalues 6/10 (unordered)] {'name__0': 'Мария', 'global_id__0': 1023016553, 'month__0': 'Март', 'id__0': 5901, 'number_of_persons__0': 225, 'year__0': 2019, 'name__1': 'Анна', 'global_id__1': 1023016554, 'month__1': 'Март', 'id__1': 5902, 'number_of_persons__1': 222, 'year__1': 2019, 'name__2': 'Алиса', 'global_id__2': 1023016555, 'month__2': 'Март', 'id__2': 5903, 'number_of_persons__2': 188, 'year__2': 2019, 'name__3': 'Полина', 'global_id__3': 1023016556, 'month__3': 'Март', 'id__3': 5904, 'number_of_persons__3': 176, 'year__3': 2019, 'name__4': 'Виктория', 'global_id__4': 1023016557, 'month__4': 'Март', 'id__4': 5905, 'number_of_persons__4': 174, 'year__4': 2019, 'name__5': 'София', 'global_id__5': 1023016558, 'month__5': 'Март', 'id__5': 5906, 'number_of_persons__5': 164, 'year__5': 2019, 'name__6': 'Анастасия', 'global_id__6': 1023016559, 'month__6': 'Март', 'id__6': 5907, 'number_of_persons__6': 155, 'year__6': 2019, 'name__7': 'Варвара', 'global_id__7': 1023016560, 'month__7': 'Март', 'id__7': 5908, 'number_of_persons__7': 144, 'year__7': 2019, 'name__8': 'Елизавета', 'global_id__8': 1023016561 ... 5900 parameters truncated ... 'number_of_persons__991': 8, 'year__991': 2019, 'name__992': 'Зоя', 'global_id__992': 1026791955, 'month__992': 'Декабрь', 'id__992': 6893, 'number_of_persons__992': 7, 'year__992': 2019, 'name__993': 'Пелагея', 'global_id__993': 1026791956, 'month__993': 'Декабрь', 'id__993': 6894, 'number_of_persons__993': 7, 'year__993': 2019, 'name__994': 'Арианна', 'global_id__994': 1026791957, 'month__994': 'Декабрь', 'id__994': 6895, 'number_of_persons__994': 7, 'year__994': 2019, 'name__995': 'Лия', 'global_id__995': 1026791958, 'month__995': 'Декабрь', 'id__995': 6896, 'number_of_persons__995': 7, 'year__995': 2019, 'name__996': 'Виолетта', 'global_id__996': 1026791959, 'month__996': 'Декабрь', 'id__996': 6897, 'number_of_persons__996': 7, 'year__996': 2019, 'name__997': 'Сабрина', 'global_id__997': 1026791960, 'month__997': 'Декабрь', 'id__997': 6898, 'number_of_persons__997': 7, 'year__997': 2019, 'name__998': 'Муслима', 'global_id__998': 1026791961, 'month__998': 'Декабрь', 'id__998': 6899, 'number_of_persons__998': 7, 'year__998': 2019, 'name__999': 'Аделя', 'global_id__999': 1026791962, 'month__999': 'Декабрь', 'id__999': 6900, 'number_of_persons__999': 7, 'year__999': 2019}
# 2023-06-19 07:51:03,756 INFO sqlalchemy.engine.Engine INSERT INTO bulk_names (id, name, number_of_persons, global_id, year, month) VALUES (%(id__0)s, %(name__0)s, %(number_of_persons__0)s, %(global_id__0)s, %(year__0)s, %(month__0)s), (%(id__1)s, %(name__1)s, %(number_of_persons__1)s, %(global_id__1)s,  ... 108072 characters truncated ... 999)s, %(name__999)s, %(number_of_persons__999)s, %(global_id__999)s, %(year__999)s, %(month__999)s)
# 2023-06-19 07:51:03,756 INFO sqlalchemy.engine.Engine [insertmanyvalues 7/10 (unordered)] {'name__0': 'Мария', 'global_id__0': 1029420312, 'month__0': 'Январь', 'id__0': 6901, 'number_of_persons__0': 180, 'year__0': 2020, 'name__1': 'София', 'global_id__1': 1029420313, 'month__1': 'Январь', 'id__1': 6902, 'number_of_persons__1': 174, 'year__1': 2020, 'name__2': 'Анна', 'global_id__2': 1029420314, 'month__2': 'Январь', 'id__2': 6903, 'number_of_persons__2': 162, 'year__2': 2020, 'name__3': 'Полина', 'global_id__3': 1029420315, 'month__3': 'Январь', 'id__3': 6904, 'number_of_persons__3': 160, 'year__3': 2020, 'name__4': 'Алиса', 'global_id__4': 1029420316, 'month__4': 'Январь', 'id__4': 6905, 'number_of_persons__4': 151, 'year__4': 2020, 'name__5': 'Виктория', 'global_id__5': 1029420317, 'month__5': 'Январь', 'id__5': 6906, 'number_of_persons__5': 130, 'year__5': 2020, 'name__6': 'Анастасия', 'global_id__6': 1029420318, 'month__6': 'Январь', 'id__6': 6907, 'number_of_persons__6': 127, 'year__6': 2020, 'name__7': 'Александра', 'global_id__7': 1029420319, 'month__7': 'Январь', 'id__7': 6908, 'number_of_persons__7': 111, 'year__7': 2020, 'name__8': 'Дарья', 'global_id__8': 1029420320 ... 5900 parameters truncated ... 'number_of_persons__991': 10, 'year__991': 2020, 'name__992': 'Эмили', 'global_id__992': 1078697379, 'month__992': 'Октябрь', 'id__992': 8093, 'number_of_persons__992': 10, 'year__992': 2020, 'name__993': 'Евангелина', 'global_id__993': 1078697380, 'month__993': 'Октябрь', 'id__993': 8094, 'number_of_persons__993': 9, 'year__993': 2020, 'name__994': 'Марина', 'global_id__994': 1078697381, 'month__994': 'Октябрь', 'id__994': 8095, 'number_of_persons__994': 9, 'year__994': 2020, 'name__995': 'Сара', 'global_id__995': 1078697382, 'month__995': 'Октябрь', 'id__995': 8096, 'number_of_persons__995': 9, 'year__995': 2020, 'name__996': 'Мелисса', 'global_id__996': 1078697383, 'month__996': 'Октябрь', 'id__996': 8097, 'number_of_persons__996': 9, 'year__996': 2020, 'name__997': 'Доминика', 'global_id__997': 1078697384, 'month__997': 'Октябрь', 'id__997': 8098, 'number_of_persons__997': 9, 'year__997': 2020, 'name__998': 'Сумая', 'global_id__998': 1078697385, 'month__998': 'Октябрь', 'id__998': 8099, 'number_of_persons__998': 9, 'year__998': 2020, 'name__999': 'Агния', 'global_id__999': 1078697386, 'month__999': 'Октябрь', 'id__999': 8100, 'number_of_persons__999': 9, 'year__999': 2020}
# 2023-06-19 07:51:03,778 INFO sqlalchemy.engine.Engine INSERT INTO bulk_names (id, name, number_of_persons, global_id, year, month) VALUES (%(id__0)s, %(name__0)s, %(number_of_persons__0)s, %(global_id__0)s, %(year__0)s, %(month__0)s), (%(id__1)s, %(name__1)s, %(number_of_persons__1)s, %(global_id__1)s,  ... 108072 characters truncated ... 999)s, %(name__999)s, %(number_of_persons__999)s, %(global_id__999)s, %(year__999)s, %(month__999)s)
# 2023-06-19 07:51:03,779 INFO sqlalchemy.engine.Engine [insertmanyvalues 8/10 (unordered)] {'name__0': 'Мария', 'global_id__0': 1078697387, 'month__0': 'Ноябрь', 'id__0': 8101, 'number_of_persons__0': 174, 'year__0': 2020, 'name__1': 'София', 'global_id__1': 1078697388, 'month__1': 'Ноябрь', 'id__1': 8102, 'number_of_persons__1': 173, 'year__1': 2020, 'name__2': 'Анна', 'global_id__2': 1078697389, 'month__2': 'Ноябрь', 'id__2': 8103, 'number_of_persons__2': 169, 'year__2': 2020, 'name__3': 'Полина', 'global_id__3': 1078697390, 'month__3': 'Ноябрь', 'id__3': 8104, 'number_of_persons__3': 157, 'year__3': 2020, 'name__4': 'Виктория', 'global_id__4': 1078697391, 'month__4': 'Ноябрь', 'id__4': 8105, 'number_of_persons__4': 144, 'year__4': 2020, 'name__5': 'Алиса', 'global_id__5': 1078697392, 'month__5': 'Ноябрь', 'id__5': 8106, 'number_of_persons__5': 141, 'year__5': 2020, 'name__6': 'Елизавета', 'global_id__6': 1078697393, 'month__6': 'Ноябрь', 'id__6': 8107, 'number_of_persons__6': 134, 'year__6': 2020, 'name__7': 'Ева', 'global_id__7': 1078697394, 'month__7': 'Ноябрь', 'id__7': 8108, 'number_of_persons__7': 131, 'year__7': 2020, 'name__8': 'Варвара', 'global_id__8': 1078697395 ... 5900 parameters truncated ... 'number_of_persons__991': 10, 'year__991': 2021, 'name__992': 'Лидия', 'global_id__992': 1146179171, 'month__992': 'Август', 'id__992': 9093, 'number_of_persons__992': 10, 'year__992': 2021, 'name__993': 'Афина', 'global_id__993': 1146179172, 'month__993': 'Август', 'id__993': 9094, 'number_of_persons__993': 9, 'year__993': 2021, 'name__994': 'Милена', 'global_id__994': 1146179173, 'month__994': 'Август', 'id__994': 9095, 'number_of_persons__994': 9, 'year__994': 2021, 'name__995': 'Хадиджа', 'global_id__995': 1146179174, 'month__995': 'Август', 'id__995': 9096, 'number_of_persons__995': 9, 'year__995': 2021, 'name__996': 'Анфиса', 'global_id__996': 1146179175, 'month__996': 'Август', 'id__996': 9097, 'number_of_persons__996': 9, 'year__996': 2021, 'name__997': 'Сумая', 'global_id__997': 1146179176, 'month__997': 'Август', 'id__997': 9098, 'number_of_persons__997': 8, 'year__997': 2021, 'name__998': 'Нина', 'global_id__998': 1146179177, 'month__998': 'Август', 'id__998': 9099, 'number_of_persons__998': 8, 'year__998': 2021, 'name__999': 'Ярослава', 'global_id__999': 1146179178, 'month__999': 'Август', 'id__999': 9100, 'number_of_persons__999': 8, 'year__999': 2021}
# 2023-06-19 07:51:03,801 INFO sqlalchemy.engine.Engine INSERT INTO bulk_names (id, name, number_of_persons, global_id, year, month) VALUES (%(id__0)s, %(name__0)s, %(number_of_persons__0)s, %(global_id__0)s, %(year__0)s, %(month__0)s), (%(id__1)s, %(name__1)s, %(number_of_persons__1)s, %(global_id__1)s,  ... 108072 characters truncated ... 999)s, %(name__999)s, %(number_of_persons__999)s, %(global_id__999)s, %(year__999)s, %(month__999)s)
# 2023-06-19 07:51:03,802 INFO sqlalchemy.engine.Engine [insertmanyvalues 9/10 (unordered)] {'name__0': 'София', 'global_id__0': 1266741020, 'month__0': 'Сентябрь', 'id__0': 9101, 'number_of_persons__0': 228, 'year__0': 2021, 'name__1': 'Мария', 'global_id__1': 1266741021, 'month__1': 'Сентябрь', 'id__1': 9102, 'number_of_persons__1': 217, 'year__1': 2021, 'name__2': 'Анна', 'global_id__2': 1266741022, 'month__2': 'Сентябрь', 'id__2': 9103, 'number_of_persons__2': 173, 'year__2': 2021, 'name__3': 'Алиса', 'global_id__3': 1266741023, 'month__3': 'Сентябрь', 'id__3': 9104, 'number_of_persons__3': 159, 'year__3': 2021, 'name__4': 'Елизавета', 'global_id__4': 1266741024, 'month__4': 'Сентябрь', 'id__4': 9105, 'number_of_persons__4': 136, 'year__4': 2021, 'name__5': 'Виктория', 'global_id__5': 1266741025, 'month__5': 'Сентябрь', 'id__5': 9106, 'number_of_persons__5': 135, 'year__5': 2021, 'name__6': 'Ева', 'global_id__6': 1266741026, 'month__6': 'Сентябрь', 'id__6': 9107, 'number_of_persons__6': 134, 'year__6': 2021, 'name__7': 'Полина', 'global_id__7': 1266741027, 'month__7': 'Сентябрь', 'id__7': 9108, 'number_of_persons__7': 113, 'year__7': 2021, 'name__8': 'Варвара', 'global_id__8': 1266741028 ... 5900 parameters truncated ... 'number_of_persons__991': 9, 'year__991': 2022, 'name__992': 'Амира', 'global_id__992': 2375970845, 'month__992': 'Июнь', 'id__992': 10093, 'number_of_persons__992': 9, 'year__992': 2022, 'name__993': 'Аниса', 'global_id__993': 2375970846, 'month__993': 'Июнь', 'id__993': 10094, 'number_of_persons__993': 9, 'year__993': 2022, 'name__994': 'Хадижа', 'global_id__994': 2375970847, 'month__994': 'Июнь', 'id__994': 10095, 'number_of_persons__994': 9, 'year__994': 2022, 'name__995': 'Мариям', 'global_id__995': 2375970848, 'month__995': 'Июнь', 'id__995': 10096, 'number_of_persons__995': 9, 'year__995': 2022, 'name__996': 'Теона', 'global_id__996': 2375970849, 'month__996': 'Июнь', 'id__996': 10097, 'number_of_persons__996': 9, 'year__996': 2022, 'name__997': 'Эвелина', 'global_id__997': 2375970850, 'month__997': 'Июнь', 'id__997': 10098, 'number_of_persons__997': 8, 'year__997': 2022, 'name__998': 'Азалия', 'global_id__998': 2375970851, 'month__998': 'Июнь', 'id__998': 10099, 'number_of_persons__998': 8, 'year__998': 2022, 'name__999': 'Марина', 'global_id__999': 2375970852, 'month__999': 'Июнь', 'id__999': 10100, 'number_of_persons__999': 8, 'year__999': 2022}
# 2023-06-19 07:51:03,817 INFO sqlalchemy.engine.Engine INSERT INTO bulk_names (id, name, number_of_persons, global_id, year, month) VALUES (%(id__0)s, %(name__0)s, %(number_of_persons__0)s, %(global_id__0)s, %(year__0)s, %(month__0)s), (%(id__1)s, %(name__1)s, %(number_of_persons__1)s, %(global_id__1)s,  ... 93902 characters truncated ... 869)s, %(name__869)s, %(number_of_persons__869)s, %(global_id__869)s, %(year__869)s, %(month__869)s)
# 2023-06-19 07:51:03,817 INFO sqlalchemy.engine.Engine [insertmanyvalues 10/10 (unordered)] {'name__0': 'София', 'global_id__0': 2382082201, 'month__0': 'Июль', 'id__0': 10101, 'number_of_persons__0': 202, 'year__0': 2022, 'name__1': 'Мария', 'global_id__1': 2382082202, 'month__1': 'Июль', 'id__1': 10102, 'number_of_persons__1': 184, 'year__1': 2022, 'name__2': 'Анна', 'global_id__2': 2382082203, 'month__2': 'Июль', 'id__2': 10103, 'number_of_persons__2': 161, 'year__2': 2022, 'name__3': 'Алиса', 'global_id__3': 2382082204, 'month__3': 'Июль', 'id__3': 10104, 'number_of_persons__3': 147, 'year__3': 2022, 'name__4': 'Виктория', 'global_id__4': 2382082205, 'month__4': 'Июль', 'id__4': 10105, 'number_of_persons__4': 139, 'year__4': 2022, 'name__5': 'Ева', 'global_id__5': 2382082207, 'month__5': 'Июль', 'id__5': 10106, 'number_of_persons__5': 136, 'year__5': 2022, 'name__6': 'Елизавета', 'global_id__6': 2382082208, 'month__6': 'Июль', 'id__6': 10107, 'number_of_persons__6': 128, 'year__6': 2022, 'name__7': 'Полина', 'global_id__7': 2382082209, 'month__7': 'Июль', 'id__7': 10108, 'number_of_persons__7': 118, 'year__7': 2022, 'name__8': 'Варвара', 'global_id__8': 2382082210 ... 5120 parameters truncated ... 'number_of_persons__861': 12, 'year__861': 2023, 'name__862': 'Камила', 'global_id__862': 2587775495, 'month__862': 'Апрель', 'id__862': 11077, 'number_of_persons__862': 11, 'year__862': 2023, 'name__863': 'Аниса', 'global_id__863': 2587775502, 'month__863': 'Апрель', 'id__863': 11083, 'number_of_persons__863': 11, 'year__863': 2023, 'name__864': 'Аглая', 'global_id__864': 2587775504, 'month__864': 'Апрель', 'id__864': 11085, 'number_of_persons__864': 10, 'year__864': 2023, 'name__865': 'Антонина', 'global_id__865': 2587775507, 'month__865': 'Апрель', 'id__865': 11088, 'number_of_persons__865': 10, 'year__865': 2023, 'name__866': 'Дария', 'global_id__866': 2587775512, 'month__866': 'Апрель', 'id__866': 11093, 'number_of_persons__866': 9, 'year__866': 2023, 'name__867': 'Айла', 'global_id__867': 2587775513, 'month__867': 'Апрель', 'id__867': 11094, 'number_of_persons__867': 9, 'year__867': 2023, 'name__868': 'Лидия', 'global_id__868': 2587775514, 'month__868': 'Апрель', 'id__868': 11095, 'number_of_persons__868': 9, 'year__868': 2023, 'name__869': 'Мелисса', 'global_id__869': 2587775517, 'month__869': 'Апрель', 'id__869': 11098, 'number_of_persons__869': 8, 'year__869': 2023}
# 2023-06-19 07:51:03,832 INFO sqlalchemy.engine.Engine COMMIT
