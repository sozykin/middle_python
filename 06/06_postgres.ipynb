# %% [markdown]
# # Работа в SQL Alchemy с PostgreSQL
#
# <a target="_blank" href="https://colab.research.google.com/github/sozykin/middle_python/blob/main/06/06_postgres.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
from sqlalchemy.orm import DeclarativeBase
from sqlalchemy.orm import mapped_column
from sqlalchemy.orm import Mapped
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import URL
from sqlalchemy import select
from typing import Optional
from typing import List

# %% [markdown]
# ## Установка соединения с PostgreSQL
#
# Для работы с PostgreSQL необходимо предварительно установить библиотеку psycopg2

# %%
url = "postgresql+psycopg2://postgres:1234qwer@localhost:5432/postgres"
engine = create_engine(url, echo=True)

# %% [markdown]
# Создание ссылки для подключения к базе данных

# %%
url_object = URL.create(
    "postgresql+psycopg2",
    username="postgres",
    password="1234qwer",  
    host="localhost",
    database="postgres",
)

# %%
url_object
# Out:
# postgresql+psycopg2://postgres:***@localhost/postgres

# %%
engine = create_engine(url_object, echo=True)

# %% [markdown]
# ## Создание класса с ORM

# %%
# Базовый класс для создание классов, которые будут сохраняться в базе данных
class Base(DeclarativeBase):
    pass

# %%
# Создаем класс и описываем отображение атрибутов в столбцы таблицы базы данных
class Name(Base):
    # Название таблицы в базе данных
    __tablename__ = 'names'

    # Атрибуты  
    id: Mapped[int] 
    name: Mapped[str]
    number_of_persons: Mapped[str] 
    global_id: Mapped[int] = mapped_column(primary_key=True)
    year: Mapped[int]
    month: Mapped[str]

    # Текстовое представление объекта
    def __repr__(self):
        return(f"{self.id}, {self.name}, {self.number_of_persons}, {self.global_id}, {self.year}, {self.month}")

# %%
# Создаем таблицу
Base.metadata.create_all(engine)
# Out:
# 2023-06-18 17:46:17,800 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-18 17:46:17,800 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-18 17:46:17,801 INFO sqlalchemy.engine.Engine [cached since 67.54s ago] {'table_name': 'names', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-18 17:46:17,802 INFO sqlalchemy.engine.Engine
# CREATE TABLE names (
# 	id INTEGER NOT NULL,
# 	name VARCHAR NOT NULL,
# 	number_of_persons VARCHAR NOT NULL,
# 	global_id SERIAL NOT NULL,
# 	year INTEGER NOT NULL,
# 	month VARCHAR NOT NULL,
# 	PRIMARY KEY (global_id)
# )
#
#
# 2023-06-18 17:46:17,803 INFO sqlalchemy.engine.Engine [no key 0.00062s] {}
# 2023-06-18 17:46:17,826 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ## Добавляем объект в таблицу

# %%
new_name = Name(id=3,
                 name='Анна', 
                 number_of_persons=190, 
                 global_id=37750256,
                 year=2015, 
                 month='январь')

# %%
with Session(engine) as session:
    session.add(new_name)
    session.commit()
# Out:
# 2023-06-18 17:47:32,696 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-18 17:47:32,699 INFO sqlalchemy.engine.Engine INSERT INTO names (id, name, number_of_persons, global_id, year, month) VALUES (%(id)s, %(name)s, %(number_of_persons)s, %(global_id)s, %(year)s, %(month)s)
# 2023-06-18 17:47:32,700 INFO sqlalchemy.engine.Engine [generated in 0.00056s] {'id': 3, 'name': 'Анна', 'number_of_persons': 190, 'global_id': 37750256, 'year': 2015, 'month': 'январь'}
# 2023-06-18 17:47:32,702 INFO sqlalchemy.engine.Engine COMMIT

# %%
new_name.metadata.tables
# Out:
# FacadeDict({'names': Table('names', MetaData(), Column('id', Integer(), table=<names>, nullable=False), Column('name', String(), table=<names>, nullable=False), Column('number_of_persons', String(), table=<names>, nullable=False), Column('global_id', Integer(), table=<names>, primary_key=True, nullable=False), Column('year', Integer(), table=<names>, nullable=False), Column('month', String(), table=<names>, nullable=False), schema=None)})

# %% [markdown]
# ## Получение информации о таблице из базы данных

# %%
class Base(DeclarativeBase):
    pass

# %%
# Загружаем информацию обо всех таблицах
Base.metadata.reflect(bind=engine)
# Out:
# 2023-06-18 18:46:08,233 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-18 18:46:08,234 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s]) AND pg_catalog.pg_class.relpersistence != %(relpersistence_1)s AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-18 18:46:08,235 INFO sqlalchemy.engine.Engine [cached since 2952s ago] {'param_1': 'r', 'param_2': 'p', 'relpersistence_1': 't', 'nspname_1': 'pg_catalog'}
# 2023-06-18 18:46:08,237 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_attribute.attname AS name, pg_catalog.format_type(pg_catalog.pg_attribute.atttypid, pg_catalog.pg_attribute.atttypmod) AS format_type, (SELECT pg_catalog.pg_get_expr(pg_catalog.pg_attrdef.adbin, pg_catalog.pg_attrdef.adrelid) AS pg_get_expr_1
# FROM pg_catalog.pg_attrdef
# WHERE pg_catalog.pg_attrdef.adrelid = pg_catalog.pg_attribute.attrelid AND pg_catalog.pg_attrdef.adnum = pg_catalog.pg_attribute.attnum AND pg_catalog.pg_attribute.atthasdef) AS "default", pg_catalog.pg_attribute.attnotnull AS not_null, pg_catalog.pg_class.relname AS table_name, pg_catalog.pg_description.description AS comment, pg_catalog.pg_attribute.attgenerated AS generated, (SELECT json_build_object(%(json_build_object_2)s, pg_catalog.pg_attribute.attidentity = %(attidentity_1)s, %(json_build_object_3)s, pg_catalog.pg_sequence.seqstart, %(json_build_object_4)s, pg_catalog.pg_sequence.seqincrement, %(json_build_object_5)s, pg_catalog.pg_sequence.seqmin, %(json_build_object_6)s, pg_catalog.pg_sequence.seqmax, %(json_build_object_7)s, pg_catalog.pg_sequence.seqcache, %(json_build_object_8)s, pg_catalog.pg_sequence.seqcycle) AS json_build_object_1
# FROM pg_catalog.pg_sequence
# WHERE pg_catalog.pg_attribute.attidentity != %(attidentity_2)s AND pg_catalog.pg_sequence.seqrelid = CAST(CAST(pg_catalog.pg_get_serial_sequence(CAST(CAST(pg_catalog.pg_attribute.attrelid AS REGCLASS) AS TEXT), pg_catalog.pg_attribute.attname) AS REGCLASS) AS OID)) AS identity_options
# FROM pg_catalog.pg_class LEFT OUTER JOIN pg_catalog.pg_attribute ON pg_catalog.pg_class.oid = pg_catalog.pg_attribute.attrelid AND pg_catalog.pg_attribute.attnum > %(attnum_1)s AND NOT pg_catalog.pg_attribute.attisdropped LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_description.objoid = pg_catalog.pg_attribute.attrelid AND pg_catalog.pg_description.objsubid = pg_catalog.pg_attribute.attnum JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s AND pg_catalog.pg_class.relname IN (%(filter_names_1)s, %(filter_names_2)s, %(filter_names_3)s, %(filter_names_4)s, %(filter_names_5)s, %(filter_names_6)s, %(filter_names_7)s, %(filter_names_8)s, %(filter_names_9)s, %(filter_names_10)s, %(filter_names_11)s, %(filter_names_12)s, %(filter_names_13)s, %(filter_names_14)s) ORDER BY pg_catalog.pg_class.relname, pg_catalog.pg_attribute.attnum
# 2023-06-18 18:46:08,237 INFO sqlalchemy.engine.Engine [cached since 2952s ago] {'json_build_object_2': 'always', 'attidentity_1': 'a', 'json_build_object_3': 'start', 'json_build_object_4': 'increment', 'json_build_object_5': 'minvalue', 'json_build_object_6': 'maxvalue', 'json_build_object_7': 'cache', 'json_build_object_8': 'cycle', 'attidentity_2': '', 'attnum_1': 0, 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'nspname_1': 'pg_catalog', 'filter_names_1': 'names', 'filter_names_2': 'salesperson', 'filter_names_3': 'company', 'filter_names_4': 'person', 'filter_names_5': 'employee', 'filter_names_6': 'blocks', 'filter_names_7': 'decrypted_ballots', 'filter_names_8': 'transactions', 'filter_names_9': 'superheroes', 'filter_names_10': 'customers', 'filter_names_11': 'sales', 'filter_names_12': 'product_types', 'filter_names_13': 'products', 'filter_names_14': 'orders'}
# 2023-06-18 18:46:08,239 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_type.typname AS name, pg_catalog.format_type(pg_catalog.pg_type.typbasetype, pg_catalog.pg_type.typtypmod) AS attype, NOT pg_catalog.pg_type.typnotnull AS nullable, pg_catalog.pg_type.typdefault AS "default", pg_catalog.pg_type_is_visible(pg_catalog.pg_type.oid) AS visible, pg_catalog.pg_namespace.nspname AS schema, domain_constraints.condefs, domain_constraints.connames
# FROM pg_catalog.pg_type JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_type.typnamespace LEFT OUTER JOIN (SELECT pg_catalog.pg_constraint.contypid AS contypid, array_agg(pg_catalog.pg_get_constraintdef(pg_catalog.pg_constraint.oid, %(pg_get_constraintdef_1)s)) AS condefs, array_agg(pg_catalog.pg_constraint.conname) AS connames
# FROM pg_catalog.pg_constraint
# WHERE pg_catalog.pg_constraint.contypid != %(contypid_1)s GROUP BY pg_catalog.pg_constraint.contypid) AS domain_constraints ON pg_catalog.pg_type.oid = domain_constraints.contypid
# WHERE pg_catalog.pg_type.typtype = %(typtype_1)s ORDER BY pg_catalog.pg_namespace.nspname, pg_catalog.pg_type.typname
# 2023-06-18 18:46:08,240 INFO sqlalchemy.engine.Engine [cached since 2952s ago] {'pg_get_constraintdef_1': True, 'contypid_1': 0, 'typtype_1': 'd'}
# 2023-06-18 18:46:08,241 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_type.typname AS name, pg_catalog.pg_type_is_visible(pg_catalog.pg_type.oid) AS visible, pg_catalog.pg_namespace.nspname AS schema, lbl_agg.labels AS labels
# FROM pg_catalog.pg_type JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_type.typnamespace LEFT OUTER JOIN (SELECT pg_catalog.pg_enum.enumtypid AS enumtypid, array_agg(pg_catalog.pg_enum.enumlabel ORDER BY pg_catalog.pg_enum.enumsortorder) AS labels
# FROM pg_catalog.pg_enum GROUP BY pg_catalog.pg_enum.enumtypid) AS lbl_agg ON pg_catalog.pg_type.oid = lbl_agg.enumtypid
# WHERE pg_catalog.pg_type.typtype = %(typtype_1)s ORDER BY pg_catalog.pg_namespace.nspname, pg_catalog.pg_type.typname
# 2023-06-18 18:46:08,241 INFO sqlalchemy.engine.Engine [cached since 2952s ago] {'typtype_1': 'e'}
# 2023-06-18 18:46:08,242 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.oid, pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s AND pg_catalog.pg_class.relname IN (%(filter_names_1)s, %(filter_names_2)s, %(filter_names_3)s, %(filter_names_4)s, %(filter_names_5)s, %(filter_names_6)s, %(filter_names_7)s, %(filter_names_8)s, %(filter_names_9)s, %(filter_names_10)s, %(filter_names_11)s, %(filter_names_12)s, %(filter_names_13)s, %(filter_names_14)s)
# 2023-06-18 18:46:08,242 INFO sqlalchemy.engine.Engine [cached since 2952s ago] {'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'nspname_1': 'pg_catalog', 'filter_names_1': 'names', 'filter_names_2': 'salesperson', 'filter_names_3': 'company', 'filter_names_4': 'person', 'filter_names_5': 'employee', 'filter_names_6': 'blocks', 'filter_names_7': 'decrypted_ballots', 'filter_names_8': 'transactions', 'filter_names_9': 'superheroes', 'filter_names_10': 'customers', 'filter_names_11': 'sales', 'filter_names_12': 'product_types', 'filter_names_13': 'products', 'filter_names_14': 'orders'}
# 2023-06-18 18:46:08,243 INFO sqlalchemy.engine.Engine SELECT attr.conrelid, array_agg(attr.attname ORDER BY attr.ord) AS cols, attr.conname, min(attr.description) AS description
# FROM (SELECT con.conrelid AS conrelid, con.conname AS conname, con.description AS description, con.ord AS ord, pg_catalog.pg_attribute.attname AS attname
# FROM pg_catalog.pg_attribute JOIN (SELECT pg_catalog.pg_constraint.conrelid AS conrelid, pg_catalog.pg_constraint.conname AS conname, unnest(pg_catalog.pg_constraint.conkey) AS attnum, generate_subscripts(pg_catalog.pg_constraint.conkey, %(generate_subscripts_1)s) AS ord, pg_catalog.pg_description.description AS description
# FROM pg_catalog.pg_constraint LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_description.objoid = pg_catalog.pg_constraint.oid
# WHERE pg_catalog.pg_constraint.contype = %(contype)s AND pg_catalog.pg_constraint.conrelid IN (%(oids_1)s, %(oids_2)s, %(oids_3)s, %(oids_4)s, %(oids_5)s, %(oids_6)s, %(oids_7)s, %(oids_8)s, %(oids_9)s, %(oids_10)s, %(oids_11)s, %(oids_12)s, %(oids_13)s, %(oids_14)s)) AS con ON pg_catalog.pg_attribute.attnum = con.attnum AND pg_catalog.pg_attribute.attrelid = con.conrelid) AS attr GROUP BY attr.conrelid, attr.conname ORDER BY attr.conrelid, attr.conname
# 2023-06-18 18:46:08,243 INFO sqlalchemy.engine.Engine [cached since 2952s ago] {'generate_subscripts_1': 1, 'contype': 'p', 'oids_1': 20642, 'oids_2': 20266, 'oids_3': 20269, 'oids_4': 16823, 'oids_5': 16828, 'oids_6': 16836, 'oids_7': 16842, 'oids_8': 16847, 'oids_9': 20415, 'oids_10': 20427, 'oids_11': 20433, 'oids_12': 20421, 'oids_13': 20444, 'oids_14': 20454}
# 2023-06-18 18:46:08,245 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname, pg_catalog.pg_constraint.conname, CASE WHEN (pg_catalog.pg_constraint.oid IS NOT NULL) THEN pg_catalog.pg_get_constraintdef(pg_catalog.pg_constraint.oid, %(pg_get_constraintdef_1)s) END AS anon_1, nsp_ref.nspname, pg_catalog.pg_description.description
# FROM pg_catalog.pg_class LEFT OUTER JOIN pg_catalog.pg_constraint ON pg_catalog.pg_class.oid = pg_catalog.pg_constraint.conrelid AND pg_catalog.pg_constraint.contype = %(contype_1)s LEFT OUTER JOIN pg_catalog.pg_class AS cls_ref ON cls_ref.oid = pg_catalog.pg_constraint.confrelid LEFT OUTER JOIN pg_catalog.pg_namespace AS nsp_ref ON cls_ref.relnamespace = nsp_ref.oid LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_description.objoid = pg_catalog.pg_constraint.oid JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s AND pg_catalog.pg_class.relname IN (%(filter_names_1)s, %(filter_names_2)s, %(filter_names_3)s, %(filter_names_4)s, %(filter_names_5)s, %(filter_names_6)s, %(filter_names_7)s, %(filter_names_8)s, %(filter_names_9)s, %(filter_names_10)s, %(filter_names_11)s, %(filter_names_12)s, %(filter_names_13)s, %(filter_names_14)s) ORDER BY pg_catalog.pg_class.relname, pg_catalog.pg_constraint.conname
# 2023-06-18 18:46:08,246 INFO sqlalchemy.engine.Engine [cached since 2952s ago] {'pg_get_constraintdef_1': True, 'contype_1': 'f', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'nspname_1': 'pg_catalog', 'filter_names_1': 'names', 'filter_names_2': 'salesperson', 'filter_names_3': 'company', 'filter_names_4': 'person', 'filter_names_5': 'employee', 'filter_names_6': 'blocks', 'filter_names_7': 'decrypted_ballots', 'filter_names_8': 'transactions', 'filter_names_9': 'superheroes', 'filter_names_10': 'customers', 'filter_names_11': 'sales', 'filter_names_12': 'product_types', 'filter_names_13': 'products', 'filter_names_14': 'orders'}
# 2023-06-18 18:46:08,248 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_index.indrelid, cls_idx.relname AS relname_index, pg_catalog.pg_index.indisunique, pg_catalog.pg_constraint.conrelid IS NOT NULL AS has_constraint, pg_catalog.pg_index.indoption, cls_idx.reloptions, pg_catalog.pg_am.amname, CASE WHEN (pg_catalog.pg_index.indpred IS NOT NULL) THEN pg_catalog.pg_get_expr(pg_catalog.pg_index.indpred, pg_catalog.pg_index.indrelid) END AS filter_definition, pg_catalog.pg_index.indnkeyatts, idx_cols.elements, idx_cols.elements_is_expr
# FROM pg_catalog.pg_index JOIN pg_catalog.pg_class AS cls_idx ON pg_catalog.pg_index.indexrelid = cls_idx.oid JOIN pg_catalog.pg_am ON cls_idx.relam = pg_catalog.pg_am.oid LEFT OUTER JOIN (SELECT idx_attr.indexrelid AS indexrelid, min(idx_attr.indrelid) AS min_1, array_agg(idx_attr.element ORDER BY idx_attr.ord) AS elements, array_agg(idx_attr.is_expr ORDER BY idx_attr.ord) AS elements_is_expr
# FROM (SELECT idx.indexrelid AS indexrelid, idx.indrelid AS indrelid, idx.ord AS ord, CASE WHEN (idx.attnum = %(attnum_1)s) THEN pg_catalog.pg_get_indexdef(idx.indexrelid, idx.ord + %(ord_1)s, %(pg_get_indexdef_1)s) ELSE CAST(pg_catalog.pg_attribute.attname AS TEXT) END AS element, idx.attnum = %(attnum_2)s AS is_expr
# FROM (SELECT pg_catalog.pg_index.indexrelid AS indexrelid, pg_catalog.pg_index.indrelid AS indrelid, unnest(pg_catalog.pg_index.indkey) AS attnum, generate_subscripts(pg_catalog.pg_index.indkey, %(generate_subscripts_1)s) AS ord
# FROM pg_catalog.pg_index
# WHERE NOT pg_catalog.pg_index.indisprimary AND pg_catalog.pg_index.indrelid IN (%(oids_1)s, %(oids_2)s, %(oids_3)s, %(oids_4)s, %(oids_5)s, %(oids_6)s, %(oids_7)s, %(oids_8)s, %(oids_9)s, %(oids_10)s, %(oids_11)s, %(oids_12)s, %(oids_13)s, %(oids_14)s)) AS idx LEFT OUTER JOIN pg_catalog.pg_attribute ON pg_catalog.pg_attribute.attnum = idx.attnum AND pg_catalog.pg_attribute.attrelid = idx.indrelid
# WHERE idx.indrelid IN (%(oids_1)s, %(oids_2)s, %(oids_3)s, %(oids_4)s, %(oids_5)s, %(oids_6)s, %(oids_7)s, %(oids_8)s, %(oids_9)s, %(oids_10)s, %(oids_11)s, %(oids_12)s, %(oids_13)s, %(oids_14)s)) AS idx_attr GROUP BY idx_attr.indexrelid) AS idx_cols ON pg_catalog.pg_index.indexrelid = idx_cols.indexrelid LEFT OUTER JOIN pg_catalog.pg_constraint ON pg_catalog.pg_index.indrelid = pg_catalog.pg_constraint.conrelid AND pg_catalog.pg_index.indexrelid = pg_catalog.pg_constraint.conindid AND pg_catalog.pg_constraint.contype = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s])
# WHERE pg_catalog.pg_index.indrelid IN (%(oids_1)s, %(oids_2)s, %(oids_3)s, %(oids_4)s, %(oids_5)s, %(oids_6)s, %(oids_7)s, %(oids_8)s, %(oids_9)s, %(oids_10)s, %(oids_11)s, %(oids_12)s, %(oids_13)s, %(oids_14)s) AND NOT pg_catalog.pg_index.indisprimary ORDER BY pg_catalog.pg_index.indrelid, cls_idx.relname
# 2023-06-18 18:46:08,248 INFO sqlalchemy.engine.Engine [cached since 2952s ago] {'attnum_1': 0, 'ord_1': 1, 'pg_get_indexdef_1': True, 'attnum_2': 0, 'generate_subscripts_1': 1, 'param_1': 'p', 'param_2': 'u', 'param_3': 'x', 'oids_1': 20642, 'oids_2': 20266, 'oids_3': 20269, 'oids_4': 16823, 'oids_5': 16828, 'oids_6': 16836, 'oids_7': 16842, 'oids_8': 16847, 'oids_9': 20415, 'oids_10': 20427, 'oids_11': 20433, 'oids_12': 20421, 'oids_13': 20444, 'oids_14': 20454}
# 2023-06-18 18:46:08,251 INFO sqlalchemy.engine.Engine SELECT attr.conrelid, array_agg(attr.attname ORDER BY attr.ord) AS cols, attr.conname, min(attr.description) AS description
# FROM (SELECT con.conrelid AS conrelid, con.conname AS conname, con.description AS description, con.ord AS ord, pg_catalog.pg_attribute.attname AS attname
# FROM pg_catalog.pg_attribute JOIN (SELECT pg_catalog.pg_constraint.conrelid AS conrelid, pg_catalog.pg_constraint.conname AS conname, unnest(pg_catalog.pg_constraint.conkey) AS attnum, generate_subscripts(pg_catalog.pg_constraint.conkey, %(generate_subscripts_1)s) AS ord, pg_catalog.pg_description.description AS description
# FROM pg_catalog.pg_constraint LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_description.objoid = pg_catalog.pg_constraint.oid
# WHERE pg_catalog.pg_constraint.contype = %(contype)s AND pg_catalog.pg_constraint.conrelid IN (%(oids_1)s, %(oids_2)s, %(oids_3)s, %(oids_4)s, %(oids_5)s, %(oids_6)s, %(oids_7)s, %(oids_8)s, %(oids_9)s, %(oids_10)s, %(oids_11)s, %(oids_12)s, %(oids_13)s, %(oids_14)s)) AS con ON pg_catalog.pg_attribute.attnum = con.attnum AND pg_catalog.pg_attribute.attrelid = con.conrelid) AS attr GROUP BY attr.conrelid, attr.conname ORDER BY attr.conrelid, attr.conname
# 2023-06-18 18:46:08,251 INFO sqlalchemy.engine.Engine [cached since 2952s ago] {'generate_subscripts_1': 1, 'contype': 'u', 'oids_1': 20642, 'oids_2': 20266, 'oids_3': 20269, 'oids_4': 16823, 'oids_5': 16828, 'oids_6': 16836, 'oids_7': 16842, 'oids_8': 16847, 'oids_9': 20415, 'oids_10': 20427, 'oids_11': 20433, 'oids_12': 20421, 'oids_13': 20444, 'oids_14': 20454}
# 2023-06-18 18:46:08,252 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname, pg_catalog.pg_description.description
# FROM pg_catalog.pg_class LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_class.oid = pg_catalog.pg_description.objoid AND pg_catalog.pg_description.objsubid = %(objsubid_1)s JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s AND pg_catalog.pg_class.relname IN (%(filter_names_1)s, %(filter_names_2)s, %(filter_names_3)s, %(filter_names_4)s, %(filter_names_5)s, %(filter_names_6)s, %(filter_names_7)s, %(filter_names_8)s, %(filter_names_9)s, %(filter_names_10)s, %(filter_names_11)s, %(filter_names_12)s, %(filter_names_13)s, %(filter_names_14)s)
# 2023-06-18 18:46:08,252 INFO sqlalchemy.engine.Engine [cached since 2952s ago] {'objsubid_1': 0, 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'nspname_1': 'pg_catalog', 'filter_names_1': 'names', 'filter_names_2': 'salesperson', 'filter_names_3': 'company', 'filter_names_4': 'person', 'filter_names_5': 'employee', 'filter_names_6': 'blocks', 'filter_names_7': 'decrypted_ballots', 'filter_names_8': 'transactions', 'filter_names_9': 'superheroes', 'filter_names_10': 'customers', 'filter_names_11': 'sales', 'filter_names_12': 'product_types', 'filter_names_13': 'products', 'filter_names_14': 'orders'}
# 2023-06-18 18:46:08,253 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname, pg_catalog.pg_constraint.conname, CASE WHEN (pg_catalog.pg_constraint.oid IS NOT NULL) THEN pg_catalog.pg_get_constraintdef(pg_catalog.pg_constraint.oid, %(pg_get_constraintdef_1)s) END AS anon_1, pg_catalog.pg_description.description
# FROM pg_catalog.pg_class LEFT OUTER JOIN pg_catalog.pg_constraint ON pg_catalog.pg_class.oid = pg_catalog.pg_constraint.conrelid AND pg_catalog.pg_constraint.contype = %(contype_1)s LEFT OUTER JOIN pg_catalog.pg_description ON pg_catalog.pg_description.objoid = pg_catalog.pg_constraint.oid JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s AND pg_catalog.pg_class.relname IN (%(filter_names_1)s, %(filter_names_2)s, %(filter_names_3)s, %(filter_names_4)s, %(filter_names_5)s, %(filter_names_6)s, %(filter_names_7)s, %(filter_names_8)s, %(filter_names_9)s, %(filter_names_10)s, %(filter_names_11)s, %(filter_names_12)s, %(filter_names_13)s, %(filter_names_14)s) ORDER BY pg_catalog.pg_class.relname, pg_catalog.pg_constraint.conname
# 2023-06-18 18:46:08,253 INFO sqlalchemy.engine.Engine [cached since 2952s ago] {'pg_get_constraintdef_1': True, 'contype_1': 'c', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'nspname_1': 'pg_catalog', 'filter_names_1': 'names', 'filter_names_2': 'salesperson', 'filter_names_3': 'company', 'filter_names_4': 'person', 'filter_names_5': 'employee', 'filter_names_6': 'blocks', 'filter_names_7': 'decrypted_ballots', 'filter_names_8': 'transactions', 'filter_names_9': 'superheroes', 'filter_names_10': 'customers', 'filter_names_11': 'sales', 'filter_names_12': 'product_types', 'filter_names_13': 'products', 'filter_names_14': 'orders'}
# 2023-06-18 18:46:08,255 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s]) AND pg_catalog.pg_class.relpersistence = %(relpersistence_1)s AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-18 18:46:08,255 INFO sqlalchemy.engine.Engine [cached since 2952s ago] {'param_1': 'r', 'param_2': 'p', 'relpersistence_1': 't', 'nspname_1': 'pg_catalog'}
# 2023-06-18 18:46:08,259 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
# Просматриваем имена таблиц
for table in Base.metadata.tables:
    print(table)
# Out:
# names
# salesperson
# company
# person
# employee
# blocks
# decrypted_ballots
# transactions
# superheroes
# customers
# sales
# orders
# products
# product_types

# %%
Base.metadata.tables['products']
# Out:
# Table('products', MetaData(), Column('id', INTEGER(), table=<products>, primary_key=True, nullable=False, server_default=Identity(start=1, increment=1, minvalue=1, maxvalue=2147483647, cycle=False, cache=1)), Column('name', VARCHAR(length=100), table=<products>), Column('type_id', INTEGER(), ForeignKey('product_types.id'), table=<products>), Column('price', INTEGER(), table=<products>), schema=None)

# %% [markdown]
# ## Создаем класс на основе загруженной таблицы

# %%
class Product(Base):
    __table__ = Base.metadata.tables['products']

    def __repr__(self):
        return(f"{self.name}, {self.type_id}, {self.price}")

# %%
# Читаем данные из таблицы и загружаем в класс
with Session(engine) as session:
    results = session.execute(select(Product))
    for row in results:
        print(row)
# Out:
# 2023-06-18 18:46:21,499 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-18 18:46:21,500 INFO sqlalchemy.engine.Engine SELECT products.id, products.name, products.type_id, products.price
# FROM products
# 2023-06-18 18:46:21,501 INFO sqlalchemy.engine.Engine [generated in 0.00051s] {}
# (Основы искусственного интеллекта, 1, 15000,)
# (Технологии обработки больших данных, 1, 50000,)
# (Программирование глубоких нейронных сетей, 1, 30000,)
# (Нейронные сети для анализа текстов, 1, 50000,)
# (Нейронные сети для анализа изображений, 1, 50000,)
# (Инженерия искусственного интеллекта, 1, 60000,)
# (Как стать DataScientist'ом, 2, 0,)
# (Планирование карьеры в DataScience, 2, 2000,)
# (Области применения нейросетей: в какой развивать экспертность, 2, 4000,)
# (Программирование глубоких нейронных сетей на Python, 3, 1000,)
# (Математика для DataScience, 3, 2000,)
# (Основы визуализации данных, 3, 500,)
# (Анализ временных рядов, None, 30000,)
# 2023-06-18 18:46:21,502 INFO sqlalchemy.engine.Engine ROLLBACK

# %% [markdown]
# ## Описываем два связанных класса

# %%
from sqlalchemy.orm import relationship
from sqlalchemy import ForeignKey

# %%
class Base(DeclarativeBase):
    pass

# %%
# Пользователи
class User(Base):
    __tablename__ = "users"

    id: Mapped[int] = mapped_column(primary_key=True)
    name: Mapped[Optional[str]]
    login: Mapped[Optional[str]]
    # Связи с объектом/таблицей email
    emails: Mapped[List["Email"]] = relationship(back_populates="user")


    def __repr__(self) -> str:
        return f"Пользователь (id={self.id}, name={self.name!r}, login={self.login})"

# %%
# email адреса
class Email(Base):
     __tablename__ = "emails"

     id: Mapped[int] = mapped_column(primary_key=True)
     email_address: Mapped[str]
     user_id = mapped_column(ForeignKey("users.id"))
     # Связи с объектом/таблицей users
     user: Mapped[User] = relationship(back_populates="emails")

     def __repr__(self) -> str:
         return f"email (id={self.id}, email_address={self.email_address})"

# %%
Base.metadata.create_all(engine)
# Out:
# 2023-06-18 19:39:57,289 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-18 19:39:57,290 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-18 19:39:57,290 INFO sqlalchemy.engine.Engine [cached since 1829s ago] {'table_name': 'users', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-18 19:39:57,291 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-18 19:39:57,292 INFO sqlalchemy.engine.Engine [cached since 1829s ago] {'table_name': 'emails', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-18 19:39:57,293 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ## Создаем связанные объекты

# %%
user1 = User(id=1, name="Andrey Sozykin", login="sozykin")

# %%
user1
# Out:
# Пользователь (id=1, name='Andrey Sozykin', login=sozykin)

# %%
user1.emails
# Out:
# []

# %%
email1 = Email(id=1, email_address='sozykin@gmail.com')

# %%
user1.emails.append(email1)

# %%
user1.emails
# Out:
# [email (id=1, email_address=sozykin@gmail.com)]

# %%
email2 = Email(id=2, email_address='sozykin@mail.ru')

# %%
user1.emails.append(email2)

# %%
user1.emails
# Out:
# [email (id=1, email_address=sozykin@gmail.com),
#  email (id=2, email_address=sozykin@mail.ru)]

# %% [markdown]
# ## Записываем связанные объекты в базу данных

# %%
with Session(engine) as session:
    session.add(user1)
    session.commit()
# Out:
# 2023-06-18 19:43:50,445 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-18 19:43:50,447 INFO sqlalchemy.engine.Engine INSERT INTO users (id, name, login) VALUES (%(id)s, %(name)s, %(login)s)
# 2023-06-18 19:43:50,447 INFO sqlalchemy.engine.Engine [generated in 0.00045s] {'id': 1, 'name': 'Andrey Sozykin', 'login': 'sozykin'}
# 2023-06-18 19:43:50,449 INFO sqlalchemy.engine.Engine INSERT INTO emails (id, email_address, user_id) VALUES (%(id__0)s, %(email_address__0)s, %(user_id__0)s), (%(id__1)s, %(email_address__1)s, %(user_id__1)s)
# 2023-06-18 19:43:50,449 INFO sqlalchemy.engine.Engine [generated in 0.00004s (insertmanyvalues) 1/1 (unordered)] {'email_address__0': 'sozykin@gmail.com', 'id__0': 1, 'user_id__0': 1, 'email_address__1': 'sozykin@mail.ru', 'id__1': 2, 'user_id__1': 1}
# 2023-06-18 19:43:50,456 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ## Пакетная вставка

# %%
import json
from sqlalchemy import insert
from sqlalchemy.types import BigInteger

# %%
with open("names_f.json", "r") as read_file:
    data = json.load(read_file)

# %%
data
# Out:
# [{'ID': 1,
#   'Name': 'Мария',
#   'NumberOfPersons': 252,
#   'global_id': 37750254,
#   'Year': 2015,
#   'Month': 'январь'},
#  {'ID': 2,
#   'Name': 'Анастасия',
#   'NumberOfPersons': 224,
#   'global_id': 37750255,
#   'Year': 2015,
#   'Month': 'январь'},
#  {'ID': 3,
#   'Name': 'Анна',
#   'NumberOfPersons': 190,
#   'global_id': 37750256,
#   'Year': 2015,
#   'Month': 'январь'},
#  {'ID': 4,
#   'Name': 'Варвара',
#   'NumberOfPersons': 190,
#   'global_id': 37750257,
#   'Year': 2015,
#   'Month': 'январь'},
#  {'ID': 5,
#   'Name': 'Виктория',
#   'NumberOfPersons': 186,
#   'global_id': 37750258,
#   'Year': 2015,
#   'Month': 'январь'},
#  {'ID': 483,
#   'Name': 'Амелия',
#   'NumberOfPersons': 8,
#   'global_id': 62367755,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 484,
#   'Name': 'Камила',
#   'NumberOfPersons': 8,
#   'global_id': 62367756,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 485,
#   'Name': 'Евангелина',
#   'NumberOfPersons': 8,
#   'global_id': 62367757,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 486,
#   'Name': 'Альбина',
#   'NumberOfPersons': 8,
#   'global_id': 62367758,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 487,
#   'Name': 'Владислава',
#   'NumberOfPersons': 8,
#   'global_id': 62367759,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 488,
#   'Name': 'Айлин',
#   'NumberOfPersons': 8,
#   'global_id': 62367760,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 489,
#   'Name': 'Евдокия',
#   'NumberOfPersons': 7,
#   'global_id': 62367761,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 490,
#   'Name': 'Марьям',
#   'NumberOfPersons': 7,
#   'global_id': 62367762,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 491,
#   'Name': 'Лейла',
#   'NumberOfPersons': 7,
#   'global_id': 62367763,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 492,
#   'Name': 'Мелисса',
#   'NumberOfPersons': 7,
#   'global_id': 62367764,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 493,
#   'Name': 'Амира',
#   'NumberOfPersons': 7,
#   'global_id': 62367765,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 494,
#   'Name': 'Оливия',
#   'NumberOfPersons': 7,
#   'global_id': 62367766,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 495,
#   'Name': 'Виталина',
#   'NumberOfPersons': 7,
#   'global_id': 62367767,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 496,
#   'Name': 'Станислава',
#   'NumberOfPersons': 6,
#   'global_id': 62367768,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 497,
#   'Name': 'Марьяна',
#   'NumberOfPersons': 6,
#   'global_id': 62367769,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 498,
#   'Name': 'Фатима',
#   'NumberOfPersons': 6,
#   'global_id': 62367770,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 499,
#   'Name': 'Влада',
#   'NumberOfPersons': 6,
#   'global_id': 62367771,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 500,
#   'Name': 'Дана',
#   'NumberOfPersons': 6,
#   'global_id': 62367772,
#   'Year': 2015,
#   'Month': 'май'},
#  {'ID': 501,
#   'Name': 'Мария',
#   'NumberOfPersons': 271,
#   'global_id': 62367773,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 502,
#   'Name': 'Анастасия',
#   'NumberOfPersons': 242,
#   'global_id': 62367774,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 503,
#   'Name': 'Виктория',
#   'NumberOfPersons': 226,
#   'global_id': 62367775,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 504,
#   'Name': 'София',
#   'NumberOfPersons': 217,
#   'global_id': 62367776,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 505,
#   'Name': 'Анна',
#   'NumberOfPersons': 216,
#   'global_id': 62367777,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 506,
#   'Name': 'Елизавета',
#   'NumberOfPersons': 214,
#   'global_id': 62367778,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 507,
#   'Name': 'Алиса',
#   'NumberOfPersons': 191,
#   'global_id': 62367779,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 508,
#   'Name': 'Дарья',
#   'NumberOfPersons': 189,
#   'global_id': 62367780,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 509,
#   'Name': 'Александра',
#   'NumberOfPersons': 182,
#   'global_id': 62367781,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 510,
#   'Name': 'Полина',
#   'NumberOfPersons': 161,
#   'global_id': 62367782,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 511,
#   'Name': 'Ксения',
#   'NumberOfPersons': 157,
#   'global_id': 62367783,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 512,
#   'Name': 'Варвара',
#   'NumberOfPersons': 155,
#   'global_id': 62367784,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 513,
#   'Name': 'Валерия',
#   'NumberOfPersons': 149,
#   'global_id': 62367785,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 514,
#   'Name': 'Екатерина',
#   'NumberOfPersons': 141,
#   'global_id': 62367786,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 515,
#   'Name': 'Арина',
#   'NumberOfPersons': 134,
#   'global_id': 62367787,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 516,
#   'Name': 'Вероника',
#   'NumberOfPersons': 118,
#   'global_id': 62367789,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 517,
#   'Name': 'Софья',
#   'NumberOfPersons': 110,
#   'global_id': 62367790,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 518,
#   'Name': 'Василиса',
#   'NumberOfPersons': 108,
#   'global_id': 62367791,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 519,
#   'Name': 'Милана',
#   'NumberOfPersons': 103,
#   'global_id': 62367792,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 520,
#   'Name': 'Ульяна',
#   'NumberOfPersons': 101,
#   'global_id': 62367794,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 521,
#   'Name': 'Ева',
#   'NumberOfPersons': 99,
#   'global_id': 62367795,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 522,
#   'Name': 'Кира',
#   'NumberOfPersons': 86,
#   'global_id': 62367796,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 523,
#   'Name': 'Вера',
#   'NumberOfPersons': 67,
#   'global_id': 62367797,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 524,
#   'Name': 'Маргарита',
#   'NumberOfPersons': 66,
#   'global_id': 62367798,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 525,
#   'Name': 'Таисия',
#   'NumberOfPersons': 65,
#   'global_id': 62367800,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 526,
#   'Name': 'Алёна',
#   'NumberOfPersons': 62,
#   'global_id': 62367801,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 527,
#   'Name': 'Кристина',
#   'NumberOfPersons': 62,
#   'global_id': 62367802,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 528,
#   'Name': 'Алина',
#   'NumberOfPersons': 59,
#   'global_id': 62367803,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 529,
#   'Name': 'Юлия',
#   'NumberOfPersons': 53,
#   'global_id': 62367804,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 530,
#   'Name': 'Елена',
#   'NumberOfPersons': 46,
#   'global_id': 62367805,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 531,
#   'Name': 'Диана',
#   'NumberOfPersons': 45,
#   'global_id': 62367806,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 532,
#   'Name': 'Амина',
#   'NumberOfPersons': 44,
#   'global_id': 62367807,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 533,
#   'Name': 'Ольга',
#   'NumberOfPersons': 43,
#   'global_id': 62367808,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 534,
#   'Name': 'Стефания',
#   'NumberOfPersons': 42,
#   'global_id': 62367809,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 535,
#   'Name': 'Евгения',
#   'NumberOfPersons': 36,
#   'global_id': 62367810,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 536,
#   'Name': 'Майя',
#   'NumberOfPersons': 34,
#   'global_id': 62367811,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 537,
#   'Name': 'Ангелина',
#   'NumberOfPersons': 32,
#   'global_id': 62367812,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 538,
#   'Name': 'Надежда',
#   'NumberOfPersons': 30,
#   'global_id': 62367813,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 539,
#   'Name': 'Яна',
#   'NumberOfPersons': 29,
#   'global_id': 62367814,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 540,
#   'Name': 'Марина',
#   'NumberOfPersons': 29,
#   'global_id': 62367815,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 541,
#   'Name': 'Есения',
#   'NumberOfPersons': 28,
#   'global_id': 62367816,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 542,
#   'Name': 'Татьяна',
#   'NumberOfPersons': 27,
#   'global_id': 62367817,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 543,
#   'Name': 'Эмилия',
#   'NumberOfPersons': 27,
#   'global_id': 62367818,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 544,
#   'Name': 'Мирослава',
#   'NumberOfPersons': 26,
#   'global_id': 62367819,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 545,
#   'Name': 'Элина',
#   'NumberOfPersons': 26,
#   'global_id': 62367820,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 546,
#   'Name': 'Злата',
#   'NumberOfPersons': 26,
#   'global_id': 62367821,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 547,
#   'Name': 'Агата',
#   'NumberOfPersons': 25,
#   'global_id': 62367822,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 548,
#   'Name': 'Ирина',
#   'NumberOfPersons': 23,
#   'global_id': 62367823,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 549,
#   'Name': 'Ярослава',
#   'NumberOfPersons': 23,
#   'global_id': 62367824,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 550,
#   'Name': 'Сафия',
#   'NumberOfPersons': 23,
#   'global_id': 62367825,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 551,
#   'Name': 'Аделина',
#   'NumberOfPersons': 22,
#   'global_id': 62367826,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 552,
#   'Name': 'Марьям',
#   'NumberOfPersons': 20,
#   'global_id': 62367827,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 553,
#   'Name': 'Евдокия',
#   'NumberOfPersons': 18,
#   'global_id': 62367828,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 554,
#   'Name': 'Антонина',
#   'NumberOfPersons': 18,
#   'global_id': 62367829,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 555,
#   'Name': 'Ясмина',
#   'NumberOfPersons': 17,
#   'global_id': 62367830,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 556,
#   'Name': 'Любовь',
#   'NumberOfPersons': 17,
#   'global_id': 62367831,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 557,
#   'Name': 'Нина',
#   'NumberOfPersons': 17,
#   'global_id': 62367832,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 558,
#   'Name': 'Олеся',
#   'NumberOfPersons': 16,
#   'global_id': 62367834,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 559,
#   'Name': 'Светлана',
#   'NumberOfPersons': 16,
#   'global_id': 62367835,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 560,
#   'Name': 'Ника',
#   'NumberOfPersons': 16,
#   'global_id': 62367836,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 561,
#   'Name': 'Николь',
#   'NumberOfPersons': 16,
#   'global_id': 62367837,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 562,
#   'Name': 'Карина',
#   'NumberOfPersons': 15,
#   'global_id': 62367838,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 563,
#   'Name': 'Алия',
#   'NumberOfPersons': 15,
#   'global_id': 62367839,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 564,
#   'Name': 'Лидия',
#   'NumberOfPersons': 14,
#   'global_id': 62367840,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 565,
#   'Name': 'Дарина',
#   'NumberOfPersons': 13,
#   'global_id': 62367841,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 566,
#   'Name': 'Милена',
#   'NumberOfPersons': 13,
#   'global_id': 62367842,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 567,
#   'Name': 'Лилия',
#   'NumberOfPersons': 13,
#   'global_id': 62367843,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 568,
#   'Name': 'Марьяна',
#   'NumberOfPersons': 12,
#   'global_id': 62367844,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 569,
#   'Name': 'Лейла',
#   'NumberOfPersons': 12,
#   'global_id': 62367845,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 570,
#   'Name': 'Мила',
#   'NumberOfPersons': 12,
#   'global_id': 62367846,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 571,
#   'Name': 'Камилла',
#   'NumberOfPersons': 11,
#   'global_id': 62367847,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 572,
#   'Name': 'Камила',
#   'NumberOfPersons': 11,
#   'global_id': 62367848,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 573,
#   'Name': 'Зоя',
#   'NumberOfPersons': 11,
#   'global_id': 62367849,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 574,
#   'Name': 'Амелия',
#   'NumberOfPersons': 11,
#   'global_id': 62367850,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 575,
#   'Name': 'Фатима',
#   'NumberOfPersons': 11,
#   'global_id': 62367851,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 576,
#   'Name': 'Амалия',
#   'NumberOfPersons': 11,
#   'global_id': 62367852,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 577,
#   'Name': 'Ариана',
#   'NumberOfPersons': 10,
#   'global_id': 62367853,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 578,
#   'Name': 'Марианна',
#   'NumberOfPersons': 10,
#   'global_id': 62367854,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 579,
#   'Name': 'Виолетта',
#   'NumberOfPersons': 10,
#   'global_id': 62367855,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 580,
#   'Name': 'Каролина',
#   'NumberOfPersons': 10,
#   'global_id': 62367857,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 581,
#   'Name': 'Альбина',
#   'NumberOfPersons': 9,
#   'global_id': 62367858,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 582,
#   'Name': 'Аиша',
#   'NumberOfPersons': 9,
#   'global_id': 62367859,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 583,
#   'Name': 'Марта',
#   'NumberOfPersons': 9,
#   'global_id': 62367860,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 584,
#   'Name': 'Амира',
#   'NumberOfPersons': 9,
#   'global_id': 62367861,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 585,
#   'Name': 'Аглая',
#   'NumberOfPersons': 9,
#   'global_id': 62367862,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 586,
#   'Name': 'Самира',
#   'NumberOfPersons': 9,
#   'global_id': 62367863,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 587,
#   'Name': 'Эмма',
#   'NumberOfPersons': 9,
#   'global_id': 62367864,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 588,
#   'Name': 'Малика',
#   'NumberOfPersons': 8,
#   'global_id': 62367865,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 589,
#   'Name': 'Раяна',
#   'NumberOfPersons': 8,
#   'global_id': 62367866,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 590,
#   'Name': 'Эвелина',
#   'NumberOfPersons': 8,
#   'global_id': 62367867,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 591,
#   'Name': 'Наталья',
#   'NumberOfPersons': 8,
#   'global_id': 62367868,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 592,
#   'Name': 'Анжелика',
#   'NumberOfPersons': 8,
#   'global_id': 62367869,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 593,
#   'Name': 'Айлин',
#   'NumberOfPersons': 8,
#   'global_id': 62367870,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 594,
#   'Name': 'Асия',
#   'NumberOfPersons': 8,
#   'global_id': 62367871,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 595,
#   'Name': 'Аяна',
#   'NumberOfPersons': 8,
#   'global_id': 62367872,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 596,
#   'Name': 'Агния',
#   'NumberOfPersons': 8,
#   'global_id': 62367873,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 597,
#   'Name': 'Милослава',
#   'NumberOfPersons': 8,
#   'global_id': 62367874,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 598,
#   'Name': 'Евангелина',
#   'NumberOfPersons': 8,
#   'global_id': 62367875,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 599,
#   'Name': 'Алисия',
#   'NumberOfPersons': 7,
#   'global_id': 62367876,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 600,
#   'Name': 'Сабина',
#   'NumberOfPersons': 7,
#   'global_id': 62367877,
#   'Year': 2015,
#   'Month': 'июнь'},
#  {'ID': 601,
#   'Name': 'Мария',
#   'NumberOfPersons': 331,
#   'global_id': 62367878,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 602,
#   'Name': 'Анна',
#   'NumberOfPersons': 287,
#   'global_id': 62367879,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 603,
#   'Name': 'Анастасия',
#   'NumberOfPersons': 270,
#   'global_id': 62367880,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 604,
#   'Name': 'София',
#   'NumberOfPersons': 230,
#   'global_id': 62367881,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 605,
#   'Name': 'Виктория',
#   'NumberOfPersons': 226,
#   'global_id': 62367882,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 606,
#   'Name': 'Елизавета',
#   'NumberOfPersons': 218,
#   'global_id': 62367883,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 607,
#   'Name': 'Александра',
#   'NumberOfPersons': 214,
#   'global_id': 62367884,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 608,
#   'Name': 'Полина',
#   'NumberOfPersons': 203,
#   'global_id': 62367885,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 609,
#   'Name': 'Алиса',
#   'NumberOfPersons': 200,
#   'global_id': 62367886,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 610,
#   'Name': 'Варвара',
#   'NumberOfPersons': 191,
#   'global_id': 62367887,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 611,
#   'Name': 'Дарья',
#   'NumberOfPersons': 179,
#   'global_id': 62367888,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 612,
#   'Name': 'Екатерина',
#   'NumberOfPersons': 172,
#   'global_id': 62367889,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 613,
#   'Name': 'Арина',
#   'NumberOfPersons': 149,
#   'global_id': 62367890,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 614,
#   'Name': 'Софья',
#   'NumberOfPersons': 138,
#   'global_id': 62367891,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 615,
#   'Name': 'Ксения',
#   'NumberOfPersons': 133,
#   'global_id': 62367892,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 616,
#   'Name': 'Вероника',
#   'NumberOfPersons': 128,
#   'global_id': 62367893,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 617,
#   'Name': 'Василиса',
#   'NumberOfPersons': 124,
#   'global_id': 62367894,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 618,
#   'Name': 'Валерия',
#   'NumberOfPersons': 122,
#   'global_id': 62367895,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 619,
#   'Name': 'Милана',
#   'NumberOfPersons': 121,
#   'global_id': 62367896,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 620,
#   'Name': 'Ульяна',
#   'NumberOfPersons': 121,
#   'global_id': 62367897,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 621,
#   'Name': 'Ева',
#   'NumberOfPersons': 107,
#   'global_id': 62367898,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 622,
#   'Name': 'Маргарита',
#   'NumberOfPersons': 82,
#   'global_id': 62367899,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 623,
#   'Name': 'Вера',
#   'NumberOfPersons': 81,
#   'global_id': 62367900,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 624,
#   'Name': 'Алёна',
#   'NumberOfPersons': 79,
#   'global_id': 62367901,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 625,
#   'Name': 'Ольга',
#   'NumberOfPersons': 75,
#   'global_id': 62367902,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 626,
#   'Name': 'Кира',
#   'NumberOfPersons': 74,
#   'global_id': 62367903,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 627,
#   'Name': 'Кристина',
#   'NumberOfPersons': 65,
#   'global_id': 62367904,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 628,
#   'Name': 'Юлия',
#   'NumberOfPersons': 61,
#   'global_id': 62367905,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 629,
#   'Name': 'Ангелина',
#   'NumberOfPersons': 58,
#   'global_id': 62367906,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 630,
#   'Name': 'Алина',
#   'NumberOfPersons': 58,
#   'global_id': 62367907,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 631,
#   'Name': 'Таисия',
#   'NumberOfPersons': 55,
#   'global_id': 62367908,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 632,
#   'Name': 'Диана',
#   'NumberOfPersons': 49,
#   'global_id': 62367909,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 633,
#   'Name': 'Амина',
#   'NumberOfPersons': 46,
#   'global_id': 62367911,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 634,
#   'Name': 'Яна',
#   'NumberOfPersons': 44,
#   'global_id': 62367912,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 635,
#   'Name': 'Евгения',
#   'NumberOfPersons': 42,
#   'global_id': 62367913,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 636,
#   'Name': 'Мирослава',
#   'NumberOfPersons': 40,
#   'global_id': 62367914,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 637,
#   'Name': 'Сафия',
#   'NumberOfPersons': 34,
#   'global_id': 62367915,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 638,
#   'Name': 'Ирина',
#   'NumberOfPersons': 29,
#   'global_id': 62367916,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 639,
#   'Name': 'Надежда',
#   'NumberOfPersons': 29,
#   'global_id': 62367917,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 640,
#   'Name': 'Елена',
#   'NumberOfPersons': 28,
#   'global_id': 62367918,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 641,
#   'Name': 'Стефания',
#   'NumberOfPersons': 28,
#   'global_id': 62367919,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 642,
#   'Name': 'Татьяна',
#   'NumberOfPersons': 26,
#   'global_id': 62367920,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 643,
#   'Name': 'Марина',
#   'NumberOfPersons': 26,
#   'global_id': 62367921,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 644,
#   'Name': 'Ника',
#   'NumberOfPersons': 26,
#   'global_id': 62367922,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 645,
#   'Name': 'Аделина',
#   'NumberOfPersons': 25,
#   'global_id': 62367924,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 646,
#   'Name': 'Майя',
#   'NumberOfPersons': 25,
#   'global_id': 62367925,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 647,
#   'Name': 'Элина',
#   'NumberOfPersons': 24,
#   'global_id': 62367926,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 648,
#   'Name': 'Эмилия',
#   'NumberOfPersons': 24,
#   'global_id': 62367927,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 649,
#   'Name': 'Олеся',
#   'NumberOfPersons': 22,
#   'global_id': 62367928,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 650,
#   'Name': 'Ясмина',
#   'NumberOfPersons': 22,
#   'global_id': 62367929,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 651,
#   'Name': 'Агата',
#   'NumberOfPersons': 22,
#   'global_id': 62367930,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 652,
#   'Name': 'Марьям',
#   'NumberOfPersons': 22,
#   'global_id': 62367931,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 653,
#   'Name': 'Аиша',
#   'NumberOfPersons': 21,
#   'global_id': 62367932,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 654,
#   'Name': 'Ярослава',
#   'NumberOfPersons': 20,
#   'global_id': 62367933,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 655,
#   'Name': 'Милена',
#   'NumberOfPersons': 20,
#   'global_id': 62367934,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 656,
#   'Name': 'Злата',
#   'NumberOfPersons': 19,
#   'global_id': 62367936,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 657,
#   'Name': 'Дарина',
#   'NumberOfPersons': 18,
#   'global_id': 62367937,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 658,
#   'Name': 'Любовь',
#   'NumberOfPersons': 18,
#   'global_id': 62367938,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 659,
#   'Name': 'Есения',
#   'NumberOfPersons': 18,
#   'global_id': 62367939,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 660,
#   'Name': 'Антонина',
#   'NumberOfPersons': 15,
#   'global_id': 62367940,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 661,
#   'Name': 'Камилла',
#   'NumberOfPersons': 15,
#   'global_id': 62367941,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 662,
#   'Name': 'Алия',
#   'NumberOfPersons': 14,
#   'global_id': 62367942,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 663,
#   'Name': 'Мила',
#   'NumberOfPersons': 14,
#   'global_id': 62367943,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 664,
#   'Name': 'Каролина',
#   'NumberOfPersons': 14,
#   'global_id': 62367944,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 665,
#   'Name': 'Агния',
#   'NumberOfPersons': 14,
#   'global_id': 62367945,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 666,
#   'Name': 'Эвелина',
#   'NumberOfPersons': 14,
#   'global_id': 62367946,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 667,
#   'Name': 'Светлана',
#   'NumberOfPersons': 14,
#   'global_id': 62367947,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 668,
#   'Name': 'Зоя',
#   'NumberOfPersons': 14,
#   'global_id': 62367948,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 669,
#   'Name': 'Камила',
#   'NumberOfPersons': 13,
#   'global_id': 62367949,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 670,
#   'Name': 'Евангелина',
#   'NumberOfPersons': 12,
#   'global_id': 62367950,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 671,
#   'Name': 'Владислава',
#   'NumberOfPersons': 12,
#   'global_id': 62367951,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 672,
#   'Name': 'Амелия',
#   'NumberOfPersons': 12,
#   'global_id': 62367952,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 673,
#   'Name': 'Лилия',
#   'NumberOfPersons': 12,
#   'global_id': 62367953,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 674,
#   'Name': 'Нина',
#   'NumberOfPersons': 12,
#   'global_id': 62367954,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 675,
#   'Name': 'Раяна',
#   'NumberOfPersons': 12,
#   'global_id': 62367955,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 676,
#   'Name': 'Марианна',
#   'NumberOfPersons': 11,
#   'global_id': 62367956,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 677,
#   'Name': 'Валентина',
#   'NumberOfPersons': 11,
#   'global_id': 62367957,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 678,
#   'Name': 'Карина',
#   'NumberOfPersons': 11,
#   'global_id': 62367958,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 679,
#   'Name': 'Лейла',
#   'NumberOfPersons': 11,
#   'global_id': 62367959,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 680,
#   'Name': 'Николь',
#   'NumberOfPersons': 11,
#   'global_id': 62367960,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 681,
#   'Name': 'Айлин',
#   'NumberOfPersons': 10,
#   'global_id': 62367961,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 682,
#   'Name': 'Юлиана',
#   'NumberOfPersons': 10,
#   'global_id': 62367962,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 683,
#   'Name': 'Малика',
#   'NumberOfPersons': 10,
#   'global_id': 62367964,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 684,
#   'Name': 'Ариана',
#   'NumberOfPersons': 9,
#   'global_id': 62367965,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 685,
#   'Name': 'Наталья',
#   'NumberOfPersons': 9,
#   'global_id': 62367966,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 686,
#   'Name': 'Анжелика',
#   'NumberOfPersons': 9,
#   'global_id': 62367967,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 687,
#   'Name': 'Мира',
#   'NumberOfPersons': 9,
#   'global_id': 62367968,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 688,
#   'Name': 'Марьяна',
#   'NumberOfPersons': 9,
#   'global_id': 62367969,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 689,
#   'Name': 'Самира',
#   'NumberOfPersons': 9,
#   'global_id': 62367970,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 690,
#   'Name': 'Виолетта',
#   'NumberOfPersons': 9,
#   'global_id': 62367971,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 691,
#   'Name': 'Мадина',
#   'NumberOfPersons': 9,
#   'global_id': 62367972,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 692,
#   'Name': 'Аглая',
#   'NumberOfPersons': 9,
#   'global_id': 62367973,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 693,
#   'Name': 'Лада',
#   'NumberOfPersons': 9,
#   'global_id': 62367974,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 694,
#   'Name': 'Лидия',
#   'NumberOfPersons': 9,
#   'global_id': 62367975,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 695,
#   'Name': 'Наталия',
#   'NumberOfPersons': 9,
#   'global_id': 62367976,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 696,
#   'Name': 'Евдокия',
#   'NumberOfPersons': 8,
#   'global_id': 62367977,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 697,
#   'Name': 'Марта',
#   'NumberOfPersons': 8,
#   'global_id': 62367978,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 698,
#   'Name': 'Алсу',
#   'NumberOfPersons': 8,
#   'global_id': 62367979,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 699,
#   'Name': 'Зарина',
#   'NumberOfPersons': 8,
#   'global_id': 62367980,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 700,
#   'Name': 'Амира',
#   'NumberOfPersons': 8,
#   'global_id': 62367981,
#   'Year': 2015,
#   'Month': 'июль'},
#  {'ID': 701,
#   'Name': 'Мария',
#   'NumberOfPersons': 312,
#   'global_id': 62367982,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 702,
#   'Name': 'Анна',
#   'NumberOfPersons': 257,
#   'global_id': 62367983,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 703,
#   'Name': 'София',
#   'NumberOfPersons': 225,
#   'global_id': 62367984,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 704,
#   'Name': 'Анастасия',
#   'NumberOfPersons': 216,
#   'global_id': 62367985,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 705,
#   'Name': 'Елизавета',
#   'NumberOfPersons': 202,
#   'global_id': 62367986,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 706,
#   'Name': 'Виктория',
#   'NumberOfPersons': 201,
#   'global_id': 62367987,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 707,
#   'Name': 'Полина',
#   'NumberOfPersons': 192,
#   'global_id': 62367988,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 708,
#   'Name': 'Дарья',
#   'NumberOfPersons': 187,
#   'global_id': 62367989,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 709,
#   'Name': 'Алиса',
#   'NumberOfPersons': 180,
#   'global_id': 62367990,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 710,
#   'Name': 'Александра',
#   'NumberOfPersons': 159,
#   'global_id': 62367991,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 711,
#   'Name': 'Арина',
#   'NumberOfPersons': 149,
#   'global_id': 62367993,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 712,
#   'Name': 'Екатерина',
#   'NumberOfPersons': 148,
#   'global_id': 62367994,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 713,
#   'Name': 'Ксения',
#   'NumberOfPersons': 140,
#   'global_id': 62367995,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 714,
#   'Name': 'Вероника',
#   'NumberOfPersons': 133,
#   'global_id': 62367996,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 715,
#   'Name': 'Варвара',
#   'NumberOfPersons': 132,
#   'global_id': 62367997,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 716,
#   'Name': 'Милана',
#   'NumberOfPersons': 109,
#   'global_id': 62367998,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 717,
#   'Name': 'Василиса',
#   'NumberOfPersons': 100,
#   'global_id': 62367999,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 718,
#   'Name': 'Валерия',
#   'NumberOfPersons': 97,
#   'global_id': 62368000,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 719,
#   'Name': 'Ева',
#   'NumberOfPersons': 97,
#   'global_id': 62368001,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 720,
#   'Name': 'Софья',
#   'NumberOfPersons': 94,
#   'global_id': 62368002,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 721,
#   'Name': 'Ульяна',
#   'NumberOfPersons': 90,
#   'global_id': 62368003,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 722,
#   'Name': 'Маргарита',
#   'NumberOfPersons': 81,
#   'global_id': 62368004,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 723,
#   'Name': 'Кира',
#   'NumberOfPersons': 76,
#   'global_id': 62368005,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 724,
#   'Name': 'Кристина',
#   'NumberOfPersons': 68,
#   'global_id': 62368006,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 725,
#   'Name': 'Ольга',
#   'NumberOfPersons': 68,
#   'global_id': 62368007,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 726,
#   'Name': 'Таисия',
#   'NumberOfPersons': 64,
#   'global_id': 62368008,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 727,
#   'Name': 'Алёна',
#   'NumberOfPersons': 61,
#   'global_id': 62368009,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 728,
#   'Name': 'Диана',
#   'NumberOfPersons': 61,
#   'global_id': 62368010,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 729,
#   'Name': 'Юлия',
#   'NumberOfPersons': 60,
#   'global_id': 62368011,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 730,
#   'Name': 'Алина',
#   'NumberOfPersons': 56,
#   'global_id': 62368012,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 731,
#   'Name': 'Вера',
#   'NumberOfPersons': 55,
#   'global_id': 62368013,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 732,
#   'Name': 'Мирослава',
#   'NumberOfPersons': 51,
#   'global_id': 62368014,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 733,
#   'Name': 'Ангелина',
#   'NumberOfPersons': 50,
#   'global_id': 62368015,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 734,
#   'Name': 'Амина',
#   'NumberOfPersons': 49,
#   'global_id': 62368016,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 735,
#   'Name': 'Злата',
#   'NumberOfPersons': 32,
#   'global_id': 62368017,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 736,
#   'Name': 'Елена',
#   'NumberOfPersons': 31,
#   'global_id': 62368018,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 737,
#   'Name': 'Яна',
#   'NumberOfPersons': 31,
#   'global_id': 62368019,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 738,
#   'Name': 'Евгения',
#   'NumberOfPersons': 30,
#   'global_id': 62368020,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 739,
#   'Name': 'Татьяна',
#   'NumberOfPersons': 30,
#   'global_id': 62368021,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 740,
#   'Name': 'Ирина',
#   'NumberOfPersons': 27,
#   'global_id': 62368022,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 741,
#   'Name': 'Сафия',
#   'NumberOfPersons': 27,
#   'global_id': 62368023,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 742,
#   'Name': 'Аделина',
#   'NumberOfPersons': 25,
#   'global_id': 62368024,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 743,
#   'Name': 'Есения',
#   'NumberOfPersons': 25,
#   'global_id': 62368025,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 744,
#   'Name': 'Элина',
#   'NumberOfPersons': 23,
#   'global_id': 62368026,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 745,
#   'Name': 'Майя',
#   'NumberOfPersons': 22,
#   'global_id': 62368027,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 746,
#   'Name': 'Стефания',
#   'NumberOfPersons': 22,
#   'global_id': 62368028,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 747,
#   'Name': 'Марина',
#   'NumberOfPersons': 21,
#   'global_id': 62368029,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 748,
#   'Name': 'Камилла',
#   'NumberOfPersons': 19,
#   'global_id': 62368030,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 749,
#   'Name': 'Милена',
#   'NumberOfPersons': 19,
#   'global_id': 62368031,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 750,
#   'Name': 'Надежда',
#   'NumberOfPersons': 19,
#   'global_id': 62368032,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 751,
#   'Name': 'Нина',
#   'NumberOfPersons': 19,
#   'global_id': 62368033,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 752,
#   'Name': 'Эмилия',
#   'NumberOfPersons': 19,
#   'global_id': 62368034,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 753,
#   'Name': 'Агата',
#   'NumberOfPersons': 18,
#   'global_id': 62368036,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 754,
#   'Name': 'Светлана',
#   'NumberOfPersons': 18,
#   'global_id': 62368037,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 755,
#   'Name': 'Любовь',
#   'NumberOfPersons': 17,
#   'global_id': 62368038,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 756,
#   'Name': 'Ярослава',
#   'NumberOfPersons': 17,
#   'global_id': 62368039,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 757,
#   'Name': 'Агния',
#   'NumberOfPersons': 16,
#   'global_id': 62368040,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 758,
#   'Name': 'Ника',
#   'NumberOfPersons': 16,
#   'global_id': 62368041,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 759,
#   'Name': 'Лилия',
#   'NumberOfPersons': 15,
#   'global_id': 62368042,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 760,
#   'Name': 'Малика',
#   'NumberOfPersons': 15,
#   'global_id': 62368043,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 761,
#   'Name': 'Марьям',
#   'NumberOfPersons': 15,
#   'global_id': 62368044,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 762,
#   'Name': 'Николь',
#   'NumberOfPersons': 15,
#   'global_id': 62368045,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 763,
#   'Name': 'Амелия',
#   'NumberOfPersons': 14,
#   'global_id': 62368046,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 764,
#   'Name': 'Антонина',
#   'NumberOfPersons': 14,
#   'global_id': 62368047,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 765,
#   'Name': 'Алия',
#   'NumberOfPersons': 13,
#   'global_id': 62368048,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 766,
#   'Name': 'Евангелина',
#   'NumberOfPersons': 13,
#   'global_id': 62368049,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 767,
#   'Name': 'Олеся',
#   'NumberOfPersons': 13,
#   'global_id': 62368050,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 768,
#   'Name': 'Ясмина',
#   'NumberOfPersons': 13,
#   'global_id': 62368051,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 769,
#   'Name': 'Валентина',
#   'NumberOfPersons': 12,
#   'global_id': 62368052,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 770,
#   'Name': 'Виолетта',
#   'NumberOfPersons': 12,
#   'global_id': 62368053,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 771,
#   'Name': 'Мадина',
#   'NumberOfPersons': 12,
#   'global_id': 62368054,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 772,
#   'Name': 'Самира',
#   'NumberOfPersons': 12,
#   'global_id': 62368055,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 773,
#   'Name': 'Дарина',
#   'NumberOfPersons': 11,
#   'global_id': 62368056,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 774,
#   'Name': 'Зоя',
#   'NumberOfPersons': 11,
#   'global_id': 62368057,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 775,
#   'Name': 'Камила',
#   'NumberOfPersons': 11,
#   'global_id': 62368058,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 776,
#   'Name': 'Марианна',
#   'NumberOfPersons': 11,
#   'global_id': 62368060,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 777,
#   'Name': 'Мила',
#   'NumberOfPersons': 11,
#   'global_id': 62368061,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 778,
#   'Name': 'Ариана',
#   'NumberOfPersons': 10,
#   'global_id': 62368062,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 779,
#   'Name': 'Карина',
#   'NumberOfPersons': 10,
#   'global_id': 62368063,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 780,
#   'Name': 'Оливия',
#   'NumberOfPersons': 10,
#   'global_id': 62368064,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 781,
#   'Name': 'Дана',
#   'NumberOfPersons': 9,
#   'global_id': 62368065,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 782,
#   'Name': 'Марьяна',
#   'NumberOfPersons': 9,
#   'global_id': 62368066,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 783,
#   'Name': 'Наталия',
#   'NumberOfPersons': 9,
#   'global_id': 62368067,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 784,
#   'Name': 'Серафима',
#   'NumberOfPersons': 9,
#   'global_id': 62368068,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 785,
#   'Name': 'Альбина',
#   'NumberOfPersons': 8,
#   'global_id': 62368069,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 786,
#   'Name': 'Аиша',
#   'NumberOfPersons': 8,
#   'global_id': 62368070,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 787,
#   'Name': 'Евдокия',
#   'NumberOfPersons': 8,
#   'global_id': 62368071,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 788,
#   'Name': 'Лада',
#   'NumberOfPersons': 8,
#   'global_id': 62368072,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 789,
#   'Name': 'Мариам',
#   'NumberOfPersons': 8,
#   'global_id': 62368073,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 790,
#   'Name': 'Марта',
#   'NumberOfPersons': 8,
#   'global_id': 62368074,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 791,
#   'Name': 'Мира',
#   'NumberOfPersons': 8,
#   'global_id': 62368075,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 792,
#   'Name': 'Наталья',
#   'NumberOfPersons': 8,
#   'global_id': 62368076,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 793,
#   'Name': 'Пелагея',
#   'NumberOfPersons': 8,
#   'global_id': 62368077,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 794,
#   'Name': 'Раяна',
#   'NumberOfPersons': 8,
#   'global_id': 62368078,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 795,
#   'Name': 'Тамара',
#   'NumberOfPersons': 8,
#   'global_id': 62368079,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 796,
#   'Name': 'Аглая',
#   'NumberOfPersons': 7,
#   'global_id': 62368080,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 797,
#   'Name': 'Лидия',
#   'NumberOfPersons': 7,
#   'global_id': 62368081,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 798,
#   'Name': 'Лина',
#   'NumberOfPersons': 7,
#   'global_id': 62368082,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 799,
#   'Name': 'Медина',
#   'NumberOfPersons': 7,
#   'global_id': 62368083,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 800,
#   'Name': 'Мелания',
#   'NumberOfPersons': 7,
#   'global_id': 62368084,
#   'Year': 2015,
#   'Month': 'август'},
#  {'ID': 801,
#   'Name': 'Мария',
#   'NumberOfPersons': 305,
#   'global_id': 62368085,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 802,
#   'Name': 'София',
#   'NumberOfPersons': 252,
#   'global_id': 62368086,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 803,
#   'Name': 'Анна',
#   'NumberOfPersons': 244,
#   'global_id': 62368087,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 804,
#   'Name': 'Виктория',
#   'NumberOfPersons': 223,
#   'global_id': 62368088,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 805,
#   'Name': 'Алиса',
#   'NumberOfPersons': 189,
#   'global_id': 62368089,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 806,
#   'Name': 'Анастасия',
#   'NumberOfPersons': 188,
#   'global_id': 62368090,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 807,
#   'Name': 'Полина',
#   'NumberOfPersons': 184,
#   'global_id': 62368091,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 808,
#   'Name': 'Елизавета',
#   'NumberOfPersons': 180,
#   'global_id': 62368092,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 809,
#   'Name': 'Дарья',
#   'NumberOfPersons': 167,
#   'global_id': 62368093,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 810,
#   'Name': 'Ксения',
#   'NumberOfPersons': 153,
#   'global_id': 62368094,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 811,
#   'Name': 'Арина',
#   'NumberOfPersons': 146,
#   'global_id': 62368095,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 812,
#   'Name': 'Варвара',
#   'NumberOfPersons': 140,
#   'global_id': 62368096,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 813,
#   'Name': 'Александра',
#   'NumberOfPersons': 134,
#   'global_id': 62368097,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 814,
#   'Name': 'Екатерина',
#   'NumberOfPersons': 130,
#   'global_id': 62368098,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 815,
#   'Name': 'Василиса',
#   'NumberOfPersons': 126,
#   'global_id': 62368099,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 816,
#   'Name': 'Валерия',
#   'NumberOfPersons': 114,
#   'global_id': 62368100,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 817,
#   'Name': 'Софья',
#   'NumberOfPersons': 109,
#   'global_id': 62368101,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 818,
#   'Name': 'Вероника',
#   'NumberOfPersons': 107,
#   'global_id': 62368102,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 819,
#   'Name': 'Милана',
#   'NumberOfPersons': 103,
#   'global_id': 62368103,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 820,
#   'Name': 'Ева',
#   'NumberOfPersons': 101,
#   'global_id': 62368104,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 821,
#   'Name': 'Вера',
#   'NumberOfPersons': 85,
#   'global_id': 62368105,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 822,
#   'Name': 'Кристина',
#   'NumberOfPersons': 73,
#   'global_id': 62368106,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 823,
#   'Name': 'Ульяна',
#   'NumberOfPersons': 72,
#   'global_id': 62368108,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 824,
#   'Name': 'Кира',
#   'NumberOfPersons': 70,
#   'global_id': 62368109,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 825,
#   'Name': 'Диана',
#   'NumberOfPersons': 68,
#   'global_id': 62368110,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 826,
#   'Name': 'Алёна',
#   'NumberOfPersons': 62,
#   'global_id': 62368111,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 827,
#   'Name': 'Маргарита',
#   'NumberOfPersons': 62,
#   'global_id': 62368112,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 828,
#   'Name': 'Алина',
#   'NumberOfPersons': 59,
#   'global_id': 62368113,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 829,
#   'Name': 'Мирослава',
#   'NumberOfPersons': 46,
#   'global_id': 62368114,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 830,
#   'Name': 'Амина',
#   'NumberOfPersons': 42,
#   'global_id': 62368115,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 831,
#   'Name': 'Таисия',
#   'NumberOfPersons': 41,
#   'global_id': 62368117,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 832,
#   'Name': 'Юлия',
#   'NumberOfPersons': 40,
#   'global_id': 62368118,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 833,
#   'Name': 'Ангелина',
#   'NumberOfPersons': 39,
#   'global_id': 62368119,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 834,
#   'Name': 'Ольга',
#   'NumberOfPersons': 39,
#   'global_id': 62368120,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 835,
#   'Name': 'Ирина',
#   'NumberOfPersons': 34,
#   'global_id': 62368121,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 836,
#   'Name': 'Татьяна',
#   'NumberOfPersons': 33,
#   'global_id': 62368122,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 837,
#   'Name': 'Яна',
#   'NumberOfPersons': 33,
#   'global_id': 62368123,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 838,
#   'Name': 'Евгения',
#   'NumberOfPersons': 32,
#   'global_id': 62368125,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 839,
#   'Name': 'Стефания',
#   'NumberOfPersons': 29,
#   'global_id': 62368126,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 840,
#   'Name': 'Злата',
#   'NumberOfPersons': 27,
#   'global_id': 62368127,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 841,
#   'Name': 'Сафия',
#   'NumberOfPersons': 27,
#   'global_id': 62368128,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 842,
#   'Name': 'Марьям',
#   'NumberOfPersons': 25,
#   'global_id': 62368129,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 843,
#   'Name': 'Любовь',
#   'NumberOfPersons': 24,
#   'global_id': 62368130,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 844,
#   'Name': 'Милена',
#   'NumberOfPersons': 24,
#   'global_id': 62368131,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 845,
#   'Name': 'Елена',
#   'NumberOfPersons': 23,
#   'global_id': 62368133,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 846,
#   'Name': 'Эмилия',
#   'NumberOfPersons': 23,
#   'global_id': 62368134,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 847,
#   'Name': 'Лидия',
#   'NumberOfPersons': 22,
#   'global_id': 62368135,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 848,
#   'Name': 'Ярослава',
#   'NumberOfPersons': 22,
#   'global_id': 62368136,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 849,
#   'Name': 'Марина',
#   'NumberOfPersons': 20,
#   'global_id': 62368137,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 850,
#   'Name': 'Элина',
#   'NumberOfPersons': 18,
#   'global_id': 62368138,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 851,
#   'Name': 'Надежда',
#   'NumberOfPersons': 17,
#   'global_id': 62368139,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 852,
#   'Name': 'Амелия',
#   'NumberOfPersons': 15,
#   'global_id': 62368141,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 853,
#   'Name': 'Агата',
#   'NumberOfPersons': 15,
#   'global_id': 62368142,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 854,
#   'Name': 'Есения',
#   'NumberOfPersons': 15,
#   'global_id': 62368143,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 855,
#   'Name': 'Майя',
#   'NumberOfPersons': 15,
#   'global_id': 62368144,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 856,
#   'Name': 'Анфиса',
#   'NumberOfPersons': 14,
#   'global_id': 62368145,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 857,
#   'Name': 'Дарина',
#   'NumberOfPersons': 14,
#   'global_id': 62368146,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 858,
#   'Name': 'Олеся',
#   'NumberOfPersons': 14,
#   'global_id': 62368147,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 859,
#   'Name': 'Светлана',
#   'NumberOfPersons': 14,
#   'global_id': 62368148,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 860,
#   'Name': 'Фатима',
#   'NumberOfPersons': 14,
#   'global_id': 62368149,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 861,
#   'Name': 'Ясмина',
#   'NumberOfPersons': 14,
#   'global_id': 62368150,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 862,
#   'Name': 'Агния',
#   'NumberOfPersons': 13,
#   'global_id': 62368151,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 863,
#   'Name': 'Каролина',
#   'NumberOfPersons': 13,
#   'global_id': 62368152,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 864,
#   'Name': 'Наталья',
#   'NumberOfPersons': 13,
#   'global_id': 62368153,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 865,
#   'Name': 'Аделина',
#   'NumberOfPersons': 12,
#   'global_id': 62368154,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 866,
#   'Name': 'Лилия',
#   'NumberOfPersons': 12,
#   'global_id': 62368155,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 867,
#   'Name': 'Мила',
#   'NumberOfPersons': 12,
#   'global_id': 62368156,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 868,
#   'Name': 'Ника',
#   'NumberOfPersons': 12,
#   'global_id': 62368157,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 869,
#   'Name': 'Нина',
#   'NumberOfPersons': 12,
#   'global_id': 62368158,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 870,
#   'Name': 'Аиша',
#   'NumberOfPersons': 11,
#   'global_id': 62368159,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 871,
#   'Name': 'Амира',
#   'NumberOfPersons': 11,
#   'global_id': 62368160,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 872,
#   'Name': 'Ариана',
#   'NumberOfPersons': 11,
#   'global_id': 62368161,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 873,
#   'Name': 'Виолетта',
#   'NumberOfPersons': 11,
#   'global_id': 62368162,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 874,
#   'Name': 'Евдокия',
#   'NumberOfPersons': 11,
#   'global_id': 62368163,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 875,
#   'Name': 'Камила',
#   'NumberOfPersons': 11,
#   'global_id': 62368164,
#   'Year': 2015,
#   'Month': 'сентябрь'},
#  {'ID': 876,
#   'Name': 'Карина',
#   'NumberOfPersons': 11,
#   'global_id': 62368165,
#   'Year': 2015,
# ...
#   'Name': 'Милена',
#   'NumberOfPersons': 16,
#   'global_id': 62368660,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 251,
#   'Name': 'Евдокия',
#   'NumberOfPersons': 16,
#   'global_id': 62368661,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 252,
#   'Name': 'Дарина',
#   'NumberOfPersons': 16,
#   'global_id': 62368662,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 253,
#   'Name': 'Ясмина',
#   'NumberOfPersons': 16,
#   'global_id': 62368663,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 254,
#   'Name': 'Стефания',
#   'NumberOfPersons': 15,
#   'global_id': 62368664,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 255,
#   'Name': 'Марианна',
#   'NumberOfPersons': 15,
#   'global_id': 62368665,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 256,
#   'Name': 'Есения',
#   'NumberOfPersons': 15,
#   'global_id': 62368666,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 257,
#   'Name': 'Зоя',
#   'NumberOfPersons': 15,
#   'global_id': 62368667,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 258,
#   'Name': 'Валентина',
#   'NumberOfPersons': 15,
#   'global_id': 62368668,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 259,
#   'Name': 'Владислава',
#   'NumberOfPersons': 15,
#   'global_id': 62368669,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 260,
#   'Name': 'Агния',
#   'NumberOfPersons': 15,
#   'global_id': 62368670,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 261,
#   'Name': 'Майя',
#   'NumberOfPersons': 15,
#   'global_id': 62368671,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 262,
#   'Name': 'Ярослава',
#   'NumberOfPersons': 15,
#   'global_id': 62368672,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 263,
#   'Name': 'Агата',
#   'NumberOfPersons': 14,
#   'global_id': 62368673,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 264,
#   'Name': 'Раяна',
#   'NumberOfPersons': 14,
#   'global_id': 62368674,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 265,
#   'Name': 'Нина',
#   'NumberOfPersons': 13,
#   'global_id': 62368675,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 266,
#   'Name': 'Эмилия',
#   'NumberOfPersons': 13,
#   'global_id': 62368676,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 267,
#   'Name': 'Алия',
#   'NumberOfPersons': 13,
#   'global_id': 62368677,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 268,
#   'Name': 'Самира',
#   'NumberOfPersons': 12,
#   'global_id': 62368678,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 269,
#   'Name': 'Сафия',
#   'NumberOfPersons': 12,
#   'global_id': 62368679,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 270,
#   'Name': 'Лилия',
#   'NumberOfPersons': 12,
#   'global_id': 62368680,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 271,
#   'Name': 'Антонина',
#   'NumberOfPersons': 12,
#   'global_id': 62368681,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 272,
#   'Name': 'Малика',
#   'NumberOfPersons': 11,
#   'global_id': 62368682,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 273,
#   'Name': 'Наталья',
#   'NumberOfPersons': 11,
#   'global_id': 62368683,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 274,
#   'Name': 'Амелия',
#   'NumberOfPersons': 11,
#   'global_id': 62368685,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 275,
#   'Name': 'Мадина',
#   'NumberOfPersons': 10,
#   'global_id': 62368686,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 276,
#   'Name': 'Лада',
#   'NumberOfPersons': 10,
#   'global_id': 62368687,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 277,
#   'Name': 'Сабина',
#   'NumberOfPersons': 10,
#   'global_id': 62368688,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 278,
#   'Name': 'Лидия',
#   'NumberOfPersons': 10,
#   'global_id': 62368690,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 279,
#   'Name': 'Камилла',
#   'NumberOfPersons': 10,
#   'global_id': 62368691,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 280,
#   'Name': 'Аниса',
#   'NumberOfPersons': 10,
#   'global_id': 62368692,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 281,
#   'Name': 'Карина',
#   'NumberOfPersons': 9,
#   'global_id': 62368693,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 282,
#   'Name': 'Ариана',
#   'NumberOfPersons': 9,
#   'global_id': 62368695,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 283,
#   'Name': 'Виолетта',
#   'NumberOfPersons': 9,
#   'global_id': 62368696,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 284,
#   'Name': 'Марьяна',
#   'NumberOfPersons': 9,
#   'global_id': 62368697,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 285,
#   'Name': 'Юлиана',
#   'NumberOfPersons': 8,
#   'global_id': 62368698,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 286,
#   'Name': 'Алеся',
#   'NumberOfPersons': 8,
#   'global_id': 62368700,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 287,
#   'Name': 'Любовь',
#   'NumberOfPersons': 8,
#   'global_id': 62368701,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 288,
#   'Name': 'Мила',
#   'NumberOfPersons': 8,
#   'global_id': 62368702,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 289,
#   'Name': 'Серафима',
#   'NumberOfPersons': 8,
#   'global_id': 62368703,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 290,
#   'Name': 'Камила',
#   'NumberOfPersons': 7,
#   'global_id': 62368705,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 291,
#   'Name': 'Альбина',
#   'NumberOfPersons': 7,
#   'global_id': 62368706,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 292,
#   'Name': 'Марьям',
#   'NumberOfPersons': 7,
#   'global_id': 62368707,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 293,
#   'Name': 'Станислава',
#   'NumberOfPersons': 7,
#   'global_id': 62368708,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 294,
#   'Name': 'Амира',
#   'NumberOfPersons': 7,
#   'global_id': 62368709,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 295,
#   'Name': 'Пелагея',
#   'NumberOfPersons': 7,
#   'global_id': 62368710,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 296,
#   'Name': 'Жасмина',
#   'NumberOfPersons': 6,
#   'global_id': 62368711,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 297,
#   'Name': 'Арууке',
#   'NumberOfPersons': 6,
#   'global_id': 62368712,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 298,
#   'Name': 'Эмма',
#   'NumberOfPersons': 6,
#   'global_id': 62368713,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 299,
#   'Name': 'Аделя',
#   'NumberOfPersons': 6,
#   'global_id': 62368714,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 300,
#   'Name': 'Дана',
#   'NumberOfPersons': 6,
#   'global_id': 62368715,
#   'Year': 2015,
#   'Month': 'март'},
#  {'ID': 301,
#   'Name': 'Мария',
#   'NumberOfPersons': 314,
#   'global_id': 62368716,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 302,
#   'Name': 'Анастасия',
#   'NumberOfPersons': 214,
#   'global_id': 62368717,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 303,
#   'Name': 'София',
#   'NumberOfPersons': 206,
#   'global_id': 62368718,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 304,
#   'Name': 'Виктория',
#   'NumberOfPersons': 205,
#   'global_id': 62368719,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 305,
#   'Name': 'Анна',
#   'NumberOfPersons': 202,
#   'global_id': 62368720,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 306,
#   'Name': 'Дарья',
#   'NumberOfPersons': 191,
#   'global_id': 62368721,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 307,
#   'Name': 'Полина',
#   'NumberOfPersons': 188,
#   'global_id': 62368723,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 308,
#   'Name': 'Алиса',
#   'NumberOfPersons': 178,
#   'global_id': 62368724,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 309,
#   'Name': 'Елизавета',
#   'NumberOfPersons': 171,
#   'global_id': 62368725,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 310,
#   'Name': 'Варвара',
#   'NumberOfPersons': 167,
#   'global_id': 62368726,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 311,
#   'Name': 'Александра',
#   'NumberOfPersons': 161,
#   'global_id': 62368727,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 312,
#   'Name': 'Екатерина',
#   'NumberOfPersons': 157,
#   'global_id': 62368728,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 313,
#   'Name': 'Арина',
#   'NumberOfPersons': 120,
#   'global_id': 62368729,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 314,
#   'Name': 'Ксения',
#   'NumberOfPersons': 119,
#   'global_id': 62368730,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 315,
#   'Name': 'Василиса',
#   'NumberOfPersons': 116,
#   'global_id': 62368731,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 316,
#   'Name': 'Валерия',
#   'NumberOfPersons': 105,
#   'global_id': 62368732,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 317,
#   'Name': 'Софья',
#   'NumberOfPersons': 99,
#   'global_id': 62368733,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 318,
#   'Name': 'Вероника',
#   'NumberOfPersons': 86,
#   'global_id': 62368734,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 319,
#   'Name': 'Ева',
#   'NumberOfPersons': 84,
#   'global_id': 62368735,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 320,
#   'Name': 'Милана',
#   'NumberOfPersons': 84,
#   'global_id': 62368736,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 321,
#   'Name': 'Ульяна',
#   'NumberOfPersons': 81,
#   'global_id': 62368737,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 322,
#   'Name': 'Маргарита',
#   'NumberOfPersons': 77,
#   'global_id': 62368738,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 323,
#   'Name': 'Вера',
#   'NumberOfPersons': 73,
#   'global_id': 62368739,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 324,
#   'Name': 'Кира',
#   'NumberOfPersons': 70,
#   'global_id': 62368740,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 325,
#   'Name': 'Кристина',
#   'NumberOfPersons': 55,
#   'global_id': 62368741,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 326,
#   'Name': 'Таисия',
#   'NumberOfPersons': 53,
#   'global_id': 62368742,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 327,
#   'Name': 'Юлия',
#   'NumberOfPersons': 51,
#   'global_id': 62368744,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 328,
#   'Name': 'Алёна',
#   'NumberOfPersons': 46,
#   'global_id': 62368745,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 329,
#   'Name': 'Ольга',
#   'NumberOfPersons': 43,
#   'global_id': 62368746,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 330,
#   'Name': 'Алина',
#   'NumberOfPersons': 43,
#   'global_id': 62368747,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 331,
#   'Name': 'Мирослава',
#   'NumberOfPersons': 37,
#   'global_id': 62368748,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 332,
#   'Name': 'Ника',
#   'NumberOfPersons': 36,
#   'global_id': 62368749,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 333,
#   'Name': 'Диана',
#   'NumberOfPersons': 36,
#   'global_id': 62368750,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 334,
#   'Name': 'Амина',
#   'NumberOfPersons': 36,
#   'global_id': 62368751,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 335,
#   'Name': 'Ирина',
#   'NumberOfPersons': 35,
#   'global_id': 62368752,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 336,
#   'Name': 'Злата',
#   'NumberOfPersons': 34,
#   'global_id': 62368753,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 337,
#   'Name': 'Татьяна',
#   'NumberOfPersons': 32,
#   'global_id': 62368754,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 338,
#   'Name': 'Елена',
#   'NumberOfPersons': 31,
#   'global_id': 62368755,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 339,
#   'Name': 'Надежда',
#   'NumberOfPersons': 30,
#   'global_id': 62368756,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 340,
#   'Name': 'Яна',
#   'NumberOfPersons': 30,
#   'global_id': 62368757,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 341,
#   'Name': 'Евгения',
#   'NumberOfPersons': 27,
#   'global_id': 62368758,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 342,
#   'Name': 'Ярослава',
#   'NumberOfPersons': 26,
#   'global_id': 62368759,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 343,
#   'Name': 'Марина',
#   'NumberOfPersons': 25,
#   'global_id': 62368760,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 344,
#   'Name': 'Ангелина',
#   'NumberOfPersons': 24,
#   'global_id': 62368761,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 345,
#   'Name': 'Светлана',
#   'NumberOfPersons': 22,
#   'global_id': 62368762,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 346,
#   'Name': 'Майя',
#   'NumberOfPersons': 20,
#   'global_id': 62368763,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 347,
#   'Name': 'Элина',
#   'NumberOfPersons': 20,
#   'global_id': 62368764,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 348,
#   'Name': 'Стефания',
#   'NumberOfPersons': 19,
#   'global_id': 62368765,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 349,
#   'Name': 'Есения',
#   'NumberOfPersons': 18,
#   'global_id': 62368766,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 350,
#   'Name': 'Сафия',
#   'NumberOfPersons': 18,
#   'global_id': 62368767,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 351,
#   'Name': 'Карина',
#   'NumberOfPersons': 18,
#   'global_id': 62368768,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 352,
#   'Name': 'Милена',
#   'NumberOfPersons': 17,
#   'global_id': 62368769,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 353,
#   'Name': 'Эмилия',
#   'NumberOfPersons': 17,
#   'global_id': 62368770,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 354,
#   'Name': 'Наталья',
#   'NumberOfPersons': 16,
#   'global_id': 62368771,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 355,
#   'Name': 'Аделина',
#   'NumberOfPersons': 16,
#   'global_id': 62368773,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 356,
#   'Name': 'Лидия',
#   'NumberOfPersons': 16,
#   'global_id': 62368774,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 357,
#   'Name': 'Дарина',
#   'NumberOfPersons': 15,
#   'global_id': 62368775,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 358,
#   'Name': 'Олеся',
#   'NumberOfPersons': 15,
#   'global_id': 62368776,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 359,
#   'Name': 'Лилия',
#   'NumberOfPersons': 15,
#   'global_id': 62368777,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 360,
#   'Name': 'Зоя',
#   'NumberOfPersons': 14,
#   'global_id': 62368778,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 361,
#   'Name': 'Марта',
#   'NumberOfPersons': 14,
#   'global_id': 62368779,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 362,
#   'Name': 'Марьям',
#   'NumberOfPersons': 14,
#   'global_id': 62368780,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 363,
#   'Name': 'Агата',
#   'NumberOfPersons': 14,
#   'global_id': 62368781,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 364,
#   'Name': 'Николь',
#   'NumberOfPersons': 13,
#   'global_id': 62368782,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 365,
#   'Name': 'Антонина',
#   'NumberOfPersons': 13,
#   'global_id': 62368783,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 366,
#   'Name': 'Ариана',
#   'NumberOfPersons': 12,
#   'global_id': 62368784,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 367,
#   'Name': 'Любовь',
#   'NumberOfPersons': 12,
#   'global_id': 62368785,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 368,
#   'Name': 'Фатима',
#   'NumberOfPersons': 12,
#   'global_id': 62368786,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 369,
#   'Name': 'Алия',
#   'NumberOfPersons': 12,
#   'global_id': 62368787,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 370,
#   'Name': 'Владислава',
#   'NumberOfPersons': 12,
#   'global_id': 62368788,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 371,
#   'Name': 'Евангелина',
#   'NumberOfPersons': 11,
#   'global_id': 62368789,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 372,
#   'Name': 'Амелия',
#   'NumberOfPersons': 11,
#   'global_id': 62368790,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 373,
#   'Name': 'Валентина',
#   'NumberOfPersons': 11,
#   'global_id': 62368791,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 374,
#   'Name': 'Нина',
#   'NumberOfPersons': 10,
#   'global_id': 62368792,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 375,
#   'Name': 'Марианна',
#   'NumberOfPersons': 10,
#   'global_id': 62368793,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 376,
#   'Name': 'Малика',
#   'NumberOfPersons': 10,
#   'global_id': 62368794,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 377,
#   'Name': 'Агния',
#   'NumberOfPersons': 10,
#   'global_id': 62368795,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 378,
#   'Name': 'Евдокия',
#   'NumberOfPersons': 9,
#   'global_id': 62368796,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 379,
#   'Name': 'Камилла',
#   'NumberOfPersons': 9,
#   'global_id': 62368797,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 380,
#   'Name': 'Мила',
#   'NumberOfPersons': 8,
#   'global_id': 62368798,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 381,
#   'Name': 'Лейла',
#   'NumberOfPersons': 8,
#   'global_id': 62368799,
#   'Year': 2015,
#   'Month': 'апрель'},
#  {'ID': 382,
#   'Name': 'Каролина',
#   'NumberOfPersons': 8,
#   'global_id': 62368800,
#   'Year': 2015,
#   'Month': 'апрель'},
#  ...]

# %%
class Base(DeclarativeBase):
    pass

# %%
# Создаем класс и описываем отображение атрибутов в столбцы таблицы базы данных
class Name(Base):
    # Название таблицы в базе данных
    __tablename__ = 'bulk_names'

    # Атрибуты  
    ID: Mapped[int] = mapped_column('id')
    Name: Mapped[str] = mapped_column('name')
    NumberOfPersons: Mapped[str] = mapped_column('number_of_persons')
    global_id: Mapped[int] = mapped_column(primary_key=True, type=BigInteger)
    Year: Mapped[int] = mapped_column('year')
    Month: Mapped[str] = mapped_column('month')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[111], line 2
#       1 # Создаем класс и описываем отображение атрибутов в столбцы таблицы базы данных
# ----> 2 class Name(Base):
#       3     # Название таблицы в базе данных
#       4     __tablename__ = 'bulk_names'
#       6     # Атрибуты
#
# Cell In[111], line 10, in Name()
#       8 Name: Mapped[str] = mapped_column('name')
#       9 NumberOfPersons: Mapped[str] = mapped_column('number_of_persons')
# ---> 10 global_id: Mapped[int] = mapped_column(primary_key=Tru, type=BigInteger)
#      11 Year: Mapped[int] = mapped_column('year')
#      12 Month: Mapped[str] = mapped_column('month')
#
# NameError: name 'Tru' is not defined

# %%
Base.metadata.create_all(engine)
# Out:
# 2023-06-18 19:52:13,844 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-18 19:52:13,845 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-18 19:52:13,845 INFO sqlalchemy.engine.Engine [cached since 2565s ago] {'table_name': 'bulk_names', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-18 19:52:13,846 INFO sqlalchemy.engine.Engine COMMIT

# %%
with Session(engine) as session:
    session.execute(insert(Name), data)
    session.commit()
# Out:
# 2023-06-18 19:53:36,185 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-18 19:53:36,239 INFO sqlalchemy.engine.Engine INSERT INTO bulk_names (id, name, number_of_persons, global_id, year, month) VALUES (%(id__0)s, %(name__0)s, %(number_of_persons__0)s, %(global_id__0)s, %(year__0)s, %(month__0)s), (%(id__1)s, %(name__1)s, %(number_of_persons__1)s, %(global_id__1)s,  ... 108072 characters truncated ... 999)s, %(name__999)s, %(number_of_persons__999)s, %(global_id__999)s, %(year__999)s, %(month__999)s)
# 2023-06-18 19:53:36,240 INFO sqlalchemy.engine.Engine [generated in 0.02158s (insertmanyvalues) 1/10 (unordered)] {'month__0': 'январь', 'global_id__0': 37750254, 'year__0': 2015, 'name__0': 'Мария', 'number_of_persons__0': 252, 'id__0': 1, 'month__1': 'январь', 'global_id__1': 37750255, 'year__1': 2015, 'name__1': 'Анастасия', 'number_of_persons__1': 224, 'id__1': 2, 'month__2': 'январь', 'global_id__2': 37750256, 'year__2': 2015, 'name__2': 'Анна', 'number_of_persons__2': 190, 'id__2': 3, 'month__3': 'январь', 'global_id__3': 37750257, 'year__3': 2015, 'name__3': 'Варвара', 'number_of_persons__3': 190, 'id__3': 4, 'month__4': 'январь', 'global_id__4': 37750258, 'year__4': 2015, 'name__4': 'Виктория', 'number_of_persons__4': 186, 'id__4': 5, 'month__5': 'май', 'global_id__5': 62367755, 'year__5': 2015, 'name__5': 'Амелия', 'number_of_persons__5': 8, 'id__5': 483, 'month__6': 'май', 'global_id__6': 62367756, 'year__6': 2015, 'name__6': 'Камила', 'number_of_persons__6': 8, 'id__6': 484, 'month__7': 'май', 'global_id__7': 62367757, 'year__7': 2015, 'name__7': 'Евангелина', 'number_of_persons__7': 8, 'id__7': 485, 'month__8': 'май', 'global_id__8': 62367758 ... 5900 parameters truncated ... 'number_of_persons__991': 10, 'id__991': 374, 'month__992': 'апрель', 'global_id__992': 62368793, 'year__992': 2015, 'name__992': 'Марианна', 'number_of_persons__992': 10, 'id__992': 375, 'month__993': 'апрель', 'global_id__993': 62368794, 'year__993': 2015, 'name__993': 'Малика', 'number_of_persons__993': 10, 'id__993': 376, 'month__994': 'апрель', 'global_id__994': 62368795, 'year__994': 2015, 'name__994': 'Агния', 'number_of_persons__994': 10, 'id__994': 377, 'month__995': 'апрель', 'global_id__995': 62368796, 'year__995': 2015, 'name__995': 'Евдокия', 'number_of_persons__995': 9, 'id__995': 378, 'month__996': 'апрель', 'global_id__996': 62368797, 'year__996': 2015, 'name__996': 'Камилла', 'number_of_persons__996': 9, 'id__996': 379, 'month__997': 'апрель', 'global_id__997': 62368798, 'year__997': 2015, 'name__997': 'Мила', 'number_of_persons__997': 8, 'id__997': 380, 'month__998': 'апрель', 'global_id__998': 62368799, 'year__998': 2015, 'name__998': 'Лейла', 'number_of_persons__998': 8, 'id__998': 381, 'month__999': 'апрель', 'global_id__999': 62368800, 'year__999': 2015, 'name__999': 'Каролина', 'number_of_persons__999': 8, 'id__999': 382}
# 2023-06-18 19:53:36,256 INFO sqlalchemy.engine.Engine INSERT INTO bulk_names (id, name, number_of_persons, global_id, year, month) VALUES (%(id__0)s, %(name__0)s, %(number_of_persons__0)s, %(global_id__0)s, %(year__0)s, %(month__0)s), (%(id__1)s, %(name__1)s, %(number_of_persons__1)s, %(global_id__1)s,  ... 108072 characters truncated ... 999)s, %(name__999)s, %(number_of_persons__999)s, %(global_id__999)s, %(year__999)s, %(month__999)s)
# 2023-06-18 19:53:36,257 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/10 (unordered)] {'month__0': 'апрель', 'global_id__0': 62368801, 'year__0': 2015, 'name__0': 'Людмила', 'number_of_persons__0': 8, 'id__0': 383, 'month__1': 'апрель', 'global_id__1': 62368802, 'year__1': 2015, 'name__1': 'Лада', 'number_of_persons__1': 8, 'id__1': 384, 'month__2': 'апрель', 'global_id__2': 62368804, 'year__2': 2015, 'name__2': 'Аглая', 'number_of_persons__2': 8, 'id__2': 385, 'month__3': 'апрель', 'global_id__3': 62368805, 'year__3': 2015, 'name__3': 'Мадина', 'number_of_persons__3': 8, 'id__3': 386, 'month__4': 'апрель', 'global_id__4': 62368806, 'year__4': 2015, 'name__4': 'Марьяна', 'number_of_persons__4': 8, 'id__4': 387, 'month__5': 'апрель', 'global_id__5': 62368807, 'year__5': 2015, 'name__5': 'Алеся', 'number_of_persons__5': 8, 'id__5': 388, 'month__6': 'апрель', 'global_id__6': 62368808, 'year__6': 2015, 'name__6': 'Самира', 'number_of_persons__6': 8, 'id__6': 389, 'month__7': 'апрель', 'global_id__7': 62368809, 'year__7': 2015, 'name__7': 'Влада', 'number_of_persons__7': 7, 'id__7': 390, 'month__8': 'апрель', 'global_id__8': 62368810 ... 5900 parameters truncated ... 'number_of_persons__991': 21, 'id__991': 1852, 'month__992': 'июль', 'global_id__992': 284583250, 'year__992': 2016, 'name__992': 'Марьям', 'number_of_persons__992': 20, 'id__992': 1853, 'month__993': 'июль', 'global_id__993': 284583266, 'year__993': 2016, 'name__993': 'Николь', 'number_of_persons__993': 18, 'id__993': 1854, 'month__994': 'июль', 'global_id__994': 284583283, 'year__994': 2016, 'name__994': 'Аиша', 'number_of_persons__994': 17, 'id__994': 1855, 'month__995': 'июль', 'global_id__995': 284583301, 'year__995': 2016, 'name__995': 'Аделина', 'number_of_persons__995': 17, 'id__995': 1856, 'month__996': 'июль', 'global_id__996': 284583351, 'year__996': 2016, 'name__996': 'Лилия', 'number_of_persons__996': 17, 'id__996': 1857, 'month__997': 'июль', 'global_id__997': 284583373, 'year__997': 2016, 'name__997': 'Нина', 'number_of_persons__997': 17, 'id__997': 1858, 'month__998': 'июль', 'global_id__998': 284583391, 'year__998': 2016, 'name__998': 'Элина', 'number_of_persons__998': 17, 'id__998': 1859, 'month__999': 'июль', 'global_id__999': 284583706, 'year__999': 2016, 'name__999': 'Амелия', 'number_of_persons__999': 16, 'id__999': 1860}
# 2023-06-18 19:53:36,273 INFO sqlalchemy.engine.Engine INSERT INTO bulk_names (id, name, number_of_persons, global_id, year, month) VALUES (%(id__0)s, %(name__0)s, %(number_of_persons__0)s, %(global_id__0)s, %(year__0)s, %(month__0)s), (%(id__1)s, %(name__1)s, %(number_of_persons__1)s, %(global_id__1)s,  ... 108072 characters truncated ... 999)s, %(name__999)s, %(number_of_persons__999)s, %(global_id__999)s, %(year__999)s, %(month__999)s)
# 2023-06-18 19:53:36,274 INFO sqlalchemy.engine.Engine [insertmanyvalues 3/10 (unordered)] {'month__0': 'июль', 'global_id__0': 284583732, 'year__0': 2016, 'name__0': 'Амира', 'number_of_persons__0': 16, 'id__0': 1861, 'month__1': 'июль', 'global_id__1': 284584824, 'year__1': 2016, 'name__1': 'Антонина', 'number_of_persons__1': 14, 'id__1': 1862, 'month__2': 'июль', 'global_id__2': 284584826, 'year__2': 2016, 'name__2': 'Марта', 'number_of_persons__2': 14, 'id__2': 1863, 'month__3': 'июль', 'global_id__3': 284584828, 'year__3': 2016, 'name__3': 'Агния', 'number_of_persons__3': 13, 'id__3': 1864, 'month__4': 'июль', 'global_id__4': 284584830, 'year__4': 2016, 'name__4': 'Ариана', 'number_of_persons__4': 13, 'id__4': 1865, 'month__5': 'июль', 'global_id__5': 284584832, 'year__5': 2016, 'name__5': 'Асия', 'number_of_persons__5': 13, 'id__5': 1866, 'month__6': 'июль', 'global_id__6': 284584833, 'year__6': 2016, 'name__6': 'Лидия', 'number_of_persons__6': 13, 'id__6': 1867, 'month__7': 'июль', 'global_id__7': 284584834, 'year__7': 2016, 'name__7': 'Наталья', 'number_of_persons__7': 13, 'id__7': 1868, 'month__8': 'июль', 'global_id__8': 284584835 ... 5900 parameters truncated ... 'number_of_persons__991': 8, 'id__991': 2992, 'month__992': 'июнь', 'global_id__992': 628446811, 'year__992': 2017, 'name__992': 'Антонина', 'number_of_persons__992': 8, 'id__992': 2993, 'month__993': 'июнь', 'global_id__993': 628446829, 'year__993': 2017, 'name__993': 'Мила', 'number_of_persons__993': 8, 'id__993': 2994, 'month__994': 'июнь', 'global_id__994': 628446844, 'year__994': 2017, 'name__994': 'Раяна', 'number_of_persons__994': 8, 'id__994': 2995, 'month__995': 'июнь', 'global_id__995': 628446863, 'year__995': 2017, 'name__995': 'Сабина', 'number_of_persons__995': 8, 'id__995': 2996, 'month__996': 'июнь', 'global_id__996': 628446881, 'year__996': 2017, 'name__996': 'Эмма', 'number_of_persons__996': 8, 'id__996': 2997, 'month__997': 'июнь', 'global_id__997': 628446898, 'year__997': 2017, 'name__997': 'Юлиана', 'number_of_persons__997': 7, 'id__997': 2998, 'month__998': 'июнь', 'global_id__998': 628446930, 'year__998': 2017, 'name__998': 'Сара', 'number_of_persons__998': 7, 'id__998': 2999, 'month__999': 'июнь', 'global_id__999': 628446948, 'year__999': 2017, 'name__999': 'Лидия', 'number_of_persons__999': 7, 'id__999': 3000}
# 2023-06-18 19:53:36,291 INFO sqlalchemy.engine.Engine INSERT INTO bulk_names (id, name, number_of_persons, global_id, year, month) VALUES (%(id__0)s, %(name__0)s, %(number_of_persons__0)s, %(global_id__0)s, %(year__0)s, %(month__0)s), (%(id__1)s, %(name__1)s, %(number_of_persons__1)s, %(global_id__1)s,  ... 108072 characters truncated ... 999)s, %(name__999)s, %(number_of_persons__999)s, %(global_id__999)s, %(year__999)s, %(month__999)s)
# 2023-06-18 19:53:36,291 INFO sqlalchemy.engine.Engine [insertmanyvalues 4/10 (unordered)] {'month__0': 'июль', 'global_id__0': 639909512, 'year__0': 2017, 'name__0': 'София, Софья', 'number_of_persons__0': 311, 'id__0': 3901, 'month__1': 'июль', 'global_id__1': 639909618, 'year__1': 2017, 'name__1': 'Мария', 'number_of_persons__1': 249, 'id__1': 3902, 'month__2': 'июль', 'global_id__2': 639910018, 'year__2': 2017, 'name__2': 'Анна', 'number_of_persons__2': 245, 'id__2': 3903, 'month__3': 'июль', 'global_id__3': 639910144, 'year__3': 2017, 'name__3': 'Виктория', 'number_of_persons__3': 187, 'id__3': 3904, 'month__4': 'июль', 'global_id__4': 639910523, 'year__4': 2017, 'name__4': 'Анастасия', 'number_of_persons__4': 187, 'id__4': 3905, 'month__5': 'июль', 'global_id__5': 639910624, 'year__5': 2017, 'name__5': 'Алиса', 'number_of_persons__5': 185, 'id__5': 3906, 'month__6': 'июль', 'global_id__6': 639911007, 'year__6': 2017, 'name__6': 'Полина', 'number_of_persons__6': 181, 'id__6': 3907, 'month__7': 'июль', 'global_id__7': 639911231, 'year__7': 2017, 'name__7': 'Елизавета', 'number_of_persons__7': 180, 'id__7': 3908, 'month__8': 'июль', 'global_id__8': 639911431 ... 5900 parameters truncated ... 'number_of_persons__991': 7, 'id__991': 4892, 'month__992': 'апрель', 'global_id__992': 862563997, 'year__992': 2018, 'name__992': 'Владислава', 'number_of_persons__992': 7, 'id__992': 4893, 'month__993': 'апрель', 'global_id__993': 862563998, 'year__993': 2018, 'name__993': 'Медина', 'number_of_persons__993': 7, 'id__993': 4894, 'month__994': 'апрель', 'global_id__994': 862563999, 'year__994': 2018, 'name__994': 'Мила', 'number_of_persons__994': 6, 'id__994': 4895, 'month__995': 'апрель', 'global_id__995': 862564000, 'year__995': 2018, 'name__995': 'Милена', 'number_of_persons__995': 6, 'id__995': 4896, 'month__996': 'апрель', 'global_id__996': 862564001, 'year__996': 2018, 'name__996': 'Эвелина', 'number_of_persons__996': 6, 'id__996': 4897, 'month__997': 'апрель', 'global_id__997': 862564002, 'year__997': 2018, 'name__997': 'Евангелина', 'number_of_persons__997': 6, 'id__997': 4898, 'month__998': 'апрель', 'global_id__998': 862564003, 'year__998': 2018, 'name__998': 'Лилия', 'number_of_persons__998': 6, 'id__998': 4899, 'month__999': 'апрель', 'global_id__999': 862564004, 'year__999': 2018, 'name__999': 'Лада', 'number_of_persons__999': 6, 'id__999': 4900}
# 2023-06-18 19:53:36,310 INFO sqlalchemy.engine.Engine INSERT INTO bulk_names (id, name, number_of_persons, global_id, year, month) VALUES (%(id__0)s, %(name__0)s, %(number_of_persons__0)s, %(global_id__0)s, %(year__0)s, %(month__0)s), (%(id__1)s, %(name__1)s, %(number_of_persons__1)s, %(global_id__1)s,  ... 108072 characters truncated ... 999)s, %(name__999)s, %(number_of_persons__999)s, %(global_id__999)s, %(year__999)s, %(month__999)s)
# 2023-06-18 19:53:36,310 INFO sqlalchemy.engine.Engine [insertmanyvalues 5/10 (unordered)] {'month__0': 'май', 'global_id__0': 880864952, 'year__0': 2018, 'name__0': 'София, Софья', 'number_of_persons__0': 281, 'id__0': 4901, 'month__1': 'май', 'global_id__1': 880865008, 'year__1': 2018, 'name__1': 'Виктория', 'number_of_persons__1': 206, 'id__1': 4902, 'month__2': 'май', 'global_id__2': 880865017, 'year__2': 2018, 'name__2': 'Мария', 'number_of_persons__2': 204, 'id__2': 4903, 'month__3': 'май', 'global_id__3': 880865037, 'year__3': 2018, 'name__3': 'Анастасия', 'number_of_persons__3': 186, 'id__3': 4904, 'month__4': 'май', 'global_id__4': 880865044, 'year__4': 2018, 'name__4': 'Алиса', 'number_of_persons__4': 184, 'id__4': 4905, 'month__5': 'май', 'global_id__5': 880865055, 'year__5': 2018, 'name__5': 'Анна', 'number_of_persons__5': 176, 'id__5': 4906, 'month__6': 'май', 'global_id__6': 880865069, 'year__6': 2018, 'name__6': 'Александра', 'number_of_persons__6': 150, 'id__6': 4907, 'month__7': 'май', 'global_id__7': 880865072, 'year__7': 2018, 'name__7': 'Полина', 'number_of_persons__7': 150, 'id__7': 4908, 'month__8': 'май', 'global_id__8': 880865077 ... 5900 parameters truncated ... 'number_of_persons__991': 8, 'id__991': 5892, 'month__992': 'Февраль', 'global_id__992': 1023016545, 'year__992': 2019, 'name__992': 'Марианна', 'number_of_persons__992': 8, 'id__992': 5893, 'month__993': 'Февраль', 'global_id__993': 1023016546, 'year__993': 2019, 'name__993': 'Регина', 'number_of_persons__993': 8, 'id__993': 5894, 'month__994': 'Февраль', 'global_id__994': 1023016547, 'year__994': 2019, 'name__994': 'Айша', 'number_of_persons__994': 7, 'id__994': 5895, 'month__995': 'Февраль', 'global_id__995': 1023016548, 'year__995': 2019, 'name__995': 'Лейла', 'number_of_persons__995': 7, 'id__995': 5896, 'month__996': 'Февраль', 'global_id__996': 1023016549, 'year__996': 2019, 'name__996': 'Марина', 'number_of_persons__996': 7, 'id__996': 5897, 'month__997': 'Февраль', 'global_id__997': 1023016550, 'year__997': 2019, 'name__997': 'Асия', 'number_of_persons__997': 7, 'id__997': 5898, 'month__998': 'Февраль', 'global_id__998': 1023016551, 'year__998': 2019, 'name__998': 'Наталья', 'number_of_persons__998': 7, 'id__998': 5899, 'month__999': 'Февраль', 'global_id__999': 1023016552, 'year__999': 2019, 'name__999': 'Станислава', 'number_of_persons__999': 7, 'id__999': 5900}
# 2023-06-18 19:53:36,327 INFO sqlalchemy.engine.Engine INSERT INTO bulk_names (id, name, number_of_persons, global_id, year, month) VALUES (%(id__0)s, %(name__0)s, %(number_of_persons__0)s, %(global_id__0)s, %(year__0)s, %(month__0)s), (%(id__1)s, %(name__1)s, %(number_of_persons__1)s, %(global_id__1)s,  ... 108072 characters truncated ... 999)s, %(name__999)s, %(number_of_persons__999)s, %(global_id__999)s, %(year__999)s, %(month__999)s)
# 2023-06-18 19:53:36,327 INFO sqlalchemy.engine.Engine [insertmanyvalues 6/10 (unordered)] {'month__0': 'Март', 'global_id__0': 1023016553, 'year__0': 2019, 'name__0': 'Мария', 'number_of_persons__0': 225, 'id__0': 5901, 'month__1': 'Март', 'global_id__1': 1023016554, 'year__1': 2019, 'name__1': 'Анна', 'number_of_persons__1': 222, 'id__1': 5902, 'month__2': 'Март', 'global_id__2': 1023016555, 'year__2': 2019, 'name__2': 'Алиса', 'number_of_persons__2': 188, 'id__2': 5903, 'month__3': 'Март', 'global_id__3': 1023016556, 'year__3': 2019, 'name__3': 'Полина', 'number_of_persons__3': 176, 'id__3': 5904, 'month__4': 'Март', 'global_id__4': 1023016557, 'year__4': 2019, 'name__4': 'Виктория', 'number_of_persons__4': 174, 'id__4': 5905, 'month__5': 'Март', 'global_id__5': 1023016558, 'year__5': 2019, 'name__5': 'София', 'number_of_persons__5': 164, 'id__5': 5906, 'month__6': 'Март', 'global_id__6': 1023016559, 'year__6': 2019, 'name__6': 'Анастасия', 'number_of_persons__6': 155, 'id__6': 5907, 'month__7': 'Март', 'global_id__7': 1023016560, 'year__7': 2019, 'name__7': 'Варвара', 'number_of_persons__7': 144, 'id__7': 5908, 'month__8': 'Март', 'global_id__8': 1023016561 ... 5900 parameters truncated ... 'number_of_persons__991': 8, 'id__991': 6892, 'month__992': 'Декабрь', 'global_id__992': 1026791955, 'year__992': 2019, 'name__992': 'Зоя', 'number_of_persons__992': 7, 'id__992': 6893, 'month__993': 'Декабрь', 'global_id__993': 1026791956, 'year__993': 2019, 'name__993': 'Пелагея', 'number_of_persons__993': 7, 'id__993': 6894, 'month__994': 'Декабрь', 'global_id__994': 1026791957, 'year__994': 2019, 'name__994': 'Арианна', 'number_of_persons__994': 7, 'id__994': 6895, 'month__995': 'Декабрь', 'global_id__995': 1026791958, 'year__995': 2019, 'name__995': 'Лия', 'number_of_persons__995': 7, 'id__995': 6896, 'month__996': 'Декабрь', 'global_id__996': 1026791959, 'year__996': 2019, 'name__996': 'Виолетта', 'number_of_persons__996': 7, 'id__996': 6897, 'month__997': 'Декабрь', 'global_id__997': 1026791960, 'year__997': 2019, 'name__997': 'Сабрина', 'number_of_persons__997': 7, 'id__997': 6898, 'month__998': 'Декабрь', 'global_id__998': 1026791961, 'year__998': 2019, 'name__998': 'Муслима', 'number_of_persons__998': 7, 'id__998': 6899, 'month__999': 'Декабрь', 'global_id__999': 1026791962, 'year__999': 2019, 'name__999': 'Аделя', 'number_of_persons__999': 7, 'id__999': 6900}
# 2023-06-18 19:53:36,344 INFO sqlalchemy.engine.Engine INSERT INTO bulk_names (id, name, number_of_persons, global_id, year, month) VALUES (%(id__0)s, %(name__0)s, %(number_of_persons__0)s, %(global_id__0)s, %(year__0)s, %(month__0)s), (%(id__1)s, %(name__1)s, %(number_of_persons__1)s, %(global_id__1)s,  ... 108072 characters truncated ... 999)s, %(name__999)s, %(number_of_persons__999)s, %(global_id__999)s, %(year__999)s, %(month__999)s)
# 2023-06-18 19:53:36,344 INFO sqlalchemy.engine.Engine [insertmanyvalues 7/10 (unordered)] {'month__0': 'Январь', 'global_id__0': 1029420312, 'year__0': 2020, 'name__0': 'Мария', 'number_of_persons__0': 180, 'id__0': 6901, 'month__1': 'Январь', 'global_id__1': 1029420313, 'year__1': 2020, 'name__1': 'София', 'number_of_persons__1': 174, 'id__1': 6902, 'month__2': 'Январь', 'global_id__2': 1029420314, 'year__2': 2020, 'name__2': 'Анна', 'number_of_persons__2': 162, 'id__2': 6903, 'month__3': 'Январь', 'global_id__3': 1029420315, 'year__3': 2020, 'name__3': 'Полина', 'number_of_persons__3': 160, 'id__3': 6904, 'month__4': 'Январь', 'global_id__4': 1029420316, 'year__4': 2020, 'name__4': 'Алиса', 'number_of_persons__4': 151, 'id__4': 6905, 'month__5': 'Январь', 'global_id__5': 1029420317, 'year__5': 2020, 'name__5': 'Виктория', 'number_of_persons__5': 130, 'id__5': 6906, 'month__6': 'Январь', 'global_id__6': 1029420318, 'year__6': 2020, 'name__6': 'Анастасия', 'number_of_persons__6': 127, 'id__6': 6907, 'month__7': 'Январь', 'global_id__7': 1029420319, 'year__7': 2020, 'name__7': 'Александра', 'number_of_persons__7': 111, 'id__7': 6908, 'month__8': 'Январь', 'global_id__8': 1029420320 ... 5900 parameters truncated ... 'number_of_persons__991': 10, 'id__991': 8092, 'month__992': 'Октябрь', 'global_id__992': 1078697379, 'year__992': 2020, 'name__992': 'Эмили', 'number_of_persons__992': 10, 'id__992': 8093, 'month__993': 'Октябрь', 'global_id__993': 1078697380, 'year__993': 2020, 'name__993': 'Евангелина', 'number_of_persons__993': 9, 'id__993': 8094, 'month__994': 'Октябрь', 'global_id__994': 1078697381, 'year__994': 2020, 'name__994': 'Марина', 'number_of_persons__994': 9, 'id__994': 8095, 'month__995': 'Октябрь', 'global_id__995': 1078697382, 'year__995': 2020, 'name__995': 'Сара', 'number_of_persons__995': 9, 'id__995': 8096, 'month__996': 'Октябрь', 'global_id__996': 1078697383, 'year__996': 2020, 'name__996': 'Мелисса', 'number_of_persons__996': 9, 'id__996': 8097, 'month__997': 'Октябрь', 'global_id__997': 1078697384, 'year__997': 2020, 'name__997': 'Доминика', 'number_of_persons__997': 9, 'id__997': 8098, 'month__998': 'Октябрь', 'global_id__998': 1078697385, 'year__998': 2020, 'name__998': 'Сумая', 'number_of_persons__998': 9, 'id__998': 8099, 'month__999': 'Октябрь', 'global_id__999': 1078697386, 'year__999': 2020, 'name__999': 'Агния', 'number_of_persons__999': 9, 'id__999': 8100}
# 2023-06-18 19:53:36,360 INFO sqlalchemy.engine.Engine INSERT INTO bulk_names (id, name, number_of_persons, global_id, year, month) VALUES (%(id__0)s, %(name__0)s, %(number_of_persons__0)s, %(global_id__0)s, %(year__0)s, %(month__0)s), (%(id__1)s, %(name__1)s, %(number_of_persons__1)s, %(global_id__1)s,  ... 108072 characters truncated ... 999)s, %(name__999)s, %(number_of_persons__999)s, %(global_id__999)s, %(year__999)s, %(month__999)s)
# 2023-06-18 19:53:36,360 INFO sqlalchemy.engine.Engine [insertmanyvalues 8/10 (unordered)] {'month__0': 'Ноябрь', 'global_id__0': 1078697387, 'year__0': 2020, 'name__0': 'Мария', 'number_of_persons__0': 174, 'id__0': 8101, 'month__1': 'Ноябрь', 'global_id__1': 1078697388, 'year__1': 2020, 'name__1': 'София', 'number_of_persons__1': 173, 'id__1': 8102, 'month__2': 'Ноябрь', 'global_id__2': 1078697389, 'year__2': 2020, 'name__2': 'Анна', 'number_of_persons__2': 169, 'id__2': 8103, 'month__3': 'Ноябрь', 'global_id__3': 1078697390, 'year__3': 2020, 'name__3': 'Полина', 'number_of_persons__3': 157, 'id__3': 8104, 'month__4': 'Ноябрь', 'global_id__4': 1078697391, 'year__4': 2020, 'name__4': 'Виктория', 'number_of_persons__4': 144, 'id__4': 8105, 'month__5': 'Ноябрь', 'global_id__5': 1078697392, 'year__5': 2020, 'name__5': 'Алиса', 'number_of_persons__5': 141, 'id__5': 8106, 'month__6': 'Ноябрь', 'global_id__6': 1078697393, 'year__6': 2020, 'name__6': 'Елизавета', 'number_of_persons__6': 134, 'id__6': 8107, 'month__7': 'Ноябрь', 'global_id__7': 1078697394, 'year__7': 2020, 'name__7': 'Ева', 'number_of_persons__7': 131, 'id__7': 8108, 'month__8': 'Ноябрь', 'global_id__8': 1078697395 ... 5900 parameters truncated ... 'number_of_persons__991': 10, 'id__991': 9092, 'month__992': 'Август', 'global_id__992': 1146179171, 'year__992': 2021, 'name__992': 'Лидия', 'number_of_persons__992': 10, 'id__992': 9093, 'month__993': 'Август', 'global_id__993': 1146179172, 'year__993': 2021, 'name__993': 'Афина', 'number_of_persons__993': 9, 'id__993': 9094, 'month__994': 'Август', 'global_id__994': 1146179173, 'year__994': 2021, 'name__994': 'Милена', 'number_of_persons__994': 9, 'id__994': 9095, 'month__995': 'Август', 'global_id__995': 1146179174, 'year__995': 2021, 'name__995': 'Хадиджа', 'number_of_persons__995': 9, 'id__995': 9096, 'month__996': 'Август', 'global_id__996': 1146179175, 'year__996': 2021, 'name__996': 'Анфиса', 'number_of_persons__996': 9, 'id__996': 9097, 'month__997': 'Август', 'global_id__997': 1146179176, 'year__997': 2021, 'name__997': 'Сумая', 'number_of_persons__997': 8, 'id__997': 9098, 'month__998': 'Август', 'global_id__998': 1146179177, 'year__998': 2021, 'name__998': 'Нина', 'number_of_persons__998': 8, 'id__998': 9099, 'month__999': 'Август', 'global_id__999': 1146179178, 'year__999': 2021, 'name__999': 'Ярослава', 'number_of_persons__999': 8, 'id__999': 9100}
# 2023-06-18 19:53:36,375 INFO sqlalchemy.engine.Engine INSERT INTO bulk_names (id, name, number_of_persons, global_id, year, month) VALUES (%(id__0)s, %(name__0)s, %(number_of_persons__0)s, %(global_id__0)s, %(year__0)s, %(month__0)s), (%(id__1)s, %(name__1)s, %(number_of_persons__1)s, %(global_id__1)s,  ... 108072 characters truncated ... 999)s, %(name__999)s, %(number_of_persons__999)s, %(global_id__999)s, %(year__999)s, %(month__999)s)
# 2023-06-18 19:53:36,376 INFO sqlalchemy.engine.Engine [insertmanyvalues 9/10 (unordered)] {'month__0': 'Сентябрь', 'global_id__0': 1266741020, 'year__0': 2021, 'name__0': 'София', 'number_of_persons__0': 228, 'id__0': 9101, 'month__1': 'Сентябрь', 'global_id__1': 1266741021, 'year__1': 2021, 'name__1': 'Мария', 'number_of_persons__1': 217, 'id__1': 9102, 'month__2': 'Сентябрь', 'global_id__2': 1266741022, 'year__2': 2021, 'name__2': 'Анна', 'number_of_persons__2': 173, 'id__2': 9103, 'month__3': 'Сентябрь', 'global_id__3': 1266741023, 'year__3': 2021, 'name__3': 'Алиса', 'number_of_persons__3': 159, 'id__3': 9104, 'month__4': 'Сентябрь', 'global_id__4': 1266741024, 'year__4': 2021, 'name__4': 'Елизавета', 'number_of_persons__4': 136, 'id__4': 9105, 'month__5': 'Сентябрь', 'global_id__5': 1266741025, 'year__5': 2021, 'name__5': 'Виктория', 'number_of_persons__5': 135, 'id__5': 9106, 'month__6': 'Сентябрь', 'global_id__6': 1266741026, 'year__6': 2021, 'name__6': 'Ева', 'number_of_persons__6': 134, 'id__6': 9107, 'month__7': 'Сентябрь', 'global_id__7': 1266741027, 'year__7': 2021, 'name__7': 'Полина', 'number_of_persons__7': 113, 'id__7': 9108, 'month__8': 'Сентябрь', 'global_id__8': 1266741028 ... 5900 parameters truncated ... 'number_of_persons__991': 9, 'id__991': 10092, 'month__992': 'Июнь', 'global_id__992': 2375970845, 'year__992': 2022, 'name__992': 'Амира', 'number_of_persons__992': 9, 'id__992': 10093, 'month__993': 'Июнь', 'global_id__993': 2375970846, 'year__993': 2022, 'name__993': 'Аниса', 'number_of_persons__993': 9, 'id__993': 10094, 'month__994': 'Июнь', 'global_id__994': 2375970847, 'year__994': 2022, 'name__994': 'Хадижа', 'number_of_persons__994': 9, 'id__994': 10095, 'month__995': 'Июнь', 'global_id__995': 2375970848, 'year__995': 2022, 'name__995': 'Мариям', 'number_of_persons__995': 9, 'id__995': 10096, 'month__996': 'Июнь', 'global_id__996': 2375970849, 'year__996': 2022, 'name__996': 'Теона', 'number_of_persons__996': 9, 'id__996': 10097, 'month__997': 'Июнь', 'global_id__997': 2375970850, 'year__997': 2022, 'name__997': 'Эвелина', 'number_of_persons__997': 8, 'id__997': 10098, 'month__998': 'Июнь', 'global_id__998': 2375970851, 'year__998': 2022, 'name__998': 'Азалия', 'number_of_persons__998': 8, 'id__998': 10099, 'month__999': 'Июнь', 'global_id__999': 2375970852, 'year__999': 2022, 'name__999': 'Марина', 'number_of_persons__999': 8, 'id__999': 10100}
# 2023-06-18 19:53:36,392 INFO sqlalchemy.engine.Engine ROLLBACK
# ---------------------------------------------------------------------------
# NumericValueOutOfRange                    Traceback (most recent call last)
# File c:\Users\sozyk\projects\middle_python\.venv\Lib\site-packages\sqlalchemy\engine\base.py:2113, in Connection._exec_insertmany_context(self, dialect, context)
#    2112     else:
# -> 2113         dialect.do_execute(
#    2114             cursor,
#    2115             sub_stmt,
#    2116             sub_params,
#    2117             context,
#    2118         )
#    2120 except BaseException as e:
#
# File c:\Users\sozyk\projects\middle_python\.venv\Lib\site-packages\sqlalchemy\engine\default.py:920, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     919 def do_execute(self, cursor, statement, parameters, context=None):
# --> 920     cursor.execute(statement, parameters)
#
# NumericValueOutOfRange: ОШИБКА:  целое вне диапазона
#
#
# The above exception was the direct cause of the following exception:
#
# DataError                                 Traceback (most recent call last)
# Cell In[104], line 2
#       1 with Session(engine) as session:
# ----> 2     session.execute(insert(Name), data)
#       3     session.commit()
#
# File c:\Users\sozyk\projects\middle_python\.venv\Lib\site-packages\sqlalchemy\orm\session.py:2232, in Session.execute(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event)
#    2171 def execute(
#    2172     self,
#    2173     statement: Executable,
#    (...)
#    2179     _add_event: Optional[Any] = None,
#    2180 ) -> Result[Any]:
#    2181     r"""Execute a SQL expression construct.
#    2182
#    2183     Returns a :class:`_engine.Result` object representing
#    (...)
#    2230
#    2231     """
# -> 2232     return self._execute_internal(
#    2233         statement,
#    2234         params,
#    2235         execution_options=execution_options,
#    2236         bind_arguments=bind_arguments,
#    2237         _parent_execute_state=_parent_execute_state,
#    2238         _add_event=_add_event,
#    2239     )
#
# File c:\Users\sozyk\projects\middle_python\.venv\Lib\site-packages\sqlalchemy\orm\session.py:2127, in Session._execute_internal(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event, _scalar_result)
#    2122     return conn.scalar(
#    2123         statement, params or {}, execution_options=execution_options
#    2124     )
#    2126 if compile_state_cls:
# -> 2127     result: Result[Any] = compile_state_cls.orm_execute_statement(
#    2128         self,
#    2129         statement,
#    2130         params or {},
#    2131         execution_options,
#    2132         bind_arguments,
#    2133         conn,
#    2134     )
#    2135 else:
#    2136     result = conn.execute(
#    2137         statement, params or {}, execution_options=execution_options
#    2138     )
#
# File c:\Users\sozyk\projects\middle_python\.venv\Lib\site-packages\sqlalchemy\orm\bulk_persistence.py:1268, in BulkORMInsert.orm_execute_statement(cls, session, statement, params, execution_options, bind_arguments, conn)
#    1266     assert mapper is not None
#    1267     assert session._transaction is not None
# -> 1268     result = _bulk_insert(
#    1269         mapper,
#    1270         cast(
#    1271             "Iterable[Dict[str, Any]]",
#    1272             [params] if isinstance(params, dict) else params,
#    1273         ),
#    1274         session._transaction,
#    1275         isstates=False,
#    1276         return_defaults=insert_options._return_defaults,
#    1277         render_nulls=insert_options._render_nulls,
#    1278         use_orm_insert_stmt=statement,
#    1279         execution_options=execution_options,
#    1280     )
#    1281 elif insert_options._dml_strategy == "orm":
#    1282     result = conn.execute(
#    1283         statement, params or {}, execution_options=execution_options
#    1284     )
#
# File c:\Users\sozyk\projects\middle_python\.venv\Lib\site-packages\sqlalchemy\orm\bulk_persistence.py:200, in _bulk_insert(mapper, mappings, session_transaction, isstates, return_defaults, render_nulls, use_orm_insert_stmt, execution_options)
#     160 extra_bp_names = (
#     161     [
#     162         b.key
#    (...)
#     167     else ()
#     168 )
#     170 records = (
#     171     (
#     172         None,
#    (...)
#     197     )
#     198 )
# --> 200 result = persistence._emit_insert_statements(
#     201     base_mapper,
#     202     None,
#     203     super_mapper,
#     204     table,
#     205     records,
#     206     bookkeeping=bookkeeping,
#     207     use_orm_insert_stmt=use_orm_insert_stmt,
#     208     execution_options=execution_options,
#     209 )
#     210 if use_orm_insert_stmt is not None:
#     211     if not use_orm_insert_stmt._returning or return_result is None:
#
# File c:\Users\sozyk\projects\middle_python\.venv\Lib\site-packages\sqlalchemy\orm\persistence.py:1040, in _emit_insert_statements(base_mapper, uowtransaction, mapper, table, insert, bookkeeping, use_orm_insert_stmt, execution_options)
#    1037 records = list(records)
#    1038 multiparams = [rec[2] for rec in records]
# -> 1040 result = connection.execute(
#    1041     statement, multiparams, execution_options=execution_options
#    1042 )
#    1043 if bookkeeping:
#    1044     for (
#    1045         (
#    1046             state,
#    (...)
#    1055         last_inserted_params,
#    1056     ) in zip(records, result.context.compiled_parameters):
#
# File c:\Users\sozyk\projects\middle_python\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1413, in Connection.execute(self, statement, parameters, execution_options)
#    1411     raise exc.ObjectNotExecutableError(statement) from err
#    1412 else:
# -> 1413     return meth(
#    1414         self,
#    1415         distilled_parameters,
#    1416         execution_options or NO_OPTIONS,
#    1417     )
#
# File c:\Users\sozyk\projects\middle_python\.venv\Lib\site-packages\sqlalchemy\sql\elements.py:483, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     481     if TYPE_CHECKING:
#     482         assert isinstance(self, Executable)
# --> 483     return connection._execute_clauseelement(
#     484         self, distilled_params, execution_options
#     485     )
#     486 else:
#     487     raise exc.ObjectNotExecutableError(self)
#
# File c:\Users\sozyk\projects\middle_python\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1637, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1625 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1626     "compiled_cache", self.engine._compiled_cache
#    1627 )
#    1629 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1630     dialect=dialect,
#    1631     compiled_cache=compiled_cache,
#    (...)
#    1635     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1636 )
# -> 1637 ret = self._execute_context(
#    1638     dialect,
#    1639     dialect.execution_ctx_cls._init_compiled,
#    1640     compiled_sql,
#    1641     distilled_parameters,
#    1642     execution_options,
#    1643     compiled_sql,
#    1644     distilled_parameters,
#    1645     elem,
#    1646     extracted_params,
#    1647     cache_hit=cache_hit,
#    1648 )
#    1649 if has_events:
#    1650     self.dispatch.after_execute(
#    1651         self,
#    1652         elem,
#    (...)
#    1656         ret,
#    1657     )
#
# File c:\Users\sozyk\projects\middle_python\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1841, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1838 context.pre_exec()
#    1840 if context.execute_style is ExecuteStyle.INSERTMANYVALUES:
# -> 1841     return self._exec_insertmany_context(
#    1842         dialect,
#    1843         context,
#    1844     )
#    1845 else:
#    1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File c:\Users\sozyk\projects\middle_python\.venv\Lib\site-packages\sqlalchemy\engine\base.py:2121, in Connection._exec_insertmany_context(self, dialect, context)
#    2113         dialect.do_execute(
#    2114             cursor,
#    2115             sub_stmt,
#    2116             sub_params,
#    2117             context,
#    2118         )
#    2120 except BaseException as e:
# -> 2121     self._handle_dbapi_exception(
#    2122         e,
#    2123         sql_util._long_statement(sub_stmt),
#    2124         sub_params,
#    2125         cursor,
#    2126         context,
#    2127         is_sub_exec=True,
#    2128     )
#    2130 if engine_events:
#    2131     self.dispatch.after_cursor_execute(
#    2132         self,
#    2133         cursor,
#    (...)
#    2137         context.executemany,
#    2138     )
#
# File c:\Users\sozyk\projects\middle_python\.venv\Lib\site-packages\sqlalchemy\engine\base.py:2344, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2342 elif should_wrap:
#    2343     assert sqlalchemy_exception is not None
# -> 2344     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2345 else:
#    2346     assert exc_info[1] is not None
#
# File c:\Users\sozyk\projects\middle_python\.venv\Lib\site-packages\sqlalchemy\engine\base.py:2113, in Connection._exec_insertmany_context(self, dialect, context)
#    2111             break
#    2112     else:
# -> 2113         dialect.do_execute(
#    2114             cursor,
#    2115             sub_stmt,
#    2116             sub_params,
#    2117             context,
#    2118         )
#    2120 except BaseException as e:
#    2121     self._handle_dbapi_exception(
#    2122         e,
#    2123         sql_util._long_statement(sub_stmt),
#    (...)
#    2127         is_sub_exec=True,
#    2128     )
#
# File c:\Users\sozyk\projects\middle_python\.venv\Lib\site-packages\sqlalchemy\engine\default.py:920, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     919 def do_execute(self, cursor, statement, parameters, context=None):
# --> 920     cursor.execute(statement, parameters)
#
# DataError: (psycopg2.errors.NumericValueOutOfRange) ОШИБКА:  целое вне диапазона
#
# [SQL: INSERT INTO bulk_names (id, name, number_of_persons, global_id, year, month) VALUES (%(id__0)s, %(name__0)s, %(number_of_persons__0)s, %(global_id__0)s, %(year__0)s, %(month__0)s), (%(id__1)s, %(name__1)s, %(number_of_persons__1)s, %(global_id__1)s,  ... 108072 characters truncated ... 999)s, %(name__999)s, %(number_of_persons__999)s, %(global_id__999)s, %(year__999)s, %(month__999)s)]
# [parameters: {'month__0': 'Сентябрь', 'global_id__0': 1266741020, 'year__0': 2021, 'name__0': 'София', 'number_of_persons__0': 228, 'id__0': 9101, 'month__1': 'Сентябрь', 'global_id__1': 1266741021, 'year__1': 2021, 'name__1': 'Мария', 'number_of_persons__1': 217, 'id__1': 9102, 'month__2': 'Сентябрь', 'global_id__2': 1266741022, 'year__2': 2021, 'name__2': 'Анна', 'number_of_persons__2': 173, 'id__2': 9103, 'month__3': 'Сентябрь', 'global_id__3': 1266741023, 'year__3': 2021, 'name__3': 'Алиса', 'number_of_persons__3': 159, 'id__3': 9104, 'month__4': 'Сентябрь', 'global_id__4': 1266741024, 'year__4': 2021, 'name__4': 'Елизавета', 'number_of_persons__4': 136, 'id__4': 9105, 'month__5': 'Сентябрь', 'global_id__5': 1266741025, 'year__5': 2021, 'name__5': 'Виктория', 'number_of_persons__5': 135, 'id__5': 9106, 'month__6': 'Сентябрь', 'global_id__6': 1266741026, 'year__6': 2021, 'name__6': 'Ева', 'number_of_persons__6': 134, 'id__6': 9107, 'month__7': 'Сентябрь', 'global_id__7': 1266741027, 'year__7': 2021, 'name__7': 'Полина', 'number_of_persons__7': 113, 'id__7': 9108, 'month__8': 'Сентябрь', 'global_id__8': 1266741028 ... 5900 parameters truncated ... 'number_of_persons__991': 9, 'id__991': 10092, 'month__992': 'Июнь', 'global_id__992': 2375970845, 'year__992': 2022, 'name__992': 'Амира', 'number_of_persons__992': 9, 'id__992': 10093, 'month__993': 'Июнь', 'global_id__993': 2375970846, 'year__993': 2022, 'name__993': 'Аниса', 'number_of_persons__993': 9, 'id__993': 10094, 'month__994': 'Июнь', 'global_id__994': 2375970847, 'year__994': 2022, 'name__994': 'Хадижа', 'number_of_persons__994': 9, 'id__994': 10095, 'month__995': 'Июнь', 'global_id__995': 2375970848, 'year__995': 2022, 'name__995': 'Мариям', 'number_of_persons__995': 9, 'id__995': 10096, 'month__996': 'Июнь', 'global_id__996': 2375970849, 'year__996': 2022, 'name__996': 'Теона', 'number_of_persons__996': 9, 'id__996': 10097, 'month__997': 'Июнь', 'global_id__997': 2375970850, 'year__997': 2022, 'name__997': 'Эвелина', 'number_of_persons__997': 8, 'id__997': 10098, 'month__998': 'Июнь', 'global_id__998': 2375970851, 'year__998': 2022, 'name__998': 'Азалия', 'number_of_persons__998': 8, 'id__998': 10099, 'month__999': 'Июнь', 'global_id__999': 2375970852, 'year__999': 2022, 'name__999': 'Марина', 'number_of_persons__999': 8, 'id__999': 10100}]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)
