# %% [markdown]
# # Использование библиотеку requests
#
# <a target="_blank" href="https://colab.research.google.com/github/sozykin/middle_python/blob/main/06/06_orm.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# Подключаем библиотеку requests
import requests

# %%
# Загружаем Web-страницу
# Используем метод GET
result = requests.get("https://msk.rt.ru/")

# %%
# Проверяем код ответа
result.status_code
# Out:
# 200

# %%
# Смотрим заголовки ответа
result.headers
# Out:
# {'content-type': 'text/html; charset=UTF-8', 'cache-control': 'max-age=10800, public', 'date': 'Thu, 22 Jun 2023 17:54:18 GMT', 'x-drupal-dynamic-cache': 'HIT', 'x-ua-compatible': 'IE=edge', 'content-language': 'ru', 'x-content-type-options': 'nosniff', 'expires': 'Sun, 19 Nov 1978 05:00:00 GMT', 'last-modified': 'Fri, 23 Jun 2023 06:01:44 GMT', 'etag': 'W/"1687500105:dtagent1026123022015223440qU"', 'vary': 'Cookie', 'page-render': 'CMS', 'set-cookie': 'utm_data=%7B%22utm_source%22%3A%22direct%22%2C%22utm_medium%22%3A%22none%22%7D; expires=Sat, 24-Jun-2023 06:01:45 GMT; Max-Age=86400; path=/, userRegionName=%D0%9C%D0%BE%D1%81%D0%BA%D0%B2%D0%B0; expires=Fri, 30-Jun-2023 06:01:45 GMT; Max-Age=604800; path=/; domain=.rt.ru, userRegionEng=moskva; expires=Fri, 30-Jun-2023 06:01:45 GMT; Max-Age=604800; path=/; domain=.rt.ru, userLocalityName=%D0%9C%D0%BE%D1%81%D0%BA%D0%B2%D0%B0; expires=Fri, 30-Jun-2023 06:01:45 GMT; Max-Age=604800; path=/; domain=.rt.ru, userLocalityEng=deleted; expires=Thu, 23-Jun-2022 06:01:44 GMT; Max-Age=0; path=/; domain=.rt.ru, regionKladrId=77; expires=Fri, 30-Jun-2023 06:01:45 GMT; Max-Age=604800; path=/; domain=.rt.ru, userMrf=CENTER; expires=Fri, 30-Jun-2023 06:01:45 GMT; Max-Age=604800; path=/; domain=.rt.ru, userIp=93.175.28.142; expires=Fri, 30-Jun-2023 06:01:45 GMT; Max-Age=604800; path=/; domain=.rt.ru, userRegionORPON=5200048; expires=Fri, 30-Jun-2023 06:01:45 GMT; Max-Age=604800; path=/; domain=.rt.ru, userLocalityORPON=5200048; expires=Fri, 30-Jun-2023 06:01:45 GMT; Max-Age=604800; path=/; domain=.rt.ru, subdomain=msk; expires=Fri, 30-Jun-2023 06:01:45 GMT; Max-Age=604800; path=/; domain=.rt.ru, userLocalityType=%D0%B3.; expires=Fri, 30-Jun-2023 06:01:45 GMT; Max-Age=604800; path=/; domain=.rt.ru, dtCookie=v_4_srv_88_sn_BB6D34EC2DBE57129697129D1CB01938_perc_100000_ol_0_mul_1_app-3Af3f80edc351ea086_1; Path=/; Domain=.rt.ru, TS01f3d16c=...; Path=/; Domain=.msk.rt.ru', 'x-oneagent-js-injection': 'true', 'x-ruxit-js-agent': 'true', 'server-timing': 'dtSInfo;desc="0", dtRpid;desc="-898749129"', 'content-encoding': 'gzip', 'x-frame-options': 'SAMEORIGIN', 'Transfer-Encoding': 'chunked'}

# %%
# Смотрим содержимое страницы
result.content[0:70]
# Out:
# b'<!DOCTYPE html>\n<html lang="ru-RU" dir="ltr">\n  <head>\n    <title>\xd0\xa0\xd0\xbe'

# %%
result.text[0:150]
# Out:
# '<!DOCTYPE html>\n<html lang="ru-RU" dir="ltr">\n  <head>\n    <title>Ростелеком - официальный сайт для физических лиц. г. Москва. Услуги доступа в интерн'

# %%
# Подключаем библиотеку 
from bs4 import BeautifulSoup

# %%
# Создаем объект soup на основе загруженной Web-страницы
soup = BeautifulSoup(result.content, 'lxml')

# %%
# Печатаем "красивую" версию HTML-страницы
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="ru-RU">
#  <head>
#   <title>
#    Ростелеком - официальный сайт для физических лиц. г. Москва. Услуги доступа в интернет, ТВ и телефонной связи.
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="Выгодные тарифы на подключение Ростелеком в г. Москва. Цифровые услуги со скидкой 50%. Пакеты услуг. Мобильная связь. Безлимитные звонки. Быстрый домашний интернет. Мессенджеры и соцсети. Онлайн-кинотеатр и ТВ. Подключить Ростелеком в 1 клик.
#
#
# " name="description"/>
#   <link href="https://msk.rt.ru" rel="canonical"/>
#   <link href="https://msk.rt.ru/" rel="shortlink"/>
#   <link href="https://www.rt.ru/themes/rt_ru__b2b/templates/icons/favicon-250x250.png" rel="image_src"/>
#   <meta content="width" name="MobileOptimized"/>
#   <meta content="true" name="HandheldFriendly"/>
#   <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no, shrink-to-fit=no" name="viewport"/>
#   <meta content="nopin" name="pinterest"/>
#   <meta content="19b2d9ffc2fcce74" name="yandex-verification"/>
#   <meta content="ie=edge" http-equiv="X-UA-Compatible"/>
#   <script defer="" type="text/javascript">
#    window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
#
# /* Google-Tag */
# var valueGTM=window.location.pathname.indexOf('/b2b/kp_video')!== -1? 'GTM-PBFVGDW':'GTM-NMSM2ZF';
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push(
#     {'gtm.start': new Date().getTime(),event:'gtm.js'}
# );var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&amp;l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer',valueGTM);
#
#
# // Yandex.Metrika script
# (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
#     m[i].l=1*new Date();
#     k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
#   (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
# // Yandex.Metrika script options
# const METRIC_OPTIONS = {
#     clickmap: true,
#     trackLinks: true,
#     accurateTrackBounce: true,
#     webvisor: true,
#     ecommerce: 'dataLayer'
# }
#
# const METRIC_OPTIONS_FOR_NEW_RT = {
#     clickmap: true,
#     trackLinks: true,
#     accurateTrackBounce: true,
#     ecommerce: 'dataLayer'
# }
#
# // Yandex.Metrika ids counters
# window.RTK_YANDEX_COUNTER_IDS = {
#     NEW_RT: 46297389,
#     B2B: 87747728,
#     B2C: 87747669,
#     B2O: 87747838,
#     GAME: 87747880,
#     LC: 50289415,
#     ECO_VATS: 89936172
# }
#
# function isGamePage () {
#     return ['gg', 'rtx', 'gfn'].some(function (host) { return window.location.hostname.startsWith(host); }) ||
#         ['4game', 'games', 'gfn', 'igrovoy', 'rtx', 'vkplay', 'wargaming', 'lestagames'].some(function (path) { return window.location.pathname.indexOf('/' + path) !== -1; })
# }
#
# let currentSegmentCode
# // Yandex.Metrika b2b
# if (window.location.pathname.includes('/b2b')) {
#     currentSegmentCode = window.RTK_YANDEX_COUNTER_IDS.B2B;
#     // Yandex.Metrika b2o
# } else if (window.location.pathname.includes('/b2o')) {
#     currentSegmentCode = window.RTK_YANDEX_COUNTER_IDS.B2O;
#     // Yandex.Metrika lc
# } else if (window.location.pathname.includes('/lc')) {
#     currentSegmentCode = window.RTK_YANDEX_COUNTER_IDS.LC;
#     // Yandex.Metrika eco
# } else if (window.location.pathname.includes('/eco')) {
#     currentSegmentCode = window.RTK_YANDEX_COUNTER_IDS.ECO_VATS;
#     ym(window.RTK_YANDEX_COUNTER_IDS.B2B, 'init', METRIC_OPTIONS);
# } else {
#     // Yandex.Metrika b2c
#     currentSegmentCode = window.RTK_YANDEX_COUNTER_IDS.B2C;
# }
# // Yandex.Metrika all pages
# ym(window.RTK_YANDEX_COUNTER_IDS.NEW_RT, 'init', METRIC_OPTIONS_FOR_NEW_RT);
# // Yandex.Metrika segment
# ym(currentSegmentCode, 'init', METRIC_OPTIONS);
# // Yandex.Metrika gg
# if (isGamePage()) {
#     ym(window.RTK_YANDEX_COUNTER_IDS.GAME, 'init', METRIC_OPTIONS);
# }
#   </script>
#   <script defer="" type="text/javascript">
#    window.geoData={
#           mrf:"",
#           regionEng:"moskva",
#           regionId:"5200048",
#           regionName:"Москва",
#           localityEng:"",
#           localityId:"5200048",
#           localityName:"Москва",
#           localityType:"г.",
#           regionKladrid:"77",
#         };
#         if(window.dataLayer)window.dataLayer.push(geoData);
#   </script>
#   <link href="/themes/rt_ru/icons/site.webmanifest" rel="manifest"/>
#   <link href="/themes/rt_ru/icons/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="/themes/rt_ru/icons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/themes/rt_ru/icons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/themes/rt_ru/icons/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <meta content="#7700ff" name="theme-color"/>
#   <meta content="#7700ff" name="msapplication-TileColor"/>
#   <link href="/themes/rt_ru/icons/safari-mask-icon.svg" rel="mask-icon"/>
#   <meta content="noyaca" name="robots"/>
#   <meta content="SyLJI-sasGgw8xVZBbN7nonBmPn78b3vFvK8sSE-J6E" name="google-site-verification"/>
#   <meta content="pTcYwn7rMj-tquNL4qCd-ntM9lRln0dnuuJonZ9fDVk" name="google-site-verification"/>
#   <meta content="website" property="og:type"/>
#   <meta content="ru_RU" property="og:locale"/>
#   <meta content="https://msk.rt.ru/" property="og:url"/>
#   <meta content="Ростелеком - официальный сайт для физических лиц. г. Москва. Услуги доступа в интернет, ТВ и телефонной связи." property="og:title"/>
#   <meta content="Выгодные тарифы на подключение Ростелеком в г. Москва. Цифровые услуги со скидкой 50%. Пакеты услуг. Мобильная связь. Безлимитные звонки. Быстрый домашний интернет. Мессенджеры и соцсети. Онлайн-кинотеатр и ТВ. Подключить Ростелеком в 1 клик.
#
#
# " property="og:description"/>
#   <meta content="https://msk.rt.ru/themes/rt_ru/icons/RT_RGB_Vertical_rus_1200x630px.png" property="og:image"/>
#   <meta content="https://msk.rt.ru/themes/rt_ru/icons/RT_RGB_Vertical_rus_630x630px.png" property="og:image"/>
#   <meta content="https://msk.rt.ru/themes/rt_ru/icons/RT_RGB_Vertical_rus_537x240px.png" property="vk:image"/>
#   <!--[if lt IE 9]>
#       <script type="text/javascript">window.location = '/fault-browser'</script>
#     <![endif]-->
#   <script data-dtconfig="rid=RID_2418|rpid=-1805729783|domain=rt.ru|reportUrl=/rb_f2ed73c2-b661-4adc-8c5e-33be5b1728bf|app=f3f80edc351ea086|featureHash=ICA27NVfghjqrux|vcv=2|rdnt=0|uxrgce=1|bp=3|cuc=0vuhwdtl|mel=100000|md=mdcc1=a#top-bar ^rb div ^rb div.unit-50.text-right ^rb a.profile-link.hor-bar-unit.hor-bar-unit_pos-right ^rb span,mdcc2=dutm_source,mdcc3=dutm_medium,mdcc4=dutm_campaign,mdcc5=duserMrf|ssv=4|lastModification=1687074129300|dtVersion=10259230221142207|tp=500,50,0,1|uxdcw=1500|agentUri=/dyna/ruxitagentjs_ICA27NVfghjqrux_10259230221142207.js" src="/dyna/ruxitagentjs_ICA27NVfghjqrux_10259230221142207.js" type="text/javascript">
#   </script>
#   <link as="font" crossorigin="" href="https://rt-static.rt.ru/themes/rt_ru/fonts/BasisGrotesquePro-Medium-Web.woff2" rel="preload"/>
#   <link as="font" crossorigin="" href="https://rt-static.rt.ru/themes/rt_ru/fonts/BasisGrotesquePro-Regular-Web.woff2" rel="preload"/>
#   <link as="font" crossorigin="" href="https://rt-static.rt.ru/themes/rt_ru/fonts/BasisGrotesquePro-Light-Web.woff2" rel="preload"/>
#   <link as="font" crossorigin="" href="https://rt-static.rt.ru/themes/rt_ru/fonts/BasisGrotesquePro-Bold-Web.woff2" rel="preload"/>
#   <link as="font" crossorigin="" href="https://rt-static.rt.ru/themes/rt_ru/fonts/MaterialIcons.woff2" rel="preload"/>
#   <style data-block="fonts">
#    @font-face {
#   font-family: "RT Fonts";
#   src: url('https://rt-static.rt.ru/themes/rt_ru/fonts/BasisGrotesquePro-Light-Web.eot');
#   src: url('https://rt-static.rt.ru/themes/rt_ru/fonts/BasisGrotesquePro-Light-Web.eot?#iefix') format("embedded-opentype"), url('https://rt-static.rt.ru/themes/rt_ru/fonts/BasisGrotesquePro-Light-Web.woff2') format("woff2"), url('https://rt-static.rt.ru/themes/rt_ru/fonts/BasisGrotesquePro-Light-Web.woff') format("woff"), url('https://rt-static.rt.ru/themes/rt_ru/fonts/BasisGrotesquePro-Light-Web.ttf') format("ttf");
#   font-style: normal;
#   font-weight: 200;
#   font-display: swap;
# }
# @font-face {
#   font-family: "RT Fonts";
#   src: url('https://rt-static.rt.ru/themes/rt_ru/fonts/BasisGrotesquePro-Light-Web.eot');
#   src: url('https://rt-static.rt.ru/themes/rt_ru/fonts/BasisGrotesquePro-Light-Web.eot?#iefix') format("embedded-opentype"), url('https://rt-static.rt.ru/themes/rt_ru/fonts/BasisGrotesquePro-Light-Web.woff2') format("woff2"), url('https://rt-static.rt.ru/themes/rt_ru/fonts/BasisGrotesquePro-Light-Web.woff') format("woff"), url('https://rt-static.rt.ru/themes/rt_ru/fonts/BasisGrotesquePro-Light-Web.ttf') format("ttf");
#   font-style: normal;
#   font-weight: 300;
#   font-display: swap;
# }
# @font-face {
#   font-family: "RT Fonts";
#   src: url('https://rt-static.rt.ru/themes/rt_ru/fonts/BasisGrotesquePro-Regular-Web.eot');
#   src: url('https://rt-static.rt.ru/themes/rt_ru/fonts/BasisGrotesquePro-Regular-Web.eot?#iefix') format("embedded-opentype"), url('https://rt-static.rt.ru/themes/rt_ru/fonts/BasisGrotesquePro-Regular-Web.woff2') format("woff2"), url('https://rt-static.rt.ru/themes/rt_ru/fonts/BasisGrotesquePro-Regular-Web.woff') format("woff"), url('https://rt-static.rt.ru/themes/rt_ru/fonts/BasisGrotesquePro-Regular-Web.ttf') format("ttf");
#   font-style: normal;
#   font-weight: 400;
#   font-display: swap;
# }
# @font-face {
#   font-family: "RT Fonts";
#   src: url('https://rt-static.rt.ru/themes/rt_ru/fonts/BasisGrotesquePro-Medium-Web.eot');
#   src: url('https://rt-static.rt.ru/themes/rt_ru/fonts/BasisGrotesquePro-Medium-Web.eot?#iefix') format("embedded-opentype"), url('https://rt-static.rt.ru/themes/rt_ru/fonts/BasisGrotesquePro-Medium-Web.woff2') format("woff2"), url('https://rt-static.rt.ru/themes/rt_ru/fonts/BasisGrotesquePro-Medium-Web.woff') format("woff"), url('https://rt-static.rt.ru/themes/rt_ru/fonts/BasisGrotesquePro-Medium-Web.ttf') format("ttf");
#   font-style: normal;
#   font-weight: 500;
#   font-display: swap;
# }
# @font-face {
#   font-family: "RT Fonts";
#   src: url('https://rt-static.rt.ru/themes/rt_ru/fonts/BasisGrotesquePro-Bold-Web.eot');
#   src: url('https://rt-static.rt.ru/themes/rt_ru/fonts/BasisGrotesquePro-Bold-Web.eot?#iefix') format("embedded-opentype"), url('https://rt-static.rt.ru/themes/rt_ru/fonts/BasisGrotesquePro-Bold-Web.woff2') format("woff2"), url('https://rt-static.rt.ru/themes/rt_ru/fonts/BasisGrotesquePro-Bold-Web.woff') format("woff"), url('https://rt-static.rt.ru/themes/rt_ru/fonts/BasisGrotesquePro-Bold-Web.ttf') format("ttf");
#   font-style: normal;
#   font-weight: 600;
#   font-display: swap;
# }
# @font-face {
#   font-family: "RT Fonts";
#   src: url('https://rt-static.rt.ru/themes/rt_ru/fonts/BasisGrotesquePro-Bold-Web.eot');
#   src: url('https://rt-static.rt.ru/themes/rt_ru/fonts/BasisGrotesquePro-Bold-Web.eot?#iefix') format("embedded-opentype"), url('https://rt-static.rt.ru/themes/rt_ru/fonts/BasisGrotesquePro-Bold-Web.woff2') format("woff2"), url('https://rt-static.rt.ru/themes/rt_ru/fonts/BasisGrotesquePro-Bold-Web.woff') format("woff"), url('https://rt-static.rt.ru/themes/rt_ru/fonts/BasisGrotesquePro-Bold-Web.ttf') format("ttf");
#   font-style: normal;
#   font-weight: 800;
#   font-display: swap;
# }
# .i__logo {
#   background: url("/themes/rt_ru__super/logo.svg") no-repeat 50%;
#   display: block;
#   margin-top: -4px;
#   width: 160px;
#   height: 40px;
# }
# .i__logo-only {
#   background: url("/themes/rt_ru__super/logo-only.svg") no-repeat 50%;
#   display: inline-block;
#   width: 51px;
#   height: 85px;
#   background-size: contain;
# }
# /**
#  * Icons
#  */
# /* Material */
# @font-face {
#   font-family: 'Material Icons';
#   font-style: normal;
#   font-weight: 400;
#   src: url('https://rt-static.rt.ru/themes/rt_ru/fonts/MaterialIcons.woff2') format('woff2'), url('https://rt-static.rt.ru/themes/rt_ru/fonts/MaterialIcons.woff') format('woff');
#   font-display: swap;
# }
# .mdi {
#   color: inherit;
#   direction: ltr;
#   display: inline-block;
#   font-family: 'Material Icons';
#   font-weight: normal;
#   font-style: normal;
#   font-size: 24px;
#   line-height: inherit;
#   letter-spacing: normal;
#   text-transform: none;
#   white-space: nowrap;
#   word-wrap: normal;
#   -webkit-font-feature-settings: 'liga';
#   -webkit-font-smoothing: antialiased;
# }
# .mdi__account_circle:before {
#   content: "\E853";
# }
# .mdi__add:before {
#   content: "\E145";
# }
# .mdi__add_circle:before {
#   content: "\E147";
# }
# .mdi__block:before {
#   content: "\E14B";
# }
# .mdi__check:before {
#   content: "\E5CA";
# }
# .mdi__check_box:before {
#   content: "\E834";
# }
# .mdi__check_circle:before {
#   content: "\E86C";
# }
# .mdi__close:before {
#   content: "\E5CD";
# }
# .mdi__date_range:before {
#   content: "\E916";
# }
# .mdi__error_outline:before {
#   content: "\E001";
# }
# .mdi__insert_drive_file:before {
#   content: "\E24D";
# }
# .mdi__near_me:before {
#   content: "\E569";
# }
# .mdi__person:before {
#   content: "\E7FD";
# }
# .mdi__place:before {
#   content: "\E55F";
# }
# .mdi__remove:before {
#   content: "\E15B";
# }
# .mdi__remove_circle:before {
#   content: "\E15C";
# }
#   </style>
#   <link href="/sites/default/files/css/css_3SOb5szLytoUJvT7VZL5vaxRw_D3vlzj7rZaRnVz42Y.css" media="all" rel="stylesheet"/>
#   <link href="/modules/custom/rit_blog_preview/css/styles.css?rwck0d" media="all" rel="stylesheet"/>
#   <link href="/sites/default/files/css/css_v52pnKvzGMwJsCsbQob1gLXKl-3n3S7iFQHISwvruAA.css" media="all" rel="stylesheet"/>
#   <link href="/sites/default/files/css/css_bpqGcaFhp0RgfVvM5oIAkC18cbi20DaqKCHsGn-Yedk.css" media="all" rel="stylesheet"/>
#   <script src="/sites/default/files/js/js_GK89ItxdJ6-pdMUb5gOQHgUfGdiKRAQm5ep0sD-xgKY.js">
#   </script>
#  </head>
#  <body class="rtkid-on segment-b2c path-frontpage">
#   <script type="application/ld+json">
#    {
#       "@context": "https://schema.org",
#       "@type": "Organization",
#       "url": "https://msk.rt.ru/",
#       "logo": "https://msk.rt.ru/sites/default/files/img/logo.png"
#     }
#   </script>
#   <script type="application/ld+json">
#    {
#       "@context": "https://schema.org",
#       "@type": "Organization",
#       "name": "Ростелеком",
#       "url": "https://msk.rt.ru/",
#       "sameAs": [
#         "https://www.facebook.com/Rostelecom.Official",
#         "https://www.instagram.com/rostelecom.official/",
#         "https://www.youtube.com/user/rostelec",
#         "https://twitter.com/Rostelecom_News",
#         "http://www.flickr.com/photos/rostelecom_photostream"
#       ]
#     }
#   </script>
#   <div class="rtk-loader">
#    <div class="rtk-loader__wrap">
#     <div class="wc-inline">
#      <rt-spinner>
#      </rt-spinner>
#     </div>
#    </div>
#   </div>
#   <script data-drupal-selector="drupal-settings-json" type="application/json">
#    {"path":{"baseUrl":"\/","scriptPath":null,"pathPrefix":"","currentPath":"geo-page\/305","currentPathIsAdmin":false,"isFront":true,"currentLanguage":"ru"},"pluralDelimiter":"\u0003","geography":{"userRegion":null,"userRegionName":"\u041c\u043e\u0441\u043a\u0432\u0430","userRegionEng":"moskva","userLocalityName":"\u041c\u043e\u0441\u043a\u0432\u0430","userLocalityEng":"","userLocalityType":"\u0433.","userMrf":"","userRegionORPON":"5200048","userLocalityORPON":"5200048","regionKladrId":77,"subdomain":"msk"},"user":{"uid":0,"permissionsHash":"253eb6f6a1ae0a86f810b545f656af6d50be25ddc4aec4234fbf8b4067e560f4"}}
#   </script>
#   <script src="/sites/default/files/js/js_6MN5gE04rrZjZ5xUhrrOH8I-Nm_Em6UX9kaZAmdj0JM.js">
#   </script>
#   <style>
#    @import "/themes/rt_ru__super/css/theme.css";
#       @import "/themes/rt_ru__super/css/header.css";
#       @import "/themes/rt_ru__super/css/footer.css";
#   </style>
#   <div class="dialog-off-canvas-main-canvas" data-off-canvas-main-canvas="">
#    <div class="main-wrapper">
#     <div class="main-wrapper__inner">
#      <div class="region region-absolute-top">
#       <div class="settings-tray-editable block block-block-content block-block-content3f8e0e9f-8f8e-45b3-b239-44d23ceb72b2" data-drupal-settingstray="editable" id="block-b2cvkmt">
#        <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item">
#         <script data-ssr-ignore="" type="text/javascript">
#          window.VK_PERFORMANCE_PIXEL_ID = "VK-RTRG-372231-5jnG2"
#   !function(){var t=document.createElement("script");t.type="text/javascript",t.async=!0,t.src='https://vk.com/js/api/openapi.js?169',t.onload=function(){
#     VK.Retargeting.Init(VK_PERFORMANCE_PIXEL_ID),VK.Retargeting.Hit()},document.head.appendChild(t)}();
#         </script>
#         <noscript>
#          <img alt="" src="https://vk.com/rtrg?p=VK-RTRG-372231-5jnG2" style="position:fixed; left:-999px;"/>
#         </noscript>
#         <!-- Rating Mail.ru counter -->
#         <script type="text/javascript">
#          window.RTK_MAIL_TMR_ID = "3241205"
#   var _tmr = window._tmr || (window._tmr = []);
#   _tmr.push({id: "3241205", type: "pageView", start: (new Date()).getTime(), pid: "USER_ID"});
#   (function (d, w, id) {
#     if (d.getElementById(id)) return;
#     var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#     ts.src = "https://top-fwz1.mail.ru/js/code.js";
#     var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#     if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
#   })(document, window, "topmailru-code");
#         </script>
#         <noscript>
#          <div>
#           <img alt="Top.Mail.Ru" src="https://top-fwz1.mail.ru/counter?id=3241205;js=na" style="border:0;position:absolute;left:-9999px;"/>
#          </div>
#         </noscript>
#         <!-- //Rating Mail.ru counter -->
#        </div>
#       </div>
#       <div class="settings-tray-editable block block-block-content block-block-content4f198864-5029-4714-8d9e-3d671cf36637" data-drupal-settingstray="editable" id="block-rt-ru-super-globalnyemetody">
#        <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item">
#         <script data-ssr="" type="text/javascript">
#          /** Функция для получения значения в cookie */
# function getCookie(name) {
#   var matches = document.cookie.match(new RegExp(
#     "(?:^|; )" + name.replace(/([\.$?*|{}\(\)\[\]\\\/\+^])/g, '\\$1') + "=([^;]*)"
#   ));
#   return matches ? decodeURIComponent(matches[1]) : undefined;
# }
# window.getCookie=getCookie
#
# /** Функция для получения значения в параметрах URL */
# function getParam(name){
#   return (new URLSearchParams(location.search)).get(name)
# }
# window.getParam=getParam
#
# /**
#  * Get DOM-element when him is appended
#  */
# function waitLoaded(selector, callback) {
#   var call = 0,
#     condition = function () { return call > 50 || document.querySelector(selector) },
#     promise = function () { if (condition()) { callback(document.querySelector(selector)); } else { var timer = setInterval(function () { if (condition()) { clearInterval(timer); callback(document.querySelector(selector)); } else { call++; } }, 250); } };
#   promise();
# };
# window.waitLoaded=waitLoaded
#
# /**
#  * Check current GEO by regions array
#  */
# function checkGeo(regionIds) {
#   if (!regionIds || !Array.isArray(regionIds)) return console.log('Не найден список regionIds');
#   return regionIds.indexOf(parseInt(geoData.regionId)) !== -1
# }
# window.checkGeo=checkGeo
#
#
# // Определяет тач-девайс
# function isTouchDevice() { return "ontouchstart" in document.documentElement }
#
# // Добавляет CSS-класс
# function addClass(e, t) { e.classList ? e.classList.add(t) : e.className += " " + t }
#
# // Пушит в метрику данные
# function linkToConstructorClicked(e, slide) {
#   window.RTK_UTILS_METRICS({
#       event: 'constructor_show',
#       detail: {
#         offerId: slide.offerId,
#         offerName: slide.offerName || slide.title,
#         constructorStep: 'settings',
#       },
#       referrer: window.location.href
#     },
#     {
#       isNew: true,
#       key: 'constructorSEO'
#     }
#   )
# }
#
# // Сигнализирует что это тач-девайс
# if (isTouchDevice()) addClass(document.body, 'is-touch');
#
# (function () {
#   if (decodeURI(window.location.href).match(/(?!&)utm_[^=]*=[^&]*(?=&)/g)) {
#     window.sessionStorage.setItem('utm_label', JSON.stringify(
#       decodeURI(window.location.href).match(/(?!&)utm_[^=]*=[^&]*(?=&)/g).reduce(function (acc, param) {
#         var separator = param.split('=')
#         acc[separator[0]] = separator[1]
#         return acc
#       }, {})
#     ))
#   }
# })()
#
# // Регионозависимое уведомление о смене региона
# window.RTK_USE_GEO_POPUP = {
#   onShow: function (geo) { setTimeout(function () { if (window.RTK_USE_GEO_POPUP.current && window.RTK_USE_GEO_POPUP.current === "region-notification-dark") { window.RTK_UTILS.metrics({ event: 'b2c', type: 'view_geo_popup', value: geo.regionEng }) } }, 5) },
#   dark: [].concat(
#     //mrfSeveroZapad,
#     //mrfCenter,
#     //mrfMoscow,
#     //mrfUral,
#     //mrfVolga,
#     //mrfSibir,
#     //mrfDV,
#     //mrfYug
#   ),
#   old: [].concat(
#     mrfSeveroZapad,
#     mrfCenter,
#     mrfMoscow,
#     mrfUral,
#     mrfVolga,
#     mrfSibir,
#     mrfDV,
#     mrfYug
#   )
# }
#
# window.RTK_VALIDATE_FIELDS_SUGGEST_ADDRESS = ['house']
# window.RTK_CHECK_TECH_CAPABILITY = [5200048]
# window.RTK_LABELS_TECH_CAPABILITY = {
#   gpon: {
#     title: 'Ура! Вы можете подключить GPON Turbo',
#     popover: 'description'
#   },
#   docsis: {
#     title: 'Предложим альтернативу GPON Turbo',
#     popover: 'description'
#   },
#   xdsl: 'Ура! Вам доступно подключение интернета',
#   success: 'Ура! Вам доступно высокоскоростное подключение',
#   question: 'Оператор уточнит возможность подключения',
#   error: 'К сожалению, пока нет возможности подключения'
# }
#
# const commonRegions = [5200081,5200068,5200011,5200024,5200039,5200018,5200074,5200067,5200028,5200014,5200051,5200054,5200040,5200087,5200047,5200080,5200046,5200031,5200063,5200055,5200085,5200035,5200008,5200004,5200050,5200013,5200070,5200023,5200015,5200048,5200043,5200049,5200045,5200061,5200032,5200012,5200042,5200079,5200025,5200016,5200077,5200083,5200082,5200036,5200019,5200006,5200069,5200084,5200071,5200058,5200064,5200086,5200034,5200005,5200027,5200009,5200073,5200033,5200066,5200041,5200029,5200030,5200059,5200072,5200007,5200052]
# var mvnoEnabled = [...commonRegions,5200026,5200021].indexOf(parseInt(window.geoData.regionId)) > -1;
# var vnEnabled = [...commonRegions,5200020,5200060,5200065,5200022,5200038,5200056,5200053,5200003,5200010,5200075,5200037,5200076].indexOf(parseInt(window.geoData.regionId)) > -1;
# var otaEnabled = [...commonRegions,5200020,5200065,5200022,5200038,5200056,5200053,5200003,5200010,5200075,5200037,5200076,5200026,5200021,5200062].indexOf(parseInt(window.geoData.regionId)) > -1;
# var tvEnabled = [...commonRegions,5200020,5200060,5200065,5200022,5200038,5200056,5200053,5200003,5200010,5200075,5200037,5200076,5200026,5200021,5200062].indexOf(parseInt(window.geoData.regionId)) > -1;
#         </script>
#        </div>
#       </div>
#       <div class="settings-tray-editable block block-block-content block-block-contentd1b70201-ba8f-447c-9154-b7ddfc5921c5" data-drupal-settingstray="editable" id="block-allyandexmetricsnoscript">
#        <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item">
#         <noscript>
#          <div>
#           <img alt="" src="https://mc.yandex.ru/watch/46297389" style="position:absolute; left:-9999px;"/>
#          </div>
#         </noscript>
#        </div>
#       </div>
#       <div class="settings-tray-editable block block-block-content block-block-content1533ee91-816f-41f6-9993-ea06a95efe30" data-drupal-settingstray="editable" id="block-b2cyandexmetricsnoscript">
#        <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item">
#         <noscript>
#          <div>
#           <img alt="" src="https://mc.yandex.ru/watch/87747669" style="position:absolute; left:-9999px;"/>
#          </div>
#         </noscript>
#        </div>
#       </div>
#       <div class="settings-tray-editable block block-block-content block-block-content2c11c7b3-7124-419c-9c12-a40f71680950" data-drupal-settingstray="editable" id="block-b2cpodklyucheniestylekitstiley">
#        <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item">
#         <noindex>
#          <script>
#           /* Конфиг виджетов */
#   window.RTK_ASSETS_URL='https://rt-static.rt.ru/rt-ru/2023061611/'; // Путь до собранных виджетов 2023061515
#   window.RTK_ENVIRONMENTS='https://rt-static.rt.ru/widgets-configs/2023053111/b2c-widgets-env.js'; // Переменные окружения(2023042515)
#   window.RTK_SEO_SOURCES={
#     FORMS: 'https://rt-static.rt.ru/seo/forms.min.js',
#     METHODS: 'https://rt-static.rt.ru/seo/seo.min.js'
#   };
#   window.RTK_VUE_GLOBAL='https://rt-static.rt.ru/dist/vue.min.js';
#   window.RTK_COOKIE_NOTIFICATION={
#     message: 'Для удобства работы с сайтом мы используем файлы cookie',
#     explainRef: '/cookie'
#   };
#   window.RTK_SEGMENT='b2c';
#   if(!window.RTK_STYLE) window.RTK_STYLE={};
#   window.RTK_STYLE.molecules = { dynamic: true }
#   window.RTK_STYLE.icons_path='https://rt-static.rt.ru/icons/';
#   window.RTK_STYLE.icons_svg_path='https://rt-static.rt.ru/icons/new/';
#   /* EXPERIMENTAL Body-loading */
#   var
#     mainLoader=document.querySelector('.rtk-loader'),
#     mainWrapper=document.querySelector('.main-wrapper');
#   function hideBlock(el){if(el)el.style.display='none'};
#   function showBlock(el){if(el)el.style.display='block'};
#   showBlock(mainLoader);
#   hideBlock(mainWrapper);
#   /* Функции для сборки скриптов */
#   function addStyle(link){
#     var
#       _style=document.createElement('link'),
#       _container=document.head;
#     _style.href=link;
#     _style.rel="stylesheet";
#     _style.type='text/css';
#     _container.appendChild(_style);
#     return _style;
#   }
#   function addScript(link,noDefer){
#     var
#       _script=document.createElement('script'),
#       _container=document.body||document.head;
#     _script.src=link;
#     _script.type='text/javascript';
#     if(!noDefer)_script.defer=1;
#     _container.appendChild(_script);
#     return _script
#   }
#   function createPreloadedLink(link, as){
#     function _createLink(){return document.createElement('link')}
#     if(window.preloadedLinksSupports === undefined)
#       window.preloadedLinksSupports=_createLink().relList.supports('preload')||0
#     if(window.preloadedLinksSupports) {
#       var _link=_createLink();
#       _link.rel='preload';
#       _link.href=link;
#       _link.as=as||'script';
#       document.head.appendChild(_link);
#     }
#   }
#   // createPreloadedLink(window.RTK_ASSETS_URL+'css/stylekit-styles.css', 'style');
#   addStyle(window.RTK_ASSETS_URL+'css/stylekit-styles.css').onload=function(){
#     showBlock(mainWrapper);
#     hideBlock(mainLoader);
#   };
#   // createPreloadedLink(window.RTK_ENVIRONMENTS);
#   // createPreloadedLink(window.RTK_VUE_GLOBAL);
#   // createPreloadedLink(window.RTK_ASSETS_URL+'css/stylekit-atoms.css', 'style');
#   // createPreloadedLink(window.RTK_ASSETS_URL+'/js/chunk-vendors.js');
#   // createPreloadedLink(window.RTK_ASSETS_URL+'/js/app.js');
#   // createPreloadedLink(window.RTK_ASSETS_URL+'/js/wc-inline-component.js');
#   addScript(window.RTK_ENVIRONMENTS).onload=function(){ // приоритизация
#     document.body.classList+=' env-loaded';
#     addScript(window.RTK_VUE_GLOBAL,1).onload=function(){ //в rt-static отключено кэширование
#       addScript(window.RTK_ASSETS_URL+'js/chunk-vendors.js');
#       addScript(window.RTK_ASSETS_URL+'js/app.js');
#     }
#   }
#          </script>
#          <style>
#           /* убрать это после фикса  начало*/
# .tariff-comparison__close{
# z-index: 2;
# }
# /* убрать это после фикса  конец*/
# .app-dialog__content{background:#fff}
#   /* Основной пакет стилей */
#   /* @import "https://rttest3.south.rt.ru/rt-ru/test/css/stylekit-styles.css"; Так мы перезаписываем стили из компонентов */
#          </style>
#         </noindex>
#         <style>
#          /* Убрать после правки поповеров*/
# .rt-popover-appended{
# z-index: 1000
# }
#         </style>
#         <script>
#          setTimeout(function(){
#
# document.querySelectorAll('.rt-input-v2__input').forEach((input) => {
#   input.addEventListener('input', () => {
#
#     input.closest('.rt-input-v2').querySelectorAll('.rt-input-v2__hidden-el').forEach((el) => {
#       setTimeout(() => {
#         el.remove()
#       }, 100)
#     })
#   })
# })
# },10000)
#         </script>
#        </div>
#       </div>
#       <div class="settings-tray-editable block block-block-content block-block-contenta383db70-568c-4059-80dc-625db60ef96b" data-drupal-settingstray="editable" id="block-baseconfigdlyaallinoneconnection">
#        <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item">
#         <script>
#          if (!window.BASE_CONFIGS) window.BASE_CONFIGS = {}
# 	if (!window.BASE_CONFIGS['allInOneConnection']) window.BASE_CONFIGS['allInOneConnection'] = {}
# 	window.BASE_CONFIGS['allInOneConnection']['nadezhda'] = {
# 		lcs: 'active', // Статус продуктового предложения, выводимого на витрину
# 		orderUrlFlexible: '/flexorder', // URL страницы быстрой заявки для гибких пакетов
# 		detailsUrl: '/about_offer', // URL для перехода при нажатии на кнопку "Настроить тариф" для старых карточек
# 		detailsUrlFlexible: '/fconstructor', // URL для перехода при нажатии на кнопку "Настроить тариф" для карточек ГПП
# 		pR7: window.checkGeo([2492396, 5200048]) ? 'PREPAID' : 'POSTPAIDUNLIM', // Система расчетов для АП (везде - кредитная, на Москве - авансовая)
# 		isFastOrder: false, // Включение быстрой заявки
# 		tvChannelsPopup: false, // Включение Поп-апа с отображением каналов
# 		loaderConfig: { type: 'skeleton', count: 4, rows: 4, sub: 2 }, // Вывод карточек со skeleton лоадером
# 		grouped: true, // В ответе микросервиса данные по карточкам будут сгруппированы по ПП
# 		disabledTvChannels: true, // В ответе микросервиса данные по карточкам вернутся без данных о ТВ-каналах
# 		searchType: 'internet', // Поиск доступных карточек (ПП). internet - поиск ПП с интернетом
# 		disableSearch: false, // Включение автопоиска в ЕПК
# 		cacheResult: true, // Кеширование вкладок Табов на главной
# 		isComparisonDisabled: false, // Скрывает сравнение тарифов на карточках
# 		enableButtonMore: true, // Включение перехода на раздел о тарифе
# 		isOffersAuthorizedZone: true, // Скрывать тарифы для новых клиентов в А/З
# 		poOrder: [ // Порядок отображения карточек продуктовых предложений
# 			{
# 				sortPrice: 'asc',
# 				regionIds: allMrf,
# 				offerIds: []
# 			}
# 		],
#
# 		technology: [ // Вывод определённой технологии
# 			{
# 				regionIds: [
# 					5200024, // Белгородская
# 					5200039, // Брянская
# 					5200074, // Владимирская
# 					5200014, // Воронежская
# 					5200040, // Ивановская
# 					5200080, // Калужская
# 					5200085, // Костромская
# 					5200050, // Курская
# 					5200070, // Липецкая
# 					5200079, // Орловская
# 					5200082, // Рязанская
# 					5200071, // Смоленская
# 					5200086, // Тверская
# 					5200005, // Тульская
# 					5200007, // Ярославская
# 					5200081, // Адыгея
# 					5200075, // Астраханская
# 					5200067, // Волгоградская
# 					5200022, // Дагестан
# 					5200065, // Ингушетия
# 					5200038, // Кабардино-Балкарская
# 					5200056, // Калмыкия
# 					5200053, // Карачаево-Черкесская
# 					5200035, // Краснодарский
# 					5200083, // Ростовская
# 					5200003, // Северная Осетия - Алания
# 					5200010, // Ставропольский
# 				],
# 				technology: 'FTTb'
# 			},
# 			{
# 				regionIds: [
# 					5200058, // Тамбовская
# 				],
# 				technology: 'xPON'
# 			},
# 			{
# 				localityIds: [ // добавить обработку параметра ID ОРПОН н.п.
# 					5202277, // г. Смоленск
# 					5202199, // г. Иваново
# 					5202108, // г. Липецк
# 					5202094, // г. Калуга
# 					5202133, // г. Воронеж
# 					5203031, // г. Обнинск
# 					5202213, // г. Рыбное
# 					5206746, // г. Анапа
# 					5202196, // г. Новороссийск
# 					5202845, // г. Белореченск
# 					5203174, // г. Владикавказ
# 					5202218, // г. Михайловск
# 				],
# 				technology: 'xPON'
# 			},
# 			{
# 				localityIds: [
# 					5244673, // с. Новая Ольшанка
# 				],
# 				technology: 'ADSL'
# 			},
# 		],
#
# 		// poExclude: [ // Исключение тарифов на регионах
# 		// 	{
# 		// 		regionIds: [5200055], // Коми
# 		// 		offerIds: [416108794352]
# 		// 	}
# 		// ],
#
# 		microTabs: [ // Управления микротабами карточки https://confluence.rt.ru/pages/viewpage.action?pageId=180127310
# 			{
# 				code: 'STOCK',
# 				theme: 'purple',
# 				offerIds: [421150311230, 421150719608, 421162904314], // Юбилейные
# 				geoIds: allMrf
# 			},
# 			'WINK_5_IN_1', // Акция 5в1
# 			// {
# 			// 				code: 'STOCK',
# 			// 				theme: 'snow',
# 			// 				offerIds: [420452279472, 420452280608, 420421006148, 420452330602, 420441919218, 420452358442, 420420770902, 420428570350, 420452543046, 420452469806, 420452479254, 420464575682, 420452360310, 420452465206, 420452579278, 420452633086, 420421005138, 420452362692, 420420940180, 420452309814, 420420842376, 420420858614, 420410299442, 420420866188, 420410301432, 420421026738, 420410295558, 420420961560,], // Новогодние карточки
# 			// 				geoIds: allMrf
# 			// },
# 			'STOCK', // Акция ПП
# 			{
# 				code: 'CUSTOM',
# 				name: 'Управление просмотром',
# 				desc: 'Пауза, запись, перемотка и доступ к архиву передач',
# 				// theme: 'orange',
# 				offerIds: [421150719608, 421162904314],
# 				geoIds: allMrf
# 			},
# 			// {
# 			// 				code: 'CUSTOM',
# 			// 				name: '60 дней бесплатно',
# 			// 				desc: 'В одной подписке: до 260 ТВ-каналов, 50000 фильмов и сериалов, 22000 аудиокниг',
# 			// 				theme: 'gradient-border',
# 			// 				offerIds: [416108724590],
# 			// 				geoIds: allMrf
# 			// },
# 			// {
# 			// 				code: 'CUSTOM',
# 			// 				name: 'Удаленка',
# 			// 				desc: 'Видеоконференции без потери качества сигнала',
# 			// 				theme: 'orange',
# 			// 				offerIds: [416485734532, 416517665024, 416536668626, 416599784728, 416109150988, 415057714720, 415118408998, 416110057346, 416213102746, 415117615804, 416108731672],
# 			// 				geoIds: allMrf
# 			// },
# 			{
# 				code: 'CUSTOM',
# 				name: 'Опция',
# 				desc: 'Скоростной интернет для любых задач',
# 				theme: 'orange',
# 				offerIds: [414217965146],
# 				geoIds: allMrf
# 			},
# 			'GAMING_ADVANTAGES', // Игровые опции
# 			'MAIL_RU_CLOUD', // Облако MAIL
# 			'PROMO',
# 			'DISCOUNT', // Скидка
# 			'SIM_CARDS', // Сим-карты
# 			'ANTIVIRUS', // Антивирус
# 			'Multiscreen', // Просмотр на 5 устройств
# 			'turbo_night', // Турбо-ночь
# 			'HARDWARE', // Оборудование
# 			// {code: 'HARDWARE', hide: true},
# 		],
#
# 		optionsOrder: [ // Порядок отображения продуктов
# 			{
# 				aboveLine: [
# 					{
# 						productCode: 'SHPD',
# 						limit: 1,
# 						collapsed: true,
# 						expandable: true
# 					},
# 					{
# 						productCode: 'IPTV',
# 						limit: 0,
# 						collapsed: true,
# 						expandable: true
# 					},
# 					{
# 						productCode: 'Digital_TV',
# 						limit: 0,
# 						collapsed: true,
# 						expandable: true
# 					},
# 					{
# 						productCode: 'ONLINE_CINEMA',
# 						limit: 0,
# 						collapsed: true,
# 						expandable: true
# 					},
# 					{
# 						productCode: 'GAMING_ADVANTAGES',
# 						limit: 0,
# 						hidden: true,
# 						collapsed: true,
# 						expandable: true
# 					},
# 					{
# 						productCode: 'SOTOVAYA_SVYAZ_MVNO',
# 						limit: 1,
# 						collapsed: true,
# 						expandable: true
# 					},
# 					{
# 						productCode: 'VIDEONABLYUDENIE',
# 						limit: 1,
# 						collapsed: true,
# 						expandable: true,
# 						show: [
# 							'VIDIO_SURV_SERV',
# 							// 'camera'
# 						],
# 					},
# 					{
# 						productCode: 'FIKSIROVANNAYA_SVYAZ',
# 						limit: 0,
# 						hidden: true,
# 						collapsed: true,
# 						expandable: true
# 					},
# 					{
# 						productCode: 'turbo_night',
# 						limit: 0,
# 						hidden: true,
# 						collapsed: true,
# 						expandable: true
# 					},
# 					{
# 						productCode: 'MAIL_RU_IN_TARIF',
# 						limit: 0,
# 						hidden: true,
# 						collapsed: true,
# 						expandable: true
# 					},
# 					{
# 						productCode: 'MAIL_RU_8+',
# 						limit: 0,
# 						hidden: true,
# 						collapsed: true,
# 						expandable: true
# 					},
# 					{
# 						productCode: 'MAIL_RU_CLOUD',
# 						limit: 0,
# 						hidden: true,
# 						collapsed: true,
# 						expandable: true
# 					},
# 					{
# 						productCode: 'ROSTELECOM_LYCEUM',
# 						limit: 0,
# 						hidden: true,
# 						collapsed: true,
# 						expandable: true
# 					}
# 				],
# 				underLine: [
# 					{
# 						productCode: 'STOCK',
# 						options: [
# 							'Local_Telephony',
# 							'intercom_mobile',
# 							'intercom_fixed',
# 							'artificial_product_stock',
# 							'artificial_product_discount',
# 							'artificial_product_hardware'
# 						]
# 					},
# 					'PROMO',
# 					'DISCOUNT',
# 					'HARDWARE',
# 					'STOCK',
# 				]
# 			},
# 		],
#
# 		cartBtnTitle: [ // Название на кнопке
# 			{
# 				geoIds: allMrf,
# 				offerIds: ['421150254198'],
# 				text: '1 месяц со скидкой'
# 			},
# 			{
# 				geoIds: allMrf,
# 				offerIds: ['421150311230'],
# 				text: '2 месяца со скидкой'
# 			},
# 			{
# 				geoIds: allMrf,
# 				offerIds: ['421150719608'],
# 				text: '3 месяца со скидкой'
# 			},
# 			{
# 				geoIds: allMrf,
# 				offerIds: ['421162904314'],
# 				text: '4 месяца со скидкой'
# 			},
# 		],
#
# 		// customThemes: [ // Новое оформление карточек
# 		// 	{
# 		// 		offerIds: [421150254198, 421150311230, 421150719608, 421162904314],
# 		// 		geoIds: allMrf,
# 		// 		theme: 'jubilee'
# 		// 	}
# 		// ],
#
# 		badges: [ // Изменяет оформление карточки
# 			{
# 				code: 'CUSTOM',
# 				theme: 'gradient',
# 				offerIds: [
# 					418391530970, 419213233284, 418807184574, 418400678054,
# 				],
# 				geoIds: allMrf
# 			},
# 			{
# 				discount: '%',
# 				offerIds: [421150254198, 421150311230, 421150719608, 421162904314],
# 				geoIds: allMrf,
# 				theme: 'jubilee'
# 			},
# 			// {
# 			// 	code: 'CUSTOM',
# 			// 	theme: 'snow',
# 			// 	offerIds: [
# 			// 		420452279472, 420452280608, 420421006148, 420452330602, 420441919218, 420452358442, 420420770902, 420428570350, 420452543046, 420452469806, 420452479254, 420464575682, 420452360310, 420452465206, 420452579278, 420452633086, 420421005138, 420452362692, 420420940180, 420452309814, 420420842376, 420420858614, 420410299442, 420420866188, 420410301432, 420421026738, 420410295558, 420420961560,  // Новогодние карточки
# 			// 	],
# 			// 	geoIds: allMrf
# 			// },
# 			{
# 				code: 'CUSTOM',
# 				theme: 'orange',
# 				offerIds: [
# 					416108731672, 415117615804, 416113248942, 415135506576, 416110057346, 415118408998, 416108794352, 416108876570, 415112046902, 415144062894, 416108906276, 416111414696, 415089635588, 416109150988, 415057714720, 415100720266, 421150254198, 421150311230, 421150719608, 421162904314,
# 				],
# 				geoIds: allMrf
# 			},
# 		],
#
# 	}
#         </script>
#        </div>
#       </div>
#       <div class="settings-tray-editable block block-rit-rtkid block-rtkid-block" data-drupal-settingstray="editable" id="block-blokrtkid">
#        <script>
#         window.RTK_USER_AUTH_CONTOUR="prod";
# window.RTK_USER_AUTH_ENDPOINT="https://b2c.passport.rt.ru";
# window.RTK_USER_AUTH_REALM="b2c";
# window.RTK_USER_AUTH_APP="lk_decosystems";
# window.isNewRtkHeader=true;
#        </script>
#        <div class="wc-inline">
#         <client-only>
#          <user-panel v-if="global.isNewRtkHeader">
#          </user-panel>
#         </client-only>
#        </div>
#        <style>
#         .rtk-user-panel__enter{
#   font-size:14px;
#   line-height:20px;
#   position:relative;
#   top:2px
# }
# .rtk-user-panel__link{
#   font-size:14px;
#   line-height:20px;
#   color:rgba(16,24,40,0.7);
#   transition: color 0.3s ease-in-out;
# }
# .rtk-user-panel__link:hover{color:#FF4F12}
# .rtk-user-panel__sp{
#   border-left:1px solid rgba(16,24,40,0.25);
#   height:24px;
# }
# .header__rtkid{color:rgba(16,24,40,1);margin-bottom: -1px}
# .rtkid-on .header__segments-menu .rtk-links__item.is--active:after{
#   background:#FF4F12;
#   width:calc(100% - 10px);
#   margin:auto;
#   top:30px;
#   right:0;
# }
# /* Panels */
# .rtkid-on .header__p-top,
# .rtkid-on .header__p-top > div,
# .rtkid-on .header__p-top > div > div{min-height:59px}
# /* Segments-menu */
# .segment-b2c.rtkid-on .header__p-top-right .rtk-links .rtk-links__drop-btn{display: block;padding-right: 19px;}
# .rtkid-on .header__p-top-right .rtk-links .rtk-links__drop-btn-lbl{display:initial}
# .rtkid-on .header__p-top-right .rtk-links .rtk-links__drop-btn-fe{position: absolute;right: 10px;top: 10px;}
# .rtkid-on .header__segments-menu .rtk-links__list .rtk-links__item{transition:color 0.3s ease-in-out}
# .rtkid-on .header__segments-menu .rtk-links .rtk-links__drop-btn:hover,
# .rtkid-on .header__segments-menu .rtk-links.is--opened .rtk-links__drop-btn,
# .rtkid-on .header__segments-menu .rtk-links__list .rtk-links__item:not(.is--active):hover,
# .rtkid-on .header__segments-menu .rtk-links__drop-list .rtk-links__item:hover{color:#FF4F12}
# .rtkid-on .header__segments-menu .rtk-links.is--opened .rtk-links__drop-btn svg,
# .rtkid-on .header__segments-menu .rtk-links__drop-btn:hover svg{fill:#FF4F12}
# .rtkid-on .header__segments-menu .rtk-links .rtk-links__drop-btn:hover .rtk-links__drop-btn-fe,
# .rtkid-on .header__segments-menu .rtk-links.is--opened .rtk-links__drop-btn .rtk-links__drop-btn-fe{background-image: url('data:image/svg+xml;base64,...');}
# /* Geo */
# .rtkid-on .change-region .geo-name{transition:color 0.3s ease-in-out}
# .rtkid-on .change-region:hover svg{fill:#FF4F12}
# .rtkid-on .change-region:hover .geo-name{color:#FF4F12;opacity:1}
# /* Product-menu */
# .rtkid-on .rtk-tabs__item .el-link,
# .rtkid-on .rtk-tabs__item a:not(.btn),
# .rtkid-on .rtk-tabs__item span{font-weight:500!important}
# .rtkid-on .rtk-tabs__item span{color:inherit;text-shadow:none!important}
# .rtkid-on .rtk-tabs__item .main-nav__link{font-size:16px;letter-spacing:0.2px;transition:color 0.3s ease-in-out}
# .rtkid-on .main-nav__link-wrap.js-hover-active-link .main-nav__link,
# .rtkid-on .main-nav-subcategory__item .main-nav__link:hover,
# .rtkid-on .rtk-tabs__item .main-nav__link:hover{color:#FF4F12}
# .rtkid-on .main-nav-subcategory__item .main-nav__link,
# .rtkid-on .main-nav__link-popup-wrap .main-nav__link{transition:color 0.3s ease-in-out}
# .rtkid-on .main-nav__link-popup-wrap .main-nav__link:hover{color:#FF4F12}
# /* TMP */
# .rtkid-on .rt-header__ab-content-block .rt-link--purple{color:rgba(16,24,40,1);transition:color 0.3s ease-in-out}
# .rtkid-on .rt-header__ab-content-block .rt-link--purple:hover{color:#FF4F12}
# /* FPC */
# .header:not(.ready) .rtk-user-panel__enter,
# .header [v-if] {display:none}
#
# @media(min-width:1280px) and (max-width:1399px){.rtkid-on .ntwrap{
#   max-width: 1280px; /* included 20*2 for inner spaces */
# }}
# @media(min-width:1400px) and (max-width:1599px){.rtkid-on .ntwrap{
#   padding-left:80px;
#   padding-right:80px;
# }}
# @media(min-width:1600px){
# .rtkid-on .ntwrap{max-width:1480px}
# }
# /* Override header elements */
# @media(max-width:767px){
#   .rtk-user-panel__enter{font-size:13px}
#   .rtkid-on{height:56px}
#   /* .rtkid-on .header__segments-menu{display:none} */
#   .rtkid-on .header__p-top{height:100%}
#   .rtkid-on .header__p-top,
#   .rtkid-on .header__p-top>div,
#   .rtkid-on .header__p-top>div>div{min-height:56px}
#   .rtkid-on .rtk-logo{
#     width:108px;
#     height:28px;
#     top:-4px;
#   }
#   .rtkid-on .header__burger.expanded .b-top{top:-1px}
#   .rtkid-on .header__segments-menu .rtk-links{margin-bottom:-6px}
#   .rtkid-on .header__p-top-right .nav__change-region{left:20px}
#   .rtkid-on .header__upor{
#     position: absolute;
#     left:20px;
#     top:16px;
#   }
#   .rtkid-on .header__rtkid h2{display:block}
#   .rtkid-on .header__rtkid h2+*{display:none}
# }
# @media(max-width:1024px){
#   .rtkid-on .header__p-top{border-bottom:none}
#   .rtkid-on .header__burger{top:-1px;right:22px}
#   .rtkid-on .header__burger .b{height:2px}
#   .rtkid-on .header__burger .b-top{top:1px}
#   .rtkid-on .header__burger .b-middle{top:7px}
#   .rtkid-on .header__burger .b-bottom{top:13px}
# }
# @media(min-width:768px) and (max-width:1024px){
#   .rtkid-on .header__p-top{border-bottom:none}
#   .rtkid-on .header__segments-menu{
#     display:flex;
#     align-items:flex-end;
#     margin-bottom:-2px;
#     position:relative;
#     z-index:1002;
#   }
#   .rtkid-on .header__segments-menu .rtk-links{margin-bottom:-6px}
#   .rtkid-on .header__segments-menu .rtk-links__item{
#     font-size:14px;
#     line-height: 21px;
#     margin:0 5px;
#     padding:0 5px;
#     position:relative;
#     white-space:nowrap;
#   }
#   .rtkid-on .header__segments-menu .rtk-links__item.is--active{cursor:pointer}
#   .rtkid-on .header__segments-menu .rtk-links__item.is--active:after{
#     content:'';
#     display:block;
#     position:absolute;
#     height: 2px;
#     left: 0;
#     top:33px;
#   }
#   .rtkid-on .header__segments-menu .rtk-links__drop{margin-left:9px}
#   .rtkid-on .header__segments-menu .rtk-links__drop-list{
#     left:0;
#     top:37px;
#     padding:20px 10px;
#   }
#   .rtkid-on .header__segments-menu .rtk-links__drop-list .rtk-links__item+.rtk-links__item{
#     margin-top:23px
#   }
#   .rtkid-on .header__burger:not(.collapsed) .b-top{top:-1px}
#   .rtkid-on .header__upor{margin-bottom:-1px}
#   .header__rtkid{margin-bottom:-2px}
#   .rtkid-on .rtk-logo{
#     margin-top:-12px;
#     width:140px;
#     height:36px;
#   }
# }
# @media(min-width:1025px){
#   .rtkid-on .header__logo .rtk-logo{margin-right:30px;height:36px;top:-3px}
#   .rtkid-on .header__p-nav,
#   .rtkid-on .main-nav__wrap{height:56px}
#   .rtkid-on .main-nav__link-wrap{margin-top:3px;padding: 0 16px;}
#   .rtkid-on .main-nav__link-wrap:first-child{padding-left:0}
#   /*.rtkid-on .header__p-nav .main-nav__link span{letter-spacing: -0.9px}*/
#   .rtkid-on .nav__change-region .geo-name{margin-left: 3px}
#   .rtkid-on .header__p-top .change-region-popup .notification{top:60px}
#   .rtkid-on .header__links{margin-right:55px}
#   .rtkid-on .header__segments-menu .rtk-links{margin-bottom:-1px}
#   .rtkid-on .header__segments-menu .rtk-links__drop-list{
#     border:none;
#     box-shadow:0px 0px 20px rgba(28, 41, 61, 0.05), 0px 12px 20px rgba(28, 41, 61, 0.06);
#     padding:0 20px 20px;
#     top:35px;
#   }
# }
# /* @media(min-width:1025px) and (max-width:1300px){
#   .rtkid-on .main-nav__link-wrap{padding:0 16px}
#   .rtkid-on .main-nav__link-wrap:first-child{padding-left:0}
# } */
#        </style>
#        <noindex>
#         <script>
#          window.waitLoaded('.header', function (headerEl) {
#   if (!headerEl) return
#   window.waitLoaded('#userPanelComponent', function (el) {
#     if (!el) return
#     const cmp = el.__vue__
#     if (!cmp) return
#     window.RTK_AUTH_LINK=cmp.ssoLink
#     const manager = cmp.init()
#     const blockName = 'short-name-block-id'
#     const checkerDelay = 3000
#     manager.subscribe('onAuthenticated', function (isAuth) {
#       window.RTK_EVENT_BUS.setData('userAuthorized', isAuth)
#       if (isAuth) {
#         manager.renderShortNameWidget(blockName)
#         window.RTK_AUTH_API=manager.api
#       }
#       //console.log('onAuthenticated', isAuth, cmp, manager)
#       cmp.onAuthenticated(isAuth)
#     })
#     // проверяем валидность куки
#     // const refreshToken=()=>window.location.href='//start.rt.ru'
#     // setTimeout(() => {
#     //   //console.log('reAuthenticate', manager.isAuthenticated, !!document.getElementById(blockName).innerHTML, cmp, manager)
#     //   if (manager.isAuthenticated && !document.getElementById(blockName).innerHTML) {
#     //     manager.api('/v2/lego-session').then(resp=>{
#     //       if(!resp.data.role){
#     //         refreshToken()
#     //       }
#     //     }).catch(() => {
#     //       refreshToken()
#     //     })
#     //   }
#     // }, checkerDelay)
#   })
# })
#         </script>
#        </noindex>
#       </div>
#       <div class="settings-tray-editable block block-block-content block-block-contentb84f4403-2443-45a0-aa0c-db52c87529f8" data-drupal-settingstray="editable" id="block-b2cnastroykishapki">
#        <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item">
#         <div id="mainHeader">
#         </div>
#         <script data-ssr="">
#          window.RTK_SEGMENT='b2c';
#   const isMskLocality=window.geoData.localityId=='5200048'
#   const convertMosoblastRegion=data=>Object.assign({region:5200043,region_name:'Московская',region_eng:'moskovskaja',region_kladr_id:5000000000000},data)
#
#   window.RTK_HEADER = {
#     template: 'panels',
#     type: 'scroll-top-sticky',
#     logo: {
#       fillColor: '#7800ff',
#       firstColor: '#ff4f12',
#       text: true
#     },
#     navTopMDShow: true,
#     navMDHide: false,
#     navTDHide: false,
#     mobileTabs: false,
#     // Ссылки для сквозного меню и мобильных вкладок
# ...
#     function setHeaderPhone(phone,desc){
#         if(!phone) return;
#         window.headerPhone.title=phone;
#         window.headerPhone.url=convertStrToTel(phone);
#         if(desc)window.headerPhone.desc=desc;
#     }
#     function setListPhone(phone,desc,key){
#         if(!phone) return;
#         var phoneItem=window.phonesList[key||0];
#         if(!phoneItem) return;
#         phoneItem.title=phone;
#         phoneItem.url=convertStrToTel(phone);
#         if(desc)phoneItem.desc=desc;
#     }
#     function setBadges(links){
#         var
#             getBadge=function(badge){return document.getElementById(badge);},
#             badgeApple=getBadge('apple-store'),
#             badgeGoogle=getBadge('google-store'),
#             badgeHuawei=getBadge('app-gallery');
#         if(badgeApple&&links.apple)badgeApple.href=links.apple;
#         if(badgeGoogle&&links.google)badgeGoogle.href=links.google;
#         if(badgeHuawei)badgeHuawei.style.display='none';
#     }
#     function initPhones(){
#         if(isCustomPhones) return;
#         if(isOnlime){
#             setBadges(appsLinks);
#             setListPhone(onlimeSupportPhone,null,1);
#             setListPhone(getPhone(phonesOnlime));
#         }else if(isSZ){
#             setListPhone(getPhone(phonesSZ));
#             setListPhone(mainPhone,null,1);
#         }else if(isUral){
#             setListPhone(getPhone(phonesUral));
#             setListPhone(uralSupportPhone,null,1);
#         }else if(isMosoblast){
#             setListPhone(getPhone(phonesMosoblast));
#             setListPhone(federalSupportPhone,null,1);
#         }else if(isFederal){
#             var
#                 federalCallPhone=getPhone(phonesCenter);
#             setListPhone(federalCallPhone);
#             setListPhone(federalSupportPhone,null,1)
#         }else if(isNewRule){
#             setListPhone(window.checkGeo(window.mrfYug) ? '8 800 301 38 60' : '8 800 301 84 30');
#         }else{
#             window.phonesList.splice(0,1);
#             window.phonesList[0].desc=phoneCombineDesc;
#         }
#     }
#     initPhones();
#           </script>
#          </noindex>
#         </div>
#        </div>
#        <div class="settings-tray-editable block block-block-content block-block-contentab947991-7a72-4d4d-adce-b8618a82792a" data-drupal-settingstray="editable" id="block-b2crazmetkaglavnoystranicy">
#         <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item">
#          <script>
#           // RTRU-15179 Разметка главной страницы
# (function () {
#   const mainShowcaseSelector = '[about="/main_noindex"] .web-component'
#   function isUserAuth() {
#     let status = false
#     try {
#       if (window.sessionStorage.getItem('is_user_auth')==='1') status = true
#     } catch (err) { }
#     return status
#   }
#   function markActionForHomePage(eventName, val) {
#     const pushData = { [eventName]: val }
#     if (isUserAuth()) pushData[eventName] = { [val]: 'rostelecom' }
#     const data = { b2c_head_click: { [window._getGaClientId()]: pushData } }
#     if (window.ym) window.ym(window.RTK_YANDEX_COUNTER_IDS.B2C, 'params', data)
#   }
#
#   // Tabs
#   waitLoaded(`${mainShowcaseSelector} .rt-tabs`, el => {
#     if (!el) return
#     el.querySelectorAll('.rt-tabs-nav-v2_item button').forEach(tab => tab.addEventListener('click', e => markActionForHomePage('main_tab', tab.innerText)))
#   })
#
#   // Tariff cards
#   waitLoaded(`${mainShowcaseSelector} .rtk-fo__case .rt-tariff`, card => {
#     if (!card) return
#     document.querySelectorAll(`${mainShowcaseSelector} .rtk-fo__case .rt-tariff`).forEach(card => {
#       card.querySelectorAll('.rt-font-right button, .rt-tariff__link')
#         .forEach(btn => btn.addEventListener('click', e =>
#           markActionForHomePage('card_click', card.querySelector('.rt-tariff__title').innerText)
#         ))
#     })
#   })
#
#   // Payment
#   waitLoaded('.web-component .payment-form', form => {
#     if (!form) return
#     const cmp = form.__vue__
#     form.querySelector('button').addEventListener('click', e =>
#       markActionForHomePage('payment', cmp.account && cmp.sum ? 'Перейти к оплате' : 'error'))
#   })
#   waitLoaded('.web-component .payment-search', btn => {
#     if (!btn) return
#     btn.addEventListener('click', e =>
#       markActionForHomePage('payment_search', 'Поиск платежа')
#     )
#   })
#   waitLoaded('.web-component .payment-other', btn => {
#     if (!btn) return
#     btn.addEventListener('click', e =>
#       markActionForHomePage('payment_other', 'Оплата услуг других организаций')
#     )
#   })
#
#   // Popular services
#   waitLoaded('.web-component .popular-services .popular-services__cards', cards => {
#     if (!cards) return
#     cards.querySelectorAll('a').forEach(link => {
#       if (!link.parentElement) return // Avoid carousel's slots resolver effect
#       link.addEventListener('click', e =>
#         markActionForHomePage('popular_services', link.querySelector('.rt-card-image__label')?.innerText)
#       )
#     })
#   })
#
#   // Product banner
#   waitLoaded('.web-component .productBanner', banner => {
#     if (!banner) return
#     banner.querySelector('a').addEventListener('click', e =>
#       markActionForHomePage('banner_product', banner.querySelector('.productBanner__title')?.innerText)
#     )
#   })
#
#   // Special services
#   waitLoaded('.web-component .special-services .special-services__cards', cards => {
#     if (!cards) return
#     cards.querySelectorAll('a').forEach(link => {
#       if (!link.parentElement) return // Avoid carousel's slots resolver effect
#       link.addEventListener('click', e =>
#         markActionForHomePage('special_offers', link.querySelector('.rt-card-image__label')?.innerText)
#       )
#     })
#   })
#
#   // Blog announces
#   waitLoaded('#announce .announce', a => {
#     if (!a) return
#     function getAnnounceTitle(link) {
#       const textEl = link.classList.contains('announce__weekly__cover') ? link.parentElement.querySelector('.announce__weekly__info__title') : link
#       return textEl.innerText
#     }
#     a.querySelectorAll('a').forEach(link => {
#       if (!link.href) return
#       link.addEventListener('click', e =>
#         markActionForHomePage('blog_click', getAnnounceTitle(link))
#       )
#     })
#   })
# })()
#          </script>
#         </div>
#        </div>
#        <div class="settings-tray-editable block block-block-content block-block-contentdfdc696a-80ed-4dff-b616-75a5c9847c1c" data-drupal-settingstray="editable" id="block-baseconfigdlyalanding-4">
#         <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item">
#          <script>
#           if (!window.BASE_CONFIGS) window.BASE_CONFIGS = {}
# 	if (!window.BASE_CONFIGS['landing']) window.BASE_CONFIGS['landing'] = {}
# 	window.BASE_CONFIGS['landing']['newLanding'] = {
# 		cardsLoaderV2Type: 'main', // Настройка нового лоадера
# 		choiceCatalog: true, //
# 		redirectToMainIfNoResults: true, // Редирект, если нет тарифа
# 		isLegals: true, // Вывод лигала
# 		lcs: 'active', // Статус продуктовых предложений
# 		disableSearch: true, // Отключение автопоиска тарифа
# 		template: 'lightplus', // Шаблон
# 		validateFieldsAddress: ['house'], // Валидация адреса до дома/квартиры
# 		checkTechCapability: [5200048], // Проверка ТхВ Москва всегда
#
# 		positionPrice: 'form', // Цена у кнопки
#
# 		title: 'Отправьте заявку',
# 		subTitle: 'Наш специалист свяжется с Вами в ближайшее время',
# 		buttonTitle: "Подключить",
#
# 		productSort: [ // Сортировка продуктов
# 			{ productCodes: ["SHPD", "IPTV", "SOTOVAYA_SVYAZ_MVNO", "STOCK"], },
# 		],
#
# 		includesProductsChannels: ["Multiscreen", "Multiroom"], // доп.продукты ТВ
#
# 		// auxiliaryBlock: { // Настройка дополнительного текста
# 		//  text: 'Хотите посмотреть другие тарифы доступные для подключения?',
# 		//  textBtn: 'Перейти на сайт',
# 		//  link: '/homeinternet'
# 		// },
#
# 		labelsTechCapability: { // Уведомления по умолчанию для проверки ТхВ
# 			gpon: {
# 				title: 'Ура! Вы можете подключить GPON Turbo',
# 				popover: 'GPON (Gigabit-capable Passive Optical Networks) — передовая технология, позволяющая предоставлять интернет на качественно новом уровне. Пропускная способность сети составляет 1 Гбит/сек, что на практике означает возможность подключаться к сети с нескольких устройств одновременно без «зависаний» и долгой загрузки.'
# 			},
# 			docsis: {
# 				title: 'Предложим альтернативу GPON Turbo',
# 				popover: 'DOCSIS — ( Data Over Cable Service Interface Specifications) стандарт передачи данных по коаксиальному (телевизионному) кабелю'
# 			},
# 			xdsl: 'Ура! Вам доступно подключение интернета',
# 			success: 'Ура! Вам доступно высокоскоростное подключение',
# 			question: 'Оператор уточнит возможность подключения',
# 			error: 'К сожалению, пока нет возможности подключения'
# 		},
# 	}
#          </script>
#         </div>
#        </div>
#        <div class="settings-tray-editable block block-block-content block-block-content35f81b5e-62c7-4c7f-8e62-5efd6f467e70" data-drupal-settingstray="editable" id="block-gapushformenu">
#         <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item">
#          <script>
#           const counters={b2c:'87747669',b2b:'46297389',b2o:'87747838'}
# const counterId=counters[window.RTK_SEGMENT]||console.error('Ошибка получения счетчика аналитики')
# const ymSafePush=(...data)=>{
#   if(window.RTK_SEGMENT!=='b2b')ym(counters['b2b'], ...data) // b2b=all(omg) @see RTRU-15163
#   ym(counterId,...data)
# }
# const promoBlockSelector='.rt-header-menu-promo-block'
# // const isRtkUser=()=>+window.sessionStorage.getItem('is_user_auth')?'rostelecom':null // @TMP
# if(typeof ym!=='function') ym=(...a)=>console.log('YM.debug',a,JSON.stringify(a))
#
# function pushGA(data) {
#   if (!data.event || data.event === 'b2c') return
#   if (!window.dataLayer) window.dataLayer = []
#   window.dataLayer.push(data)
# }
# const promoBlockPush=data=>{
#   const events={
#     event:window.RTK_SEGMENT,
#     type:'nav',
#     value:'element_click',
#     label:'banner_nav',
#     content:data.title||'Заголовок не определен',
#     num:'NA'
#   }
#   ymSafePush('reachGoal','events',{events})
#   if(window.RTK_SEGMENT === 'b2c'){
#     const authorized=isRtkUser()
#     const params={[`${window.RTK_SEGMENT}_banner_nav`]:{}}
#     params[`${window.RTK_SEGMENT}_banner_nav`][_getGaClientId()]=(authorized)?{[data.title]:authorized}:data.title
#     ymSafePush('params',params)
#   }
# }
#
# if (window.RTK_SEGMENT === 'b2b') {
#   // RTRUB2B-7204
#   document.addEventListener('click', function(e) {
#     if(e.target) {
#       const isCurrentNodeIsA = e.target.classList.contains('main-nav__link')
#       const isParentNodeIsA =  e.target?.parentNode.classList.contains('main-nav__link')
#       if (isCurrentNodeIsA || isParentNodeIsA) {
#         const objectToSend = {
#           event:'b2b',
#           type: 'nav',
#           value: 'element_click',
#           label: 'main_nav',
#           content: e.target.innerText.trim(),
#           num: 'NA',
#         }
#         pushGA(objectToSend)
#         if(ym) ym(46297389,  'reachGoal', 'events', { events: objectToSend})
#       }
#     }
#     else if(e.target &&  e.target.nodeName == 'A' && e.target.closest('.promo-block')) {
#       const objectToSend = {
#       event:'b2b',
#       type: 'nav',
#       value: 'element_click',
#       label: 'banner_nav',
#       content: e.target.innerText.trim(),
#       num: 'NA',
#       }
#       pushGA(objectToSend)
#       if(ym) ym(46297389,  'reachGoal', 'events', { events: objectToSend})
#     }
#   })
# } else {
#   // RTRU-14912
#   waitLoaded('.header.ready',h=>{
#     if(!h)return
#     // Menu-links
#     document.querySelectorAll('.main-nav__link').forEach(l=>{
#       if(l.href)l.addEventListener('click',e=>{
#         const parentTitle=l.closest('[data-parent-link]')?.getAttribute('data-parent-link')
#         const authorized=isRtkUser()
#         const params={[`${window.RTK_SEGMENT}_main_nav`]:{}}
#         const v=(authorized)?{[l.innerText]:authorized}:l.innerText
#         params[`${window.RTK_SEGMENT}_main_nav`][_getGaClientId()]=parentTitle?{[parentTitle]:v}:v
#         ymSafePush('params',params)
#       })
#     })
#     // Menu promo-block
#     // waitLoaded(promoBlockSelector, pb=>{
#     //   if(!pb)return
#     //   document.querySelectorAll(promoBlockSelector).forEach(l=>{
#     //     if(l.href)l.addEventListener('click',e=>{
#     //       const title=l.querySelector('.rt-header-menu-promo-block__title')?.innerText?.trim()||'Ошибка верстки, заголовок'
#     //       promoBlockPush({title})
#     //     })
#     //   })
#     // })
#   })
# }
#
# if (window.RTK_HEADER) {
#   // Deprecated, @TODO - move to SSR
#   window.RTK_HEADER.linkClick=val=>{
#     pushGA({
#       event: RTK_SEGMENT,
#       type: 'main_nav',
#       value: val
#     })
#   }
#   window.RTK_HEADER.bannerLinkClick=val=>{
#     pushGA({
#       event: RTK_SEGMENT,
#       type: 'banner_nav',
#       value: val.title
#     })
#     promoBlockPush(val)
#   }
#   window.RTK_HEADER.burgerLinkClick=val=>{
#     const objectToSend = {
#       event:RTK_SEGMENT,
#       type:'nav',
#       value:'element_click',
#       label:'main_nav',
#       content:val,
#       num:'NA',
#     }
#     pushGA(objectToSend)
#     ymSafePush('reachGoal','events',{events:objectToSend})
#   }
#   window.RTK_HEADER.confirmGeoNotificationOpened=()=>{
#     ymSafePush('reachGoal','b2c_view_geo_popup_Y')
#   }
# }
#
# // FAQ annotations, if not exists .faq-custom-push
# waitLoaded('header', function () {
#   waitLoaded('.rt-annotation', function (el) {
#     if (!el) return;
#     var elFaq = document.querySelector('#faq')
#     if (!elFaq || elFaq.classList.contains('faq-custom-push')) return;
#     var items = elFaq.parentElement.querySelectorAll('.rt-annotation__title');
#     items && items.forEach(function (i) {
#       i.addEventListener('click', function () {
#         pushGA({
#           event: window.RTK_SEGMENT,
#           type: 'support_question',
#           value: (i.textContent).trim()
#         })
#       })
#     })
#   })
# })
#
# // App-Stores links
# waitLoaded('.web-component .rtk-footer__badges', function (el) {
#   if (!el) return
#   var map = [['.rtk-badge_google-play', 'google-play'], ['.rtk-badge_app-store', 'app-store']]
#   map.forEach(function (data) {
#     var links = document.querySelectorAll(data[0])
#     if (!links) return
#     links.forEach(function (el) {
#       el.addEventListener('click', function () {
#         pushGA({
#           event: RTK_SEGMENT,
#           type: 'store',
#           value: data[1]
#         })
#       })
#     })
#   })
# })
#          </script>
#         </div>
#        </div>
#        <div class="settings-tray-editable block block-block-content block-block-contentb5ada37d-d79b-4b94-951c-752990f121a5" data-drupal-settingstray="editable" id="block-gapushfortopmenu">
#         <div class="clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item">
#          <script>
#           var registerGaTopMenuRight = function (items)  {
#
#     var menuNav = document.querySelectorAll('.segmentNavGa')
#
#
#     menuNav.forEach(
#       function (nav) {
#         nav.children.forEach(
#           function (link) {
#             link.addEventListener('click', function () {
#               var segment = RTK_UTILS ? RTK_UTILS.currentSegment : 'b2c'
#               if(segment === 'b2c') return
#               dataLayer.push({
#                   'event': segment,
#                   'type': 'header_nav',
#                   'value': link.textContent
#                 }
#               )
#             })
#           }
#         )
#       }
#     )
#
#   }
#   window.addEventListener('load', registerGaTopMenuRight)
#          </script>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <noscript style="color:#FA5A5A;font-size:16px;font-weight:bold;position:absolute;top:0;z-index:9999;background-color:rgba(0, 0, 0, 0.7);width:100%;padding:8px 0;display:flex;justify-content:center;align-items:center">
#    <div>
#     Упс! В вашем браузере не включен JavaScript. Включите его
#     <a href="http://enable-javascript.com/ru" style="color: #FDFAFA;" target="_blank">
#      в настройках
#     </a>
#     и обновите страницу
#    </div>
#   </noscript>
#  </body>
# </html>

# %%
# Поиск всех ссылок (тэг а)
links = soup.find_all("a")

# %%
# Печатаем ссылки
for link in links:
        print(link.text, link.attrs.get('href'))
# Out:
# Cookies /cookie
# Cookies /cookie
# Войти None
#  https://start.rt.ru/
#
# Войти
#  None
#
#
#
#  None
#  Видеонаблюдение
#  /videocontrol
# с ТВ и онлайн-кинотеатром /homeinternet/internet_tv
# с мобильной связью /homeinternet/internet_mobile
# с ТВ, онлайн-кинотеатром и мобильной связью /homeinternet/internet_tv_mobile
# Все пакеты /packages/tariffs
# Тарифы для геймеров /igrovoy
# Мобильная связь /mobile/mobile_tariff
# Переход со своим номером /mobile_number_portability
# Домашний интернет /homeinternet
# Интернет в частный дом /homeinternet/private_house
# Антивирусы /homeinternet/antiviruses
# Облачное хранилище /vk_cloud
# Родительский контроль /parental_control
# Роутеры и модемы /homeinternet/equipment
# О видеосервисе /hometv
# Тарифы /homeinternet/internet_tv
# ТВ-приставка Wink+ /hometv/wifitvwink
# Bluetooth пульт для Wink+ /pult_wink
# Голосовое управление /capsula
# Оборудование /hometv/equipment
# Умный дом /smarthome
# Умная колонка /capsula
# Умные детские часы /watch
# Ключ: решение для ЖК и домов https://key.rt.ru
# Цифровое ТВ /digitaltv
# Кабельное ТВ /hometv/analog_tv
# Домашний телефон /hometel
# Игровая платформа https://igrovoy.rt.ru
# Тариф «Игровой» https://gg.rt.ru/
# Облачные игры VK Play https://igrovoy.rt.ru/subscriptions/27
# Облачные игры GFN.RU https://igrovoy.rt.ru/subscriptions/28
# Игровой Маркет https://market.rt.ru/
# Игровой Роутер https://rtx.rt.ru/
# Лицей /lc
# Книги /books
# Цифровой переезд https://start.rt.ru/pereezd/?utm_source=rtru&utm_medium=menu_others_service&utm_campaign=b2c_pereezd&utm_content=start_pereezd&utm_term=all
# Таксофон /hometel/uus
# Точка доступа Wi-Fi /homeinternet/uus
# Подвижная радиотелефонная связь /mobile/uus
# Партнерские сервисы /homeinternet/digital_servises
#
#
#
#  None
#
#
#
#  None
# г. Москва None
# сертификаты НУЦ Минцифры https://www.gosuslugi.ru/crt
# Яндекс.Браузер https://browser.yandex.ru/
#
#
#
#
#
#
# Подпишитесь на безопасность
#
# С антивирусом от Ростелекома
#
#
#  /homeinternet/antiviruses
#
#
#
#
#
#
#
#                                 Гарантия плюс
#
#
# Заменим оборудование в случае поломки
#
#
#  /guarantee_plus
#
#
#
#
#
#
#
#                                 Карты пополнений Xbox и PlayStation
#
#
# Теперь доступны на Игровой Платформе
#
#
#  https://igrovoy.rt.ru/market
#
#
#
#
#
#
#
#                                 VK Капсула с Марусей
#
#
# Выберите свою умную колонку в рассрочку
#
#
#  /capsula
#
#
#
#
#
#
#
# 								Подключайте тариф «Облачный»
#
#
# Ваше защищенное облачное хранилище – 1 ТБ ежемесячно
#
#
#  /vk_cloud
#
#
#
#
#
#
# Дарим подарки, потому что ценим
#
# Участвуйте в программе «Бонус» и выбирайте лучшее для себя
# 									и близких
#
#
#  /bonus
#
#
#
#
#
#
# Сделай свой тариф Игровым
#
# Подключи опцию «Мир Танков. Мир Кораблей» на своем тарифе
#
#
#  https://igrovoy.rt.ru/
# ТЕМА НЕДЕЛИ https://blog.rt.ru/b2c/chto-umeyut-rossiiskie-neiroseti.htm
#
#     Что умеют российские нейросети
#    https://blog.rt.ru/b2c/chto-umeyut-rossiiskie-neiroseti.htm
#
#     Что такое онлайн-клуб по интересам
#    https://blog.rt.ru/b2c/chto-takoe-onlain-klub-po-interesam.htm
#
#     Фильмы про IT, основанные на реальных событиях
#    https://blog.rt.ru/b2c/filmy-pro-it-osnovannye-na-realnykh-sobytiyakh.htm
#
#     Что такое сookies и зачем они нужны
#    https://blog.rt.ru/b2c/chto-takoe-sookies-i-zachem-oni-nuzhny.htm
#
#         Читать другие статьи
#          https://blog.rt.ru/b2c
#  None
#  None
#  https://appgallery.huawei.com/#/app/C101527755
#  None
# Пакеты /packages/tariffs
# Интернет /homeinternet
# Видеосервис Wink /hometv
# Видеонаблюдение /videocontrol
# Кабельное ТВ /hometv/analog_tv
# Программа «Бонус» /bonus
# Пакеты с мобильной связью /mobile/mobile_tariff
# Интернет в частный дом /homeinternet/private_house
# Интернет в новостройку /homeinternet/v-novostroyke
# Для партнёров /partners
# Архив тарифов /fare_archives
# Новости /events
# О компании https://www.company.rt.ru/about/
# Работа в компании https://www.company.rt.ru/career/vacancy/
# Пресс-центр https://www.company.rt.ru/press/
# Азбука Интернета https://azbukainterneta.ru/
# Договоры и соглашения /support/documents
# Помощь /help
# Обратная связь /help#contacts
# Офисы продаж /sale-office
# Раскрытие информации https://www.company.rt.ru/about/disclosure/
# Лицензии и сертификаты https://www.company.rt.ru/about/lic_and_cert/licence/
# Закупки https://zakupki.rostelecom.ru/
# Сообщить о нарушении этического кодекса /ethics_code_hotline
# Политикой конфиденциальности /legal
# Пользовательским соглашением https://www.rt.ru/sites/default/files/doc/lk/TermsOfService.pdf
# Политикой обработки персональных данных https://www.company.rt.ru/about/disclosure/index.php#pd
#
#
#  https://vk.com/rostelecom
#
#
#  https://t.me/rostelecomofficial
#
#
#  https://ok.ru/rostelecom.official
#
#
#  https://www.flickr.com/photos/rostelecom_photostream
# в настройках http://enable-javascript.com/ru
