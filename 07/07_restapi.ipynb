# %% [markdown]
# # Вызовы REST API на Python
#
# <a target="_blank" href="https://colab.research.google.com/github/sozykin/middle_python/blob/main/07/07_restapi.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
import requests

# %% [markdown]
# ## Обращаемся к API hh.ru
#
# Документация - https://dev.hh.ru/

# %%
url = "https://api.hh.ru/vacancies?text=middle python разработчик&per_page=20"

# %% [markdown]
# Запускаем запрос

# %%
result = requests.get(url)

# %% [markdown]
# Проверяем ответ

# %%
result.status_code
# Out:
# 200

# %% [markdown]
# Проверяем содержание ответа

# %%
result.json()
# Out:
# {'items': [{'id': '82247456',
#    'premium': False,
#    'name': 'Junior/Middle Python разработчик',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '212',
#     'name': 'Тольятти',
#     'url': 'https://api.hh.ru/areas/212'},
#    'salary': {'from': 50000, 'to': None, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Тольятти',
#     'street': 'Новый проезд',
#     'building': '8',
#     'lat': 53.515809,
#     'lng': 49.283732,
#     'description': None,
#     'raw': 'Тольятти, Новый проезд, 8',
#     'metro': None,
#     'metro_stations': [],
#     'id': '12119035'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-24T15:15:47+0300',
#    'created_at': '2023-06-24T15:15:47+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82247456',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/82247456?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/82247456',
#    'relations': [],
#    'employer': {'id': '2930884',
#     'name': 'Интернет вещей',
#     'url': 'https://api.hh.ru/employers/2930884',
#     'alternate_url': 'https://hh.ru/employer/2930884',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/1027607.png',
#      '240': 'https://hhcdn.ru/employer-logo/5731189.png',
#      '90': 'https://hhcdn.ru/employer-logo/5731188.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2930884',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт работы в разработке на <highlighttext>Python</highlighttext> от 2 лет. Знание Flask/Django и опыт работы с веб-фреймворками. ',
#     'responsibility': 'Разработка и поддержка нашего продукта на <highlighttext>Python</highlighttext>. Создание высококачественного и надежного кода. Участие в разработке архитектуры приложения. Тестирование и отладка...'},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '82347857',
#    'premium': False,
#    'name': 'Python разработчик',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': '2-й Южнопортовый проезд',
#     'building': '33с1',
#     'lat': 55.703515,
#     'lng': 37.696705,
#     'description': None,
#     'raw': 'Москва, 2-й Южнопортовый проезд, 33с1',
#     'metro': {'station_name': 'Кожуховская',
#      'line_name': 'Люблинско-Дмитровская',
#      'station_id': '10.52',
#      'line_id': '10',
#      'lat': 55.706156,
#      'lng': 37.68544},
#     'metro_stations': [{'station_name': 'Кожуховская',
#       'line_name': 'Люблинско-Дмитровская',
#       'station_id': '10.52',
#       'line_id': '10',
#       'lat': 55.706156,
#       'lng': 37.68544}],
#     'id': '11188205'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-23T15:56:54+0300',
#    'created_at': '2023-06-23T15:56:54+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82347857',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/82347857?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/82347857',
#    'relations': [],
#    'employer': {'id': '865',
#     'name': 'TerraLink',
#     'url': 'https://api.hh.ru/employers/865',
#     'alternate_url': 'https://hh.ru/employer/865',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/2655142.png',
#      '90': 'https://hhcdn.ru/employer-logo/2655141.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/553417.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=865',
#     'accredited_it_employer': True,
#     'trusted': True},
#    'snippet': {'requirement': 'Знание <highlighttext>Python</highlighttext>, SQL. Опыт работы с библиотеками по обработке данных. Разработка интеграции с web сервисами.',
#     'responsibility': 'Работа в команде для создания и поддержки новых собственных проектов. Изучение регламентов и систем компании Terralink.'},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '81780083',
#    'premium': False,
#    'name': 'Программист Python (Junior-Middle)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 60000, 'to': 100000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-25T15:51:50+0300',
#    'created_at': '2023-06-25T15:51:50+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=81780083',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/81780083?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/81780083',
#    'relations': [],
#    'employer': {'id': '5414554',
#     'name': 'Dreamx (ИП Саченков Тимофей Вячеславович)',
#     'url': 'https://api.hh.ru/employers/5414554',
#     'alternate_url': 'https://hh.ru/employer/5414554',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/1008019.png',
#      '90': 'https://hhcdn.ru/employer-logo/5652852.png',
#      '240': 'https://hhcdn.ru/employer-logo/5652853.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5414554',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Ты знаешь <highlighttext>Python</highlighttext>. Ты работал с в e-commerce сфере и с маркетплейсами. Умеешь планировать свое время и свято чтишь...',
#     'responsibility': 'Поддерживать текущие автоматизации и писать ботов. Составлять Excel таблицы с макросами и сложными формулами.'},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '82135615',
#    'premium': False,
#    'name': 'Middle Java Developer',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Мытная улица',
#     'building': '66',
#     'lat': 55.713136,
#     'lng': 37.620222,
#     'description': None,
#     'raw': 'Москва, Мытная улица, 66',
#     'metro': {'station_name': 'Тульская',
#      'line_name': 'Серпуховско-Тимирязевская',
#      'station_id': '9.142',
#      'line_id': '9',
#      'lat': 55.70961,
#      'lng': 37.622569},
#     'metro_stations': [{'station_name': 'Тульская',
#       'line_name': 'Серпуховско-Тимирязевская',
#       'station_id': '9.142',
#       'line_id': '9',
#       'lat': 55.70961,
#       'lng': 37.622569},
#      {'station_name': 'Шаболовская',
#       'line_name': 'Калужско-Рижская',
#       'station_id': '6.157',
#       'line_id': '6',
#       'lat': 55.718828,
#       'lng': 37.607892}],
#     'id': '815280'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-19T16:31:36+0300',
#    'created_at': '2023-06-19T16:31:36+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82135615',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/82135615?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/82135615',
#    'relations': [],
#    'employer': {'id': '941273',
#     'name': 'Voximplant',
#     'url': 'https://api.hh.ru/employers/941273',
#     'alternate_url': 'https://hh.ru/employer/941273',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/517483.png',
#      '240': 'https://hhcdn.ru/employer-logo/2511410.png',
#      '90': 'https://hhcdn.ru/employer-logo/2511409.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=941273',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Java Se 8, 11. Опыт коммерческой разработки на Java от 2 лет (мы используем 8 и 11 версию). ',
#     'responsibility': '200+ сотрудников. 1 млрд звонков обрабатываем в год. Нагруженными инсталляциями PostgreSQL.'},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '81949300',
#    'premium': False,
#    'name': 'Junior/Middle Python-developer',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '2',
#     'name': 'Санкт-Петербург',
#     'url': 'https://api.hh.ru/areas/2'},
#    'salary': {'from': 50000, 'to': None, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Санкт-Петербург',
#     'street': 'Московский проспект',
#     'building': '115',
#     'lat': 59.888392,
#     'lng': 30.318653,
#     'description': None,
#     'raw': 'Санкт-Петербург, Московский проспект, 115',
#     'metro': {'station_name': 'Московские ворота',
#      'line_name': 'Московско-Петроградская',
#      'station_id': '15.221',
#      'line_id': '15',
#      'lat': 59.891788,
#      'lng': 30.317873},
#     'metro_stations': [{'station_name': 'Московские ворота',
#       'line_name': 'Московско-Петроградская',
#       'station_id': '15.221',
#       'line_id': '15',
#       'lat': 59.891788,
#       'lng': 30.317873}],
#     'id': '5221594'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-15T11:32:08+0300',
#    'created_at': '2023-06-15T11:32:08+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=81949300',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/81949300?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/81949300',
#    'relations': [],
#    'employer': {'id': '143439',
#     'name': 'НИИАС',
#     'url': 'https://api.hh.ru/employers/143439',
#     'alternate_url': 'https://hh.ru/employer/143439',
#     'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/740573.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/740574.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/201667.jpg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=143439',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Linux, уверенный пользователь. <highlighttext>Python</highlighttext> >= 3.5. SQL. Postgres, MySQL. Docker, docker-compose. ORM (Alchemy). Опыт использования продуктов Attlassian. ',
#     'responsibility': 'Ежедневный код-ревью. Разработка инструментов для взаимодействия с СУБД. Участие в разработке и оптимизации архитектуры БД. Разработка ПО для конвертации...'},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '81867563',
#    'premium': False,
#    'name': 'Middle developer',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '2759',
#     'name': 'Ташкент',
#     'url': 'https://api.hh.ru/areas/2759'},
#    'salary': {'from': 500, 'to': 1500, 'currency': 'USD', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Ташкент',
#     'street': '1-й проезд Оккургон',
#     'building': '60',
#     'lat': 41.327675,
#     'lng': 69.302689,
#     'description': None,
#     'raw': 'Ташкент, 1-й проезд Оккургон, 60',
#     'metro': None,
#     'metro_stations': [],
#     'id': '3822976'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-13T18:45:37+0300',
#    'created_at': '2023-06-13T18:45:37+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=81867563',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/81867563?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/81867563',
#    'relations': [],
#    'employer': {'id': '3637281',
#     'name': 'Kash APP',
#     'url': 'https://api.hh.ru/employers/3637281',
#     'alternate_url': 'https://hh.ru/employer/3637281',
#     'logo_urls': None,
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3637281',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'React, Typescript. 2. Желательный опыт работы с Nodejs backend или <highlighttext>Python</highlighttext> backend. 3. git, git flow. 4. База данных: Postgres...',
#     'responsibility': None},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '81330856',
#    'premium': False,
#    'name': 'Web-программист',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '89', 'name': 'Тверь', 'url': 'https://api.hh.ru/areas/89'},
#    'salary': {'from': 60000, 'to': 120000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Тверь',
#     'street': None,
#     'building': None,
#     'lat': 56.859625,
#     'lng': 35.91186,
#     'description': None,
#     'raw': 'Тверь',
#     'metro': None,
#     'metro_stations': [],
#     'id': '13271778'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-05-30T22:43:21+0300',
#    'created_at': '2023-05-30T22:43:21+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=81330856',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/81330856?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/81330856',
#    'relations': [],
#    'employer': {'id': '9506283',
#     'name': 'MRKTRADING',
#     'url': 'https://api.hh.ru/employers/9506283',
#     'alternate_url': 'https://hh.ru/employer/9506283',
#     'logo_urls': None,
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=9506283',
#     'accredited_it_employer': False,
#     'trusted': False},
#    'snippet': {'requirement': 'Было бы плюсом — наличие опыта работы с GraphQL. Энтузиазм. Квалификация — <highlighttext>Middle</highlighttext>, либо Junior с опытом от 1 года. ',
#     'responsibility': 'Backend <highlighttext>программист</highlighttext>. Участие в проработке интерфейса и архитектуры. Основные задачи — интеграция платёжных систем, отложенные вызовы функций, создание реферальной, партнерской и...'},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': True,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '82104952',
#    'premium': False,
#    'name': 'Middle Python Developer',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1002',
#     'name': 'Минск',
#     'url': 'https://api.hh.ru/areas/1002'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Минск',
#     'street': 'проспект Дзержинского',
#     'building': '104к2',
#     'lat': 53.860752,
#     'lng': 27.478935,
#     'description': None,
#     'raw': 'Минск, проспект Дзержинского, 104к2',
#     'metro': {'station_name': 'Петровщина',
#      'line_name': 'Московская',
#      'station_id': '62.415',
#      'line_id': '62',
#      'lat': 53.86458,
#      'lng': 27.485807},
#     'metro_stations': [{'station_name': 'Петровщина',
#       'line_name': 'Московская',
#       'station_id': '62.415',
#       'line_id': '62',
#       'lat': 53.86458,
#       'lng': 27.485807}],
#     'id': '6836175'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-19T10:52:07+0300',
#    'created_at': '2023-06-19T10:52:07+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82104952',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/82104952?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/82104952',
#    'relations': [],
#    'employer': {'id': '5028612',
#     'name': 'ПлейсДев',
#     'url': 'https://api.hh.ru/employers/5028612',
#     'alternate_url': 'https://hh.ru/employer/5028612',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/1022369.png',
#      '240': 'https://hhcdn.ru/employer-logo/5710245.png',
#      '90': 'https://hhcdn.ru/employer-logo/5710244.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5028612',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Необходимые качества и опыт: Практический опыт разработки программного обеспечения с использованием <highlighttext>Python</highlighttext>. Понимание ключевых концепций в архитектуре и дизайне современных...',
#     'responsibility': '<highlighttext>Python</highlighttext>, <highlighttext>Python</highlighttext> data structures and algorithms, Pytest, Unittest.'},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '82054624',
#    'premium': False,
#    'name': 'Backend - разработчик на Python',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-25T17:30:27+0300',
#    'created_at': '2023-06-25T17:30:27+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82054624',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/82054624?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/82054624',
#    'relations': [],
#    'employer': {'id': '3072286',
#     'name': 'ГРЕЧКА',
#     'url': 'https://api.hh.ru/employers/3072286',
#     'alternate_url': 'https://hh.ru/employer/3072286',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/854806.jpg',
#      '240': 'https://hhcdn.ru/employer-logo/3860100.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3860099.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3072286',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт в написании телеграм-ботов. Опыт коммерческой разработки на <highlighttext>Python</highlighttext> от 1 года. Умение адекватно оценивать трудоёмкость и сроки, соблюдать...',
#     'responsibility': 'Разрабатываем digital-решения для бизнеса. Создаем сайты и web-приложения, программируем сложный функционал систем, продумываем дизайн, проектируем интерфейс. '},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '81941871',
#    'premium': False,
#    'name': 'Программист Python/Data Scientist (junior / middle)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '4',
#     'name': 'Новосибирск',
#     'url': 'https://api.hh.ru/areas/4'},
#    'salary': {'from': 70000, 'to': 150000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-15T10:15:47+0300',
#    'created_at': '2023-06-15T10:15:47+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=81941871',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/81941871?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/81941871',
#    'relations': [],
#    'employer': {'id': '4602050',
#     'name': 'Апэрбот',
#     'url': 'https://api.hh.ru/employers/4602050',
#     'alternate_url': 'https://hh.ru/employer/4602050',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3376217.png',
#      '90': 'https://hhcdn.ru/employer-logo/3376216.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/733785.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4602050',
#     'accredited_it_employer': False,
#     'trusted': False},
#    'snippet': {'requirement': 'Знаешь <highlighttext>Python</highlighttext> + основные пакеты работы с данными и ML: pandas, numpy, torch, Scikit-learn, matplotlib. Знаешь основы математической статистики. ',
#     'responsibility': 'Под руководством опытного специалиста в машинном обучении и NLP (natural language processing) улучшение моделей по обработке текстов и изображений. '},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '82260854',
#    'premium': False,
#    'name': 'C#/Python developer junior / middle',
#    'department': None,
#    'has_test': True,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 100000, 'to': 160000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'улица Правды',
#     'building': '26',
#     'lat': 55.790687657162835,
#     'lng': 37.58470127116276,
#     'description': None,
#     'raw': 'Москва, улица Правды, 26',
#     'metro': {'station_name': 'Белорусская',
#      'line_name': 'Замоскворецкая',
#      'station_id': '2.19',
#      'line_id': '2',
#      'lat': 55.777439,
#      'lng': 37.582107},
#     'metro_stations': [{'station_name': 'Белорусская',
#       'line_name': 'Замоскворецкая',
#       'station_id': '2.19',
#       'line_id': '2',
#       'lat': 55.777439,
#       'lng': 37.582107},
#      {'station_name': 'Савёловская',
#       'line_name': 'Серпуховско-Тимирязевская',
#       'station_id': '9.128',
#       'line_id': '9',
#       'lat': 55.794054,
#       'lng': 37.587163}],
#     'id': '1494631'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-24T10:56:19+0300',
#    'created_at': '2023-06-24T10:56:19+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82260854',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/82260854?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/82260854',
#    'relations': [],
#    'employer': {'id': '205152',
#     'name': 'Mindbox',
#     'url': 'https://api.hh.ru/employers/205152',
#     'alternate_url': 'https://hh.ru/employer/205152',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/1035026.png',
#      '240': 'https://hhcdn.ru/employer-logo/5760865.png',
#      '90': 'https://hhcdn.ru/employer-logo/5760864.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=205152',
#     'accredited_it_employer': True,
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт веб разработки с помощью C# и SQL в production. Чистый код, шаблоны архитектуры, typescript, react. Есть удаленная оплачиваемая стажировка...',
#     'responsibility': 'Net6+ везде, многое в k8s. Монолит - не легаси, поддерживаем на актуальном стеке и активно развиваем, 30...'},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '82140949',
#    'premium': False,
#    'name': 'QA Specialist (middle)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': None,
#     'street': None,
#     'building': None,
#     'lat': None,
#     'lng': None,
#     'description': None,
#     'raw': None,
#     'metro': {'station_name': 'Маяковская',
#      'line_name': 'Замоскворецкая',
#      'station_id': '2.80',
#      'line_id': '2',
#      'lat': 55.769808,
#      'lng': 37.596192},
#     'metro_stations': [{'station_name': 'Маяковская',
#       'line_name': 'Замоскворецкая',
#       'station_id': '2.80',
#       'line_id': '2',
#       'lat': 55.769808,
#       'lng': 37.596192},
#      {'station_name': 'Пушкинская',
#       'line_name': 'Таганско-Краснопресненская',
#       'station_id': '7.124',
#       'line_id': '7',
#       'lat': 55.765607,
#       'lng': 37.604356},
#      {'station_name': 'Чеховская',
#       'line_name': 'Серпуховско-Тимирязевская',
#       'station_id': '9.123',
#       'line_id': '9',
#       'lat': 55.765747,
#       'lng': 37.608493}],
#     'id': '13524467'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-19T17:58:09+0300',
#    'created_at': '2023-06-19T17:58:09+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82140949',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/82140949?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/82140949',
#    'relations': [],
#    'employer': {'id': '7851',
#     'name': 'Риалвеб, Интернет-агентство',
#     'url': 'https://api.hh.ru/employers/7851',
#     'alternate_url': 'https://hh.ru/employer/7851',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/1715567.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/318300.jpg',
#      '90': 'https://hhcdn.ru/employer-logo/1715566.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=7851',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Понимаешь принципы разработки как с технической (OOP, SQL, один из языков программирования Java, <highlighttext>Python</highlighttext>, JS), так и с организационной точки...',
#     'responsibility': 'Составлять планы тестирования и писать чек-листы и тест-кейсы, как Маяковский стихи. Проверять граничные случаи, но не доводить проверки...'},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '124', 'name': 'Тестировщик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '82339421',
#    'premium': False,
#    'name': 'Middle Frontend-stack',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-23T13:43:02+0300',
#    'created_at': '2023-06-23T13:43:02+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82339421',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/82339421?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/82339421',
#    'relations': [],
#    'employer': {'id': '2888',
#     'name': 'DSSL',
#     'url': 'https://api.hh.ru/employers/2888',
#     'alternate_url': 'https://hh.ru/employer/2888',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/232219.bmp',
#      '240': 'https://hhcdn.ru/employer-logo/546156.png',
#      '90': 'https://hhcdn.ru/employer-logo/546155.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2888',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт коммерческой разработки на React от 2 лет. Базовые знание SQL (PostgreSQL). Базовые знание <highlighttext>Python</highlighttext>.',
#     'responsibility': 'Разработка интерфейса для нового функционала "Trassir Cloud". Перенос части frontend’а на React. Участие в развитии и совершенствовании архитектуры проекта. '},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '82163919',
#    'premium': False,
#    'name': 'Инженер по тестированию (Middle)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-20T10:33:16+0300',
#    'created_at': '2023-06-20T10:33:16+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82163919',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/82163919?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/82163919',
#    'relations': [],
#    'employer': {'id': '2464195',
#     'name': 'БОЛЬШАЯ ТРОЙКА',
#     'url': 'https://api.hh.ru/employers/2464195',
#     'alternate_url': 'https://hh.ru/employer/2464195',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/470696.png',
#      '240': 'https://hhcdn.ru/employer-logo/2324637.png',
#      '90': 'https://hhcdn.ru/employer-logo/2324636.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2464195',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': '...средствами <highlighttext>разработчика</highlighttext> браузера. SQL на базовом уровне. Имеете опыт интеграционного тестирования web, знание инструментов. Имеете базовые знания программирования (<highlighttext>python</highlighttext> в...',
#     'responsibility': 'Тестирование продукта в рамках задач. Регрессионное тестирование. Взаимодействие с командами разработки, технической поддержки, автоматизации тестирования.'},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '124', 'name': 'Тестировщик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '82320737',
#    'premium': False,
#    'name': 'Middle django-разработчик (Удаленно)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 120000, 'to': None, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-23T08:51:30+0300',
#    'created_at': '2023-06-23T08:51:30+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82320737',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/82320737?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/82320737',
#    'relations': [],
#    'employer': {'id': '3136448',
#     'name': 'Онлайн-гимназия',
#     'url': 'https://api.hh.ru/employers/3136448',
#     'alternate_url': 'https://hh.ru/employer/3136448',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/1076086.jpg',
#      '240': 'https://hhcdn.ru/employer-logo/5924974.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/5924973.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3136448',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Наличие опыта коммерческой разработки от 1 года (минимум). - Наличие демонстрационного публичного пет проекта (желательно). - Обязательные навыки: <highlighttext>Python</highlighttext>, Django REST, Docker...',
#     'responsibility': 'Написание логики бэкенд приложения, api-методов и автотестов для них.'},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': True,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '82248835',
#    'premium': False,
#    'name': 'Java разработчик (Подписка)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-21T15:33:01+0300',
#    'created_at': '2023-06-21T15:33:01+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82248835',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/82248835?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/82248835',
#    'relations': [],
#    'employer': {'id': '4543942',
#     'name': 'Почтатех',
#     'url': 'https://api.hh.ru/employers/4543942',
#     'alternate_url': 'https://hh.ru/employer/4543942',
#     'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/3387105.png',
#      '240': 'https://hhcdn.ru/employer-logo/3387106.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/736532.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4543942',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Владеет стеком: Java 8/11, Apache Maven, Spring Framework, Spring Boot, Hibernate, SQL и PostgreSQL. Имеет от трех лет опыта...',
#     'responsibility': 'Разрабатывать сервисы для интеграции с внешними системами. Общаться с командой разработки и командами, развивающими смежные сервисы. Разрабатывать и поддерживать техническую...'},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '80238850',
#    'premium': False,
#    'name': 'Cпециалист по внедрению системы (Middle - Senior)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-09T13:41:14+0300',
#    'created_at': '2023-06-09T13:41:14+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=80238850',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/80238850?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/80238850',
#    'relations': [],
#    'employer': {'id': '5672',
#     'name': 'Инфотекс Интернет Траст',
#     'url': 'https://api.hh.ru/employers/5672',
#     'alternate_url': 'https://hh.ru/employer/5672',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/4190869.png',
#      '90': 'https://hhcdn.ru/employer-logo/4190868.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/937581.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5672',
#     'accredited_it_employer': True,
#     'trusted': True},
#    'snippet': {'requirement': 'Базовые знания принципов построения сетей и основных протоколов (OSI и прочие). Понимание кода <highlighttext>python</highlighttext> (С++), bash- скриптов. Базовое знание технического...',
#     'responsibility': 'Участие в процессах внедрения и поддержки решения в качестве технического эксперта. Консультирование заказчиков по функционалу информационной системы. Анализ проблем, поступающих...'},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '107', 'name': 'Руководитель проектов'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '82092062',
#    'premium': False,
#    'name': 'Middle Python|Django|FastAPI разработчик',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '160',
#     'name': 'Алматы',
#     'url': 'https://api.hh.ru/areas/160'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-19T08:14:03+0300',
#    'created_at': '2023-06-19T08:14:03+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82092062',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/82092062?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/82092062',
#    'relations': [],
#    'employer': {'id': '3628184',
#     'name': 'EUROPHARMA, ТМ (ТОО AK NIET GROUP)',
#     'url': 'https://api.hh.ru/employers/3628184',
#     'alternate_url': 'https://hh.ru/employer/3628184',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/808607.png',
#      '240': 'https://hhcdn.ru/employer-logo/3675316.png',
#      '90': 'https://hhcdn.ru/employer-logo/3675315.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3628184',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Уверенные знания <highlighttext>Python</highlighttext>. Знание FastAPI. Знание PostgreSQL, Redis. Знание RabbitMQ, Celery. Понимание принципов и работы HTML, CSS (блочная, кросс-браузерная...',
#     'responsibility': 'Разработка и поддержка проектов компании на <highlighttext>Python</highlighttext> (FastAPI). Ответственность и соблюдение сроков при реализации проектов компании. Вывод проектов в продакшн...'},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '76709182',
#    'premium': False,
#    'name': 'C# developer junior / middle (.net, full-stack / back-end)',
#    'department': None,
#    'has_test': True,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 100000, 'to': 250000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'улица Правды',
#     'building': '26',
#     'lat': 55.790687657162835,
#     'lng': 37.58470127116276,
#     'description': None,
#     'raw': 'Москва, улица Правды, 26',
#     'metro': {'station_name': 'Белорусская',
#      'line_name': 'Замоскворецкая',
#      'station_id': '2.19',
#      'line_id': '2',
#      'lat': 55.777439,
#      'lng': 37.582107},
#     'metro_stations': [{'station_name': 'Белорусская',
#       'line_name': 'Замоскворецкая',
#       'station_id': '2.19',
#       'line_id': '2',
#       'lat': 55.777439,
#       'lng': 37.582107},
#      {'station_name': 'Савёловская',
#       'line_name': 'Серпуховско-Тимирязевская',
#       'station_id': '9.128',
#       'line_id': '9',
#       'lat': 55.794054,
#       'lng': 37.587163}],
#     'id': '1494631'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-24T10:56:58+0300',
#    'created_at': '2023-06-24T10:56:58+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=76709182',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/76709182?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/76709182',
#    'relations': [],
#    'employer': {'id': '205152',
#     'name': 'Mindbox',
#     'url': 'https://api.hh.ru/employers/205152',
#     'alternate_url': 'https://hh.ru/employer/205152',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/1035026.png',
#      '240': 'https://hhcdn.ru/employer-logo/5760865.png',
#      '90': 'https://hhcdn.ru/employer-logo/5760864.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=205152',
#     'accredited_it_employer': True,
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт веб разработки с помощью C# и SQL в production. Есть удаленная оплачиваемая стажировка на случай нехватки опыта или знаний.',
#     'responsibility': 'Net6+ везде, многое в k8s. Монолит - не легаси, поддерживаем на актуальном стеке и активно развиваем, 20...'},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '81768372',
#    'premium': False,
#    'name': 'Java Developer (middle)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-09T18:03:04+0300',
#    'created_at': '2023-06-09T18:03:04+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=81768372',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/81768372?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/81768372',
#    'relations': [],
#    'employer': {'id': '703850',
#     'name': 'Московский филиал АО ЦентрИнформ',
#     'url': 'https://api.hh.ru/employers/703850',
#     'alternate_url': 'https://hh.ru/employer/703850',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/1997539.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/388821.png',
#      '90': 'https://hhcdn.ru/employer-logo/1997538.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=703850',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Уверенное знание Java 11 и современных фреймворков (Spring Boot). Ясное представление того, чем хороший код отличается от плохого. ',
#     'responsibility': 'Мы используем современные подходы к разработке на основе Java, <highlighttext>Python</highlighttext>, kafka, Spark, Clickhouse, Vertica . Мы используем гибкие методологии и DevOps...'},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}}],
#  'found': 578,
#  'pages': 29,
#  'per_page': 20,
#  'page': 0,
#  'clusters': None,
#  'arguments': None,
#  'alternate_url': 'https://hh.ru/search/vacancy?enable_snippets=true&text=middle+python+%D1%80%D0%B0%D0%B7%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D1%87%D0%B8%D0%BA'}

# %% [markdown]
# ## Просматриваем список вакансий

# %%
vacancies = result.json().get('items')

# %%
vacancies
# Out:
# [{'id': '82247456',
#   'premium': False,
#   'name': 'Junior/Middle Python разработчик',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '212',
#    'name': 'Тольятти',
#    'url': 'https://api.hh.ru/areas/212'},
#   'salary': {'from': 50000, 'to': None, 'currency': 'RUR', 'gross': True},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Тольятти',
#    'street': 'Новый проезд',
#    'building': '8',
#    'lat': 53.515809,
#    'lng': 49.283732,
#    'description': None,
#    'raw': 'Тольятти, Новый проезд, 8',
#    'metro': None,
#    'metro_stations': [],
#    'id': '12119035'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2023-06-24T15:15:47+0300',
#   'created_at': '2023-06-24T15:15:47+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82247456',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/82247456?host=hh.ru',
#   'adv_response_url': None,
#   'alternate_url': 'https://hh.ru/vacancy/82247456',
#   'relations': [],
#   'employer': {'id': '2930884',
#    'name': 'Интернет вещей',
#    'url': 'https://api.hh.ru/employers/2930884',
#    'alternate_url': 'https://hh.ru/employer/2930884',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/1027607.png',
#     '240': 'https://hhcdn.ru/employer-logo/5731189.png',
#     '90': 'https://hhcdn.ru/employer-logo/5731188.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2930884',
#    'accredited_it_employer': False,
#    'trusted': True},
#   'snippet': {'requirement': 'Опыт работы в разработке на <highlighttext>Python</highlighttext> от 2 лет. Знание Flask/Django и опыт работы с веб-фреймворками. ',
#    'responsibility': 'Разработка и поддержка нашего продукта на <highlighttext>Python</highlighttext>. Создание высококачественного и надежного кода. Участие в разработке архитектуры приложения. Тестирование и отладка...'},
#   'contacts': None,
#   'schedule': None,
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'}},
#  {'id': '82347857',
#   'premium': False,
#   'name': 'Python разработчик',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Москва',
#    'street': '2-й Южнопортовый проезд',
#    'building': '33с1',
#    'lat': 55.703515,
#    'lng': 37.696705,
#    'description': None,
#    'raw': 'Москва, 2-й Южнопортовый проезд, 33с1',
#    'metro': {'station_name': 'Кожуховская',
#     'line_name': 'Люблинско-Дмитровская',
#     'station_id': '10.52',
#     'line_id': '10',
#     'lat': 55.706156,
#     'lng': 37.68544},
#    'metro_stations': [{'station_name': 'Кожуховская',
#      'line_name': 'Люблинско-Дмитровская',
#      'station_id': '10.52',
#      'line_id': '10',
#      'lat': 55.706156,
#      'lng': 37.68544}],
#    'id': '11188205'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2023-06-23T15:56:54+0300',
#   'created_at': '2023-06-23T15:56:54+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82347857',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/82347857?host=hh.ru',
#   'adv_response_url': None,
#   'alternate_url': 'https://hh.ru/vacancy/82347857',
#   'relations': [],
#   'employer': {'id': '865',
#    'name': 'TerraLink',
#    'url': 'https://api.hh.ru/employers/865',
#    'alternate_url': 'https://hh.ru/employer/865',
#    'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/2655142.png',
#     '90': 'https://hhcdn.ru/employer-logo/2655141.png',
#     'original': 'https://hhcdn.ru/employer-logo-original/553417.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=865',
#    'accredited_it_employer': True,
#    'trusted': True},
#   'snippet': {'requirement': 'Знание <highlighttext>Python</highlighttext>, SQL. Опыт работы с библиотеками по обработке данных. Разработка интеграции с web сервисами.',
#    'responsibility': 'Работа в команде для создания и поддержки новых собственных проектов. Изучение регламентов и систем компании Terralink.'},
#   'contacts': None,
#   'schedule': None,
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'}},
#  {'id': '81780083',
#   'premium': False,
#   'name': 'Программист Python (Junior-Middle)',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': {'from': 60000, 'to': 100000, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2023-06-25T15:51:50+0300',
#   'created_at': '2023-06-25T15:51:50+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=81780083',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/81780083?host=hh.ru',
#   'adv_response_url': None,
#   'alternate_url': 'https://hh.ru/vacancy/81780083',
#   'relations': [],
#   'employer': {'id': '5414554',
#    'name': 'Dreamx (ИП Саченков Тимофей Вячеславович)',
#    'url': 'https://api.hh.ru/employers/5414554',
#    'alternate_url': 'https://hh.ru/employer/5414554',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/1008019.png',
#     '90': 'https://hhcdn.ru/employer-logo/5652852.png',
#     '240': 'https://hhcdn.ru/employer-logo/5652853.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5414554',
#    'accredited_it_employer': False,
#    'trusted': True},
#   'snippet': {'requirement': 'Ты знаешь <highlighttext>Python</highlighttext>. Ты работал с в e-commerce сфере и с маркетплейсами. Умеешь планировать свое время и свято чтишь...',
#    'responsibility': 'Поддерживать текущие автоматизации и писать ботов. Составлять Excel таблицы с макросами и сложными формулами.'},
#   'contacts': None,
#   'schedule': None,
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'}},
#  {'id': '82135615',
#   'premium': False,
#   'name': 'Middle Java Developer',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Москва',
#    'street': 'Мытная улица',
#    'building': '66',
#    'lat': 55.713136,
#    'lng': 37.620222,
#    'description': None,
#    'raw': 'Москва, Мытная улица, 66',
#    'metro': {'station_name': 'Тульская',
#     'line_name': 'Серпуховско-Тимирязевская',
#     'station_id': '9.142',
#     'line_id': '9',
#     'lat': 55.70961,
#     'lng': 37.622569},
#    'metro_stations': [{'station_name': 'Тульская',
#      'line_name': 'Серпуховско-Тимирязевская',
#      'station_id': '9.142',
#      'line_id': '9',
#      'lat': 55.70961,
#      'lng': 37.622569},
#     {'station_name': 'Шаболовская',
#      'line_name': 'Калужско-Рижская',
#      'station_id': '6.157',
#      'line_id': '6',
#      'lat': 55.718828,
#      'lng': 37.607892}],
#    'id': '815280'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2023-06-19T16:31:36+0300',
#   'created_at': '2023-06-19T16:31:36+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82135615',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/82135615?host=hh.ru',
#   'adv_response_url': None,
#   'alternate_url': 'https://hh.ru/vacancy/82135615',
#   'relations': [],
#   'employer': {'id': '941273',
#    'name': 'Voximplant',
#    'url': 'https://api.hh.ru/employers/941273',
#    'alternate_url': 'https://hh.ru/employer/941273',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/517483.png',
#     '240': 'https://hhcdn.ru/employer-logo/2511410.png',
#     '90': 'https://hhcdn.ru/employer-logo/2511409.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=941273',
#    'accredited_it_employer': False,
#    'trusted': True},
#   'snippet': {'requirement': 'Java Se 8, 11. Опыт коммерческой разработки на Java от 2 лет (мы используем 8 и 11 версию). ',
#    'responsibility': '200+ сотрудников. 1 млрд звонков обрабатываем в год. Нагруженными инсталляциями PostgreSQL.'},
#   'contacts': None,
#   'schedule': None,
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'}},
#  {'id': '81949300',
#   'premium': False,
#   'name': 'Junior/Middle Python-developer',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '2',
#    'name': 'Санкт-Петербург',
#    'url': 'https://api.hh.ru/areas/2'},
#   'salary': {'from': 50000, 'to': None, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Санкт-Петербург',
#    'street': 'Московский проспект',
#    'building': '115',
#    'lat': 59.888392,
#    'lng': 30.318653,
#    'description': None,
#    'raw': 'Санкт-Петербург, Московский проспект, 115',
#    'metro': {'station_name': 'Московские ворота',
#     'line_name': 'Московско-Петроградская',
#     'station_id': '15.221',
#     'line_id': '15',
#     'lat': 59.891788,
#     'lng': 30.317873},
#    'metro_stations': [{'station_name': 'Московские ворота',
#      'line_name': 'Московско-Петроградская',
#      'station_id': '15.221',
#      'line_id': '15',
#      'lat': 59.891788,
#      'lng': 30.317873}],
#    'id': '5221594'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2023-06-15T11:32:08+0300',
#   'created_at': '2023-06-15T11:32:08+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=81949300',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/81949300?host=hh.ru',
#   'adv_response_url': None,
#   'alternate_url': 'https://hh.ru/vacancy/81949300',
#   'relations': [],
#   'employer': {'id': '143439',
#    'name': 'НИИАС',
#    'url': 'https://api.hh.ru/employers/143439',
#    'alternate_url': 'https://hh.ru/employer/143439',
#    'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/740573.jpeg',
#     '240': 'https://hhcdn.ru/employer-logo/740574.jpeg',
#     'original': 'https://hhcdn.ru/employer-logo-original/201667.jpg'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=143439',
#    'accredited_it_employer': False,
#    'trusted': True},
#   'snippet': {'requirement': 'Linux, уверенный пользователь. <highlighttext>Python</highlighttext> >= 3.5. SQL. Postgres, MySQL. Docker, docker-compose. ORM (Alchemy). Опыт использования продуктов Attlassian. ',
#    'responsibility': 'Ежедневный код-ревью. Разработка инструментов для взаимодействия с СУБД. Участие в разработке и оптимизации архитектуры БД. Разработка ПО для конвертации...'},
#   'contacts': None,
#   'schedule': None,
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'}},
#  {'id': '81867563',
#   'premium': False,
#   'name': 'Middle developer',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '2759',
#    'name': 'Ташкент',
#    'url': 'https://api.hh.ru/areas/2759'},
#   'salary': {'from': 500, 'to': 1500, 'currency': 'USD', 'gross': True},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Ташкент',
#    'street': '1-й проезд Оккургон',
#    'building': '60',
#    'lat': 41.327675,
#    'lng': 69.302689,
#    'description': None,
#    'raw': 'Ташкент, 1-й проезд Оккургон, 60',
#    'metro': None,
#    'metro_stations': [],
#    'id': '3822976'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2023-06-13T18:45:37+0300',
#   'created_at': '2023-06-13T18:45:37+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=81867563',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/81867563?host=hh.ru',
#   'adv_response_url': None,
#   'alternate_url': 'https://hh.ru/vacancy/81867563',
#   'relations': [],
#   'employer': {'id': '3637281',
#    'name': 'Kash APP',
#    'url': 'https://api.hh.ru/employers/3637281',
#    'alternate_url': 'https://hh.ru/employer/3637281',
#    'logo_urls': None,
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3637281',
#    'accredited_it_employer': False,
#    'trusted': True},
#   'snippet': {'requirement': 'React, Typescript. 2. Желательный опыт работы с Nodejs backend или <highlighttext>Python</highlighttext> backend. 3. git, git flow. 4. База данных: Postgres...',
#    'responsibility': None},
#   'contacts': None,
#   'schedule': None,
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'}},
#  {'id': '81330856',
#   'premium': False,
#   'name': 'Web-программист',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '89', 'name': 'Тверь', 'url': 'https://api.hh.ru/areas/89'},
#   'salary': {'from': 60000, 'to': 120000, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Тверь',
#    'street': None,
#    'building': None,
#    'lat': 56.859625,
#    'lng': 35.91186,
#    'description': None,
#    'raw': 'Тверь',
#    'metro': None,
#    'metro_stations': [],
#    'id': '13271778'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2023-05-30T22:43:21+0300',
#   'created_at': '2023-05-30T22:43:21+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=81330856',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/81330856?host=hh.ru',
#   'adv_response_url': None,
#   'alternate_url': 'https://hh.ru/vacancy/81330856',
#   'relations': [],
#   'employer': {'id': '9506283',
#    'name': 'MRKTRADING',
#    'url': 'https://api.hh.ru/employers/9506283',
#    'alternate_url': 'https://hh.ru/employer/9506283',
#    'logo_urls': None,
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=9506283',
#    'accredited_it_employer': False,
#    'trusted': False},
#   'snippet': {'requirement': 'Было бы плюсом — наличие опыта работы с GraphQL. Энтузиазм. Квалификация — <highlighttext>Middle</highlighttext>, либо Junior с опытом от 1 года. ',
#    'responsibility': 'Backend <highlighttext>программист</highlighttext>. Участие в проработке интерфейса и архитектуры. Основные задачи — интеграция платёжных систем, отложенные вызовы функций, создание реферальной, партнерской и...'},
#   'contacts': None,
#   'schedule': None,
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#   'accept_incomplete_resumes': True,
#   'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'}},
#  {'id': '82104952',
#   'premium': False,
#   'name': 'Middle Python Developer',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1002',
#    'name': 'Минск',
#    'url': 'https://api.hh.ru/areas/1002'},
#   'salary': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Минск',
#    'street': 'проспект Дзержинского',
#    'building': '104к2',
#    'lat': 53.860752,
#    'lng': 27.478935,
#    'description': None,
#    'raw': 'Минск, проспект Дзержинского, 104к2',
#    'metro': {'station_name': 'Петровщина',
#     'line_name': 'Московская',
#     'station_id': '62.415',
#     'line_id': '62',
#     'lat': 53.86458,
#     'lng': 27.485807},
#    'metro_stations': [{'station_name': 'Петровщина',
#      'line_name': 'Московская',
#      'station_id': '62.415',
#      'line_id': '62',
#      'lat': 53.86458,
#      'lng': 27.485807}],
#    'id': '6836175'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2023-06-19T10:52:07+0300',
#   'created_at': '2023-06-19T10:52:07+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82104952',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/82104952?host=hh.ru',
#   'adv_response_url': None,
#   'alternate_url': 'https://hh.ru/vacancy/82104952',
#   'relations': [],
#   'employer': {'id': '5028612',
#    'name': 'ПлейсДев',
#    'url': 'https://api.hh.ru/employers/5028612',
#    'alternate_url': 'https://hh.ru/employer/5028612',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/1022369.png',
#     '240': 'https://hhcdn.ru/employer-logo/5710245.png',
#     '90': 'https://hhcdn.ru/employer-logo/5710244.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5028612',
#    'accredited_it_employer': False,
#    'trusted': True},
#   'snippet': {'requirement': 'Необходимые качества и опыт: Практический опыт разработки программного обеспечения с использованием <highlighttext>Python</highlighttext>. Понимание ключевых концепций в архитектуре и дизайне современных...',
#    'responsibility': '<highlighttext>Python</highlighttext>, <highlighttext>Python</highlighttext> data structures and algorithms, Pytest, Unittest.'},
#   'contacts': None,
#   'schedule': None,
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'}},
#  {'id': '82054624',
#   'premium': False,
#   'name': 'Backend - разработчик на Python',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2023-06-25T17:30:27+0300',
#   'created_at': '2023-06-25T17:30:27+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82054624',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/82054624?host=hh.ru',
#   'adv_response_url': None,
#   'alternate_url': 'https://hh.ru/vacancy/82054624',
#   'relations': [],
#   'employer': {'id': '3072286',
#    'name': 'ГРЕЧКА',
#    'url': 'https://api.hh.ru/employers/3072286',
#    'alternate_url': 'https://hh.ru/employer/3072286',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/854806.jpg',
#     '240': 'https://hhcdn.ru/employer-logo/3860100.jpeg',
#     '90': 'https://hhcdn.ru/employer-logo/3860099.jpeg'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3072286',
#    'accredited_it_employer': False,
#    'trusted': True},
#   'snippet': {'requirement': 'Опыт в написании телеграм-ботов. Опыт коммерческой разработки на <highlighttext>Python</highlighttext> от 1 года. Умение адекватно оценивать трудоёмкость и сроки, соблюдать...',
#    'responsibility': 'Разрабатываем digital-решения для бизнеса. Создаем сайты и web-приложения, программируем сложный функционал систем, продумываем дизайн, проектируем интерфейс. '},
#   'contacts': None,
#   'schedule': None,
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'}},
#  {'id': '81941871',
#   'premium': False,
#   'name': 'Программист Python/Data Scientist (junior / middle)',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '4',
#    'name': 'Новосибирск',
#    'url': 'https://api.hh.ru/areas/4'},
#   'salary': {'from': 70000, 'to': 150000, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2023-06-15T10:15:47+0300',
#   'created_at': '2023-06-15T10:15:47+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=81941871',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/81941871?host=hh.ru',
#   'adv_response_url': None,
#   'alternate_url': 'https://hh.ru/vacancy/81941871',
#   'relations': [],
#   'employer': {'id': '4602050',
#    'name': 'Апэрбот',
#    'url': 'https://api.hh.ru/employers/4602050',
#    'alternate_url': 'https://hh.ru/employer/4602050',
#    'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3376217.png',
#     '90': 'https://hhcdn.ru/employer-logo/3376216.png',
#     'original': 'https://hhcdn.ru/employer-logo-original/733785.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4602050',
#    'accredited_it_employer': False,
#    'trusted': False},
#   'snippet': {'requirement': 'Знаешь <highlighttext>Python</highlighttext> + основные пакеты работы с данными и ML: pandas, numpy, torch, Scikit-learn, matplotlib. Знаешь основы математической статистики. ',
#    'responsibility': 'Под руководством опытного специалиста в машинном обучении и NLP (natural language processing) улучшение моделей по обработке текстов и изображений. '},
#   'contacts': None,
#   'schedule': None,
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'}},
#  {'id': '82260854',
#   'premium': False,
#   'name': 'C#/Python developer junior / middle',
#   'department': None,
#   'has_test': True,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': {'from': 100000, 'to': 160000, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Москва',
#    'street': 'улица Правды',
#    'building': '26',
#    'lat': 55.790687657162835,
#    'lng': 37.58470127116276,
#    'description': None,
#    'raw': 'Москва, улица Правды, 26',
#    'metro': {'station_name': 'Белорусская',
#     'line_name': 'Замоскворецкая',
#     'station_id': '2.19',
#     'line_id': '2',
#     'lat': 55.777439,
#     'lng': 37.582107},
#    'metro_stations': [{'station_name': 'Белорусская',
#      'line_name': 'Замоскворецкая',
#      'station_id': '2.19',
#      'line_id': '2',
#      'lat': 55.777439,
#      'lng': 37.582107},
#     {'station_name': 'Савёловская',
#      'line_name': 'Серпуховско-Тимирязевская',
#      'station_id': '9.128',
#      'line_id': '9',
#      'lat': 55.794054,
#      'lng': 37.587163}],
#    'id': '1494631'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2023-06-24T10:56:19+0300',
#   'created_at': '2023-06-24T10:56:19+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82260854',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/82260854?host=hh.ru',
#   'adv_response_url': None,
#   'alternate_url': 'https://hh.ru/vacancy/82260854',
#   'relations': [],
#   'employer': {'id': '205152',
#    'name': 'Mindbox',
#    'url': 'https://api.hh.ru/employers/205152',
#    'alternate_url': 'https://hh.ru/employer/205152',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/1035026.png',
#     '240': 'https://hhcdn.ru/employer-logo/5760865.png',
#     '90': 'https://hhcdn.ru/employer-logo/5760864.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=205152',
#    'accredited_it_employer': True,
#    'trusted': True},
#   'snippet': {'requirement': 'Опыт веб разработки с помощью C# и SQL в production. Чистый код, шаблоны архитектуры, typescript, react. Есть удаленная оплачиваемая стажировка...',
#    'responsibility': 'Net6+ везде, многое в k8s. Монолит - не легаси, поддерживаем на актуальном стеке и активно развиваем, 30...'},
#   'contacts': None,
#   'schedule': None,
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'}},
#  {'id': '82140949',
#   'premium': False,
#   'name': 'QA Specialist (middle)',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': None,
#    'street': None,
#    'building': None,
#    'lat': None,
#    'lng': None,
#    'description': None,
#    'raw': None,
#    'metro': {'station_name': 'Маяковская',
#     'line_name': 'Замоскворецкая',
#     'station_id': '2.80',
#     'line_id': '2',
#     'lat': 55.769808,
#     'lng': 37.596192},
#    'metro_stations': [{'station_name': 'Маяковская',
#      'line_name': 'Замоскворецкая',
#      'station_id': '2.80',
#      'line_id': '2',
#      'lat': 55.769808,
#      'lng': 37.596192},
#     {'station_name': 'Пушкинская',
#      'line_name': 'Таганско-Краснопресненская',
#      'station_id': '7.124',
#      'line_id': '7',
#      'lat': 55.765607,
#      'lng': 37.604356},
#     {'station_name': 'Чеховская',
#      'line_name': 'Серпуховско-Тимирязевская',
#      'station_id': '9.123',
#      'line_id': '9',
#      'lat': 55.765747,
#      'lng': 37.608493}],
#    'id': '13524467'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2023-06-19T17:58:09+0300',
#   'created_at': '2023-06-19T17:58:09+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82140949',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/82140949?host=hh.ru',
#   'adv_response_url': None,
#   'alternate_url': 'https://hh.ru/vacancy/82140949',
#   'relations': [],
#   'employer': {'id': '7851',
#    'name': 'Риалвеб, Интернет-агентство',
#    'url': 'https://api.hh.ru/employers/7851',
#    'alternate_url': 'https://hh.ru/employer/7851',
#    'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/1715567.jpeg',
#     'original': 'https://hhcdn.ru/employer-logo-original/318300.jpg',
#     '90': 'https://hhcdn.ru/employer-logo/1715566.jpeg'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=7851',
#    'accredited_it_employer': False,
#    'trusted': True},
#   'snippet': {'requirement': 'Понимаешь принципы разработки как с технической (OOP, SQL, один из языков программирования Java, <highlighttext>Python</highlighttext>, JS), так и с организационной точки...',
#    'responsibility': 'Составлять планы тестирования и писать чек-листы и тест-кейсы, как Маяковский стихи. Проверять граничные случаи, но не доводить проверки...'},
#   'contacts': None,
#   'schedule': None,
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'professional_roles': [{'id': '124', 'name': 'Тестировщик'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'}},
#  {'id': '82339421',
#   'premium': False,
#   'name': 'Middle Frontend-stack',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2023-06-23T13:43:02+0300',
#   'created_at': '2023-06-23T13:43:02+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82339421',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/82339421?host=hh.ru',
#   'adv_response_url': None,
#   'alternate_url': 'https://hh.ru/vacancy/82339421',
#   'relations': [],
#   'employer': {'id': '2888',
#    'name': 'DSSL',
#    'url': 'https://api.hh.ru/employers/2888',
#    'alternate_url': 'https://hh.ru/employer/2888',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/232219.bmp',
#     '240': 'https://hhcdn.ru/employer-logo/546156.png',
#     '90': 'https://hhcdn.ru/employer-logo/546155.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2888',
#    'accredited_it_employer': False,
#    'trusted': True},
#   'snippet': {'requirement': 'Опыт коммерческой разработки на React от 2 лет. Базовые знание SQL (PostgreSQL). Базовые знание <highlighttext>Python</highlighttext>.',
#    'responsibility': 'Разработка интерфейса для нового функционала "Trassir Cloud". Перенос части frontend’а на React. Участие в развитии и совершенствовании архитектуры проекта. '},
#   'contacts': None,
#   'schedule': None,
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'}},
#  {'id': '82163919',
#   'premium': False,
#   'name': 'Инженер по тестированию (Middle)',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2023-06-20T10:33:16+0300',
#   'created_at': '2023-06-20T10:33:16+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82163919',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/82163919?host=hh.ru',
#   'adv_response_url': None,
#   'alternate_url': 'https://hh.ru/vacancy/82163919',
#   'relations': [],
#   'employer': {'id': '2464195',
#    'name': 'БОЛЬШАЯ ТРОЙКА',
#    'url': 'https://api.hh.ru/employers/2464195',
#    'alternate_url': 'https://hh.ru/employer/2464195',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/470696.png',
#     '240': 'https://hhcdn.ru/employer-logo/2324637.png',
#     '90': 'https://hhcdn.ru/employer-logo/2324636.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2464195',
#    'accredited_it_employer': False,
#    'trusted': True},
#   'snippet': {'requirement': '...средствами <highlighttext>разработчика</highlighttext> браузера. SQL на базовом уровне. Имеете опыт интеграционного тестирования web, знание инструментов. Имеете базовые знания программирования (<highlighttext>python</highlighttext> в...',
#    'responsibility': 'Тестирование продукта в рамках задач. Регрессионное тестирование. Взаимодействие с командами разработки, технической поддержки, автоматизации тестирования.'},
#   'contacts': None,
#   'schedule': None,
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'professional_roles': [{'id': '124', 'name': 'Тестировщик'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'}},
#  {'id': '82320737',
#   'premium': False,
#   'name': 'Middle django-разработчик (Удаленно)',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': {'from': 120000, 'to': None, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2023-06-23T08:51:30+0300',
#   'created_at': '2023-06-23T08:51:30+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82320737',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/82320737?host=hh.ru',
#   'adv_response_url': None,
#   'alternate_url': 'https://hh.ru/vacancy/82320737',
#   'relations': [],
#   'employer': {'id': '3136448',
#    'name': 'Онлайн-гимназия',
#    'url': 'https://api.hh.ru/employers/3136448',
#    'alternate_url': 'https://hh.ru/employer/3136448',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/1076086.jpg',
#     '240': 'https://hhcdn.ru/employer-logo/5924974.jpeg',
#     '90': 'https://hhcdn.ru/employer-logo/5924973.jpeg'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3136448',
#    'accredited_it_employer': False,
#    'trusted': True},
#   'snippet': {'requirement': 'Наличие опыта коммерческой разработки от 1 года (минимум). - Наличие демонстрационного публичного пет проекта (желательно). - Обязательные навыки: <highlighttext>Python</highlighttext>, Django REST, Docker...',
#    'responsibility': 'Написание логики бэкенд приложения, api-методов и автотестов для них.'},
#   'contacts': None,
#   'schedule': None,
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': True,
#   'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'}},
#  {'id': '82248835',
#   'premium': False,
#   'name': 'Java разработчик (Подписка)',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2023-06-21T15:33:01+0300',
#   'created_at': '2023-06-21T15:33:01+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82248835',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/82248835?host=hh.ru',
#   'adv_response_url': None,
#   'alternate_url': 'https://hh.ru/vacancy/82248835',
#   'relations': [],
#   'employer': {'id': '4543942',
#    'name': 'Почтатех',
#    'url': 'https://api.hh.ru/employers/4543942',
#    'alternate_url': 'https://hh.ru/employer/4543942',
#    'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/3387105.png',
#     '240': 'https://hhcdn.ru/employer-logo/3387106.png',
#     'original': 'https://hhcdn.ru/employer-logo-original/736532.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4543942',
#    'accredited_it_employer': False,
#    'trusted': True},
#   'snippet': {'requirement': 'Владеет стеком: Java 8/11, Apache Maven, Spring Framework, Spring Boot, Hibernate, SQL и PostgreSQL. Имеет от трех лет опыта...',
#    'responsibility': 'Разрабатывать сервисы для интеграции с внешними системами. Общаться с командой разработки и командами, развивающими смежные сервисы. Разрабатывать и поддерживать техническую...'},
#   'contacts': None,
#   'schedule': None,
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'}},
#  {'id': '80238850',
#   'premium': False,
#   'name': 'Cпециалист по внедрению системы (Middle - Senior)',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2023-06-09T13:41:14+0300',
#   'created_at': '2023-06-09T13:41:14+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=80238850',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/80238850?host=hh.ru',
#   'adv_response_url': None,
#   'alternate_url': 'https://hh.ru/vacancy/80238850',
#   'relations': [],
#   'employer': {'id': '5672',
#    'name': 'Инфотекс Интернет Траст',
#    'url': 'https://api.hh.ru/employers/5672',
#    'alternate_url': 'https://hh.ru/employer/5672',
#    'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/4190869.png',
#     '90': 'https://hhcdn.ru/employer-logo/4190868.png',
#     'original': 'https://hhcdn.ru/employer-logo-original/937581.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5672',
#    'accredited_it_employer': True,
#    'trusted': True},
#   'snippet': {'requirement': 'Базовые знания принципов построения сетей и основных протоколов (OSI и прочие). Понимание кода <highlighttext>python</highlighttext> (С++), bash- скриптов. Базовое знание технического...',
#    'responsibility': 'Участие в процессах внедрения и поддержки решения в качестве технического эксперта. Консультирование заказчиков по функционалу информационной системы. Анализ проблем, поступающих...'},
#   'contacts': None,
#   'schedule': None,
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'professional_roles': [{'id': '107', 'name': 'Руководитель проектов'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'}},
#  {'id': '82092062',
#   'premium': False,
#   'name': 'Middle Python|Django|FastAPI разработчик',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '160',
#    'name': 'Алматы',
#    'url': 'https://api.hh.ru/areas/160'},
#   'salary': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2023-06-19T08:14:03+0300',
#   'created_at': '2023-06-19T08:14:03+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82092062',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/82092062?host=hh.ru',
#   'adv_response_url': None,
#   'alternate_url': 'https://hh.ru/vacancy/82092062',
#   'relations': [],
#   'employer': {'id': '3628184',
#    'name': 'EUROPHARMA, ТМ (ТОО AK NIET GROUP)',
#    'url': 'https://api.hh.ru/employers/3628184',
#    'alternate_url': 'https://hh.ru/employer/3628184',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/808607.png',
#     '240': 'https://hhcdn.ru/employer-logo/3675316.png',
#     '90': 'https://hhcdn.ru/employer-logo/3675315.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3628184',
#    'accredited_it_employer': False,
#    'trusted': True},
#   'snippet': {'requirement': 'Уверенные знания <highlighttext>Python</highlighttext>. Знание FastAPI. Знание PostgreSQL, Redis. Знание RabbitMQ, Celery. Понимание принципов и работы HTML, CSS (блочная, кросс-браузерная...',
#    'responsibility': 'Разработка и поддержка проектов компании на <highlighttext>Python</highlighttext> (FastAPI). Ответственность и соблюдение сроков при реализации проектов компании. Вывод проектов в продакшн...'},
#   'contacts': None,
#   'schedule': None,
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'}},
#  {'id': '76709182',
#   'premium': False,
#   'name': 'C# developer junior / middle (.net, full-stack / back-end)',
#   'department': None,
#   'has_test': True,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': {'from': 100000, 'to': 250000, 'currency': 'RUR', 'gross': False},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Москва',
#    'street': 'улица Правды',
#    'building': '26',
#    'lat': 55.790687657162835,
#    'lng': 37.58470127116276,
#    'description': None,
#    'raw': 'Москва, улица Правды, 26',
#    'metro': {'station_name': 'Белорусская',
#     'line_name': 'Замоскворецкая',
#     'station_id': '2.19',
#     'line_id': '2',
#     'lat': 55.777439,
#     'lng': 37.582107},
#    'metro_stations': [{'station_name': 'Белорусская',
#      'line_name': 'Замоскворецкая',
#      'station_id': '2.19',
#      'line_id': '2',
#      'lat': 55.777439,
#      'lng': 37.582107},
#     {'station_name': 'Савёловская',
#      'line_name': 'Серпуховско-Тимирязевская',
#      'station_id': '9.128',
#      'line_id': '9',
#      'lat': 55.794054,
#      'lng': 37.587163}],
#    'id': '1494631'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2023-06-24T10:56:58+0300',
#   'created_at': '2023-06-24T10:56:58+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=76709182',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/76709182?host=hh.ru',
#   'adv_response_url': None,
#   'alternate_url': 'https://hh.ru/vacancy/76709182',
#   'relations': [],
#   'employer': {'id': '205152',
#    'name': 'Mindbox',
#    'url': 'https://api.hh.ru/employers/205152',
#    'alternate_url': 'https://hh.ru/employer/205152',
#    'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/1035026.png',
#     '240': 'https://hhcdn.ru/employer-logo/5760865.png',
#     '90': 'https://hhcdn.ru/employer-logo/5760864.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=205152',
#    'accredited_it_employer': True,
#    'trusted': True},
#   'snippet': {'requirement': 'Опыт веб разработки с помощью C# и SQL в production. Есть удаленная оплачиваемая стажировка на случай нехватки опыта или знаний.',
#    'responsibility': 'Net6+ везде, многое в k8s. Монолит - не легаси, поддерживаем на актуальном стеке и активно развиваем, 20...'},
#   'contacts': None,
#   'schedule': None,
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'}},
#  {'id': '81768372',
#   'premium': False,
#   'name': 'Java Developer (middle)',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2023-06-09T18:03:04+0300',
#   'created_at': '2023-06-09T18:03:04+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=81768372',
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/81768372?host=hh.ru',
#   'adv_response_url': None,
#   'alternate_url': 'https://hh.ru/vacancy/81768372',
#   'relations': [],
#   'employer': {'id': '703850',
#    'name': 'Московский филиал АО ЦентрИнформ',
#    'url': 'https://api.hh.ru/employers/703850',
#    'alternate_url': 'https://hh.ru/employer/703850',
#    'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/1997539.png',
#     'original': 'https://hhcdn.ru/employer-logo-original/388821.png',
#     '90': 'https://hhcdn.ru/employer-logo/1997538.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=703850',
#    'accredited_it_employer': False,
#    'trusted': True},
#   'snippet': {'requirement': 'Уверенное знание Java 11 и современных фреймворков (Spring Boot). Ясное представление того, чем хороший код отличается от плохого. ',
#    'responsibility': 'Мы используем современные подходы к разработке на основе Java, <highlighttext>Python</highlighttext>, kafka, Spark, Clickhouse, Vertica . Мы используем гибкие методологии и DevOps...'},
#   'contacts': None,
#   'schedule': None,
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'}}]

# %%
for i, vacancy in enumerate(vacancies):
    print(i + 1, vacancy['name'], vacancy['url'], vacancy['alternate_url'])
# Out:
# 1 Junior/Middle Python разработчик https://api.hh.ru/vacancies/82247456?host=hh.ru https://hh.ru/vacancy/82247456
# 2 Python разработчик https://api.hh.ru/vacancies/82347857?host=hh.ru https://hh.ru/vacancy/82347857
# 3 Программист Python (Junior-Middle) https://api.hh.ru/vacancies/81780083?host=hh.ru https://hh.ru/vacancy/81780083
# 4 Middle Java Developer https://api.hh.ru/vacancies/82135615?host=hh.ru https://hh.ru/vacancy/82135615
# 5 Junior/Middle Python-developer https://api.hh.ru/vacancies/81949300?host=hh.ru https://hh.ru/vacancy/81949300
# 6 Middle developer https://api.hh.ru/vacancies/81867563?host=hh.ru https://hh.ru/vacancy/81867563
# 7 Web-программист https://api.hh.ru/vacancies/81330856?host=hh.ru https://hh.ru/vacancy/81330856
# 8 Middle Python Developer https://api.hh.ru/vacancies/82104952?host=hh.ru https://hh.ru/vacancy/82104952
# 9 Backend - разработчик на Python https://api.hh.ru/vacancies/82054624?host=hh.ru https://hh.ru/vacancy/82054624
# 10 Программист Python/Data Scientist (junior / middle) https://api.hh.ru/vacancies/81941871?host=hh.ru https://hh.ru/vacancy/81941871
# 11 C#/Python developer junior / middle https://api.hh.ru/vacancies/82260854?host=hh.ru https://hh.ru/vacancy/82260854
# 12 QA Specialist (middle) https://api.hh.ru/vacancies/82140949?host=hh.ru https://hh.ru/vacancy/82140949
# 13 Middle Frontend-stack https://api.hh.ru/vacancies/82339421?host=hh.ru https://hh.ru/vacancy/82339421
# 14 Инженер по тестированию (Middle) https://api.hh.ru/vacancies/82163919?host=hh.ru https://hh.ru/vacancy/82163919
# 15 Middle django-разработчик (Удаленно) https://api.hh.ru/vacancies/82320737?host=hh.ru https://hh.ru/vacancy/82320737
# 16 Java разработчик (Подписка) https://api.hh.ru/vacancies/82248835?host=hh.ru https://hh.ru/vacancy/82248835
# 17 Cпециалист по внедрению системы (Middle - Senior) https://api.hh.ru/vacancies/80238850?host=hh.ru https://hh.ru/vacancy/80238850
# 18 Middle Python|Django|FastAPI разработчик https://api.hh.ru/vacancies/82092062?host=hh.ru https://hh.ru/vacancy/82092062
# 19 C# developer junior / middle (.net, full-stack / back-end) https://api.hh.ru/vacancies/76709182?host=hh.ru https://hh.ru/vacancy/76709182
# 20 Java Developer (middle) https://api.hh.ru/vacancies/81768372?host=hh.ru https://hh.ru/vacancy/81768372

# %% [markdown]
# ## Просматриваем вакансию

# %%
url = "https://api.hh.ru/vacancies/81225938?host=hh.ru"
