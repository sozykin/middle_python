# %% [markdown]
# # Использование модуля pathlib в Python
#
# <a target="_blank" href="https://colab.research.google.com/github/sozykin/middle_python/blob/main/02/02_collections.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
from pathlib import Path

# %% [markdown]
# ## Объектно-ориентированный подход к работе с файловой системой

# %%
path = Path('sales.csv')

# %%
path
# Out:
# WindowsPath('sales.csv')

# %%
path.stem
# Out:
# 'sales'

# %%
path.suffix
# Out:
# '.csv'

# %%
path.name
# Out:
# 'sales.csv'

# %%
path.absolute()
# Out:
# WindowsPath('c:/Users/sozyk/projects/middle_python/03/sales.csv')

# %%
path.cwd()
# Out:
# WindowsPath('c:/Users/sozyk/projects/middle_python/03')

# %%
path.home()
# Out:
# WindowsPath('C:/Users/sozyk')

# %% [markdown]
# ## Создание составного пути

# %%
path = Path('test', 'newfile.txt')

# %%
path
# Out:
# WindowsPath('test/newfile.txt')

# %% [markdown]
# Задание пути в формате Windows

# %%
path = Path('text\newfile.txt')

# %%
path
# Out:
# WindowsPath('text\newfile.txt')

# %% [markdown]
# Указываем ESC символ

# %%
path = Path('text\\newfile.txt')

# %%
path
# Out:
# WindowsPath('text/newfile.txt')

# %% [markdown]
# Создание пути в формате Unix (POSIX)

# %%
path = Path('text/newfile.txt')

# %%
path
# Out:
# WindowsPath('text/newfile.txt')

# %% [markdown]
# Объединение путей

# %%
path = Path.home().joinpath('projects', 'middle_python', '03', 'sales.csv')

# %%
path
# Out:
# WindowsPath('C:/Users/sozyk/projects/middle_python/03/sales.csv')

# %%
path = Path.home() / 'projects' / 'middle_python' / '03' / 'sales.csv'

# %%
path
# Out:
# WindowsPath('C:/Users/sozyk/projects/middle_python/03/sales.csv')

# %% [markdown]
# ## Операции с файлами

# %% [markdown]
# Переименование файла

# %%
path = Path('sales.csv')

# %%
new_path = path.with_stem('renamed_sales')

# %%
path = path.replace(new_path)

# %%
new_extension = path.with_suffix('.txt')

# %%
path = path.replace(new_extension)

# %% [markdown]
# Копирование файла

# %%
source = Path("sales.csv")
destination = source.with_stem("sales_copy")
destination.write_text(source.read_text())
# Out:
# 391

# %% [markdown]
# Чтение файла

# %%
source = Path("sales.csv")
data = source.read_text()

# %%
data
# Out:
# 'id,date,store_nbr,family,sales,onpromotion\n298919,2013-06-17,46,BREAD/BAKERY,566.253,0\n298920,2013-06-17,46,CELEBRATION,0.0,0\n298921,2013-06-17,46,CLEANING,1707.0,0\n298922,2013-06-17,46,DAIRY,711.0,0\n298923,2013-06-17,46,DELI,709.268,0\n298924,2013-06-17,46,EGGS,203.0,0\n298925,2013-06-17,46,FROZEN FOODS,249.0,0\n298926,2013-06-17,46,GROCERY I,5715.0,0\n298927,2013-06-17,46,GROCERY II,42.0,0\n'

# %% [markdown]
# Запись в файл

# %%
source = Path("write_sales.csv")
data = source.write_text(data)

# %% [markdown]
# Удаление файла

# %%
path = Path("write_sales.csv")
path.unlink()

# %% [markdown]
# Создание пустого файла

# %%
path = Path("empty.txt")
path.touch()

# %% [markdown]
# ## Операции с каталогами

# %% [markdown]
# Получаем список файлов в каталоге

# %%
entries = Path.home() / 'projects' / 'middle_python' / '03'
for entry in entries.iterdir():
    print(entry.name)
# Out:
# 03_exceptions.ipynb
# 03_files_open.ipynb
# 03_file_read_write.ipynb
# 03_os.ipynb
# 03_pathlib.ipynb
# 03_test_no_file_close.py
# 03_zip.ipynb
# empty.txt
# name
# names.zip
# notebooks.zip
# renamed_sales.txt
# sales.csv
# sales_copy.csv

# %% [markdown]
# Определяем тип файла в каталоге

# %%
entries = Path.home() / 'projects' / 'middle_python'
for entry in entries.iterdir():
    if entry.is_file():
        print(f"Файл {entry.name}")
    elif entry.is_dir():
        print(f"Каталог {entry.name}")
# Out:
# Каталог .git
# Файл .gitignore
# Каталог .venv
# Каталог 01
# Каталог 02
# Каталог 03
# Каталог 04
# Файл LICENSE
# Файл README.md
# Файл test.txt

# %% [markdown]
# Ищем файлы, соответвующие шаблону

# %%
entries = Path.home() / 'projects' / 'middle_python' / '01'

# %%
for file in entries.glob('*.ipynb'):
    print(file.name)
# Out:
# 01_data_structures.ipynb
# 01_pandas.ipynb
# 01_tables.ipynb

# %% [markdown]
# Рекурсивный поиск файлов в каталогах

# %%
entries = Path.home() / 'projects' / 'middle_python'

# %%
for file in entries.glob('**/*.ipynb'):
    print(file.name)
# Out:
# 01_data_structures.ipynb
# 01_pandas.ipynb
# 01_tables.ipynb
# 02_collections.ipynb
# 02_collections_abc.ipynb
# 02_generators.ipynb
# 02_word_count.ipynb
# 03_exceptions.ipynb
# 03_files_open.ipynb
# 03_file_read_write.ipynb
# 03_os.ipynb
# 03_pathlib.ipynb
# 03_zip.ipynb
# 04_csv.ipynb
# 04_json.ipynb
# 04_pandas.ipynb
# 04_pickle.ipynb

# %% [markdown]
# Создание каталога

# %%
dir = Path('new_dir')

# %%
dir.mkdir()

# %% [markdown]
# Удаление каталога

# %%
dir.rmdir()

# %% [markdown]
# ## Печатаем структуру каталогов

# %%
def tree(directory):
    print(f"+ {directory}")
    for path in sorted(directory.rglob("*")):
        depth = len(path.relative_to(directory).parts)
        spacer = "    " * depth
        print(f"{spacer}+ {path.name}")

# %%
tree(Path.home() / 'projects' / 'middle_python')
# Out:
# + C:\Users\sozyk\projects\middle_python
#     + .git
#         + COMMIT_EDITMSG
#         + config
#         + description
#         + FETCH_HEAD
#         + HEAD
#         + hooks
#             + applypatch-msg.sample
#             + commit-msg.sample
#             + fsmonitor-watchman.sample
#             + post-update.sample
#             + pre-applypatch.sample
#             + pre-commit.sample
#             + pre-merge-commit.sample
#             + pre-push.sample
#             + pre-rebase.sample
#             + pre-receive.sample
#             + prepare-commit-msg.sample
#             + push-to-checkout.sample
#             + update.sample
#         + index
#         + info
#             + exclude
#         + logs
#             + HEAD
#             + refs
#                 + heads
#                     + main
#                 + remotes
#                     + origin
#                         + HEAD
#                         + main
#         + objects
#             + 00
#                 + 85e909ac05528353ee1bf06833cabd27a40d5f
#                 + 8fd6547b90c7ad68cffd1176f8be5c24b5a115
#             + 03
#                 + d875118b0b502dae58260cefd0888c81d7a577
#             + 04
#                 + 7eb517367e2a1a34b6ba6ce599bc809780bd20
#             + 0a
#                 + 663e9e47cb3be9e3bb88da5d5d7c989f1ac2ac
#             + 0f
#                 + f5193edd5a33c9d13dd3209c030e36f533fc9e
#             + 11
#                 + 7861abe5b367223b8550cec169ad07e1c46ebd
#             + 14
#                 + 01439901c0ec50ebb4b7a9888cb2c2ebce10c2
#             + 18
#                 + e240991cd559ebb009e354c5fb5d5dca344e3f
#             + 1a
#                 + 145d7c7e9fe5e198ff1304d1dfc87a9eeb3c77
#             + 1d
#                 + 4c218d96ed18ab7e23c6247a5ae0a332f059e9
#             + 23
#                 + 990b16663637a0da4b811bad046f3852a5daf7
#             + 24
#                 + d450c437a68cc888b498814e5ea73d8c84f7e2
#             + 25
#                 + 8e723bad084ef3d464d839e4367aaf9234c08c
#             + 26
#                 + b94af5666eede5f9e3bc55c5a8a33e9c7b2585
#             + 27
#                 + 54099495d99eb0c97f4922d3fb537182bc82e2
#                 + c6e9ea96436fc0481060c2650084cb8422dac9
#             + 2c
#                 + 240431578056bb78e4e6d21ddceed9335c0f38
#             + 30
#                 + edd432a0f2263d91e67443a09424dd79afa1c7
#             + 31
#                 + 2e70871e9aa4e9b2696a656c9aad172036999c
#             + 33
#                 + 6827cf03cd9a91039b625d316db5b1280e9cc3
#                 + 72e15e1af7b3848ae5dc1f2c68c2315d9e82ff
#                 + dfa8e107669697f2c321cc66a0b975639b552d
#             + 37
#                 + 5d28c38bda8e62e0c2d1d6ca52d00502715d00
#             + 39
#                 + 78fda03dfe8fa80a02c5a92951f64c5478afd7
#             + 3a
#                 + 1bbb15cd64516ee55aac761e05d5b55f4ce308
#                 + fc6adf289144ecbc2514970fa5a6e761833b2f
#             + 3d
#                 + ee538e1a49af5ab1716353d0ae7ab5211f67f4
#             + 40
#                 + 9e5eac7b90f8a92e234dc362721c7c264e1d32
#             + 41
#                 + 4b03e011aac0402b477cf011eb67a836e05d65
#             + 42
#                 + e1c45b7acc632fc39386bb7a4fc6176efb33b0
#             + 4b
#                 + badec731ffca8a8e2161ebcad77247aa08d6c0
#             + 51
#                 + 989f525bb2615374245035be9e7b460d53710b
#             + 53
#                 + a409bdf215a9d56ac1a1ef1ec68f30f79d243b
#             + 54
#                 + ef67c27a4b4b1c6600375a1531f08c16c5db66
#             + 58
#                 + f68fdcac9f45bb5100f81f9cf3e5c0775a796b
#             + 5c
#                 + 91d24f28b7760026ace3a792cf73f36e587e40
#             + 5d
#                 + 0e9f5837ac10cdefe9faadf36077ab9b965339
#             + 63
#                 + 52da1244d9c7e994897bbfb4030de1f218ebd4
#                 + ea3b79b3886d6723e1d0077b5e7b8e5e0fda02
#             + 67
#                 + 1cd3f2872c976d6d944f81bec3d411f27b49f8
#             + 6c
#                 + 18abead372be2309ebae1fcd8be44d326c88f5
#             + 6e
#                 + b179b235a0c31c4cc0f88e357a72ce62099682
#             + 77
#                 + e340ddf473d8bab838ceed155d60398fd32fc6
#             + 79
#                 + 3f869049750afe518d38aff40dbd2f632c82e8
#             + 7c
#                 + ff756bc15c0e725bb7f80e6e5b403a19d78cfe
#             + 7d
#                 + 2ceb0c73cfde7155c5ee33ed50e51b3a570be8
#                 + eaf872c8de65a827a6a4c09660a14e726194f3
#             + 80
#                 + f1b7df8512bde220c0b2f03d73da84b045c69c
#             + 84
#                 + 2539329a302ca068a52fa2ae44c711c1e24428
#                 + f017aec2313fddf81df4dbce5cfb19dde277fd
#             + 8d
#                 + cebaa5021911af86e20cae58446a130d57e67a
#             + 93
#                 + f22eedc5eb2ec36a2cb7b5c914cc2bc46d27ee
#             + 94
#                 + 7f24e5aecf86b78ebdfbc2223dd5f344409935
#             + 96
#                 + 637056f0cfd0ef39998fa1d1cd7dfac3a72c56
#                 + 84d97ede4d49a7004e5fe76b85c343fcca6a3c
#             + a2
#                 + b478dfb994fde392473baa32f40e9e7035ff05
#             + a3
#                 + 5f8826266121359b48df4558203b4ec29b17c5
#             + a7
#                 + a16549aaa78dd516c5c193a350d890ee5d24a7
#             + ab
#                 + ed2130a42cff096183a945562393f719736fd6
#             + b9
#                 + f77fceaea43426a1baedce66a4412f571916e3
#             + ba
#                 + 346892ddffa9f9518327b70162bd5e03cb1c90
#             + bb
#                 + f5b31582153e8c9829922e0f32a7ac245fefa0
#             + bd
#                 + aa3b0e5d3160d608bfccff21d7a81e882e9a14
#             + bf
#                 + e6358b0ed485a4099268fc558871d7a01c87ae
#             + c1
#                 + b579de4cd2a8b4d319301227885d946941ecc5
#             + c2
#                 + a3595fe7a890ffd469161a29c84976dd5fd973
#             + c3
#                 + 9bb90ad178f1d102a3f3240b873ccad9b64ee6
#             + c4
#                 + 5e54f7e4afdb4b9968dbe5c81a2eaff0245b56
#             + cd
#                 + 10da9c0ac40f709405b2c58b30bd24c72adde9
#             + cf
#                 + 3ef26c83cda5016aa17a99638f52df0d845e08
#             + d1
#                 + 95a9c6da1a8650833dd22ccfdd24989bedff56
#             + d3
#                 + b86e8091d626432968568ec80d36736eb1aed8
#             + d5
#                 + 59a97a66248b1f60b56a7811dc128a703cf11d
#             + d9
#                 + 8fe3b3d33b71cf5323b0a2962a3faa476fda21
#             + dc
#                 + a09e04c2f53778ffa703a7c787d4add0f4a26e
#                 + afc824820305da3de07efb4348147806cf0b40
#             + de
#                 + 1d6fbd89dbcdda765ab538fa911ec85a20b53f
#             + e0
#                 + ee857e004da3d6752ac21b1f7665c87e6e5746
#             + e3
#                 + 9d61ddd943ecce3189a8304af05403a218f2e0
#             + e6
#                 + c83875da49e92a7eb72bcfd61abacfdc6075da
#             + eb
#                 + a1f45e54ddbca8147fa249f8ace3862596b546
#             + ec
#                 + 2a27351116d9955d8ed6fcc6349624cc66a020
#                 + 471ccd699fb1ccf19e677d5b0be2160394984c
#             + ed
#                 + 83565c33a3c9bde4b465d04cb5002849f559e1
#                 + b409e1f4717938aafdd9d1fd89c245d1551e1a
#             + f0
#                 + 0deaaebf0b9364dd8b4d7a210020a13f00bed1
#                 + bd95840efaf85ac030c82079ab1d3443783bda
#             + f5
#                 + 48ed440ac021e18cb6be3aef1526ff6c394cf5
#             + f8
#                 + 08aec6ec9967991d6c2554530b9c4cb49555ec
#             + f9
#                 + 47c61e67dfbd9b2bc51955d0e64f92bba9ef45
#             + fb
#                 + 02a76a43eacf3de611c9d3b4f0cf76dd63a9cb
#             + fc
#                 + 3b682758325051f06557a6c61e517132c8c07c
#             + info
#             + pack
#                 + pack-54a236a449f4fd74b4413ffacbc2bb7985908eaf.idx
#                 + pack-54a236a449f4fd74b4413ffacbc2bb7985908eaf.pack
#         + packed-refs
#         + refs
#             + heads
#                 + main
#             + remotes
#                 + origin
#                     + HEAD
#                     + main
#             + tags
#     + .gitignore
#     + .venv
#         + .gitignore
#         + Include
#         + Lib
#             + site-packages
#                 + __pycache__
#                     + decorator.cpython-311.pyc
#                     + docopt.cpython-311.pyc
#                     + ipykernel_launcher.cpython-311.pyc
#                     + jupyter.cpython-311.pyc
#                     + nest_asyncio.cpython-311.pyc
#                     + pickleshare.cpython-311.pyc
#                     + pythoncom.cpython-311.pyc
#                     + six.cpython-311.pyc
#                     + wget.cpython-311.pyc
#                 + _distutils_hack
#                     + __init__.py
#                     + __pycache__
#                         + __init__.cpython-311.pyc
#                         + override.cpython-311.pyc
#                     + override.py
#                 + adodbapi
#                     + __init__.py
#                     + __pycache__
#                         + __init__.cpython-311.pyc
#                         + ado_consts.cpython-311.pyc
#                         + adodbapi.cpython-311.pyc
#                         + apibase.cpython-311.pyc
#                         + is64bit.cpython-311.pyc
#                         + process_connect_string.cpython-311.pyc
#                         + remote.cpython-311.pyc
#                         + schema_table.cpython-311.pyc
#                         + setup.cpython-311.pyc
#                     + ado_consts.py
#                     + adodbapi.py
#                     + apibase.py
#                     + examples
#                         + __pycache__
#                             + db_print.cpython-311.pyc
#                             + db_table_names.cpython-311.pyc
#                             + xls_read.cpython-311.pyc
#                             + xls_write.cpython-311.pyc
#                         + db_print.py
#                         + db_table_names.py
#                         + xls_read.py
#                         + xls_write.py
#                     + is64bit.py
#                     + license.txt
#                     + process_connect_string.py
#                     + readme.txt
#                     + remote.py
#                     + schema_table.py
#                     + setup.py
#                     + test
#                         + __pycache__
#                             + adodbapitest.cpython-311.pyc
#                             + adodbapitestconfig.cpython-311.pyc
#                             + dbapi20.cpython-311.pyc
#                             + is64bit.cpython-311.pyc
#                             + setuptestframework.cpython-311.pyc
#                             + test_adodbapi_dbapi20.cpython-311.pyc
#                             + tryconnection.cpython-311.pyc
#                         + adodbapitest.py
#                         + adodbapitestconfig.py
#                         + dbapi20.py
#                         + is64bit.py
#                         + setuptestframework.py
#                         + test_adodbapi_dbapi20.py
#                         + tryconnection.py
#                 + asttokens
#                     + __init__.py
#                     + __pycache__
#                         + __init__.cpython-311.pyc
#                         + astroid_compat.cpython-311.pyc
#                         + asttokens.cpython-311.pyc
#                         + line_numbers.cpython-311.pyc
#                         + mark_tokens.cpython-311.pyc
#                         + util.cpython-311.pyc
#                         + version.cpython-311.pyc
#                     + astroid_compat.py
#                     + asttokens.py
#                     + line_numbers.py
#                     + mark_tokens.py
#                     + py.typed
#                     + util.py
#                     + version.py
#                 + asttokens-2.2.1.dist-info
#                     + INSTALLER
#                     + LICENSE
#                     + METADATA
#                     + RECORD
#                     + top_level.txt
#                     + WHEEL
#                 + backcall
#                     + __init__.py
#                     + __pycache__
#                         + __init__.cpython-311.pyc
#                         + _signatures.cpython-311.pyc
#                         + backcall.cpython-311.pyc
#                     + _signatures.py
#                     + backcall.py
#                 + backcall-0.2.0.dist-info
#                     + INSTALLER
#                     + LICENSE
#                     + METADATA
#                     + RECORD
#                     + WHEEL
#                 + click
#                     + __init__.py
#                     + __pycache__
#                         + __init__.cpython-311.pyc
#                         + _compat.cpython-311.pyc
#                         + _termui_impl.cpython-311.pyc
#                         + _textwrap.cpython-311.pyc
#                         + _winconsole.cpython-311.pyc
#                         + core.cpython-311.pyc
#                         + decorators.cpython-311.pyc
#                         + exceptions.cpython-311.pyc
#                         + formatting.cpython-311.pyc
#                         + globals.cpython-311.pyc
#                         + parser.cpython-311.pyc
#                         + shell_completion.cpython-311.pyc
#                         + termui.cpython-311.pyc
#                         + testing.cpython-311.pyc
#                         + types.cpython-311.pyc
#                         + utils.cpython-311.pyc
#                     + _compat.py
#                     + _termui_impl.py
#                     + _textwrap.py
#                     + _winconsole.py
#                     + core.py
#                     + decorators.py
#                     + exceptions.py
#                     + formatting.py
#                     + globals.py
#                     + parser.py
#                     + py.typed
#                     + shell_completion.py
#                     + termui.py
#                     + testing.py
#                     + types.py
#                     + utils.py
#                 + click-8.1.3.dist-info
#                     + INSTALLER
#                     + LICENSE.rst
#                     + METADATA
#                     + RECORD
#                     + top_level.txt
#                     + WHEEL
#                 + colorama
#                     + __init__.py
#                     + __pycache__
#                         + __init__.cpython-311.pyc
#                         + ansi.cpython-311.pyc
#                         + ansitowin32.cpython-311.pyc
#                         + initialise.cpython-311.pyc
#                         + win32.cpython-311.pyc
#                         + winterm.cpython-311.pyc
#                     + ansi.py
#                     + ansitowin32.py
#                     + initialise.py
#                     + tests
#                         + __init__.py
#                         + __pycache__
#                             + __init__.cpython-311.pyc
#                             + ansi_test.cpython-311.pyc
#                             + ansitowin32_test.cpython-311.pyc
#                             + initialise_test.cpython-311.pyc
#                             + isatty_test.cpython-311.pyc
#                             + utils.cpython-311.pyc
#                             + winterm_test.cpython-311.pyc
#                         + ansi_test.py
#                         + ansitowin32_test.py
#                         + initialise_test.py
#                         + isatty_test.py
#                         + utils.py
#                         + winterm_test.py
#                     + win32.py
#                     + winterm.py
#                 + colorama-0.4.6.dist-info
#                     + INSTALLER
#                     + licenses
#                         + LICENSE.txt
#                     + METADATA
#                     + RECORD
#                     + WHEEL
#                 + comm
#                     + __init__.py
#                     + __pycache__
#                         + __init__.cpython-311.pyc
#                         + base_comm.cpython-311.pyc
#                     + base_comm.py
#                 + comm-0.1.3.dist-info
#                     + INSTALLER
#                     + licenses
#                         + LICENSE
#                     + METADATA
#                     + RECORD
#                     + WHEEL
#                 + dateutil
#                     + __init__.py
#                     + __pycache__
#                         + __init__.cpython-311.pyc
#                         + _common.cpython-311.pyc
#                         + _version.cpython-311.pyc
#                         + easter.cpython-311.pyc
#                         + relativedelta.cpython-311.pyc
#                         + rrule.cpython-311.pyc
#                         + tzwin.cpython-311.pyc
#                         + utils.cpython-311.pyc
#                     + _common.py
#                     + _version.py
#                     + easter.py
#                     + parser
#                         + __init__.py
#                         + __pycache__
#                             + __init__.cpython-311.pyc
#                             + _parser.cpython-311.pyc
#                             + isoparser.cpython-311.pyc
#                         + _parser.py
#                         + isoparser.py
#                     + relativedelta.py
#                     + rrule.py
#                     + tz
#                         + __init__.py
#                         + __pycache__
#                             + __init__.cpython-311.pyc
#                             + _common.cpython-311.pyc
#                             + _factories.cpython-311.pyc
#                             + tz.cpython-311.pyc
#                             + win.cpython-311.pyc
#                         + _common.py
#                         + _factories.py
#                         + tz.py
#                         + win.py
#                     + tzwin.py
#                     + utils.py
#                     + zoneinfo
#                         + __init__.py
#                         + __pycache__
#                             + __init__.cpython-311.pyc
#                             + rebuild.cpython-311.pyc
#                         + dateutil-zoneinfo.tar.gz
#                         + rebuild.py
#                 + dawg_python
#                     + __init__.py
#                     + __pycache__
#                         + __init__.cpython-311.pyc
#                         + compat.cpython-311.pyc
#                         + dawgs.cpython-311.pyc
#                         + units.cpython-311.pyc
#                         + wrapper.cpython-311.pyc
#                     + compat.py
#                     + dawgs.py
#                     + units.py
#                     + wrapper.py
#                 + DAWG_Python-0.7.2.dist-info
#                     + DESCRIPTION.rst
#                     + INSTALLER
#                     + METADATA
#                     + metadata.json
#                     + RECORD
#                     + top_level.txt
#                     + WHEEL
#                 + debugpy
#                     + __init__.py
#                     + __main__.py
#                     + __pycache__
#                         + __init__.cpython-311.pyc
#                         + __main__.cpython-311.pyc
#                         + _version.cpython-311.pyc
#                         + public_api.cpython-311.pyc
#                     + _vendored
#                         + __init__.py
#                         + __pycache__
#                             + __init__.cpython-311.pyc
#                             + _pydevd_packaging.cpython-311.pyc
#                             + _util.cpython-311.pyc
#                             + force_pydevd.cpython-311.pyc
#                         + _pydevd_packaging.py
#                         + _util.py
#                         + force_pydevd.py
#                         + pydevd
#                             + __pycache__
#                                 + pydev_app_engine_debug_startup.cpython-311.pyc
#                                 + pydev_coverage.cpython-311.pyc
#                                 + pydev_pysrc.cpython-311.pyc
#                                 + pydev_run_in_console.cpython-311.pyc
#                                 + pydevconsole.cpython-311.pyc
#                                 + pydevd.cpython-311.pyc
#                                 + pydevd_file_utils.cpython-311.pyc
#                                 + pydevd_tracing.cpython-311.pyc
#                                 + setup_pydevd_cython.cpython-311.pyc
#                             + _pydev_bundle
#                                 + __init__.py
#                                 + __pycache__
#                                     + __init__.cpython-311.pyc
#                                     + _pydev_calltip_util.cpython-311.pyc
#                                     + _pydev_completer.cpython-311.pyc
#                                     + _pydev_execfile.cpython-311.pyc
#                                     + _pydev_filesystem_encoding.cpython-311.pyc
#                                     + _pydev_getopt.cpython-311.pyc
#                                     + _pydev_imports_tipper.cpython-311.pyc
#                                     + _pydev_jy_imports_tipper.cpython-311.pyc
#                                     + _pydev_log.cpython-311.pyc
#                                     + _pydev_saved_modules.cpython-311.pyc
#                                     + _pydev_sys_patch.cpython-311.pyc
#                                     + _pydev_tipper_common.cpython-311.pyc
#                                     + pydev_console_utils.cpython-311.pyc
#                                     + pydev_import_hook.cpython-311.pyc
#                                     + pydev_imports.cpython-311.pyc
#                                     + pydev_ipython_console.cpython-311.pyc
#                                     + pydev_ipython_console_011.cpython-311.pyc
#                                     + pydev_is_thread_alive.cpython-311.pyc
#                                     + pydev_localhost.cpython-311.pyc
#                                     + pydev_log.cpython-311.pyc
#                                     + pydev_monkey.cpython-311.pyc
#                                     + pydev_monkey_qt.cpython-311.pyc
#                                     + pydev_override.cpython-311.pyc
#                                     + pydev_umd.cpython-311.pyc
#                                     + pydev_versioncheck.cpython-311.pyc
#                                 + _pydev_calltip_util.py
#                                 + _pydev_completer.py
#                                 + _pydev_execfile.py
#                                 + _pydev_filesystem_encoding.py
#                                 + _pydev_getopt.py
#                                 + _pydev_imports_tipper.py
#                                 + _pydev_jy_imports_tipper.py
#                                 + _pydev_log.py
#                                 + _pydev_saved_modules.py
#                                 + _pydev_sys_patch.py
#                                 + _pydev_tipper_common.py
#                                 + fsnotify
#                                     + __init__.py
#                                     + __pycache__
#                                         + __init__.cpython-311.pyc
#                                 + pydev_console_utils.py
#                                 + pydev_import_hook.py
#                                 + pydev_imports.py
#                                 + pydev_ipython_console.py
#                                 + pydev_ipython_console_011.py
#                                 + pydev_is_thread_alive.py
#                                 + pydev_localhost.py
#                                 + pydev_log.py
#                                 + pydev_monkey.py
#                                 + pydev_monkey_qt.py
#                                 + pydev_override.py
#                                 + pydev_umd.py
#                                 + pydev_versioncheck.py
#                             + _pydev_runfiles
#                                 + __init__.py
#                                 + __pycache__
#                                     + __init__.cpython-311.pyc
#                                     + pydev_runfiles.cpython-311.pyc
#                                     + pydev_runfiles_coverage.cpython-311.pyc
#                                     + pydev_runfiles_nose.cpython-311.pyc
#                                     + pydev_runfiles_parallel.cpython-311.pyc
#                                     + pydev_runfiles_parallel_client.cpython-311.pyc
#                                     + pydev_runfiles_pytest2.cpython-311.pyc
#                                     + pydev_runfiles_unittest.cpython-311.pyc
#                                     + pydev_runfiles_xml_rpc.cpython-311.pyc
#                                 + pydev_runfiles.py
#                                 + pydev_runfiles_coverage.py
#                                 + pydev_runfiles_nose.py
#                                 + pydev_runfiles_parallel.py
#                                 + pydev_runfiles_parallel_client.py
#                                 + pydev_runfiles_pytest2.py
#                                 + pydev_runfiles_unittest.py
#                                 + pydev_runfiles_xml_rpc.py
#                             + _pydevd_bundle
#                                 + __init__.py
#                                 + __pycache__
#                                     + __init__.cpython-311.pyc
#                                     + pydevconsole_code.cpython-311.pyc
#                                     + pydevd_additional_thread_info.cpython-311.pyc
#                                     + pydevd_additional_thread_info_regular.cpython-311.pyc
#                                     + pydevd_api.cpython-311.pyc
#                                     + pydevd_breakpoints.cpython-311.pyc
#                                     + pydevd_bytecode_utils.cpython-311.pyc
#                                     + pydevd_code_to_source.cpython-311.pyc
#                                     + pydevd_collect_bytecode_info.cpython-311.pyc
#                                     + pydevd_comm.cpython-311.pyc
#                                     + pydevd_comm_constants.cpython-311.pyc
#                                     + pydevd_command_line_handling.cpython-311.pyc
#                                     + pydevd_console.cpython-311.pyc
#                                     + pydevd_constants.cpython-311.pyc
#                                     + pydevd_custom_frames.cpython-311.pyc
#                                     + pydevd_cython_wrapper.cpython-311.pyc
#                                     + pydevd_daemon_thread.cpython-311.pyc
#                                     + pydevd_defaults.cpython-311.pyc
#                                     + pydevd_dont_trace.cpython-311.pyc
#                                     + pydevd_dont_trace_files.cpython-311.pyc
#                                     + pydevd_exec2.cpython-311.pyc
#                                     + pydevd_extension_api.cpython-311.pyc
#                                     + pydevd_extension_utils.cpython-311.pyc
#                                     + pydevd_filtering.cpython-311.pyc
#                                     + pydevd_frame.cpython-311.pyc
#                                     + pydevd_frame_utils.cpython-311.pyc
#                                     + pydevd_gevent_integration.cpython-311.pyc
#                                     + pydevd_import_class.cpython-311.pyc
#                                     + pydevd_io.cpython-311.pyc
#                                     + pydevd_json_debug_options.cpython-311.pyc
#                                     + pydevd_net_command.cpython-311.pyc
#                                     + pydevd_net_command_factory_json.cpython-311.pyc
#                                     + pydevd_net_command_factory_xml.cpython-311.pyc
#                                     + pydevd_plugin_utils.cpython-311.pyc
#                                     + pydevd_process_net_command.cpython-311.pyc
#                                     + pydevd_process_net_command_json.cpython-311.pyc
#                                     + pydevd_referrers.cpython-311.pyc
#                                     + pydevd_reload.cpython-311.pyc
#                                     + pydevd_resolver.cpython-311.pyc
#                                     + pydevd_runpy.cpython-311.pyc
#                                     + pydevd_safe_repr.cpython-311.pyc
#                                     + pydevd_save_locals.cpython-311.pyc
#                                     + pydevd_signature.cpython-311.pyc
#                                     + pydevd_source_mapping.cpython-311.pyc
#                                     + pydevd_stackless.cpython-311.pyc
#                                     + pydevd_suspended_frames.cpython-311.pyc
#                                     + pydevd_thread_lifecycle.cpython-311.pyc
#                                     + pydevd_timeout.cpython-311.pyc
#                                     + pydevd_trace_api.cpython-311.pyc
#                                     + pydevd_trace_dispatch.cpython-311.pyc
#                                     + pydevd_trace_dispatch_regular.cpython-311.pyc
#                                     + pydevd_traceproperty.cpython-311.pyc
#                                     + pydevd_utils.cpython-311.pyc
#                                     + pydevd_vars.cpython-311.pyc
#                                     + pydevd_vm_type.cpython-311.pyc
#                                     + pydevd_xml.cpython-311.pyc
#                                 + _debug_adapter
#                                     + __init__.py
#                                     + __main__pydevd_gen_debug_adapter_protocol.py
#                                     + __pycache__
#                                         + __init__.cpython-311.pyc
#                                         + __main__pydevd_gen_debug_adapter_protocol.cpython-311.pyc
#                                         + pydevd_base_schema.cpython-311.pyc
#                                         + pydevd_schema.cpython-311.pyc
#                                         + pydevd_schema_log.cpython-311.pyc
#                                     + debugProtocol.json
#                                     + debugProtocolCustom.json
#                                     + pydevd_base_schema.py
#                                     + pydevd_schema.py
#                                     + pydevd_schema_log.py
#                                 + pydevconsole_code.py
#                                 + pydevd_additional_thread_info.py
#                                 + pydevd_additional_thread_info_regular.py
#                                 + pydevd_api.py
#                                 + pydevd_breakpoints.py
#                                 + pydevd_bytecode_utils.py
#                                 + pydevd_code_to_source.py
#                                 + pydevd_collect_bytecode_info.py
#                                 + pydevd_comm.py
#                                 + pydevd_comm_constants.py
#                                 + pydevd_command_line_handling.py
#                                 + pydevd_concurrency_analyser
#                                     + __init__.py
#                                     + __pycache__
#                                         + __init__.cpython-311.pyc
#                                         + pydevd_concurrency_logger.cpython-311.pyc
#                                         + pydevd_thread_wrappers.cpython-311.pyc
#                                     + pydevd_concurrency_logger.py
#                                     + pydevd_thread_wrappers.py
#                                 + pydevd_console.py
#                                 + pydevd_constants.py
#                                 + pydevd_custom_frames.py
#                                 + pydevd_cython.c
#                                 + pydevd_cython.cp39-win_amd64.pyd
#                                 + pydevd_cython.pxd
#                                 + pydevd_cython.pyx
#                                 + pydevd_cython_wrapper.py
#                                 + pydevd_daemon_thread.py
#                                 + pydevd_defaults.py
#                                 + pydevd_dont_trace.py
#                                 + pydevd_dont_trace_files.py
#                                 + pydevd_exec2.py
#                                 + pydevd_extension_api.py
#                                 + pydevd_extension_utils.py
#                                 + pydevd_filtering.py
#                                 + pydevd_frame.py
#                                 + pydevd_frame_utils.py
#                                 + pydevd_gevent_integration.py
#                                 + pydevd_import_class.py
#                                 + pydevd_io.py
#                                 + pydevd_json_debug_options.py
#                                 + pydevd_net_command.py
#                                 + pydevd_net_command_factory_json.py
#                                 + pydevd_net_command_factory_xml.py
#                                 + pydevd_plugin_utils.py
#                                 + pydevd_process_net_command.py
#                                 + pydevd_process_net_command_json.py
#                                 + pydevd_referrers.py
#                                 + pydevd_reload.py
#                                 + pydevd_resolver.py
#                                 + pydevd_runpy.py
#                                 + pydevd_safe_repr.py
#                                 + pydevd_save_locals.py
#                                 + pydevd_signature.py
#                                 + pydevd_source_mapping.py
#                                 + pydevd_stackless.py
#                                 + pydevd_suspended_frames.py
#                                 + pydevd_thread_lifecycle.py
#                                 + pydevd_timeout.py
#                                 + pydevd_trace_api.py
#                                 + pydevd_trace_dispatch.py
#                                 + pydevd_trace_dispatch_regular.py
#                                 + pydevd_traceproperty.py
#                                 + pydevd_utils.py
#                                 + pydevd_vars.py
#                                 + pydevd_vm_type.py
#                                 + pydevd_xml.py
#                             + _pydevd_frame_eval
#                                 + .gitignore
#                                 + __init__.py
#                                 + __pycache__
#                                     + __init__.cpython-311.pyc
#                                     + pydevd_frame_eval_cython_wrapper.cpython-311.pyc
#                                     + pydevd_frame_eval_main.cpython-311.pyc
#                                     + pydevd_frame_tracing.cpython-311.pyc
#                                     + pydevd_modify_bytecode.cpython-311.pyc
#                                 + pydevd_frame_eval_cython_wrapper.py
#                                 + pydevd_frame_eval_main.py
#                                 + pydevd_frame_evaluator.c
#                                 + pydevd_frame_evaluator.cp39-win_amd64.pyd
#                                 + pydevd_frame_evaluator.pxd
#                                 + pydevd_frame_evaluator.pyx
#                                 + pydevd_frame_evaluator.template.pyx
#                                 + pydevd_frame_tracing.py
#                                 + pydevd_modify_bytecode.py
#                                 + release_mem.h
#                                 + vendored
#                                     + __init__.py
#                                     + __pycache__
#                                         + __init__.cpython-311.pyc
#                                         + pydevd_fix_code.cpython-311.pyc
#                                     + bytecode
#                                         + __init__.py
#                                         + __pycache__
#                                             + __init__.cpython-311.pyc
#                                             + bytecode.cpython-311.pyc
#                                             + cfg.cpython-311.pyc
#                                             + concrete.cpython-311.pyc
#                                             + flags.cpython-311.pyc
#                                             + instr.cpython-311.pyc
#                                             + peephole_opt.cpython-311.pyc
#                                         + bytecode.py
#                                         + cfg.py
#                                         + concrete.py
#                                         + flags.py
#                                         + instr.py
#                                         + peephole_opt.py
#                                         + tests
#                                             + __init__.py
#                                             + __pycache__
#                                                 + __init__.cpython-311.pyc
#                                                 + test_bytecode.cpython-311.pyc
#                                                 + test_cfg.cpython-311.pyc
#                                                 + test_code.cpython-311.pyc
#                                                 + test_concrete.cpython-311.pyc
#                                                 + test_flags.cpython-311.pyc
#                                                 + test_instr.cpython-311.pyc
#                                                 + test_misc.cpython-311.pyc
#                                                 + test_peephole_opt.cpython-311.pyc
#                                                 + util_annotation.cpython-311.pyc
#                                             + test_bytecode.py
#                                             + test_cfg.py
#                                             + test_code.py
#                                             + test_concrete.py
#                                             + test_flags.py
#                                             + test_instr.py
#                                             + test_misc.py
#                                             + test_peephole_opt.py
#                                             + util_annotation.py
#                                     + bytecode-0.13.0.dev0.dist-info
#                                         + COPYING
#                                         + direct_url.json
#                                         + INSTALLER
#                                         + METADATA
#                                         + RECORD
#                                         + REQUESTED
#                                         + top_level.txt
#                                         + WHEEL
#                                     + pydevd_fix_code.py
#                                     + README.txt
#                             + pydev_app_engine_debug_startup.py
#                             + pydev_coverage.py
#                             + pydev_ipython
#                                 + __init__.py
#                                 + __pycache__
#                                     + __init__.cpython-311.pyc
#                                     + inputhook.cpython-311.pyc
#                                     + inputhookglut.cpython-311.pyc
#                                     + inputhookgtk.cpython-311.pyc
#                                     + inputhookgtk3.cpython-311.pyc
#                                     + inputhookpyglet.cpython-311.pyc
#                                     + inputhookqt4.cpython-311.pyc
#                                     + inputhookqt5.cpython-311.pyc
#                                     + inputhooktk.cpython-311.pyc
#                                     + inputhookwx.cpython-311.pyc
#                                     + matplotlibtools.cpython-311.pyc
#                                     + qt.cpython-311.pyc
#                                     + qt_for_kernel.cpython-311.pyc
#                                     + qt_loaders.cpython-311.pyc
#                                     + version.cpython-311.pyc
#                                 + inputhook.py
#                                 + inputhookglut.py
#                                 + inputhookgtk.py
#                                 + inputhookgtk3.py
#                                 + inputhookpyglet.py
#                                 + inputhookqt4.py
#                                 + inputhookqt5.py
#                                 + inputhooktk.py
#                                 + inputhookwx.py
#                                 + matplotlibtools.py
#                                 + qt.py
#                                 + qt_for_kernel.py
#                                 + qt_loaders.py
#                                 + README
#                                 + version.py
#                             + pydev_pysrc.py
#                             + pydev_run_in_console.py
#                             + pydev_sitecustomize
#                                 + __not_in_default_pythonpath.txt
#                                 + __pycache__
#                                     + sitecustomize.cpython-311.pyc
#                                 + sitecustomize.py
#                             + pydevconsole.py
#                             + pydevd.py
#                             + pydevd_attach_to_process
#                                 + __pycache__
#                                     + _always_live_program.cpython-311.pyc
#                                     + _check.cpython-311.pyc
#                                     + _test_attach_to_process.cpython-311.pyc
#                                     + _test_attach_to_process_linux.cpython-311.pyc
#                                     + add_code_to_python_process.cpython-311.pyc
#                                     + attach_pydevd.cpython-311.pyc
#                                     + attach_script.cpython-311.pyc
#                                 + _always_live_program.py
#                                 + _check.py
#                                 + _test_attach_to_process.py
#                                 + _test_attach_to_process_linux.py
#                                 + add_code_to_python_process.py
#                                 + attach_amd64.dll
#                                 + attach_amd64.pdb
#                                 + attach_linux_amd64.so
#                                 + attach_linux_x86.so
#                                 + attach_pydevd.py
#                                 + attach_script.py
#                                 + attach_x86.dll
#                                 + attach_x86.pdb
#                                 + attach_x86_64.dylib
#                                 + common
#                                     + py_custom_pyeval_settrace.hpp
#                                     + py_custom_pyeval_settrace_310.hpp
#                                     + py_custom_pyeval_settrace_311.hpp
#                                     + py_custom_pyeval_settrace_common.hpp
#                                     + py_settrace.hpp
#                                     + py_utils.hpp
#                                     + py_version.hpp
#                                     + python.h
#                                     + ref_utils.hpp
#                                 + inject_dll_amd64.exe
#                                 + inject_dll_amd64.pdb
#                                 + inject_dll_x86.exe
#                                 + inject_dll_x86.pdb
#                                 + linux_and_mac
#                                     + .gitignore
#                                     + __pycache__
#                                         + lldb_prepare.cpython-311.pyc
#                                     + attach.cpp
#                                     + compile_linux.sh
#                                     + compile_mac.sh
#                                     + compile_manylinux.cmd
#                                     + lldb_prepare.py
#                                 + README.txt
#                                 + run_code_on_dllmain_amd64.dll
#                                 + run_code_on_dllmain_amd64.pdb
#                                 + run_code_on_dllmain_x86.dll
#                                 + run_code_on_dllmain_x86.pdb
#                                 + winappdbg
#                                     + __init__.py
#                                     + __pycache__
#                                         + __init__.cpython-311.pyc
#                                         + breakpoint.cpython-311.pyc
#                                         + compat.cpython-311.pyc
#                                         + crash.cpython-311.pyc
#                                         + debug.cpython-311.pyc
#                                         + disasm.cpython-311.pyc
#                                         + event.cpython-311.pyc
#                                         + interactive.cpython-311.pyc
#                                         + module.cpython-311.pyc
#                                         + process.cpython-311.pyc
#                                         + registry.cpython-311.pyc
#                                         + search.cpython-311.pyc
#                                         + sql.cpython-311.pyc
#                                         + system.cpython-311.pyc
#                                         + textio.cpython-311.pyc
#                                         + thread.cpython-311.pyc
#                                         + util.cpython-311.pyc
#                                         + window.cpython-311.pyc
#                                     + breakpoint.py
#                                     + compat.py
#                                     + crash.py
#                                     + debug.py
#                                     + disasm.py
#                                     + event.py
#                                     + interactive.py
#                                     + module.py
#                                     + process.py
#                                     + registry.py
#                                     + search.py
#                                     + sql.py
#                                     + system.py
#                                     + textio.py
#                                     + thread.py
#                                     + util.py
#                                     + win32
#                                         + __init__.py
#                                         + __pycache__
#                                             + __init__.cpython-311.pyc
#                                             + advapi32.cpython-311.pyc
#                                             + context_amd64.cpython-311.pyc
#                                             + context_i386.cpython-311.pyc
#                                             + dbghelp.cpython-311.pyc
#                                             + defines.cpython-311.pyc
#                                             + gdi32.cpython-311.pyc
#                                             + kernel32.cpython-311.pyc
#                                             + ntdll.cpython-311.pyc
#                                             + peb_teb.cpython-311.pyc
#                                             + psapi.cpython-311.pyc
#                                             + shell32.cpython-311.pyc
#                                             + shlwapi.cpython-311.pyc
#                                             + user32.cpython-311.pyc
#                                             + version.cpython-311.pyc
#                                             + wtsapi32.cpython-311.pyc
#                                         + advapi32.py
#                                         + context_amd64.py
#                                         + context_i386.py
#                                         + dbghelp.py
#                                         + defines.py
#                                         + gdi32.py
#                                         + kernel32.py
#                                         + ntdll.py
#                                         + peb_teb.py
#                                         + psapi.py
#                                         + shell32.py
#                                         + shlwapi.py
# ...
#                                 + empty_volume_cache.py
#                                 + folder_view.py
#                                 + icon_handler.py
#                                 + shell_view.py
#                             + shellexecuteex.py
#                             + viewstate.py
#                             + walk_shell_folders.py
#                         + shell.pyd
#                         + shellcon.py
#                         + test
#                             + __pycache__
#                                 + testShellFolder.cpython-311.pyc
#                                 + testShellItem.cpython-311.pyc
#                                 + testSHFileOperation.cpython-311.pyc
#                             + testShellFolder.py
#                             + testShellItem.py
#                             + testSHFileOperation.py
#                     + taskscheduler
#                         + __init__.py
#                         + __pycache__
#                             + __init__.cpython-311.pyc
#                         + taskscheduler.pyd
#                         + test
#                             + __pycache__
#                                 + test_addtask.cpython-311.pyc
#                                 + test_addtask_1.cpython-311.pyc
#                                 + test_addtask_2.cpython-311.pyc
#                                 + test_localsystem.cpython-311.pyc
#                             + test_addtask.py
#                             + test_addtask_1.py
#                             + test_addtask_2.py
#                             + test_localsystem.py
#                 + zmq
#                     + __init__.pxd
#                     + __init__.py
#                     + __init__.pyi
#                     + __pycache__
#                         + __init__.cpython-311.pyc
#                         + _future.cpython-311.pyc
#                         + _typing.cpython-311.pyc
#                         + asyncio.cpython-311.pyc
#                         + constants.cpython-311.pyc
#                         + decorators.cpython-311.pyc
#                         + error.cpython-311.pyc
#                     + _future.py
#                     + _typing.py
#                     + asyncio.py
#                     + auth
#                         + __init__.py
#                         + __pycache__
#                             + __init__.cpython-311.pyc
#                             + asyncio.cpython-311.pyc
#                             + base.cpython-311.pyc
#                             + certs.cpython-311.pyc
#                             + ioloop.cpython-311.pyc
#                             + thread.cpython-311.pyc
#                         + asyncio.py
#                         + base.py
#                         + certs.py
#                         + ioloop.py
#                         + thread.py
#                     + backend
#                         + __init__.py
#                         + __init__.pyi
#                         + __pycache__
#                             + __init__.cpython-311.pyc
#                             + select.cpython-311.pyc
#                         + cffi
#                             + __init__.py
#                             + __pycache__
#                                 + __init__.cpython-311.pyc
#                                 + _poll.cpython-311.pyc
#                                 + context.cpython-311.pyc
#                                 + devices.cpython-311.pyc
#                                 + error.cpython-311.pyc
#                                 + message.cpython-311.pyc
#                                 + socket.cpython-311.pyc
#                                 + utils.cpython-311.pyc
#                             + _cdefs.h
#                             + _poll.py
#                             + context.py
#                             + devices.py
#                             + error.py
#                             + message.py
#                             + socket.py
#                             + utils.py
#                         + cython
#                             + __init__.pxd
#                             + __init__.py
#                             + __pycache__
#                                 + __init__.cpython-311.pyc
#                             + _device.cp311-win_amd64.pyd
#                             + _poll.cp311-win_amd64.pyd
#                             + _proxy_steerable.cp311-win_amd64.pyd
#                             + _version.cp311-win_amd64.pyd
#                             + checkrc.pxd
#                             + constant_enums.pxi
#                             + context.cp311-win_amd64.pyd
#                             + context.pxd
#                             + error.cp311-win_amd64.pyd
#                             + libzmq.pxd
#                             + message.cp311-win_amd64.pyd
#                             + message.pxd
#                             + socket.cp311-win_amd64.pyd
#                             + socket.pxd
#                             + utils.cp311-win_amd64.pyd
#                         + select.py
#                     + constants.py
#                     + decorators.py
#                     + devices
#                         + __init__.py
#                         + __pycache__
#                             + __init__.cpython-311.pyc
#                             + basedevice.cpython-311.pyc
#                             + monitoredqueue.cpython-311.pyc
#                             + monitoredqueuedevice.cpython-311.pyc
#                             + proxydevice.cpython-311.pyc
#                             + proxysteerabledevice.cpython-311.pyc
#                         + basedevice.py
#                         + monitoredqueue.cp311-win_amd64.pyd
#                         + monitoredqueue.pxd
#                         + monitoredqueue.py
#                         + monitoredqueuedevice.py
#                         + proxydevice.py
#                         + proxysteerabledevice.py
#                     + error.py
#                     + eventloop
#                         + __init__.py
#                         + __pycache__
#                             + __init__.cpython-311.pyc
#                             + _deprecated.cpython-311.pyc
#                             + future.cpython-311.pyc
#                             + ioloop.cpython-311.pyc
#                             + zmqstream.cpython-311.pyc
#                         + _deprecated.py
#                         + future.py
#                         + ioloop.py
#                         + zmqstream.py
#                     + green
#                         + __init__.py
#                         + __pycache__
#                             + __init__.cpython-311.pyc
#                             + core.cpython-311.pyc
#                             + device.cpython-311.pyc
#                             + poll.cpython-311.pyc
#                         + core.py
#                         + device.py
#                         + eventloop
#                             + __init__.py
#                             + __pycache__
#                                 + __init__.cpython-311.pyc
#                                 + ioloop.cpython-311.pyc
#                                 + zmqstream.cpython-311.pyc
#                             + ioloop.py
#                             + zmqstream.py
#                         + poll.py
#                     + log
#                         + __init__.py
#                         + __main__.py
#                         + __pycache__
#                             + __init__.cpython-311.pyc
#                             + __main__.cpython-311.pyc
#                             + handlers.cpython-311.pyc
#                         + handlers.py
#                     + py.typed
#                     + ssh
#                         + __init__.py
#                         + __pycache__
#                             + __init__.cpython-311.pyc
#                             + forward.cpython-311.pyc
#                             + tunnel.cpython-311.pyc
#                         + forward.py
#                         + tunnel.py
#                     + sugar
#                         + __init__.py
#                         + __init__.pyi
#                         + __pycache__
#                             + __init__.cpython-311.pyc
#                             + attrsettr.cpython-311.pyc
#                             + context.cpython-311.pyc
#                             + frame.cpython-311.pyc
#                             + poll.cpython-311.pyc
#                             + socket.cpython-311.pyc
#                             + stopwatch.cpython-311.pyc
#                             + tracker.cpython-311.pyc
#                             + version.cpython-311.pyc
#                         + attrsettr.py
#                         + context.py
#                         + frame.py
#                         + poll.py
#                         + socket.py
#                         + stopwatch.py
#                         + tracker.py
#                         + version.py
#                     + tests
#                         + __init__.py
#                         + __pycache__
#                             + __init__.cpython-311.pyc
#                             + conftest.cpython-311.pyc
#                             + test_asyncio.cpython-311.pyc
#                             + test_auth.cpython-311.pyc
#                             + test_cffi_backend.cpython-311.pyc
#                             + test_constants.cpython-311.pyc
#                             + test_context.cpython-311.pyc
#                             + test_cython.cpython-311.pyc
#                             + test_decorators.cpython-311.pyc
#                             + test_device.cpython-311.pyc
#                             + test_draft.cpython-311.pyc
#                             + test_error.cpython-311.pyc
#                             + test_etc.cpython-311.pyc
#                             + test_ext.cpython-311.pyc
#                             + test_future.cpython-311.pyc
#                             + test_imports.cpython-311.pyc
#                             + test_includes.cpython-311.pyc
#                             + test_ioloop.cpython-311.pyc
#                             + test_log.cpython-311.pyc
#                             + test_message.cpython-311.pyc
#                             + test_monitor.cpython-311.pyc
#                             + test_monqueue.cpython-311.pyc
#                             + test_multipart.cpython-311.pyc
#                             + test_mypy.cpython-311.pyc
#                             + test_pair.cpython-311.pyc
#                             + test_poll.cpython-311.pyc
#                             + test_proxy_steerable.cpython-311.pyc
#                             + test_pubsub.cpython-311.pyc
#                             + test_reqrep.cpython-311.pyc
#                             + test_retry_eintr.cpython-311.pyc
#                             + test_security.cpython-311.pyc
#                             + test_socket.cpython-311.pyc
#                             + test_ssh.cpython-311.pyc
#                             + test_version.cpython-311.pyc
#                             + test_win32_shim.cpython-311.pyc
#                             + test_z85.cpython-311.pyc
#                             + test_zmqstream.cpython-311.pyc
#                         + conftest.py
#                         + cython_ext.pyx
#                         + test_asyncio.py
#                         + test_auth.py
#                         + test_cffi_backend.py
#                         + test_constants.py
#                         + test_context.py
#                         + test_cython.py
#                         + test_decorators.py
#                         + test_device.py
#                         + test_draft.py
#                         + test_error.py
#                         + test_etc.py
#                         + test_ext.py
#                         + test_future.py
#                         + test_imports.py
#                         + test_includes.py
#                         + test_ioloop.py
#                         + test_log.py
#                         + test_message.py
#                         + test_monitor.py
#                         + test_monqueue.py
#                         + test_multipart.py
#                         + test_mypy.py
#                         + test_pair.py
#                         + test_poll.py
#                         + test_proxy_steerable.py
#                         + test_pubsub.py
#                         + test_reqrep.py
#                         + test_retry_eintr.py
#                         + test_security.py
#                         + test_socket.py
#                         + test_ssh.py
#                         + test_version.py
#                         + test_win32_shim.py
#                         + test_z85.py
#                         + test_zmqstream.py
#                     + utils
#                         + __init__.py
#                         + __pycache__
#                             + __init__.cpython-311.pyc
#                             + garbage.cpython-311.pyc
#                             + interop.cpython-311.pyc
#                             + jsonapi.cpython-311.pyc
#                             + monitor.cpython-311.pyc
#                             + strtypes.cpython-311.pyc
#                             + win32.cpython-311.pyc
#                             + z85.cpython-311.pyc
#                         + buffers.pxd
#                         + compiler.json
#                         + config.json
#                         + garbage.py
#                         + getpid_compat.h
#                         + interop.py
#                         + ipcmaxlen.h
#                         + jsonapi.py
#                         + monitor.py
#                         + mutex.h
#                         + pyversion_compat.h
#                         + strtypes.py
#                         + win32.py
#                         + z85.py
#                         + zmq_compat.h
#         + pyvenv.cfg
#         + Scripts
#             + __pycache__
#                 + pywin32_postinstall.cpython-311.pyc
#                 + pywin32_testall.cpython-311.pyc
#             + activate
#             + activate.bat
#             + Activate.ps1
#             + deactivate.bat
#             + f2py.exe
#             + ipython.exe
#             + ipython3.exe
#             + jupyter-kernel.exe
#             + jupyter-kernelspec.exe
#             + jupyter-migrate.exe
#             + jupyter-run.exe
#             + jupyter-troubleshoot.exe
#             + jupyter.exe
#             + nltk.exe
#             + pip.exe
#             + pip3.11.exe
#             + pip3.exe
#             + pygmentize.exe
#             + pymorphy.exe
#             + python.exe
#             + pythonw.exe
#             + pywin32_postinstall.py
#             + pywin32_testall.py
#             + tqdm.exe
#         + share
#             + jupyter
#                 + kernels
#                     + python3
#                         + kernel.json
#                         + logo-32x32.png
#                         + logo-64x64.png
#                         + logo-svg.svg
#             + man
#                 + man1
#                     + ipython.1
#     + 01
#         + 01_data_structures.ipynb
#         + 01_pandas.ipynb
#         + 01_tables.ipynb
#         + new_sales.csv
#         + sales.csv
#         + sales.xlsx
#         + sales_headers.csv
#     + 02
#         + 02_collections.ipynb
#         + 02_collections_abc.ipynb
#         + 02_generators.ipynb
#         + 02_word_count.ipynb
#         + banks (1).csv
#         + banks.csv
#         + requirements.txt
#         + sales.csv
#     + 03
#         + 03_exceptions.ipynb
#         + 03_file_read_write.ipynb
#         + 03_files_open.ipynb
#         + 03_os.ipynb
#         + 03_pathlib.ipynb
#         + 03_test_no_file_close.py
#         + 03_zip.ipynb
#         + empty.txt
#         + name
#             + names_f.json
#             + names_m.json
#         + names.zip
#         + notebooks.zip
#         + renamed_sales.txt
#         + sales.csv
#         + sales_copy.csv
#     + 04
#         + 04_csv.ipynb
#         + 04_json.ipynb
#         + 04_pandas.ipynb
#         + 04_pickle.ipynb
#         + names_f.json
#         + names_m.json
#         + names_m.pickle
#         + sales.csv
#     + LICENSE
#     + README.md
#     + test.txt
